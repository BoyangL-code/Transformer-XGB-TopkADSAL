# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import random

# 固定随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # for multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)  # 设置固定种子

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import optuna
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# ----------------- CONFIGURATION -----------------
n_folds    = 10
n_trials   = 30
data_dir   = "./k_folds_model/embeddings"
batch_size = 256
num_epochs = 200
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------- MODEL DEFINITION -----------------
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        layers = []
        prev_dim = input_dim
        act = {
            'relu':     nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh':     nn.Tanh()
        }[activation]
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act]
            prev_dim = h
        layers.append(nn.Linear(prev_dim, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = self.net(x).squeeze(-1)
        return F.softplus(x)  # 输出 > 0

# ----------------- OPTUNA OBJECTIVE -----------------
def objective(trial):
    hidden_sizes      = trial.suggest_categorical('hidden_layer_sizes',
                            [(50,), (100,), (150,), (100, 50), (150, 100, 50)])
    activation        = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh'])
    lr                = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    weight_decay      = trial.suggest_float('alpha', 1e-5, 1e-2, log=True)
    optimizer_choice  = trial.suggest_categorical('optimizer', ['sgd', 'adam'])

    fold_maes = []

    for fold in range(1, n_folds + 1):
        X_train = np.load(f"{data_dir}/train_fold_{fold}.npy")
        y_train = np.load(f"{data_dir}/train_labels_fold_{fold}.npy")
        X_val   = np.load(f"{data_dir}/val_fold_{fold}.npy")
        y_val   = np.load(f"{data_dir}/val_labels_fold_{fold}.npy")

        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val   = scaler.transform(X_val)

        train_ds = TensorDataset(torch.from_numpy(X_train).float(),
                                 torch.from_numpy(y_train).float())
        val_ds = TensorDataset(torch.from_numpy(X_val).float(),
                               torch.from_numpy(y_val).float())
        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        model = MLP(input_dim=X_train.shape[1],
                    hidden_sizes=hidden_sizes,
                    activation=activation).to(device)
        criterion = nn.MSELoss()
        optimizer = {
            'sgd': torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay),
            'adam': torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        }[optimizer_choice]

        try:
            for epoch in range(num_epochs):
                model.train()
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    preds = model(xb)
                    loss = criterion(preds, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            all_preds = []
            with torch.no_grad():
                for xb, _ in val_loader:
                    xb = xb.to(device)
                    batch_pred = model(xb).cpu().numpy()
                    all_preds.append(batch_pred)
            all_preds = np.concatenate(all_preds)

            mae = mean_absolute_error(y_val, all_preds)
            fold_maes.append(mae)

        except Exception:
            return np.inf

    return float(np.mean(fold_maes))

# ----------------- RUN OPTUNA -----------------
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)

    print("\n=== Best Hyperparameters ===")
    print(study.best_params)
    print(f"Best Mean MAE: {study.best_value:.4f}")
# Out:
# [I 2025-05-16 10:02:53,100] A new study created in memory with name: no-name-a4f3efd6-b6d7-4d33-89fc-19b0f4386127
# [I 2025-05-16 10:06:12,279] Trial 0 finished with value: 0.7499591112136841 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.0015930522616241021, 'alpha': 0.001331121608073689, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:09:32,262] Trial 1 finished with value: 0.7654539346694946 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0016738085788752138, 'alpha': 2.621087878265438e-05, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:12:40,347] Trial 2 finished with value: 0.986285388469696 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00013492834268013249, 'alpha': 0.007025166339242158, 'optimizer': 'sgd'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:16:02,846] Trial 3 finished with value: 0.7554429769515991 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00032927591344236165, 'alpha': 0.0009717775305059633, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:19:17,535] Trial 4 finished with value: 0.7511550188064575 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00015030900645056822, 'alpha': 3.872118032174584e-05, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:22:25,274] Trial 5 finished with value: 0.8470107316970825 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00014096175149815865, 'alpha': 0.009133995846860976, 'optimizer': 'sgd'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:25:10,928] Trial 6 finished with value: 0.7879904508590698 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.005323617594751502, 'alpha': 0.0007411299781083245, 'optimizer': 'sgd'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:28:10,836] Trial 7 finished with value: 0.8185723423957825 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0033233042062267943, 'alpha': 0.00048287152161792117, 'optimizer': 'sgd'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:30:59,618] Trial 8 finished with value: 1.6419576406478882 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.006533305220227739, 'alpha': 5.59598687800608e-05, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:33:56,141] Trial 9 finished with value: 0.7998506426811218 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.004048966222584676, 'alpha': 3.6283583803549155e-05, 'optimizer': 'sgd'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:36:55,473] Trial 10 finished with value: 0.762597382068634 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.000724359894840497, 'alpha': 0.0026794737093069317, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:39:41,911] Trial 11 finished with value: 0.7643861174583435 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.000811620219572807, 'alpha': 0.00016477670830228577, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:42:26,935] Trial 12 finished with value: 0.7629502415657043 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00037299981541424096, 'alpha': 0.00013351056289950166, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:45:22,640] Trial 13 finished with value: 0.7688734531402588 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.0015253421517969652, 'alpha': 1.1323186753878092e-05, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:48:08,120] Trial 14 finished with value: 0.7579896450042725 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0003178109896726474, 'alpha': 0.002028902591028453, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:50:53,896] Trial 15 finished with value: 0.7797473669052124 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.0022270414378132105, 'alpha': 0.00028510287304170145, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:53:40,978] Trial 16 finished with value: 0.7612236738204956 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0007236636803416156, 'alpha': 8.903539212753443e-05, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:56:26,434] Trial 17 finished with value: 0.7570680975914001 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.00010597509676610864, 'alpha': 1.221454305162071e-05, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 10:59:24,285] Trial 18 finished with value: 0.7613378167152405 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00047119321153421984, 'alpha': 0.0023436732632306206, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 11:02:09,894] Trial 19 finished with value: 0.7513254284858704 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'logistic', 'learning_rate': 0.00021316692688415478, 'alpha': 0.00036746258917798807, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 11:05:15,220] Trial 20 finished with value: 1.1707589626312256 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.00979479165154195, 'alpha': 0.0010859851080426849, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 11:08:00,710] Trial 21 finished with value: 0.752616822719574 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'logistic', 'learning_rate': 0.00020391470296242433, 'alpha': 0.00028567547291259064, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 11:10:47,093] Trial 22 finished with value: 0.7554541230201721 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'logistic', 'learning_rate': 0.00022002993248626526, 'alpha': 0.0005606569050686692, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 11:13:33,839] Trial 23 finished with value: 0.7801206707954407 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'logistic', 'learning_rate': 0.001271284963755549, 'alpha': 0.00020337590603296428, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 11:16:19,523] Trial 24 finished with value: 0.7538971900939941 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'logistic', 'learning_rate': 0.0002139457051567871, 'alpha': 0.004305809865296748, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 11:19:05,645] Trial 25 finished with value: 0.7578700184822083 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.0004991234041800156, 'alpha': 0.001501858092767782, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 11:21:50,900] Trial 26 finished with value: 0.7943296432495117 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0025381278252359467, 'alpha': 0.00010373492729618661, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 11:24:28,312] Trial 27 finished with value: 0.8060026168823242 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'learning_rate': 0.0009869626886799513, 'alpha': 0.0004883037179831524, 'optimizer': 'sgd'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 11:27:16,080] Trial 28 finished with value: 0.7575323581695557 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'learning_rate': 0.0001658105735005659, 'alpha': 6.843354821203866e-05, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# [I 2025-05-16 11:29:59,685] Trial 29 finished with value: 0.7504332661628723 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'logistic', 'learning_rate': 0.00010549744050522123, 'alpha': 2.2451587765658737e-05, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7499591112136841.
# === Best Hyperparameters ===
# {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.0015930522616241021, 'alpha': 0.001331121608073689, 'optimizer': 'adam'}
# Best Mean MAE: 0.7500

# %%
import os
import optuna
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    # 采样超参数
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        model = XGBRegressor(n_jobs=-1, verbosity=0, **params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 以 MAE 为优化目标


# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best XGBoost Hyperparameters via Optuna ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 16:57:08,331] A new study created in memory with name: no-name-eb0c0449-cb66-4cc1-8d7f-c9ddf966e518
# [I 2025-05-16 16:59:12,453] Trial 0 finished with value: 0.8348325490951538 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 8, 'subsample': 0.8795975452591109, 'colsample_bytree': 0.6624074561769746}. Best is trial 0 with value: 0.8348325490951538.
# [I 2025-05-16 17:01:17,701] Trial 1 finished with value: 0.789669930934906 and parameters: {'n_estimators': 200, 'learning_rate': 0.011900590783184251, 'max_depth': 9, 'subsample': 0.8803345035229626, 'colsample_bytree': 0.8832290311184181}. Best is trial 1 with value: 0.789669930934906.
# [I 2025-05-16 17:01:54,290] Trial 2 finished with value: 0.7862030267715454 and parameters: {'n_estimators': 100, 'learning_rate': 0.18276027831785724, 'max_depth': 8, 'subsample': 0.7637017332034828, 'colsample_bytree': 0.6727299868828402}. Best is trial 2 with value: 0.7862030267715454.
# [I 2025-05-16 17:02:48,891] Trial 3 finished with value: 0.7542317509651184 and parameters: {'n_estimators': 200, 'learning_rate': 0.024878734419814436, 'max_depth': 6, 'subsample': 0.8295835055926347, 'colsample_bytree': 0.7164916560792167}. Best is trial 3 with value: 0.7542317509651184.
# [I 2025-05-16 17:05:04,285] Trial 4 finished with value: 0.7504980564117432 and parameters: {'n_estimators': 700, 'learning_rate': 0.01518747922672247, 'max_depth': 5, 'subsample': 0.8099085529881075, 'colsample_bytree': 0.7824279936868144}. Best is trial 4 with value: 0.7504980564117432.
# [I 2025-05-16 17:08:00,042] Trial 5 finished with value: 0.7552698850631714 and parameters: {'n_estimators': 800, 'learning_rate': 0.018187859051288217, 'max_depth': 6, 'subsample': 0.8777243706586128, 'colsample_bytree': 0.6185801650879991}. Best is trial 4 with value: 0.7504980564117432.
# [I 2025-05-16 17:09:20,815] Trial 6 finished with value: 0.7511217594146729 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'subsample': 0.984665661176, 'colsample_bytree': 0.9862528132298237}. Best is trial 4 with value: 0.7504980564117432.
# [I 2025-05-16 17:10:59,634] Trial 7 finished with value: 0.7499980926513672 and parameters: {'n_estimators': 900, 'learning_rate': 0.0249064396938244, 'max_depth': 3, 'subsample': 0.905269907953647, 'colsample_bytree': 0.7760609974958406}. Best is trial 7 with value: 0.7499980926513672.
# [I 2025-05-16 17:11:23,424] Trial 8 finished with value: 0.752059817314148 and parameters: {'n_estimators': 200, 'learning_rate': 0.04407984038169244, 'max_depth': 3, 'subsample': 0.9727961206236346, 'colsample_bytree': 0.7035119926400067}. Best is trial 7 with value: 0.7499980926513672.
# [I 2025-05-16 17:13:56,520] Trial 9 finished with value: 0.7586777806282043 and parameters: {'n_estimators': 700, 'learning_rate': 0.02544166090938368, 'max_depth': 6, 'subsample': 0.8640130838029838, 'colsample_bytree': 0.6739417822102108}. Best is trial 7 with value: 0.7499980926513672.
# [I 2025-05-16 17:16:25,554] Trial 10 finished with value: 0.7676721811294556 and parameters: {'n_estimators': 1000, 'learning_rate': 0.08138762607805286, 'max_depth': 4, 'subsample': 0.7053885626844458, 'colsample_bytree': 0.8560354009870226}. Best is trial 7 with value: 0.7499980926513672.
# [I 2025-05-16 17:18:51,220] Trial 11 finished with value: 0.7553181648254395 and parameters: {'n_estimators': 1000, 'learning_rate': 0.042799942130332856, 'max_depth': 4, 'subsample': 0.8004385528669709, 'colsample_bytree': 0.784894991903791}. Best is trial 7 with value: 0.7499980926513672.
# [I 2025-05-16 17:21:30,366] Trial 12 finished with value: 0.7509133219718933 and parameters: {'n_estimators': 800, 'learning_rate': 0.010227614236539206, 'max_depth': 5, 'subsample': 0.9464056138332538, 'colsample_bytree': 0.7890856026631795}. Best is trial 7 with value: 0.7499980926513672.
# [I 2025-05-16 17:22:58,331] Trial 13 finished with value: 0.7506173253059387 and parameters: {'n_estimators': 600, 'learning_rate': 0.02848307169336731, 'max_depth': 4, 'subsample': 0.9242928572412504, 'colsample_bytree': 0.8583425762812965}. Best is trial 7 with value: 0.7499980926513672.
# [I 2025-05-16 17:25:44,522] Trial 14 finished with value: 0.7809038758277893 and parameters: {'n_estimators': 900, 'learning_rate': 0.07890559538527207, 'max_depth': 5, 'subsample': 0.7729629237947951, 'colsample_bytree': 0.7473945810686194}. Best is trial 7 with value: 0.7499980926513672.
# [I 2025-05-16 17:26:43,171] Trial 15 finished with value: 0.751479983329773 and parameters: {'n_estimators': 500, 'learning_rate': 0.015787665140089453, 'max_depth': 3, 'subsample': 0.8321584177967812, 'colsample_bytree': 0.9489186530579984}. Best is trial 7 with value: 0.7499980926513672.
# [I 2025-05-16 17:28:16,823] Trial 16 finished with value: 0.752308189868927 and parameters: {'n_estimators': 500, 'learning_rate': 0.033382725868896894, 'max_depth': 5, 'subsample': 0.92132169117233, 'colsample_bytree': 0.8036504131271301}. Best is trial 7 with value: 0.7499980926513672.
# [I 2025-05-16 17:32:46,341] Trial 17 finished with value: 0.8175495266914368 and parameters: {'n_estimators': 900, 'learning_rate': 0.07372719540400963, 'max_depth': 7, 'subsample': 0.7416438512657763, 'colsample_bytree': 0.8952393368504932}. Best is trial 7 with value: 0.7499980926513672.
# [I 2025-05-16 17:34:27,843] Trial 18 finished with value: 0.7493018507957458 and parameters: {'n_estimators': 700, 'learning_rate': 0.019676140155671606, 'max_depth': 4, 'subsample': 0.8154903709367158, 'colsample_bytree': 0.7451045414896146}. Best is trial 18 with value: 0.7493018507957458.
# [I 2025-05-16 17:35:24,236] Trial 19 finished with value: 0.7517582178115845 and parameters: {'n_estimators': 400, 'learning_rate': 0.058490500323116035, 'max_depth': 4, 'subsample': 0.9133056925949321, 'colsample_bytree': 0.7406086632532847}. Best is trial 18 with value: 0.7493018507957458.
# [I 2025-05-16 17:36:58,886] Trial 20 finished with value: 0.7496715188026428 and parameters: {'n_estimators': 900, 'learning_rate': 0.022412406410134717, 'max_depth': 3, 'subsample': 0.7930203791848457, 'colsample_bytree': 0.6018960478612356}. Best is trial 18 with value: 0.7493018507957458.
# [I 2025-05-16 17:38:34,380] Trial 21 finished with value: 0.7501720190048218 and parameters: {'n_estimators': 900, 'learning_rate': 0.021423421601430438, 'max_depth': 3, 'subsample': 0.787472189071791, 'colsample_bytree': 0.6164745821819186}. Best is trial 18 with value: 0.7493018507957458.
# [I 2025-05-16 17:40:00,529] Trial 22 finished with value: 0.7498742341995239 and parameters: {'n_estimators': 800, 'learning_rate': 0.0335775762380481, 'max_depth': 3, 'subsample': 0.8338104192670504, 'colsample_bytree': 0.823985542065423}. Best is trial 18 with value: 0.7493018507957458.
# [I 2025-05-16 17:41:56,281] Trial 23 finished with value: 0.7513976097106934 and parameters: {'n_estimators': 800, 'learning_rate': 0.036880511434681074, 'max_depth': 4, 'subsample': 0.8407650548293878, 'colsample_bytree': 0.8274082350018885}. Best is trial 18 with value: 0.7493018507957458.
# [I 2025-05-16 17:43:01,077] Trial 24 finished with value: 0.7520270943641663 and parameters: {'n_estimators': 600, 'learning_rate': 0.05847980366354211, 'max_depth': 3, 'subsample': 0.7433080168139599, 'colsample_bytree': 0.8304814855727455}. Best is trial 18 with value: 0.7493018507957458.
# [I 2025-05-16 17:44:58,412] Trial 25 finished with value: 0.7522865533828735 and parameters: {'n_estimators': 800, 'learning_rate': 0.03287951773330428, 'max_depth': 4, 'subsample': 0.8206812747194019, 'colsample_bytree': 0.935385382628012}. Best is trial 18 with value: 0.7493018507957458.
# [I 2025-05-16 17:46:45,948] Trial 26 finished with value: 0.750053882598877 and parameters: {'n_estimators': 1000, 'learning_rate': 0.019375117215917344, 'max_depth': 3, 'subsample': 0.854886696306997, 'colsample_bytree': 0.7404569976623662}. Best is trial 18 with value: 0.7493018507957458.
# [I 2025-05-16 17:48:29,186] Trial 27 finished with value: 0.750410258769989 and parameters: {'n_estimators': 700, 'learning_rate': 0.01352841458474658, 'max_depth': 4, 'subsample': 0.7893609039254725, 'colsample_bytree': 0.6274566883247982}. Best is trial 18 with value: 0.7493018507957458.
# [I 2025-05-16 17:50:28,501] Trial 28 finished with value: 0.7616556882858276 and parameters: {'n_estimators': 600, 'learning_rate': 0.053635116051713, 'max_depth': 5, 'subsample': 0.7096166113790614, 'colsample_bytree': 0.7028883303319344}. Best is trial 18 with value: 0.7493018507957458.
# [I 2025-05-16 17:54:38,680] Trial 29 finished with value: 0.8443267941474915 and parameters: {'n_estimators': 800, 'learning_rate': 0.13390499764355235, 'max_depth': 7, 'subsample': 0.7578904166635713, 'colsample_bytree': 0.6452606057786048}. Best is trial 18 with value: 0.7493018507957458.
# === Best XGBoost Hyperparameters via Optuna ===
# {'n_estimators': 700, 'learning_rate': 0.019676140155671606, 'max_depth': 4, 'subsample': 0.8154903709367158, 'colsample_bytree': 0.7451045414896146}
# 10-Fold Mean MAE = 0.7493

# %%
import os
import optuna
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'objective': 'poisson',         # ✅ 强制正输出
        'n_jobs': -1,
        'verbose': -1
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        # Poisson 回归要求标签必须大于 0
        if np.any(y_train <= 0) or np.any(y_val <= 0):
            return np.inf

        model = LGBMRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 使用 MAE 作为优化目标

# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 17:54:38,763] A new study created in memory with name: no-name-595e722f-c652-42de-87c1-e2d9ff804ad3
# [I 2025-05-16 17:55:06,478] Trial 0 finished with value: 0.7605151429844116 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 10, 'num_leaves': 68, 'feature_fraction': 0.6624074561769746, 'bagging_fraction': 0.662397808134481}. Best is trial 0 with value: 0.7605151429844116.
# [I 2025-05-16 17:55:19,488] Trial 1 finished with value: 0.7502205143876103 and parameters: {'n_estimators': 100, 'learning_rate': 0.13394334706750485, 'max_depth': 9, 'num_leaves': 77, 'feature_fraction': 0.608233797718321, 'bagging_fraction': 0.9879639408647978}. Best is trial 1 with value: 0.7502205143876103.
# [I 2025-05-16 17:55:57,005] Trial 2 finished with value: 0.7496581198731251 and parameters: {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}. Best is trial 2 with value: 0.7496581198731251.
# [I 2025-05-16 17:56:36,698] Trial 3 finished with value: 0.7474618674251741 and parameters: {'n_estimators': 500, 'learning_rate': 0.023927528765580644, 'max_depth': 9, 'num_leaves': 31, 'feature_fraction': 0.7168578594140873, 'bagging_fraction': 0.7465447373174767}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 17:56:56,492] Trial 4 finished with value: 0.7503253291854898 and parameters: {'n_estimators': 500, 'learning_rate': 0.10508421338691762, 'max_depth': 4, 'num_leaves': 61, 'feature_fraction': 0.836965827544817, 'bagging_fraction': 0.6185801650879991}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 17:57:29,211] Trial 5 finished with value: 0.752883333262315 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'num_leaves': 96, 'feature_fraction': 0.9862528132298237, 'bagging_fraction': 0.9233589392465844}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 17:58:15,055] Trial 6 finished with value: 0.7713594787628579 and parameters: {'n_estimators': 400, 'learning_rate': 0.013399060561509796, 'max_depth': 9, 'num_leaves': 55, 'feature_fraction': 0.6488152939379115, 'bagging_fraction': 0.798070764044508}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 17:58:23,160] Trial 7 finished with value: 0.7485496342183724 and parameters: {'n_estimators': 100, 'learning_rate': 0.15242391728466367, 'max_depth': 5, 'num_leaves': 73, 'feature_fraction': 0.7246844304357644, 'bagging_fraction': 0.8080272084711243}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:00:01,335] Trial 8 finished with value: 0.7516162293833595 and parameters: {'n_estimators': 600, 'learning_rate': 0.017398074711291726, 'max_depth': 12, 'num_leaves': 82, 'feature_fraction': 0.9757995766256756, 'bagging_fraction': 0.9579309401710595}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:00:16,997] Trial 9 finished with value: 0.749272771323272 and parameters: {'n_estimators': 600, 'learning_rate': 0.15826541904647565, 'max_depth': 3, 'num_leaves': 35, 'feature_fraction': 0.6180909155642152, 'bagging_fraction': 0.7301321323053057}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:01:08,787] Trial 10 finished with value: 0.7493315269032622 and parameters: {'n_estimators': 1000, 'learning_rate': 0.039952845566170805, 'max_depth': 7, 'num_leaves': 21, 'feature_fraction': 0.8391524267229545, 'bagging_fraction': 0.876098829427658}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:01:21,072] Trial 11 finished with value: 0.780340310832533 and parameters: {'n_estimators': 100, 'learning_rate': 0.04847558836325771, 'max_depth': 6, 'num_leaves': 48, 'feature_fraction': 0.7577990966793822, 'bagging_fraction': 0.758049633365906}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:01:46,009] Trial 12 finished with value: 0.7505810090540015 and parameters: {'n_estimators': 300, 'learning_rate': 0.03673757945485903, 'max_depth': 6, 'num_leaves': 92, 'feature_fraction': 0.7209700478807325, 'bagging_fraction': 0.8470009417245111}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:02:08,188] Trial 13 finished with value: 0.7479800648136524 and parameters: {'n_estimators': 200, 'learning_rate': 0.06950720316382057, 'max_depth': 11, 'num_leaves': 46, 'feature_fraction': 0.7874820875551369, 'bagging_fraction': 0.7097939893129924}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:03:08,309] Trial 14 finished with value: 0.7587808685873508 and parameters: {'n_estimators': 800, 'learning_rate': 0.08432378032752542, 'max_depth': 12, 'num_leaves': 38, 'feature_fraction': 0.8955427636018558, 'bagging_fraction': 0.7095228898517576}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:03:29,557] Trial 15 finished with value: 0.7482300264881254 and parameters: {'n_estimators': 300, 'learning_rate': 0.06325429046713156, 'max_depth': 10, 'num_leaves': 22, 'feature_fraction': 0.7988341574443409, 'bagging_fraction': 0.6638123593227387}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:04:06,596] Trial 16 finished with value: 0.754208414347286 and parameters: {'n_estimators': 300, 'learning_rate': 0.02481948350316006, 'max_depth': 11, 'num_leaves': 43, 'feature_fraction': 0.9110846414027765, 'bagging_fraction': 0.6977930958631572}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:04:26,382] Trial 17 finished with value: 0.7700170841862166 and parameters: {'n_estimators': 200, 'learning_rate': 0.02784918805157686, 'max_depth': 8, 'num_leaves': 29, 'feature_fraction': 0.7715464060903383, 'bagging_fraction': 0.6029770270352651}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:05:06,284] Trial 18 finished with value: 0.7524996581703404 and parameters: {'n_estimators': 500, 'learning_rate': 0.0681107800180524, 'max_depth': 11, 'num_leaves': 52, 'feature_fraction': 0.690680099992256, 'bagging_fraction': 0.7555132662671672}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:06:27,403] Trial 19 finished with value: 0.7541532441481053 and parameters: {'n_estimators': 700, 'learning_rate': 0.010470281149411372, 'max_depth': 9, 'num_leaves': 46, 'feature_fraction': 0.8517314664119261, 'bagging_fraction': 0.656364941844514}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:07:11,161] Trial 20 finished with value: 0.7490321938819721 and parameters: {'n_estimators': 400, 'learning_rate': 0.027820627318372933, 'max_depth': 8, 'num_leaves': 59, 'feature_fraction': 0.7747981352314053, 'bagging_fraction': 0.7653157848151108}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:07:32,511] Trial 21 finished with value: 0.7484743833136678 and parameters: {'n_estimators': 300, 'learning_rate': 0.05760862601497562, 'max_depth': 10, 'num_leaves': 21, 'feature_fraction': 0.8062467228928262, 'bagging_fraction': 0.6700340162317235}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:07:50,276] Trial 22 finished with value: 0.7475857846598443 and parameters: {'n_estimators': 200, 'learning_rate': 0.07392954065066311, 'max_depth': 10, 'num_leaves': 28, 'feature_fraction': 0.8119714416409022, 'bagging_fraction': 0.6979300771033013}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:08:08,816] Trial 23 finished with value: 0.7479720664088786 and parameters: {'n_estimators': 200, 'learning_rate': 0.09326872794587396, 'max_depth': 11, 'num_leaves': 30, 'feature_fraction': 0.9117712809246715, 'bagging_fraction': 0.7020140135282127}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:08:26,411] Trial 24 finished with value: 0.7481060783074204 and parameters: {'n_estimators': 200, 'learning_rate': 0.09904952521441042, 'max_depth': 10, 'num_leaves': 27, 'feature_fraction': 0.9207271886500367, 'bagging_fraction': 0.7299452213271538}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:08:44,467] Trial 25 finished with value: 0.7479141789359774 and parameters: {'n_estimators': 200, 'learning_rate': 0.1228061409843295, 'max_depth': 12, 'num_leaves': 29, 'feature_fraction': 0.9526989903685098, 'bagging_fraction': 0.7844508467353642}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:09:24,260] Trial 26 finished with value: 0.7590564705840185 and parameters: {'n_estimators': 500, 'learning_rate': 0.1176817074636501, 'max_depth': 12, 'num_leaves': 40, 'feature_fraction': 0.8738445964974808, 'bagging_fraction': 0.838817870015776}. Best is trial 3 with value: 0.7474618674251741.
# [I 2025-05-16 18:09:55,700] Trial 27 finished with value: 0.747368763037101 and parameters: {'n_estimators': 400, 'learning_rate': 0.04844844622290299, 'max_depth': 8, 'num_leaves': 27, 'feature_fraction': 0.9494616849495391, 'bagging_fraction': 0.7879259337101082}. Best is trial 27 with value: 0.747368763037101.
# [I 2025-05-16 18:10:31,689] Trial 28 finished with value: 0.747733326732926 and parameters: {'n_estimators': 400, 'learning_rate': 0.03485319497508775, 'max_depth': 7, 'num_leaves': 35, 'feature_fraction': 0.9409452967417635, 'bagging_fraction': 0.8307990194879337}. Best is trial 27 with value: 0.747368763037101.
# [I 2025-05-16 18:11:01,600] Trial 29 finished with value: 0.7602593769939168 and parameters: {'n_estimators': 600, 'learning_rate': 0.19848978742652873, 'max_depth': 9, 'num_leaves': 25, 'feature_fraction': 0.67610339135715, 'bagging_fraction': 0.8672335505971374}. Best is trial 27 with value: 0.747368763037101.
# === Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===
# {'n_estimators': 400, 'learning_rate': 0.04844844622290299, 'max_depth': 8, 'num_leaves': 27, 'feature_fraction': 0.9494616849495391, 'bagging_fraction': 0.7879259337101082}
# 10-Fold Mean MAE = 0.7474
