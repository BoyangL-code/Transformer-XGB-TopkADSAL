# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import random
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error
from transformers import RobertaTokenizer, RobertaModel
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from torch.utils.data import DataLoader, Subset
from scipy.stats import pearsonr
from tqdm import tqdm
from sklearn.exceptions import FitFailedWarning
import warnings
from sklearn.model_selection import ParameterSampler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import RandomizedSearchCV
import matplotlib.pyplot as plt
from scipy.stats import norm
import matplotlib
from sklearn.base import clone

# %%
data=pd.read_excel("./fish_EC50_unique.xlsx")
data=data.dropna()
smiles_data = data['SMILES_Canonical_RDKit'].tolist()
mgperL = data['mgperL'].values
Duration_Value= data['Duration_Value'].values

# %%
mgperL=np.log1p(mgperL)

# %%
# 检查需要One-Hot编码的列，并进行编码（如果类别超过一种）
def encode_column(data, column_name):
    unique_values = data[column_name].unique()
    if len(unique_values) > 1:
        encoder = OneHotEncoder(sparse_output=False)
        return encoder.fit_transform(data[[column_name]])
    else:
        return None  # 只有一种类别时忽略

# 编码 effect、endpoint 和 species_group 列
effect_encoded = encode_column(data, 'effect')
endpoint_encoded = encode_column(data, 'endpoint')
species_encoded = encode_column(data, 'species_group')

# 将需要的列拼接成输入 X
extra_features = data['Duration_Value'].values.reshape(-1, 1)

# 拼接编码后的列（如果存在）
for encoded_feature in [effect_encoded, endpoint_encoded, species_encoded]:
    if encoded_feature is not None:
        extra_features = np.hstack((extra_features, encoded_feature))

# %%
extra_features.shape
# Out:
# (9111, 1)

# %%
extra_dim = extra_features.shape[1]

# %%
extra_dim = extra_features.shape[1]
data_extra_features = extra_features

# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from transformers import BertTokenizerFast, BertModel
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
import optuna

# -------------------------------
# 1. 数据增强与 Dataset 修改：支持额外特征 extra_features
# -------------------------------
def augment_smiles(smiles):
    """简单的数据增强方法：50% 的概率翻转 SMILES 字符串"""
    if random.random() > 0.5:
        return smiles[::-1]
    return smiles

class SMILES_Dataset(Dataset):
    def __init__(self, smiles, reg_labels, extra_features=None, use_augmentation=False):
        self.smiles = smiles
        self.reg_labels = reg_labels
        self.extra_features = extra_features  # 额外特征，要求为数组或列表（每个元素是一个数值向量）
        self.use_augmentation = use_augmentation

    def __len__(self):
        return len(self.smiles)

    def __getitem__(self, idx):
        s = self.smiles[idx]
        if self.use_augmentation:
            s = augment_smiles(s)
        reg_label = self.reg_labels[idx]
        tokens = tokenizer(s, padding='max_length', truncation=True, max_length=128, return_tensors="pt")
        # squeeze 扁平化 batch 维度（例如变为 [seq_len]）
        tokens = {key: val.squeeze(0) for key, val in tokens.items()}
        if self.extra_features is not None:
            extra_feat = self.extra_features[idx]
            extra_feat = torch.tensor(extra_feat, dtype=torch.float32)
            return tokens, torch.tensor(reg_label, dtype=torch.float32), extra_feat
        else:
            return tokens, torch.tensor(reg_label, dtype=torch.float32)

# %%
# -------------------------------
# 2. 加载本地 BERT 模型（BERT for SMILES）
# -------------------------------
# 请将 checkpoint 指向你的本地模型目录（此处示例使用 'unikei/bert-base-smiles'）
checkpoint = '../models/base_bert'
tokenizer = BertTokenizerFast.from_pretrained(checkpoint)
bert_model = BertModel.from_pretrained(checkpoint)

# -------------------------------
# 3. 模型定义：BERT_Regression
# -------------------------------
class Bert_Regression(nn.Module):
    def __init__(self, dropout_rate, fc1_size, fc2_size, fc3_size, extra_dim=0):
        """
        :param extra_dim: 额外特征维度，如果为 0 则不拼接额外特征
        """
        super(Bert_Regression, self).__init__()
        self.bert = bert_model  # 使用加载好的 BERT 模型
        hidden_size = self.bert.config.hidden_size  # 通常为768
        self.extra_dim = extra_dim
        # 拼接后的维度
        input_dim = hidden_size + extra_dim
        self.regressor = nn.Sequential(
            nn.Linear(input_dim, fc1_size),
            nn.ReLU(),
            nn.BatchNorm1d(fc1_size),
            nn.Dropout(dropout_rate),
            nn.Linear(fc1_size, fc2_size),
            nn.ReLU(),
            nn.BatchNorm1d(fc2_size),
            nn.Dropout(dropout_rate),
            nn.Linear(fc2_size, fc3_size),
            nn.ReLU(),
            nn.BatchNorm1d(fc3_size),
            nn.Dropout(dropout_rate),
            nn.Linear(fc3_size, 1),
            nn.Softplus()
        )
    
    def forward(self, tokens, extra_features=None):
        outputs = self.bert(**tokens)
        cls_embedding = outputs.last_hidden_state[:, 0, :]  # [CLS] token 嵌入，形状 [batch_size, 768]
        if self.extra_dim > 0 and extra_features is not None:
            # 拼接额外特征，要求 extra_features 的形状为 [batch_size, extra_dim]
            x = torch.cat([cls_embedding, extra_features], dim=1)
        else:
            x = cls_embedding
        reg_output = self.regressor(x)
        return reg_output

# %%
data_smiles = smiles_data
data_labels = mgperL

# 使用 SMILES 作为组依据，确保同一 SMILES 不出现在不同折中
groups = data_smiles

# 如果数据量较大，可根据需要提前封装为 Dataset
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from torch.cuda.amp import autocast, GradScaler

# %%
import os
import pickle
import numpy as np
import optuna
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.model_selection import GroupKFold
from torch.utils.data import DataLoader
from tqdm import tqdm
import torch
import torch.optim as optim
from torch.cuda.amp import autocast, GradScaler

# 假设以下变量已定义：
# data_smiles, data_labels, data_extra_features, groups, device, extra_dim
# Bert_Regression, SMILES_Dataset

os.makedirs("./optuna_model_set_1", exist_ok=True)
os.makedirs("./optuna_model_set_2", exist_ok=True)

model_sets = ["./optuna_model_set_1", "./optuna_model_set_2"]
set_errors = [float('inf'), float('inf')]
model_save_counter = 0  # 控制保存路径的交替轮换

# =============== 超参数搜索目标函数 ================
def objective(trial):
    global model_save_counter, model_sets, set_errors

    dropout_rate  = trial.suggest_float('dropout_rate', 0.1, 0.5)
    fc1_size      = trial.suggest_int('fc1_size', 256, 1024, step=64)
    fc2_size      = trial.suggest_int('fc2_size', 128, 512, step=32)
    fc3_size      = trial.suggest_int('fc3_size', 64, 256, step=32)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 5e-5, log=True)
    weight_decay  = trial.suggest_float('weight_decay', 0.0, 0.1)

    gkf = GroupKFold(n_splits=10)
    fold_errors = []
    model_set_dir = model_sets[model_save_counter % 2]

    for fold, (train_idx, val_idx) in enumerate(tqdm(gkf.split(data_smiles, data_labels, groups), total=10, desc=f"Trial {trial.number}")):
        train_smiles = [data_smiles[i] for i in train_idx]
        val_smiles = [data_smiles[i] for i in val_idx]
        train_labels = [data_labels[i] for i in train_idx]
        val_labels = [data_labels[i] for i in val_idx]
        train_extra = data_extra_features[train_idx]
        val_extra = data_extra_features[val_idx]

        train_dataset = SMILES_Dataset(train_smiles, train_labels, extra_features=train_extra)
        val_dataset = SMILES_Dataset(val_smiles, val_labels, extra_features=val_extra)

        train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True, drop_last=True, num_workers=8, pin_memory=True)
        val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False, num_workers=8, pin_memory=True)

        model = Bert_Regression(dropout_rate, fc1_size, fc2_size, fc3_size, extra_dim=extra_dim).to(device)
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        criterion = torch.nn.L1Loss()
        scaler = GradScaler()

        for epoch in range(30):
            model.train()
            for tokens, labels_tensor, extra_feats in train_loader:
                tokens = {k: v.to(device) for k, v in tokens.items()}
                extra_feats = extra_feats.to(device)
                labels_tensor = labels_tensor.to(device)

                optimizer.zero_grad()
                with autocast():
                    outputs = model(tokens, extra_feats)
                    loss = criterion(outputs.squeeze(), labels_tensor)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

        # 验证并保存模型
        model.eval()
        preds, targets = [], []
        with torch.no_grad():
            for tokens, labels_tensor, extra_feats in val_loader:
                tokens = {k: v.to(device) for k, v in tokens.items()}
                extra_feats = extra_feats.to(device)
                labels_tensor = labels_tensor.to(device)
                outputs = model(tokens, extra_feats)
                preds.extend(outputs.squeeze().cpu().numpy())
                targets.extend(labels_tensor.cpu().numpy())

        error = np.maximum(targets, preds) / np.minimum(targets, preds)
        median_error = np.median(error)
        fold_errors.append(median_error)

        torch.save(model.state_dict(), f"{model_set_dir}/bert_reg_fold_{fold+1}.pth")

    avg_median_error = np.mean(fold_errors)
    set_errors[model_save_counter % 2] = avg_median_error

    # 判断是否更新替换文件夹指针
    if set_errors[0] > set_errors[1]:
        model_save_counter = 0
    else:
        model_save_counter = 1

    return avg_median_error

# ================ 启动 Optuna 搜索 ===================
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=30)

# 输出结果
best_trial = study.best_trial
best_dir = model_sets[0] if set_errors[0] < set_errors[1] else model_sets[1]
print("Best hyperparameters:", best_trial.params)
print("Best model set directory:", best_dir)
print("Best cross-validated median error:", min(set_errors))
# Out:
# [I 2025-05-07 13:48:02,623] A new study created in memory with name: no-name-1357acfd-aece-4919-819b-f70d044d2042
# Trial 0: 100%|██████████| 10/10 [42:01<00:00, 252.12s/it]
# [I 2025-05-07 14:30:03,827] Trial 0 finished with value: 1.950448989868164 and parameters: {'dropout_rate': 0.33947475588972065, 'fc1_size': 256, 'fc2_size': 128, 'fc3_size': 192, 'learning_rate': 1.6902573405092324e-05, 'weight_decay': 0.032980163775605253}. Best is trial 0 with value: 1.950448989868164.
# Trial 1: 100%|██████████| 10/10 [42:06<00:00, 252.60s/it]
# [I 2025-05-07 15:12:09,884] Trial 1 finished with value: 1.6508785486221313 and parameters: {'dropout_rate': 0.2570663651652435, 'fc1_size': 320, 'fc2_size': 416, 'fc3_size': 256, 'learning_rate': 1.536903876697365e-05, 'weight_decay': 0.01299173692981045}. Best is trial 1 with value: 1.6508785486221313.
# Trial 2: 100%|██████████| 10/10 [42:06<00:00, 252.68s/it]
# [I 2025-05-07 15:54:16,710] Trial 2 finished with value: 1.8716239929199219 and parameters: {'dropout_rate': 0.13079640102701542, 'fc1_size': 640, 'fc2_size': 128, 'fc3_size': 96, 'learning_rate': 4.922436912686839e-05, 'weight_decay': 0.026256896270595534}. Best is trial 1 with value: 1.6508785486221313.
# Trial 3: 100%|██████████| 10/10 [42:06<00:00, 252.64s/it]
# [I 2025-05-07 16:36:23,080] Trial 3 finished with value: 1.6873691082000732 and parameters: {'dropout_rate': 0.2993455691572098, 'fc1_size': 704, 'fc2_size': 288, 'fc3_size': 64, 'learning_rate': 2.3457924326861256e-05, 'weight_decay': 0.0020389147714758304}. Best is trial 1 with value: 1.6508785486221313.
# Trial 4: 100%|██████████| 10/10 [42:07<00:00, 252.74s/it]
# [I 2025-05-07 17:18:30,464] Trial 4 finished with value: 1.8070132732391357 and parameters: {'dropout_rate': 0.23236323001194667, 'fc1_size': 896, 'fc2_size': 224, 'fc3_size': 160, 'learning_rate': 4.8337732064324594e-05, 'weight_decay': 0.05521503447705237}. Best is trial 1 with value: 1.6508785486221313.
# Trial 5: 100%|██████████| 10/10 [42:06<00:00, 252.67s/it]
# [I 2025-05-07 18:00:37,151] Trial 5 finished with value: 1.8350152969360352 and parameters: {'dropout_rate': 0.4269373738537071, 'fc1_size': 320, 'fc2_size': 448, 'fc3_size': 256, 'learning_rate': 1.1342619664138904e-05, 'weight_decay': 0.0864899508703011}. Best is trial 1 with value: 1.6508785486221313.
# Trial 6: 100%|██████████| 10/10 [42:04<00:00, 252.46s/it]
# [I 2025-05-07 18:42:41,789] Trial 6 finished with value: 1.6563756465911865 and parameters: {'dropout_rate': 0.3281855886083054, 'fc1_size': 1024, 'fc2_size': 224, 'fc3_size': 96, 'learning_rate': 4.901009631211632e-05, 'weight_decay': 0.015378801923842868}. Best is trial 1 with value: 1.6508785486221313.
# Trial 7: 100%|██████████| 10/10 [42:01<00:00, 252.13s/it]
# [I 2025-05-07 19:24:43,050] Trial 7 finished with value: 1.7953335046768188 and parameters: {'dropout_rate': 0.34435616435428495, 'fc1_size': 256, 'fc2_size': 128, 'fc3_size': 160, 'learning_rate': 4.317450784688815e-05, 'weight_decay': 0.0924817664310765}. Best is trial 1 with value: 1.6508785486221313.
# Trial 8: 100%|██████████| 10/10 [42:04<00:00, 252.44s/it]
# [I 2025-05-07 20:06:47,505] Trial 8 finished with value: 1.6584618091583252 and parameters: {'dropout_rate': 0.3737381685421196, 'fc1_size': 576, 'fc2_size': 160, 'fc3_size': 256, 'learning_rate': 3.99990498318416e-05, 'weight_decay': 0.05580859046619488}. Best is trial 1 with value: 1.6508785486221313.
# Trial 9: 100%|██████████| 10/10 [42:08<00:00, 252.81s/it]
# [I 2025-05-07 20:48:55,616] Trial 9 finished with value: 1.6611522436141968 and parameters: {'dropout_rate': 0.2267494410735223, 'fc1_size': 448, 'fc2_size': 320, 'fc3_size': 160, 'learning_rate': 3.151835819604978e-05, 'weight_decay': 0.08314032316206614}. Best is trial 1 with value: 1.6508785486221313.
# Trial 10: 100%|██████████| 10/10 [42:07<00:00, 252.74s/it]
# [I 2025-05-07 21:31:03,038] Trial 10 finished with value: 1.5878626108169556 and parameters: {'dropout_rate': 0.49152408806746894, 'fc1_size': 448, 'fc2_size': 480, 'fc3_size': 224, 'learning_rate': 1.063789342932267e-05, 'weight_decay': 0.0005546028100430131}. Best is trial 10 with value: 1.5878626108169556.
# Trial 11: 100%|██████████| 10/10 [42:05<00:00, 252.53s/it]
# [I 2025-05-07 22:13:08,320] Trial 11 finished with value: 1.6533256769180298 and parameters: {'dropout_rate': 0.49956732848715363, 'fc1_size': 448, 'fc2_size': 480, 'fc3_size': 224, 'learning_rate': 1.0414315691355345e-05, 'weight_decay': 0.0014061151994227599}. Best is trial 10 with value: 1.5878626108169556.
# Trial 12: 100%|██████████| 10/10 [42:07<00:00, 252.74s/it]
# [I 2025-05-07 22:55:15,718] Trial 12 finished with value: 1.5292736291885376 and parameters: {'dropout_rate': 0.23118717445621023, 'fc1_size': 448, 'fc2_size': 416, 'fc3_size': 224, 'learning_rate': 1.4811759244995504e-05, 'weight_decay': 0.03497456240656106}. Best is trial 12 with value: 1.5292736291885376.
# Trial 13: 100%|██████████| 10/10 [42:06<00:00, 252.61s/it]
# [I 2025-05-07 23:37:21,865] Trial 13 finished with value: 1.5214357376098633 and parameters: {'dropout_rate': 0.14621360270959488, 'fc1_size': 512, 'fc2_size': 384, 'fc3_size': 192, 'learning_rate': 1.373088373614655e-05, 'weight_decay': 0.038963703970637}. Best is trial 13 with value: 1.5214357376098633.
# Trial 14:   0%|          | 0/10 [00:00<?, ?it/s]

# %%
#optuna_model_set_1

# %%
import os
import pickle
import numpy as np
import optuna
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.model_selection import GroupKFold
from torch.utils.data import DataLoader
from tqdm import tqdm
import torch
import torch.optim as optim
from torch.cuda.amp import autocast, GradScaler

# 假设以下变量已定义：
# data_smiles, data_labels, data_extra_features, groups, device, extra_dim
# Bert_Regression, SMILES_Dataset

os.makedirs("./optuna_model_set_1", exist_ok=True)
os.makedirs("./optuna_model_set_2", exist_ok=True)

model_sets = ["./optuna_model_set_1", "./optuna_model_set_2"]
set_errors = [float('inf'), float('inf')]
model_save_counter = 0  # 控制保存路径的交替轮换

# =============== 超参数搜索目标函数 ================
def objective(trial):
    global model_save_counter, model_sets, set_errors

    dropout_rate  = trial.suggest_float('dropout_rate', 0.1, 0.5)
    fc1_size      = trial.suggest_int('fc1_size', 256, 1024, step=64)
    fc2_size      = trial.suggest_int('fc2_size', 128, 512, step=32)
    fc3_size      = trial.suggest_int('fc3_size', 64, 256, step=32)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 5e-5, log=True)
    weight_decay  = trial.suggest_float('weight_decay', 0.0, 0.1)

    gkf = GroupKFold(n_splits=10)
    fold_errors = []
    model_set_dir = model_sets[model_save_counter % 2]

    for fold, (train_idx, val_idx) in enumerate(tqdm(gkf.split(data_smiles, data_labels, groups), total=10, desc=f"Trial {trial.number}")):
        train_smiles = [data_smiles[i] for i in train_idx]
        val_smiles = [data_smiles[i] for i in val_idx]
        train_labels = [data_labels[i] for i in train_idx]
        val_labels = [data_labels[i] for i in val_idx]
        train_extra = data_extra_features[train_idx]
        val_extra = data_extra_features[val_idx]

        train_dataset = SMILES_Dataset(train_smiles, train_labels, extra_features=train_extra)
        val_dataset = SMILES_Dataset(val_smiles, val_labels, extra_features=val_extra)

        train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True, drop_last=True, num_workers=8, pin_memory=True)
        val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False, num_workers=8, pin_memory=True)

        model = Bert_Regression(dropout_rate, fc1_size, fc2_size, fc3_size, extra_dim=extra_dim).to(device)
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        criterion = torch.nn.L1Loss()
        scaler = GradScaler()

        for epoch in range(30):
            model.train()
            for tokens, labels_tensor, extra_feats in train_loader:
                tokens = {k: v.to(device) for k, v in tokens.items()}
                extra_feats = extra_feats.to(device)
                labels_tensor = labels_tensor.to(device)

                optimizer.zero_grad()
                with autocast():
                    outputs = model(tokens, extra_feats)
                    loss = criterion(outputs.squeeze(), labels_tensor)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

        # 验证并保存模型
        model.eval()
        preds, targets = [], []
        with torch.no_grad():
            for tokens, labels_tensor, extra_feats in val_loader:
                tokens = {k: v.to(device) for k, v in tokens.items()}
                extra_feats = extra_feats.to(device)
                labels_tensor = labels_tensor.to(device)
                outputs = model(tokens, extra_feats)
                preds.extend(outputs.squeeze().cpu().numpy())
                targets.extend(labels_tensor.cpu().numpy())

        error = np.maximum(targets, preds) / np.minimum(targets, preds)
        median_error = np.median(error)
        fold_errors.append(median_error)

        torch.save(model.state_dict(), f"{model_set_dir}/bert_reg_fold_{fold+1}.pth")

    avg_median_error = np.mean(fold_errors)
    set_errors[model_save_counter % 2] = avg_median_error

    # 判断是否更新替换文件夹指针
    if set_errors[0] > set_errors[1]:
        model_save_counter = 0
    else:
        model_save_counter = 1

    return avg_median_error

# ================ 启动 Optuna 搜索 ===================
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=30)

# 输出结果
best_trial = study.best_trial
best_dir = model_sets[0] if set_errors[0] < set_errors[1] else model_sets[1]
print("Best hyperparameters:", best_trial.params)
print("Best model set directory:", best_dir)
print("Best cross-validated median error:", min(set_errors))
# Out:
# [I 2025-05-08 09:47:32,958] A new study created in memory with name: no-name-fba83d56-93f8-4bf0-9291-a3c38bf9c12d
# Trial 0: 100%|██████████| 10/10 [41:05<00:00, 246.54s/it]
# [I 2025-05-08 10:28:38,339] Trial 0 finished with value: 2.1323189735412598 and parameters: {'dropout_rate': 0.19976823113261763, 'fc1_size': 1024, 'fc2_size': 384, 'fc3_size': 64, 'learning_rate': 3.314804644491532e-05, 'weight_decay': 0.09491630443767286}. Best is trial 0 with value: 2.1323189735412598.
# Trial 1: 100%|██████████| 10/10 [41:08<00:00, 246.83s/it]
# [I 2025-05-08 11:09:46,662] Trial 1 finished with value: 1.7805532217025757 and parameters: {'dropout_rate': 0.3791627838493631, 'fc1_size': 896, 'fc2_size': 192, 'fc3_size': 224, 'learning_rate': 2.9083530440720318e-05, 'weight_decay': 0.01860995029119823}. Best is trial 1 with value: 1.7805532217025757.
# Trial 2:  30%|███       | 3/10 [12:20<28:48, 246.86s/it]

# %%
import os
import pickle
import numpy as np
import optuna
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.model_selection import GroupKFold
from torch.utils.data import DataLoader
from tqdm import tqdm
import torch
import torch.optim as optim
from torch.cuda.amp import autocast, GradScaler

# 假设以下变量已定义：
# data_smiles, data_labels, data_extra_features, groups, device, extra_dim
# Bert_Regression, SMILES_Dataset

os.makedirs("./optuna_model_set_1", exist_ok=True)
os.makedirs("./optuna_model_set_2", exist_ok=True)

model_sets = ["./optuna_model_set_1", "./optuna_model_set_2"]
set_errors = [float('inf'), float('inf')]
model_save_counter = 0  # 控制保存路径的交替轮换

# =============== 超参数搜索目标函数 ================
def objective(trial):
    global model_save_counter, model_sets, set_errors

    dropout_rate  = trial.suggest_float('dropout_rate', 0.1, 0.5)
    fc1_size      = trial.suggest_int('fc1_size', 256, 1024, step=64)
    fc2_size      = trial.suggest_int('fc2_size', 128, 512, step=32)
    fc3_size      = trial.suggest_int('fc3_size', 64, 256, step=32)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 5e-5, log=True)
    weight_decay  = trial.suggest_float('weight_decay', 0.0, 0.1)

    gkf = GroupKFold(n_splits=10)
    fold_errors = []
    model_set_dir = model_sets[model_save_counter % 2]

    for fold, (train_idx, val_idx) in enumerate(tqdm(gkf.split(data_smiles, data_labels, groups), total=10, desc=f"Trial {trial.number}")):
        train_smiles = [data_smiles[i] for i in train_idx]
        val_smiles = [data_smiles[i] for i in val_idx]
        train_labels = [data_labels[i] for i in train_idx]
        val_labels = [data_labels[i] for i in val_idx]
        train_extra = data_extra_features[train_idx]
        val_extra = data_extra_features[val_idx]

        train_dataset = SMILES_Dataset(train_smiles, train_labels, extra_features=train_extra)
        val_dataset = SMILES_Dataset(val_smiles, val_labels, extra_features=val_extra)

        train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True, drop_last=True, num_workers=8, pin_memory=True)
        val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False, num_workers=8, pin_memory=True)

        model = Bert_Regression(dropout_rate, fc1_size, fc2_size, fc3_size, extra_dim=extra_dim).to(device)
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        criterion = torch.nn.L1Loss()
        scaler = GradScaler()

        for epoch in range(30):
            model.train()
            for tokens, labels_tensor, extra_feats in train_loader:
                tokens = {k: v.to(device) for k, v in tokens.items()}
                extra_feats = extra_feats.to(device)
                labels_tensor = labels_tensor.to(device)

                optimizer.zero_grad()
                with autocast():
                    outputs = model(tokens, extra_feats)
                    loss = criterion(outputs.squeeze(), labels_tensor)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

        # 验证并保存模型
        model.eval()
        preds, targets = [], []
        with torch.no_grad():
            for tokens, labels_tensor, extra_feats in val_loader:
                tokens = {k: v.to(device) for k, v in tokens.items()}
                extra_feats = extra_feats.to(device)
                labels_tensor = labels_tensor.to(device)
                outputs = model(tokens, extra_feats)
                preds.extend(outputs.squeeze().cpu().numpy())
                targets.extend(labels_tensor.cpu().numpy())

        error = np.maximum(targets, preds) / np.minimum(targets, preds)
        median_error = np.median(error)
        fold_errors.append(median_error)

        torch.save(model.state_dict(), f"{model_set_dir}/bert_reg_fold_{fold+1}.pth")

    avg_median_error = np.mean(fold_errors)
    set_errors[model_save_counter % 2] = avg_median_error

    # 判断是否更新替换文件夹指针
    if set_errors[0] > set_errors[1]:
        model_save_counter = 0
    else:
        model_save_counter = 1

    return avg_median_error

# ================ 启动 Optuna 搜索 ===================
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=30)

# 输出结果
best_trial = study.best_trial
best_dir = model_sets[0] if set_errors[0] < set_errors[1] else model_sets[1]
print("Best hyperparameters:", best_trial.params)
print("Best model set directory:", best_dir)
print("Best cross-validated median error:", min(set_errors))
# Out:
# [I 2025-05-08 11:27:07,499] A new study created in memory with name: no-name-6633b466-9a30-4a89-a4f2-d9f5ad9d78ae
# Trial 0: 100%|██████████| 10/10 [41:43<00:00, 250.35s/it]
# [I 2025-05-08 12:08:51,007] Trial 0 finished with value: 1.9519882202148438 and parameters: {'dropout_rate': 0.22479995547548098, 'fc1_size': 896, 'fc2_size': 160, 'fc3_size': 224, 'learning_rate': 1.891086534042211e-05, 'weight_decay': 0.09908446279914984}. Best is trial 0 with value: 1.9519882202148438.
# Trial 1: 100%|██████████| 10/10 [41:38<00:00, 249.82s/it]
# [I 2025-05-08 12:50:29,201] Trial 1 finished with value: 2.237727642059326 and parameters: {'dropout_rate': 0.32427230495254, 'fc1_size': 1024, 'fc2_size': 192, 'fc3_size': 64, 'learning_rate': 1.1853123106161729e-05, 'weight_decay': 0.08755613540995691}. Best is trial 0 with value: 1.9519882202148438.
# Trial 2: 100%|██████████| 10/10 [41:36<00:00, 249.66s/it]
# [I 2025-05-08 13:32:05,782] Trial 2 finished with value: 1.775197982788086 and parameters: {'dropout_rate': 0.485268379861338, 'fc1_size': 384, 'fc2_size': 224, 'fc3_size': 256, 'learning_rate': 3.427407805208093e-05, 'weight_decay': 0.005709927957246064}. Best is trial 2 with value: 1.775197982788086.
# Trial 3: 100%|██████████| 10/10 [41:40<00:00, 250.10s/it]
# [I 2025-05-08 14:13:46,744] Trial 3 finished with value: 2.24504017829895 and parameters: {'dropout_rate': 0.23692283477305223, 'fc1_size': 448, 'fc2_size': 320, 'fc3_size': 96, 'learning_rate': 1.510855354988559e-05, 'weight_decay': 0.09117589681940286}. Best is trial 2 with value: 1.775197982788086.
# Trial 4: 100%|██████████| 10/10 [41:44<00:00, 250.44s/it]
# [I 2025-05-08 14:55:31,185] Trial 4 finished with value: 1.939072847366333 and parameters: {'dropout_rate': 0.14987306875152429, 'fc1_size': 448, 'fc2_size': 224, 'fc3_size': 256, 'learning_rate': 3.7830903272590854e-05, 'weight_decay': 0.04478464002725281}. Best is trial 2 with value: 1.775197982788086.
# Trial 5: 100%|██████████| 10/10 [41:41<00:00, 250.15s/it]
# [I 2025-05-08 15:37:12,647] Trial 5 finished with value: 1.8706724643707275 and parameters: {'dropout_rate': 0.4124261470531504, 'fc1_size': 768, 'fc2_size': 352, 'fc3_size': 64, 'learning_rate': 4.56606710826036e-05, 'weight_decay': 0.018128735794846775}. Best is trial 2 with value: 1.775197982788086.
# Trial 6: 100%|██████████| 10/10 [41:39<00:00, 249.93s/it]
# [I 2025-05-08 16:18:51,955] Trial 6 finished with value: 1.7170168161392212 and parameters: {'dropout_rate': 0.22335640242935684, 'fc1_size': 640, 'fc2_size': 416, 'fc3_size': 96, 'learning_rate': 2.4425247592544954e-05, 'weight_decay': 0.05955265187735223}. Best is trial 6 with value: 1.7170168161392212.
# Trial 7: 100%|██████████| 10/10 [41:38<00:00, 249.89s/it]
# [I 2025-05-08 17:00:30,853] Trial 7 finished with value: 1.8122457265853882 and parameters: {'dropout_rate': 0.2049046675394088, 'fc1_size': 448, 'fc2_size': 320, 'fc3_size': 64, 'learning_rate': 2.169498601579705e-05, 'weight_decay': 0.019997720376826258}. Best is trial 6 with value: 1.7170168161392212.
# Trial 8: 100%|██████████| 10/10 [41:37<00:00, 249.80s/it]
# [I 2025-05-08 17:42:08,859] Trial 8 finished with value: 1.7883596420288086 and parameters: {'dropout_rate': 0.16281188897018445, 'fc1_size': 640, 'fc2_size': 128, 'fc3_size': 256, 'learning_rate': 3.048351164438048e-05, 'weight_decay': 0.05655670731764402}. Best is trial 6 with value: 1.7170168161392212.
# Trial 9: 100%|██████████| 10/10 [41:38<00:00, 249.87s/it]
# [I 2025-05-08 18:23:47,522] Trial 9 finished with value: 1.817470908164978 and parameters: {'dropout_rate': 0.3931833667375352, 'fc1_size': 768, 'fc2_size': 384, 'fc3_size': 96, 'learning_rate': 1.205677689178586e-05, 'weight_decay': 0.022889832371869645}. Best is trial 6 with value: 1.7170168161392212.
# Trial 10: 100%|██████████| 10/10 [41:37<00:00, 249.74s/it]
# [I 2025-05-08 19:05:24,910] Trial 10 finished with value: 1.6637451648712158 and parameters: {'dropout_rate': 0.29909099971016173, 'fc1_size': 640, 'fc2_size': 480, 'fc3_size': 160, 'learning_rate': 2.573304760618621e-05, 'weight_decay': 0.0651439462096866}. Best is trial 10 with value: 1.6637451648712158.
# Trial 11: 100%|██████████| 10/10 [41:35<00:00, 249.57s/it]
# [I 2025-05-08 19:47:00,633] Trial 11 finished with value: 1.6754363775253296 and parameters: {'dropout_rate': 0.301187900581163, 'fc1_size': 640, 'fc2_size': 512, 'fc3_size': 160, 'learning_rate': 2.6558901522642442e-05, 'weight_decay': 0.06850884960303939}. Best is trial 10 with value: 1.6637451648712158.
# Trial 12: 100%|██████████| 10/10 [41:37<00:00, 249.76s/it]
# [I 2025-05-08 20:28:38,242] Trial 12 finished with value: 1.742150902748108 and parameters: {'dropout_rate': 0.3094525757451019, 'fc1_size': 256, 'fc2_size': 512, 'fc3_size': 160, 'learning_rate': 2.6168076938042523e-05, 'weight_decay': 0.07095293459701396}. Best is trial 10 with value: 1.6637451648712158.
# Trial 13: 100%|██████████| 10/10 [41:41<00:00, 250.11s/it]
# [I 2025-05-08 21:10:19,352] Trial 13 finished with value: 1.704697847366333 and parameters: {'dropout_rate': 0.3567011728969459, 'fc1_size': 576, 'fc2_size': 512, 'fc3_size': 160, 'learning_rate': 1.791680862741614e-05, 'weight_decay': 0.07390854901492805}. Best is trial 10 with value: 1.6637451648712158.
# Trial 14: 100%|██████████| 10/10 [41:43<00:00, 250.32s/it]
# [I 2025-05-08 21:52:02,572] Trial 14 finished with value: 1.6532514095306396 and parameters: {'dropout_rate': 0.28711814441341604, 'fc1_size': 768, 'fc2_size': 448, 'fc3_size': 192, 'learning_rate': 2.880239028956914e-05, 'weight_decay': 0.038126483454396454}. Best is trial 14 with value: 1.6532514095306396.
# Trial 15:  30%|███       | 3/10 [12:38<29:29, 252.73s/it]
# [W 2025-05-08 22:04:40,797] Trial 15 failed with parameters: {'dropout_rate': 0.2621148377455905, 'fc1_size': 832, 'fc2_size': 448, 'fc3_size': 192, 'learning_rate': 4.0290244780977716e-05, 'weight_decay': 0.03917797765668908} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.10/site-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_136046/3777437258.py", line 70, in objective
#     scaler.step(optimizer)
#   File "/root/miniconda3/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py", line 416, in step
#     retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#   File "/root/miniconda3/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py", line 314, in _maybe_opt_step
#     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#   File "/root/miniconda3/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py", line 314, in <genexpr>
#     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
# KeyboardInterrupt
# [W 2025-05-08 22:04:40,800] Trial 15 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 104
#     102 # ================ 启动 Optuna 搜索 ===================
#     103 study = optuna.create_study(direction="minimize")
# --> 104 study.optimize(objective, n_trials=30)
#     106 # 输出结果
#     107 best_trial = study.best_trial
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/study/study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/study/_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/study/_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[12], line 70, in objective(trial)
#      68             loss = criterion(outputs.squeeze(), labels_tensor)
#      69         scaler.scale(loss).backward()
# ---> 70         scaler.step(optimizer)
#      71         scaler.update()
#      73 # 验证并保存模型
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py:416, in GradScaler.step(self, optimizer, *args, **kwargs)
#     410     self.unscale_(optimizer)
#     412 assert (
#     413     len(optimizer_state["found_inf_per_device"]) > 0
#     414 ), "No inf checks were recorded for this optimizer."
# --> 416 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     418 optimizer_state["stage"] = OptState.STEPPED
#     420 return retval
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py:314, in GradScaler._maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     312 def _maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs):
#     313     retval = None
# --> 314     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     315         retval = optimizer.step(*args, **kwargs)
#     316     return retval
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py:314, in <genexpr>(.0)
#     312 def _maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs):
#     313     retval = None
# --> 314     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     315         retval = optimizer.step(*args, **kwargs)
#     316     return retval
#
# KeyboardInterrupt:

# %%
14
