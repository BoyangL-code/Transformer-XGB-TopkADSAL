# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import torch
from sklearn.model_selection import StratifiedKFold
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.metrics import precision_recall_curve, auc
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import joblib
import optuna
from rdkit.Chem import Descriptors, AllChem
from tqdm import tqdm  # 导入tqdm
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GroupKFold

# %%
# 函数：将SMILES转换为分子描述符和指纹
def smiles_to_features(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None
    # 提取描述符
    descriptors = [
        Descriptors.MolWt(mol),  # 分子量
        Descriptors.MolLogP(mol),  # LogP
        Descriptors.NumHDonors(mol),  # 氢键供体数量
        Descriptors.NumHAcceptors(mol)  # 氢键受体数量
    ]
    # 生成Morgan指纹
    fingerprint = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=2048)
    fingerprint_array = np.zeros((2048,))
    Chem.DataStructs.ConvertToNumpyArray(fingerprint, fingerprint_array)
    # 合并描述符和指纹
    features = np.concatenate([descriptors, fingerprint_array])
    return features

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold
from tqdm import tqdm
import optuna
import numpy as np

def train_evaluate_regression_model_with_optuna(model_name, model_class, param_func, X, y, groups):
    def objective(trial):
        params = param_func(trial)
        model = model_class(**params)

        gkf = GroupKFold(n_splits=10)
        maes = []

        for train_idx, val_idx in tqdm(gkf.split(X, y, groups=groups), total=10, desc=f"Training {model_name}"):
            X_train, X_val = X[train_idx], X[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            model.fit(X_train, y_train)
            y_pred = model.predict(X_val)

            # ✅ 计算 MAE
            mae = mean_absolute_error(y_val, y_pred)
            maes.append(mae)

        return np.mean(maes)

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=30)

    print(f'Best parameters for {model_name}: {study.best_params}')
    print(f'Best mean MAE: {study.best_value:.4f}')

# %%
# 数据预处理
df = pd.read_excel('../fish_EC50_unique.xlsx')
labels = df['mgperL'].values
smiles_list = df['SMILES_Canonical_RDKit'].tolist()
endpoints_a = df['endpoint']
Duration_Values_a = df['Duration_Value'].values
effects_a = df['effect']

# %%
features = []
new_labels = []
new_smiles_list = []
endpoints = []
Duration_Values = []
effects =[]


for smiles, label,a,b,c in zip(smiles_list, labels,Duration_Values_a,effects_a,endpoints_a):
    feature = smiles_to_features(smiles)
    if feature is not None:
        features.append(feature)
        new_labels.append(label)
        new_smiles_list.append(smiles)
        Duration_Values.append(a)
        effects.append(b)
        endpoints.append(c)

X = np.array(features)
y = np.array(new_labels)
groups = new_smiles_list  # 可直接用于 GroupKFold

# %%
def encode_column(zz):
    zz_series = pd.Series(zz)  # 转换为 Series
    unique_values = zz_series.unique()
    if len(unique_values) > 1:
        encoder = OneHotEncoder(sparse_output=False)
        return encoder.fit_transform(zz_series.values.reshape(-1, 1))
    else:
        return None  # 只有一种类别时忽略

Duration_Values =pd.Series(Duration_Values)


# 编码 effect、endpoint 和 species_group 列
effect_encoded = encode_column(effects)
endpoint_encoded = encode_column(endpoints)
#species_encoded = encode_column(df, 'species_group')

# # 将需要的列拼接成输入 X
X = np.hstack((X, Duration_Values.values.reshape(-1, 1)))

# # 拼接编码后的列（如果存在）
for encoded_feature in [effect_encoded, endpoint_encoded]:
     if encoded_feature is not None:
         X = np.hstack((X, encoded_feature))



y=np.log1p(y)

# %%
def xgb_param_func(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 100, 600),
        'max_depth': trial.suggest_int('max_depth', 5, 20),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),   # L1 正则
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0)  # L2 正则
    }
from xgboost import XGBRegressor

train_evaluate_regression_model_with_optuna(
    "XGBoost",
    XGBRegressor,
    xgb_param_func,
    X, y, groups
)
# Out:
# [I 2025-05-12 05:14:13,193] A new study created in memory with name: no-name-b99887fc-5df7-42cd-8148-02fe9a19ccef
# Training XGBoost: 100%|██████████| 10/10 [01:05<00:00,  6.51s/it]
# [I 2025-05-12 05:15:18,301] Trial 0 finished with value: 1.1362279412117915 and parameters: {'n_estimators': 207, 'max_depth': 11, 'learning_rate': 0.012273593503403565, 'subsample': 0.768625567628032, 'colsample_bytree': 0.6660449704497546, 'reg_alpha': 0.3057753105881268, 'reg_lambda': 0.4511314959073932}. Best is trial 0 with value: 1.1362279412117915.
# Training XGBoost: 100%|██████████| 10/10 [00:25<00:00,  2.54s/it]
# [I 2025-05-12 05:15:43,697] Trial 1 finished with value: 1.0712505182684442 and parameters: {'n_estimators': 111, 'max_depth': 12, 'learning_rate': 0.11504532939141501, 'subsample': 0.8059380520664733, 'colsample_bytree': 0.7440748797041522, 'reg_alpha': 0.9617255486579213, 'reg_lambda': 0.16992641491696325}. Best is trial 1 with value: 1.0712505182684442.
# Training XGBoost: 100%|██████████| 10/10 [00:26<00:00,  2.65s/it]
# [I 2025-05-12 05:16:10,170] Trial 2 finished with value: 1.0790590392600785 and parameters: {'n_estimators': 146, 'max_depth': 9, 'learning_rate': 0.06790386002490274, 'subsample': 0.8945371232388676, 'colsample_bytree': 0.8044247298536014, 'reg_alpha': 0.5630049544260888, 'reg_lambda': 0.6305873269423758}. Best is trial 1 with value: 1.0712505182684442.
# Training XGBoost: 100%|██████████| 10/10 [02:06<00:00, 12.69s/it]
# [I 2025-05-12 05:18:17,055] Trial 3 finished with value: 1.0999523977308674 and parameters: {'n_estimators': 565, 'max_depth': 15, 'learning_rate': 0.1907226046631056, 'subsample': 0.9113946701064406, 'colsample_bytree': 0.9996471101968084, 'reg_alpha': 0.15726777200318964, 'reg_lambda': 0.1717395589719769}. Best is trial 1 with value: 1.0712505182684442.
# Training XGBoost: 100%|██████████| 10/10 [02:21<00:00, 14.20s/it]
# [I 2025-05-12 05:20:39,015] Trial 4 finished with value: 1.0518501800776754 and parameters: {'n_estimators': 425, 'max_depth': 19, 'learning_rate': 0.044595731842709214, 'subsample': 0.6130958038170579, 'colsample_bytree': 0.7118500532273967, 'reg_alpha': 0.5095139996249689, 'reg_lambda': 0.9182207522041729}. Best is trial 4 with value: 1.0518501800776754.
# Training XGBoost: 100%|██████████| 10/10 [02:46<00:00, 16.66s/it]
# [I 2025-05-12 05:23:25,610] Trial 5 finished with value: 1.056878237482826 and parameters: {'n_estimators': 451, 'max_depth': 18, 'learning_rate': 0.06678596147549927, 'subsample': 0.7583306821871493, 'colsample_bytree': 0.7915698061882471, 'reg_alpha': 0.5792476855432714, 'reg_lambda': 0.38783006968053313}. Best is trial 4 with value: 1.0518501800776754.
# Training XGBoost: 100%|██████████| 10/10 [00:59<00:00,  5.93s/it]
# [I 2025-05-12 05:24:24,909] Trial 6 finished with value: 1.099290980860931 and parameters: {'n_estimators': 108, 'max_depth': 18, 'learning_rate': 0.022890049953392118, 'subsample': 0.9048641083098434, 'colsample_bytree': 0.8318018850670983, 'reg_alpha': 0.6162762976615198, 'reg_lambda': 0.8727553954549055}. Best is trial 4 with value: 1.0518501800776754.
# Training XGBoost: 100%|██████████| 10/10 [01:15<00:00,  7.56s/it]
# [I 2025-05-12 05:25:40,481] Trial 7 finished with value: 1.0731425745655165 and parameters: {'n_estimators': 223, 'max_depth': 17, 'learning_rate': 0.0805195267048528, 'subsample': 0.946240445626407, 'colsample_bytree': 0.9844338945356501, 'reg_alpha': 0.626793297389476, 'reg_lambda': 0.11745569204294615}. Best is trial 4 with value: 1.0518501800776754.
# Training XGBoost: 100%|██████████| 10/10 [00:29<00:00,  2.98s/it]
# [I 2025-05-12 05:26:10,307] Trial 8 finished with value: 1.0826439764365914 and parameters: {'n_estimators': 148, 'max_depth': 10, 'learning_rate': 0.05924937457172691, 'subsample': 0.7882571912873393, 'colsample_bytree': 0.717050115736639, 'reg_alpha': 0.048886624798706535, 'reg_lambda': 0.6960437168989123}. Best is trial 4 with value: 1.0518501800776754.
# Training XGBoost: 100%|██████████| 10/10 [01:17<00:00,  7.73s/it]
# [I 2025-05-12 05:27:27,604] Trial 9 finished with value: 1.075069146532632 and parameters: {'n_estimators': 487, 'max_depth': 9, 'learning_rate': 0.030744222660657735, 'subsample': 0.8746799047260585, 'colsample_bytree': 0.7195481163011581, 'reg_alpha': 0.3072710227115706, 'reg_lambda': 0.8609635886847584}. Best is trial 4 with value: 1.0518501800776754.
# Training XGBoost: 100%|██████████| 10/10 [00:42<00:00,  4.24s/it]
# [I 2025-05-12 05:28:10,054] Trial 10 finished with value: 1.1418384828859156 and parameters: {'n_estimators': 351, 'max_depth': 5, 'learning_rate': 0.024649119404644638, 'subsample': 0.6158326248095807, 'colsample_bytree': 0.6179259159652352, 'reg_alpha': 0.8811334197145932, 'reg_lambda': 0.9894411802522739}. Best is trial 4 with value: 1.0518501800776754.
# Training XGBoost: 100%|██████████| 10/10 [02:48<00:00, 16.85s/it]
# [I 2025-05-12 05:30:58,619] Trial 11 finished with value: 1.0510408569775442 and parameters: {'n_estimators': 410, 'max_depth': 20, 'learning_rate': 0.03698132000928669, 'subsample': 0.6005790997307788, 'colsample_bytree': 0.8891009465935253, 'reg_alpha': 0.7850633241820585, 'reg_lambda': 0.39818890460308387}. Best is trial 11 with value: 1.0510408569775442.
# Training XGBoost: 100%|██████████| 10/10 [02:33<00:00, 15.38s/it]
# [I 2025-05-12 05:33:32,482] Trial 12 finished with value: 1.0517011447117661 and parameters: {'n_estimators': 377, 'max_depth': 20, 'learning_rate': 0.03469729805029612, 'subsample': 0.6058986704348872, 'colsample_bytree': 0.8932825819937539, 'reg_alpha': 0.8034948137293643, 'reg_lambda': 0.36352352859299375}. Best is trial 11 with value: 1.0510408569775442.
# Training XGBoost: 100%|██████████| 10/10 [03:04<00:00, 18.41s/it]
# [I 2025-05-12 05:36:36,564] Trial 13 finished with value: 1.0701470661404795 and parameters: {'n_estimators': 347, 'max_depth': 20, 'learning_rate': 0.01087874019293076, 'subsample': 0.6874028567520455, 'colsample_bytree': 0.9059233178484722, 'reg_alpha': 0.8243415316365731, 'reg_lambda': 0.3160090952103197}. Best is trial 11 with value: 1.0510408569775442.
# Training XGBoost: 100%|██████████| 10/10 [01:41<00:00, 10.11s/it]
# [I 2025-05-12 05:38:17,729] Trial 14 finished with value: 1.050490973523162 and parameters: {'n_estimators': 358, 'max_depth': 15, 'learning_rate': 0.0352258763743336, 'subsample': 0.6846848613516366, 'colsample_bytree': 0.8966937526466431, 'reg_alpha': 0.7964918458768926, 'reg_lambda': 0.590319447973171}. Best is trial 14 with value: 1.050490973523162.
# Training XGBoost: 100%|██████████| 10/10 [01:44<00:00, 10.47s/it]
# [I 2025-05-12 05:40:02,473] Trial 15 finished with value: 1.06891850438182 and parameters: {'n_estimators': 294, 'max_depth': 15, 'learning_rate': 0.017666490632420147, 'subsample': 0.6890811502054931, 'colsample_bytree': 0.8991613456456968, 'reg_alpha': 0.7398070937232909, 'reg_lambda': 0.5913574108740772}. Best is trial 14 with value: 1.050490973523162.
# Training XGBoost: 100%|██████████| 10/10 [03:14<00:00, 19.43s/it]
# [I 2025-05-12 05:43:16,808] Trial 16 finished with value: 1.064866813197303 and parameters: {'n_estimators': 524, 'max_depth': 15, 'learning_rate': 0.11759940531806173, 'subsample': 0.6725015673406891, 'colsample_bytree': 0.9375393774114452, 'reg_alpha': 0.9866959231822228, 'reg_lambda': 0.7460113263768369}. Best is trial 14 with value: 1.050490973523162.
# Training XGBoost: 100%|██████████| 10/10 [01:11<00:00,  7.18s/it]
# [I 2025-05-12 05:44:28,648] Trial 17 finished with value: 1.04766965991273 and parameters: {'n_estimators': 281, 'max_depth': 14, 'learning_rate': 0.045138010068837366, 'subsample': 0.6588538291905485, 'colsample_bytree': 0.8477742047837319, 'reg_alpha': 0.7158783030627213, 'reg_lambda': 0.5295174263790512}. Best is trial 17 with value: 1.04766965991273.
# Training XGBoost: 100%|██████████| 10/10 [01:04<00:00,  6.50s/it]
# [I 2025-05-12 05:45:33,667] Trial 18 finished with value: 1.0990087948184457 and parameters: {'n_estimators': 295, 'max_depth': 13, 'learning_rate': 0.2727502210718916, 'subsample': 0.7224453277991458, 'colsample_bytree': 0.8278460213884379, 'reg_alpha': 0.40599983961755504, 'reg_lambda': 0.5467502595084137}. Best is trial 17 with value: 1.04766965991273.
# Training XGBoost: 100%|██████████| 10/10 [01:32<00:00,  9.22s/it]
# [I 2025-05-12 05:47:05,886] Trial 19 finished with value: 1.0742198078726553 and parameters: {'n_estimators': 272, 'max_depth': 14, 'learning_rate': 0.01734978955329684, 'subsample': 0.6597135042920134, 'colsample_bytree': 0.8498111563846519, 'reg_alpha': 0.7201020292926739, 'reg_lambda': 0.020063118524922263}. Best is trial 17 with value: 1.04766965991273.
# Training XGBoost: 100%|██████████| 10/10 [00:23<00:00,  2.37s/it]
# [I 2025-05-12 05:47:29,603] Trial 20 finished with value: 1.1016126538123125 and parameters: {'n_estimators': 230, 'max_depth': 5, 'learning_rate': 0.10631691130702052, 'subsample': 0.8291610834623434, 'colsample_bytree': 0.9421679848190456, 'reg_alpha': 0.7118262128963866, 'reg_lambda': 0.5167159843356567}. Best is trial 17 with value: 1.04766965991273.
# Training XGBoost: 100%|██████████| 10/10 [02:15<00:00, 13.58s/it]
# [I 2025-05-12 05:49:45,472] Trial 21 finished with value: 1.0466343535503406 and parameters: {'n_estimators': 398, 'max_depth': 17, 'learning_rate': 0.041866635092570534, 'subsample': 0.6540206486905035, 'colsample_bytree': 0.8564650879368697, 'reg_alpha': 0.8851168953794568, 'reg_lambda': 0.2760472842175449}. Best is trial 21 with value: 1.0466343535503406.
# Training XGBoost: 100%|██████████| 10/10 [01:45<00:00, 10.52s/it]
# [I 2025-05-12 05:51:30,749] Trial 22 finished with value: 1.048494739671955 and parameters: {'n_estimators': 339, 'max_depth': 16, 'learning_rate': 0.04501857392749168, 'subsample': 0.7342753684849535, 'colsample_bytree': 0.8587051850896921, 'reg_alpha': 0.871820842483928, 'reg_lambda': 0.255171838885128}. Best is trial 21 with value: 1.0466343535503406.
# Training XGBoost: 100%|██████████| 10/10 [01:52<00:00, 11.24s/it]
# [I 2025-05-12 05:53:23,220] Trial 23 finished with value: 1.0468168523047798 and parameters: {'n_estimators': 324, 'max_depth': 17, 'learning_rate': 0.05111166091348653, 'subsample': 0.7321192779153192, 'colsample_bytree': 0.7777034942493285, 'reg_alpha': 0.9214269901157361, 'reg_lambda': 0.26127862053520934}. Best is trial 21 with value: 1.0466343535503406.
# Training XGBoost: 100%|██████████| 10/10 [01:26<00:00,  8.70s/it]
# [I 2025-05-12 05:54:50,221] Trial 24 finished with value: 1.0491174593622228 and parameters: {'n_estimators': 260, 'max_depth': 17, 'learning_rate': 0.052852694203539455, 'subsample': 0.6484382720248076, 'colsample_bytree': 0.7690301791787735, 'reg_alpha': 0.8980439720508236, 'reg_lambda': 0.2717137554839435}. Best is trial 21 with value: 1.0466343535503406.
# Training XGBoost: 100%|██████████| 10/10 [01:41<00:00, 10.13s/it]
# [I 2025-05-12 05:56:31,580] Trial 25 finished with value: 1.056723622744601 and parameters: {'n_estimators': 404, 'max_depth': 13, 'learning_rate': 0.08846681379187098, 'subsample': 0.7207195244487166, 'colsample_bytree': 0.7721487382021659, 'reg_alpha': 0.9342767519719931, 'reg_lambda': 0.4654113064034229}. Best is trial 21 with value: 1.0466343535503406.
# Training XGBoost: 100%|██████████| 10/10 [01:47<00:00, 10.71s/it]
# [I 2025-05-12 05:58:18,744] Trial 26 finished with value: 1.0575714557394407 and parameters: {'n_estimators': 312, 'max_depth': 17, 'learning_rate': 0.02598815262340725, 'subsample': 0.6394004795801055, 'colsample_bytree': 0.8085352508287016, 'reg_alpha': 0.6936296266240333, 'reg_lambda': 0.027940548313992064}. Best is trial 21 with value: 1.0466343535503406.
# Training XGBoost: 100%|██████████| 10/10 [03:22<00:00, 20.23s/it]
# [I 2025-05-12 06:01:41,060] Trial 27 finished with value: 1.0638556008751947 and parameters: {'n_estimators': 464, 'max_depth': 18, 'learning_rate': 0.046014238095133345, 'subsample': 0.9962769040702286, 'colsample_bytree': 0.8626043141624672, 'reg_alpha': 0.9759551702012852, 'reg_lambda': 0.22513954005834097}. Best is trial 21 with value: 1.0466343535503406.
# Training XGBoost: 100%|██████████| 10/10 [02:22<00:00, 14.20s/it]
# [I 2025-05-12 06:04:03,109] Trial 28 finished with value: 1.081832016198074 and parameters: {'n_estimators': 387, 'max_depth': 16, 'learning_rate': 0.14361364793696055, 'subsample': 0.709974711013329, 'colsample_bytree': 0.6770096470734739, 'reg_alpha': 0.8511470087586034, 'reg_lambda': 0.3255155461345004}. Best is trial 21 with value: 1.0466343535503406.
# Training XGBoost: 100%|██████████| 10/10 [00:56<00:00,  5.68s/it]
# [I 2025-05-12 06:04:59,919] Trial 29 finished with value: 1.115888636862682 and parameters: {'n_estimators': 185, 'max_depth': 11, 'learning_rate': 0.01718417173076932, 'subsample': 0.7625622217164549, 'colsample_bytree': 0.7506782586429933, 'reg_alpha': 0.665957345013596, 'reg_lambda': 0.442156699930398}. Best is trial 21 with value: 1.0466343535503406.
# Best parameters for XGBoost: {'n_estimators': 398, 'max_depth': 17, 'learning_rate': 0.041866635092570534, 'subsample': 0.6540206486905035, 'colsample_bytree': 0.8564650879368697, 'reg_alpha': 0.8851168953794568, 'reg_lambda': 0.2760472842175449}
# Best mean MAE: 1.0466

# %%
from lightgbm import LGBMRegressor

def lgbm_param_func(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 100, 600),
        'max_depth': trial.suggest_int('max_depth', 5, 20),
        'num_leaves': trial.suggest_int('num_leaves', 20, 300),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
        'verbose': -1
    }

print("Training LightGBM (Poisson)...")
train_evaluate_regression_model_with_optuna(
    "LightGBM",
    lambda **params: LGBMRegressor(objective="poisson", **params),  # ✅ 加入 Poisson 目标
    lgbm_param_func,
    X, y, groups
)
# Out:
# [I 2025-05-12 06:04:59,927] A new study created in memory with name: no-name-aed0f868-08ee-484d-83ee-377ab882c524
# Training LightGBM (Poisson)...
# Training LightGBM: 100%|██████████| 10/10 [00:18<00:00,  1.84s/it]
# [I 2025-05-12 06:05:18,362] Trial 0 finished with value: 1.0716627400432213 and parameters: {'n_estimators': 276, 'max_depth': 17, 'num_leaves': 121, 'learning_rate': 0.04506366123072864, 'feature_fraction': 0.8550261445690586, 'bagging_fraction': 0.9123972357889841, 'bagging_freq': 1, 'reg_alpha': 0.2790287354181946, 'reg_lambda': 0.02454444606490236}. Best is trial 0 with value: 1.0716627400432213.
# Training LightGBM: 100%|██████████| 10/10 [00:18<00:00,  1.83s/it]
# [I 2025-05-12 06:05:36,713] Trial 1 finished with value: 1.188351544026993 and parameters: {'n_estimators': 294, 'max_depth': 10, 'num_leaves': 103, 'learning_rate': 0.011476959351545007, 'feature_fraction': 0.9507252834651463, 'bagging_fraction': 0.8079352469219477, 'bagging_freq': 1, 'reg_alpha': 0.48435396500670125, 'reg_lambda': 0.5157600387269773}. Best is trial 0 with value: 1.0716627400432213.
# Training LightGBM: 100%|██████████| 10/10 [00:09<00:00,  1.04it/s]
# [I 2025-05-12 06:05:46,355] Trial 2 finished with value: 1.177007565637115 and parameters: {'n_estimators': 278, 'max_depth': 7, 'num_leaves': 83, 'learning_rate': 0.020176789526479194, 'feature_fraction': 0.6791068503076718, 'bagging_fraction': 0.7645305807205691, 'bagging_freq': 1, 'reg_alpha': 0.6894950330170591, 'reg_lambda': 0.8277015331137931}. Best is trial 0 with value: 1.0716627400432213.
# Training LightGBM: 100%|██████████| 10/10 [00:03<00:00,  2.53it/s]
# [I 2025-05-12 06:05:50,322] Trial 3 finished with value: 1.1906260228255616 and parameters: {'n_estimators': 132, 'max_depth': 5, 'num_leaves': 139, 'learning_rate': 0.055471134545979274, 'feature_fraction': 0.8923276246100771, 'bagging_fraction': 0.7793942784018371, 'bagging_freq': 1, 'reg_alpha': 0.24058715223166016, 'reg_lambda': 0.12610060783632493}. Best is trial 0 with value: 1.0716627400432213.
# Training LightGBM: 100%|██████████| 10/10 [00:33<00:00,  3.33s/it]
# [I 2025-05-12 06:06:23,600] Trial 4 finished with value: 1.0794627153460539 and parameters: {'n_estimators': 443, 'max_depth': 15, 'num_leaves': 266, 'learning_rate': 0.026107185054349252, 'feature_fraction': 0.6529273702480786, 'bagging_fraction': 0.9505995396536239, 'bagging_freq': 3, 'reg_alpha': 0.4700202720840372, 'reg_lambda': 0.9319117012682375}. Best is trial 0 with value: 1.0716627400432213.
# Training LightGBM: 100%|██████████| 10/10 [00:15<00:00,  1.53s/it]
# [I 2025-05-12 06:06:38,913] Trial 5 finished with value: 1.1901215278621367 and parameters: {'n_estimators': 311, 'max_depth': 11, 'num_leaves': 44, 'learning_rate': 0.012426186070349938, 'feature_fraction': 0.6976027768145678, 'bagging_fraction': 0.7457255903186985, 'bagging_freq': 2, 'reg_alpha': 0.025708975145460666, 'reg_lambda': 0.13097599319919917}. Best is trial 0 with value: 1.0716627400432213.
# Training LightGBM: 100%|██████████| 10/10 [00:08<00:00,  1.19it/s]
# [I 2025-05-12 06:06:47,309] Trial 6 finished with value: 1.3128744522319997 and parameters: {'n_estimators': 168, 'max_depth': 7, 'num_leaves': 102, 'learning_rate': 0.011114431023523457, 'feature_fraction': 0.6839798369994625, 'bagging_fraction': 0.7739229701060027, 'bagging_freq': 2, 'reg_alpha': 0.10577408833174085, 'reg_lambda': 0.5359325062829974}. Best is trial 0 with value: 1.0716627400432213.
# Training LightGBM: 100%|██████████| 10/10 [00:15<00:00,  1.57s/it]
# [I 2025-05-12 06:07:03,043] Trial 7 finished with value: 1.1166483447870799 and parameters: {'n_estimators': 443, 'max_depth': 10, 'num_leaves': 47, 'learning_rate': 0.021643778057397315, 'feature_fraction': 0.8061868017440025, 'bagging_fraction': 0.6434320275562849, 'bagging_freq': 4, 'reg_alpha': 0.6862070675677826, 'reg_lambda': 0.8088396716205805}. Best is trial 0 with value: 1.0716627400432213.
# Training LightGBM: 100%|██████████| 10/10 [00:20<00:00,  2.02s/it]
# [I 2025-05-12 06:07:23,247] Trial 8 finished with value: 1.0862351626571805 and parameters: {'n_estimators': 351, 'max_depth': 19, 'num_leaves': 245, 'learning_rate': 0.231807003415202, 'feature_fraction': 0.9101572721598963, 'bagging_fraction': 0.7799290069033115, 'bagging_freq': 7, 'reg_alpha': 0.2997141849846199, 'reg_lambda': 0.7560307935827529}. Best is trial 0 with value: 1.0716627400432213.
# Training LightGBM: 100%|██████████| 10/10 [00:11<00:00,  1.16s/it]
# [I 2025-05-12 06:07:34,898] Trial 9 finished with value: 1.1583823836872003 and parameters: {'n_estimators': 299, 'max_depth': 7, 'num_leaves': 190, 'learning_rate': 0.023107624887060092, 'feature_fraction': 0.8608212881894943, 'bagging_fraction': 0.9669352790635785, 'bagging_freq': 3, 'reg_alpha': 0.5118818536424248, 'reg_lambda': 0.4934098164709442}. Best is trial 0 with value: 1.0716627400432213.
# Training LightGBM: 100%|██████████| 10/10 [00:37<00:00,  3.80s/it]
# [I 2025-05-12 06:08:12,916] Trial 10 finished with value: 1.0629712461686915 and parameters: {'n_estimators': 599, 'max_depth': 20, 'num_leaves': 180, 'learning_rate': 0.08995004097015666, 'feature_fraction': 0.9944187324230324, 'bagging_fraction': 0.8846923494067302, 'bagging_freq': 6, 'reg_alpha': 0.9221877239800977, 'reg_lambda': 0.3076737572828708}. Best is trial 10 with value: 1.0629712461686915.
# Training LightGBM: 100%|██████████| 10/10 [00:36<00:00,  3.63s/it]
# [I 2025-05-12 06:08:49,227] Trial 11 finished with value: 1.0547500967115406 and parameters: {'n_estimators': 589, 'max_depth': 20, 'num_leaves': 189, 'learning_rate': 0.08858976551654622, 'feature_fraction': 0.9959420577048069, 'bagging_fraction': 0.8911198034972259, 'bagging_freq': 6, 'reg_alpha': 0.8745329665615481, 'reg_lambda': 0.3007061204335504}. Best is trial 11 with value: 1.0547500967115406.
# Training LightGBM: 100%|██████████| 10/10 [00:38<00:00,  3.86s/it]
# [I 2025-05-12 06:09:27,907] Trial 12 finished with value: 1.0741511107531136 and parameters: {'n_estimators': 594, 'max_depth': 20, 'num_leaves': 190, 'learning_rate': 0.12642997018399607, 'feature_fraction': 0.9937857344558316, 'bagging_fraction': 0.8713288702266679, 'bagging_freq': 7, 'reg_alpha': 0.9879454882924821, 'reg_lambda': 0.3287603667128602}. Best is trial 11 with value: 1.0547500967115406.
# Training LightGBM: 100%|██████████| 10/10 [00:28<00:00,  2.82s/it]
# [I 2025-05-12 06:09:56,194] Trial 13 finished with value: 1.0546851815372018 and parameters: {'n_estimators': 599, 'max_depth': 15, 'num_leaves': 214, 'learning_rate': 0.09633739140213587, 'feature_fraction': 0.9848954137154816, 'bagging_fraction': 0.8760470091803116, 'bagging_freq': 6, 'reg_alpha': 0.968004789456437, 'reg_lambda': 0.3364314694409975}. Best is trial 13 with value: 1.0546851815372018.
# Training LightGBM: 100%|██████████| 10/10 [00:22<00:00,  2.26s/it]
# [I 2025-05-12 06:10:18,829] Trial 14 finished with value: 1.0523341756618874 and parameters: {'n_estimators': 529, 'max_depth': 14, 'num_leaves': 228, 'learning_rate': 0.1470662822536099, 'feature_fraction': 0.7682077489820611, 'bagging_fraction': 0.8449518940376587, 'bagging_freq': 5, 'reg_alpha': 0.8475519515944978, 'reg_lambda': 0.30864829227071505}. Best is trial 14 with value: 1.0523341756618874.
# Training LightGBM: 100%|██████████| 10/10 [00:23<00:00,  2.38s/it]
# [I 2025-05-12 06:10:42,647] Trial 15 finished with value: 1.0839130332845672 and parameters: {'n_estimators': 505, 'max_depth': 15, 'num_leaves': 297, 'learning_rate': 0.2655832572584987, 'feature_fraction': 0.7825923206524903, 'bagging_fraction': 0.8226152356781229, 'bagging_freq': 5, 'reg_alpha': 0.7936216535392766, 'reg_lambda': 0.38514991139858146}. Best is trial 14 with value: 1.0523341756618874.
# Training LightGBM: 100%|██████████| 10/10 [00:21<00:00,  2.14s/it]
# [I 2025-05-12 06:11:04,089] Trial 16 finished with value: 1.0858814568583866 and parameters: {'n_estimators': 513, 'max_depth': 14, 'num_leaves': 246, 'learning_rate': 0.15394441167953862, 'feature_fraction': 0.7507937327231208, 'bagging_fraction': 0.6867496560560045, 'bagging_freq': 5, 'reg_alpha': 0.7561607484489181, 'reg_lambda': 0.6700902758653038}. Best is trial 14 with value: 1.0523341756618874.
# Training LightGBM: 100%|██████████| 10/10 [00:23<00:00,  2.34s/it]
# [I 2025-05-12 06:11:27,495] Trial 17 finished with value: 1.0586732462584236 and parameters: {'n_estimators': 526, 'max_depth': 13, 'num_leaves': 238, 'learning_rate': 0.1676907914256209, 'feature_fraction': 0.6018544953395708, 'bagging_fraction': 0.8297680271797202, 'bagging_freq': 5, 'reg_alpha': 0.9944137549179843, 'reg_lambda': 0.1984341561962547}. Best is trial 14 with value: 1.0523341756618874.
# Training LightGBM: 100%|██████████| 10/10 [00:22<00:00,  2.30s/it]
# [I 2025-05-12 06:11:50,506] Trial 18 finished with value: 1.0617607908593822 and parameters: {'n_estimators': 432, 'max_depth': 17, 'num_leaves': 214, 'learning_rate': 0.0583203364442593, 'feature_fraction': 0.7398637674578548, 'bagging_fraction': 0.7097559310861117, 'bagging_freq': 6, 'reg_alpha': 0.5932646062654144, 'reg_lambda': 0.42700106524468057}. Best is trial 14 with value: 1.0523341756618874.
# Training LightGBM: 100%|██████████| 10/10 [00:29<00:00,  2.94s/it]
# [I 2025-05-12 06:12:19,929] Trial 19 finished with value: 1.0550349073888912 and parameters: {'n_estimators': 545, 'max_depth': 17, 'num_leaves': 299, 'learning_rate': 0.09266942424288942, 'feature_fraction': 0.8104410210895128, 'bagging_fraction': 0.8525485640389053, 'bagging_freq': 4, 'reg_alpha': 0.8585032729354777, 'reg_lambda': 0.22010643405271646}. Best is trial 14 with value: 1.0523341756618874.
# Training LightGBM: 100%|██████████| 10/10 [00:18<00:00,  1.85s/it]
# [I 2025-05-12 06:12:38,517] Trial 20 finished with value: 1.0754936364331553 and parameters: {'n_estimators': 391, 'max_depth': 12, 'num_leaves': 158, 'learning_rate': 0.042624502641709576, 'feature_fraction': 0.844286822757355, 'bagging_fraction': 0.9231404480832243, 'bagging_freq': 6, 'reg_alpha': 0.7917537551512042, 'reg_lambda': 0.6184243109232984}. Best is trial 14 with value: 1.0523341756618874.
# Training LightGBM: 100%|██████████| 10/10 [00:31<00:00,  3.13s/it]
# [I 2025-05-12 06:13:09,909] Trial 21 finished with value: 1.0517482288509696 and parameters: {'n_estimators': 556, 'max_depth': 18, 'num_leaves': 210, 'learning_rate': 0.09292780271398723, 'feature_fraction': 0.9428184284588502, 'bagging_fraction': 0.8986219316464272, 'bagging_freq': 6, 'reg_alpha': 0.8879162223101631, 'reg_lambda': 0.2524304060330107}. Best is trial 21 with value: 1.0517482288509696.
# Training LightGBM: 100%|██████████| 10/10 [00:27<00:00,  2.73s/it]
# [I 2025-05-12 06:13:37,270] Trial 22 finished with value: 1.0591404873090051 and parameters: {'n_estimators': 547, 'max_depth': 16, 'num_leaves': 218, 'learning_rate': 0.126835350317674, 'feature_fraction': 0.9290101318201845, 'bagging_fraction': 0.9289750947698147, 'bagging_freq': 5, 'reg_alpha': 0.9224062196725499, 'reg_lambda': 0.2329217221698205}. Best is trial 21 with value: 1.0517482288509696.
# Training LightGBM: 100%|██████████| 10/10 [00:26<00:00,  2.70s/it]
# [I 2025-05-12 06:14:04,274] Trial 23 finished with value: 1.054600270705962 and parameters: {'n_estimators': 477, 'max_depth': 18, 'num_leaves': 212, 'learning_rate': 0.07159555638144154, 'feature_fraction': 0.9597048445911716, 'bagging_fraction': 0.9956955671894572, 'bagging_freq': 7, 'reg_alpha': 0.6382015899031399, 'reg_lambda': 0.006985456574230164}. Best is trial 21 with value: 1.0517482288509696.
# Training LightGBM: 100%|██████████| 10/10 [00:28<00:00,  2.83s/it]
# [I 2025-05-12 06:14:32,602] Trial 24 finished with value: 1.05710734994875 and parameters: {'n_estimators': 478, 'max_depth': 18, 'num_leaves': 264, 'learning_rate': 0.06742712393496007, 'feature_fraction': 0.9630533705271386, 'bagging_fraction': 0.9926654274091126, 'bagging_freq': 7, 'reg_alpha': 0.6249545222024976, 'reg_lambda': 0.002544338820277686}. Best is trial 21 with value: 1.0517482288509696.
# Training LightGBM: 100%|██████████| 10/10 [00:24<00:00,  2.49s/it]
# [I 2025-05-12 06:14:57,579] Trial 25 finished with value: 1.0682257013142362 and parameters: {'n_estimators': 472, 'max_depth': 18, 'num_leaves': 162, 'learning_rate': 0.20616818638752768, 'feature_fraction': 0.8869296873329395, 'bagging_fraction': 0.9963038229374502, 'bagging_freq': 7, 'reg_alpha': 0.7230615154457496, 'reg_lambda': 0.14757921797437784}. Best is trial 21 with value: 1.0517482288509696.
# Training LightGBM: 100%|██████████| 10/10 [00:21<00:00,  2.14s/it]
# [I 2025-05-12 06:15:19,030] Trial 26 finished with value: 1.0735396787133298 and parameters: {'n_estimators': 389, 'max_depth': 13, 'num_leaves': 230, 'learning_rate': 0.03980516789717226, 'feature_fraction': 0.9402322678185996, 'bagging_fraction': 0.9584713878322054, 'bagging_freq': 5, 'reg_alpha': 0.8314060586689349, 'reg_lambda': 0.09333095437220407}. Best is trial 21 with value: 1.0517482288509696.
# Training LightGBM: 100%|██████████| 10/10 [00:29<00:00,  2.97s/it]
# [I 2025-05-12 06:15:48,788] Trial 27 finished with value: 1.0609734413729701 and parameters: {'n_estimators': 554, 'max_depth': 18, 'num_leaves': 274, 'learning_rate': 0.11614272144876459, 'feature_fraction': 0.7358190414948328, 'bagging_fraction': 0.8379967561592405, 'bagging_freq': 7, 'reg_alpha': 0.5939194245342269, 'reg_lambda': 0.06736370176884343}. Best is trial 21 with value: 1.0517482288509696.
# Training LightGBM: 100%|██████████| 10/10 [00:24<00:00,  2.50s/it]
# [I 2025-05-12 06:16:13,796] Trial 28 finished with value: 1.0505969709050205 and parameters: {'n_estimators': 478, 'max_depth': 16, 'num_leaves': 166, 'learning_rate': 0.06705684613010883, 'feature_fraction': 0.9144546900029168, 'bagging_fraction': 0.907369469650782, 'bagging_freq': 6, 'reg_alpha': 0.4107537182011569, 'reg_lambda': 0.43408232919593037}. Best is trial 28 with value: 1.0505969709050205.
# Training LightGBM: 100%|██████████| 10/10 [00:12<00:00,  1.24s/it]
# [I 2025-05-12 06:16:26,279] Trial 29 finished with value: 1.0568804810179946 and parameters: {'n_estimators': 234, 'max_depth': 16, 'num_leaves': 135, 'learning_rate': 0.18143969254302741, 'feature_fraction': 0.8548390728426423, 'bagging_fraction': 0.907833840689301, 'bagging_freq': 4, 'reg_alpha': 0.3244902435598593, 'reg_lambda': 0.3981315019721993}. Best is trial 28 with value: 1.0505969709050205.
# Best parameters for LightGBM: {'n_estimators': 478, 'max_depth': 16, 'num_leaves': 166, 'learning_rate': 0.06705684613010883, 'feature_fraction': 0.9144546900029168, 'bagging_fraction': 0.907369469650782, 'bagging_freq': 6, 'reg_alpha': 0.4107537182011569, 'reg_lambda': 0.43408232919593037}
# Best mean MAE: 1.0506

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
import optuna
import numpy as np


class DNNWithSoftplus(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        act_fn = {
            'relu': nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh': nn.Tanh()
        }[activation]
        layers = []
        prev_dim = input_dim
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act_fn]
            prev_dim = h
        layers += [nn.Linear(prev_dim, 1)]
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return F.softplus(self.net(x)).squeeze(-1)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
def train_dnn_with_optuna_pytorch(X, y, groups, device=device):
    def dnn_param_func(trial):
        return {
            'hidden_layer_sizes': trial.suggest_categorical(
                'hidden_layer_sizes', [(50,), (100,), (150,), (100, 50), (150, 100, 50)]
            ),
            'activation': trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh']),
            'alpha': trial.suggest_float('alpha', 1e-5, 1e-2, log=True),
            'learning_rate': trial.suggest_float('learning_rate_init', 1e-4, 1e-2, log=True),
            'optimizer': trial.suggest_categorical('solver', ['adam', 'sgd'])
        }

    def objective(trial):
        params = dnn_param_func(trial)
        model = DNNWithSoftplus(
            input_dim=X.shape[1],
            hidden_sizes=params['hidden_layer_sizes'],
            activation=params['activation']
        ).to(device)

        optimizer = {
            'adam': torch.optim.Adam,
            'sgd': torch.optim.SGD
        }[params['optimizer']](model.parameters(), lr=params['learning_rate'], weight_decay=params['alpha'])

        loss_fn = nn.MSELoss()
        gkf = GroupKFold(n_splits=10)
        fold_maes = []

        for train_idx, val_idx in gkf.split(X, y, groups=groups):
            X_train, y_train = X[train_idx], y[train_idx]
            X_val, y_val = X[val_idx], y[val_idx]

            scaler = StandardScaler()
            X_train = scaler.fit_transform(X_train)
            X_val = scaler.transform(X_val)

            train_ds = TensorDataset(torch.tensor(X_train).float(), torch.tensor(y_train).float())
            train_loader = DataLoader(train_ds, batch_size=256, shuffle=True)

            model.train()
            for epoch in range(100):
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    pred = model(xb)
                    loss = loss_fn(pred, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            with torch.no_grad():
                val_preds = model(torch.tensor(X_val).float().to(device)).cpu().numpy()
                mae = mean_absolute_error(y_val, val_preds)
                fold_maes.append(mae)

        return np.mean(fold_maes)

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=30)
    print("\n✅ Best Parameters Found:")
    print(study.best_params)
    print(f"Mean MAE = {study.best_value:.4f}")
    return study.best_params


best_dnn_params = train_dnn_with_optuna_pytorch(X, y, groups)
# Out:
# [I 2025-05-15 22:00:15,574] A new study created in memory with name: no-name-a8f796f8-cea5-4a51-8e3e-06536c7f3c72
# [I 2025-05-15 22:02:08,569] Trial 0 finished with value: 0.26944159852475746 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'alpha': 1.6701479076675837e-05, 'learning_rate_init': 0.00244786584873258, 'solver': 'sgd'}. Best is trial 0 with value: 0.26944159852475746.
# [I 2025-05-15 22:04:19,554] Trial 1 finished with value: 0.4254398217593117 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'logistic', 'alpha': 0.003526161423740021, 'learning_rate_init': 0.0003393115589340009, 'solver': 'adam'}. Best is trial 0 with value: 0.26944159852475746.
# [I 2025-05-15 22:06:07,085] Trial 2 finished with value: 0.4992252929239644 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'logistic', 'alpha': 0.003916378733660452, 'learning_rate_init': 0.00011622454235813165, 'solver': 'sgd'}. Best is trial 0 with value: 0.26944159852475746.
# [I 2025-05-15 22:08:13,335] Trial 3 finished with value: 0.3739654098044925 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'alpha': 0.0019320014378259708, 'learning_rate_init': 0.0008343406889444429, 'solver': 'adam'}. Best is trial 0 with value: 0.26944159852475746.
# [I 2025-05-15 22:10:16,359] Trial 4 finished with value: 0.2711917965076581 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'logistic', 'alpha': 3.236970725218546e-05, 'learning_rate_init': 0.0007404055022703884, 'solver': 'adam'}. Best is trial 0 with value: 0.26944159852475746.
# [I 2025-05-15 22:12:18,048] Trial 5 finished with value: 0.34146596053623024 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'alpha': 8.268100826405826e-05, 'learning_rate_init': 0.0004679252734500377, 'solver': 'sgd'}. Best is trial 0 with value: 0.26944159852475746.
# [I 2025-05-15 22:14:13,435] Trial 6 finished with value: 0.3449626403102595 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'alpha': 3.4266500661133604e-05, 'learning_rate_init': 0.003710510429954677, 'solver': 'adam'}. Best is trial 0 with value: 0.26944159852475746.
# [I 2025-05-15 22:16:05,459] Trial 7 finished with value: 0.26553960077103267 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'alpha': 0.0002745679965709302, 'learning_rate_init': 0.0031443707419404857, 'solver': 'sgd'}. Best is trial 7 with value: 0.26553960077103267.
# [I 2025-05-15 22:17:58,442] Trial 8 finished with value: 0.20206844379028036 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'alpha': 6.52245718867615e-05, 'learning_rate_init': 0.007972052362778434, 'solver': 'sgd'}. Best is trial 8 with value: 0.20206844379028036.
# [I 2025-05-15 22:19:53,699] Trial 9 finished with value: 0.24938015326283489 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'logistic', 'alpha': 4.633449575425372e-05, 'learning_rate_init': 0.00045073958440155907, 'solver': 'adam'}. Best is trial 8 with value: 0.20206844379028036.
# [I 2025-05-15 22:21:40,600] Trial 10 finished with value: 0.20135145267168236 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.0002406848865500769, 'learning_rate_init': 0.00880239203845589, 'solver': 'sgd'}. Best is trial 10 with value: 0.20135145267168236.
# [I 2025-05-15 22:23:28,392] Trial 11 finished with value: 0.19789506486663982 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.00035608702215247256, 'learning_rate_init': 0.009041856420661501, 'solver': 'sgd'}. Best is trial 11 with value: 0.19789506486663982.
# [I 2025-05-15 22:25:17,290] Trial 12 finished with value: 0.19763073789296964 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.00047718675036033517, 'learning_rate_init': 0.009102942582918811, 'solver': 'sgd'}. Best is trial 12 with value: 0.19763073789296964.
# [I 2025-05-15 22:27:11,058] Trial 13 finished with value: 0.2045954698587559 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.0010454045067947299, 'learning_rate_init': 0.005022337300336607, 'solver': 'sgd'}. Best is trial 12 with value: 0.19763073789296964.
# [I 2025-05-15 22:28:58,602] Trial 14 finished with value: 0.22805985241162233 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.0007599196376420962, 'learning_rate_init': 0.0017141939042742476, 'solver': 'sgd'}. Best is trial 12 with value: 0.19763073789296964.
# [I 2025-05-15 22:30:45,158] Trial 15 finished with value: 0.22825818706378992 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.008437776095853377, 'learning_rate_init': 0.005763588876315949, 'solver': 'sgd'}. Best is trial 12 with value: 0.19763073789296964.
# [I 2025-05-15 22:32:32,570] Trial 16 finished with value: 0.23210131779229837 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.00014710087649377271, 'learning_rate_init': 0.0014729656810973499, 'solver': 'sgd'}. Best is trial 12 with value: 0.19763073789296964.
# [I 2025-05-15 22:34:25,335] Trial 17 finished with value: 0.19567647666302498 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.0005814839273775385, 'learning_rate_init': 0.009883377356767892, 'solver': 'sgd'}. Best is trial 17 with value: 0.19567647666302498.
# [I 2025-05-15 22:36:11,374] Trial 18 finished with value: 0.20487641805711604 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.0006024995059011667, 'learning_rate_init': 0.005427834438859881, 'solver': 'sgd'}. Best is trial 17 with value: 0.19567647666302498.
# [I 2025-05-15 22:37:58,673] Trial 19 finished with value: 0.23019576040825465 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.0013508886156369435, 'learning_rate_init': 0.0018701903988276975, 'solver': 'sgd'}. Best is trial 17 with value: 0.19567647666302498.
# [I 2025-05-15 22:39:49,254] Trial 20 finished with value: 0.4086990432631178 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'alpha': 0.0001367296665318854, 'learning_rate_init': 0.00011367052261103408, 'solver': 'sgd'}. Best is trial 17 with value: 0.19567647666302498.
# [I 2025-05-15 22:41:39,040] Trial 21 finished with value: 0.1998319609002562 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.0004173808491522506, 'learning_rate_init': 0.009927214870673544, 'solver': 'sgd'}. Best is trial 17 with value: 0.19567647666302498.
# [I 2025-05-15 22:43:26,266] Trial 22 finished with value: 0.2009855408646573 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.00039204853072091197, 'learning_rate_init': 0.006533294188950991, 'solver': 'sgd'}. Best is trial 17 with value: 0.19567647666302498.
# [I 2025-05-15 22:45:13,240] Trial 23 finished with value: 0.20824580072530702 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.0001868390510408482, 'learning_rate_init': 0.0036748684346238993, 'solver': 'sgd'}. Best is trial 17 with value: 0.19567647666302498.
# [I 2025-05-15 22:47:01,000] Trial 24 finished with value: 0.19642421043841626 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.0006309664534683599, 'learning_rate_init': 0.009678131321108976, 'solver': 'sgd'}. Best is trial 17 with value: 0.19567647666302498.
# [I 2025-05-15 22:48:47,753] Trial 25 finished with value: 0.2032116127171772 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'alpha': 0.0017491759745151354, 'learning_rate_init': 0.004638089196593197, 'solver': 'sgd'}. Best is trial 17 with value: 0.19567647666302498.
# [I 2025-05-15 22:50:39,985] Trial 26 finished with value: 0.4011023869537998 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.0007755640180563944, 'learning_rate_init': 0.002616000577772829, 'solver': 'adam'}. Best is trial 17 with value: 0.19567647666302498.
# [I 2025-05-15 22:52:27,745] Trial 27 finished with value: 0.20221289336501883 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.002672655837405873, 'learning_rate_init': 0.006899257104888247, 'solver': 'sgd'}. Best is trial 17 with value: 0.19567647666302498.
# [I 2025-05-15 22:54:14,540] Trial 28 finished with value: 0.34564413382524395 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'alpha': 0.0004985231697428853, 'learning_rate_init': 0.0002345264829984881, 'solver': 'sgd'}. Best is trial 17 with value: 0.19567647666302498.
# [I 2025-05-15 22:56:09,940] Trial 29 finished with value: 0.4027313987487761 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'alpha': 1.3592294721457954e-05, 'learning_rate_init': 0.002335369201486745, 'solver': 'sgd'}. Best is trial 17 with value: 0.19567647666302498.
# ✅ Best Parameters Found:
# {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.0005814839273775385, 'learning_rate_init': 0.009883377356767892, 'solver': 'sgd'}
# Mean MAE = 0.1957
