# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import torch
from sklearn.model_selection import StratifiedKFold
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.metrics import precision_recall_curve, auc
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import joblib
import optuna
from rdkit.Chem import Descriptors, AllChem
from tqdm import tqdm  # 导入tqdm
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GroupKFold

# %%
# 函数：将SMILES转换为分子描述符和指纹
def smiles_to_features(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None
    # 提取描述符
    descriptors = [
        Descriptors.MolWt(mol),  # 分子量
        Descriptors.MolLogP(mol),  # LogP
        Descriptors.NumHDonors(mol),  # 氢键供体数量
        Descriptors.NumHAcceptors(mol)  # 氢键受体数量
    ]
    # 生成Morgan指纹
    fingerprint = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=2048)
    fingerprint_array = np.zeros((2048,))
    Chem.DataStructs.ConvertToNumpyArray(fingerprint, fingerprint_array)
    # 合并描述符和指纹
    features = np.concatenate([descriptors, fingerprint_array])
    return features

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold
from tqdm import tqdm
import optuna
import numpy as np

def train_evaluate_regression_model_with_optuna(model_name, model_class, param_func, X, y, groups):
    def objective(trial):
        params = param_func(trial)
        model = model_class(**params)

        gkf = GroupKFold(n_splits=10)
        maes = []

        for train_idx, val_idx in tqdm(gkf.split(X, y, groups=groups), total=10, desc=f"Training {model_name}"):
            X_train, X_val = X[train_idx], X[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            model.fit(X_train, y_train)
            y_pred = model.predict(X_val)

            # ✅ 计算 MAE
            mae = mean_absolute_error(y_val, y_pred)
            maes.append(mae)

        return np.mean(maes)

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=30)

    print(f'Best parameters for {model_name}: {study.best_params}')
    print(f'Best mean MAE: {study.best_value:.4f}')

# %%
# 数据预处理
df = pd.read_excel('../fish_LC50_unique.xlsx')
labels = df['mgperL'].values
smiles_list = df['SMILES_Canonical_RDKit'].tolist()
endpoints_a = df['endpoint']
Duration_Values_a = df['Duration_Value'].values
effects_a = df['effect']

# %%
features = []
new_labels = []
new_smiles_list = []
endpoints = []
Duration_Values = []
effects =[]


for smiles, label,a,b,c in zip(smiles_list, labels,Duration_Values_a,effects_a,endpoints_a):
    feature = smiles_to_features(smiles)
    if feature is not None:
        features.append(feature)
        new_labels.append(label)
        new_smiles_list.append(smiles)
        Duration_Values.append(a)
        effects.append(b)
        endpoints.append(c)

X = np.array(features)
y = np.array(new_labels)
groups = new_smiles_list  # 可直接用于 GroupKFold

# %%
def encode_column(zz):
    zz_series = pd.Series(zz)  # 转换为 Series
    unique_values = zz_series.unique()
    if len(unique_values) > 1:
        encoder = OneHotEncoder(sparse_output=False)
        return encoder.fit_transform(zz_series.values.reshape(-1, 1))
    else:
        return None  # 只有一种类别时忽略

Duration_Values =pd.Series(Duration_Values)


# 编码 effect、endpoint 和 species_group 列
effect_encoded = encode_column(effects)
endpoint_encoded = encode_column(endpoints)
#species_encoded = encode_column(df, 'species_group')

# # 将需要的列拼接成输入 X
X = np.hstack((X, Duration_Values.values.reshape(-1, 1)))

# # 拼接编码后的列（如果存在）
for encoded_feature in [effect_encoded, endpoint_encoded]:
     if encoded_feature is not None:
         X = np.hstack((X, encoded_feature))



y=np.log1p(y)

# %%
def xgb_param_func(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 100, 600),
        'max_depth': trial.suggest_int('max_depth', 5, 20),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),   # L1 正则
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0)  # L2 正则
    }
from xgboost import XGBRegressor

train_evaluate_regression_model_with_optuna(
    "XGBoost",
    XGBRegressor,
    xgb_param_func,
    X, y, groups
)
# Out:
# [I 2025-05-17 14:56:00,988] A new study created in memory with name: no-name-4d8a86a7-1b75-427a-a94f-10df8d4b0ff6
# Training XGBoost: 100%|██████████| 10/10 [02:32<00:00, 15.23s/it]
# [I 2025-05-17 14:58:33,291] Trial 0 finished with value: 1.04289747699804 and parameters: {'n_estimators': 385, 'max_depth': 18, 'learning_rate': 0.020403411600968313, 'subsample': 0.8096104113580094, 'colsample_bytree': 0.6393818710768454, 'reg_alpha': 0.947674265756803, 'reg_lambda': 0.6609484861443922}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [01:38<00:00,  9.80s/it]
# [I 2025-05-17 15:00:11,344] Trial 1 finished with value: 1.068857673224464 and parameters: {'n_estimators': 206, 'max_depth': 17, 'learning_rate': 0.015623303927610554, 'subsample': 0.9079176917521865, 'colsample_bytree': 0.9093412162385428, 'reg_alpha': 0.33415403306895275, 'reg_lambda': 0.5981655233549854}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [01:28<00:00,  8.86s/it]
# [I 2025-05-17 15:01:39,929] Trial 2 finished with value: 1.068578044578728 and parameters: {'n_estimators': 541, 'max_depth': 10, 'learning_rate': 0.02612279343169127, 'subsample': 0.839798075662794, 'colsample_bytree': 0.9912629080460337, 'reg_alpha': 0.5843025703116069, 'reg_lambda': 0.3152996181456339}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [00:49<00:00,  4.94s/it]
# [I 2025-05-17 15:02:29,382] Trial 3 finished with value: 1.062212131563546 and parameters: {'n_estimators': 171, 'max_depth': 17, 'learning_rate': 0.060621237671370794, 'subsample': 0.6298737393563778, 'colsample_bytree': 0.9234978792803675, 'reg_alpha': 0.23939323968545767, 'reg_lambda': 0.25958659997433964}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [00:53<00:00,  5.31s/it]
# [I 2025-05-17 15:03:22,485] Trial 4 finished with value: 1.0597272500618677 and parameters: {'n_estimators': 171, 'max_depth': 16, 'learning_rate': 0.04848847514842379, 'subsample': 0.6107684779034928, 'colsample_bytree': 0.6442279171513975, 'reg_alpha': 0.8888883041589268, 'reg_lambda': 0.9077049061286223}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [03:25<00:00, 20.56s/it]
# [I 2025-05-17 15:06:48,100] Trial 5 finished with value: 1.0494412245426772 and parameters: {'n_estimators': 474, 'max_depth': 18, 'learning_rate': 0.010749298297979066, 'subsample': 0.8319464786850579, 'colsample_bytree': 0.8213319519904404, 'reg_alpha': 0.41657064711141, 'reg_lambda': 0.09379688453933543}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [01:54<00:00, 11.49s/it]
# [I 2025-05-17 15:08:42,996] Trial 6 finished with value: 1.072705375109738 and parameters: {'n_estimators': 326, 'max_depth': 14, 'learning_rate': 0.011826471679106275, 'subsample': 0.7468511360606624, 'colsample_bytree': 0.8900281391026508, 'reg_alpha': 0.19382286511560642, 'reg_lambda': 0.671577553099452}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [00:38<00:00,  3.85s/it]
# [I 2025-05-17 15:09:21,497] Trial 7 finished with value: 1.1338610761574384 and parameters: {'n_estimators': 365, 'max_depth': 6, 'learning_rate': 0.27762921648117506, 'subsample': 0.7888368894044235, 'colsample_bytree': 0.8718916814695141, 'reg_alpha': 0.6035755427703301, 'reg_lambda': 0.1985382947673876}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [03:44<00:00, 22.49s/it]
# [I 2025-05-17 15:13:06,404] Trial 8 finished with value: 1.060895470191125 and parameters: {'n_estimators': 479, 'max_depth': 19, 'learning_rate': 0.07931231483780593, 'subsample': 0.6589527024084023, 'colsample_bytree': 0.952849172701635, 'reg_alpha': 0.902843706709428, 'reg_lambda': 0.39996780392270026}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [02:15<00:00, 13.56s/it]
# [I 2025-05-17 15:15:22,056] Trial 9 finished with value: 1.0523456883184072 and parameters: {'n_estimators': 378, 'max_depth': 15, 'learning_rate': 0.01639681215685792, 'subsample': 0.8985635886025047, 'colsample_bytree': 0.6877144377842926, 'reg_alpha': 0.8816771450632493, 'reg_lambda': 0.5928777026871122}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [00:46<00:00,  4.67s/it]
# [I 2025-05-17 15:16:08,917] Trial 10 finished with value: 1.0612761395510186 and parameters: {'n_estimators': 277, 'max_depth': 11, 'learning_rate': 0.1365512534338168, 'subsample': 0.9708936061965084, 'colsample_bytree': 0.7400687592700484, 'reg_alpha': 0.7242021888530823, 'reg_lambda': 0.8614932723414869}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [02:45<00:00, 16.55s/it]
# [I 2025-05-17 15:18:54,412] Trial 11 finished with value: 1.0456554839817618 and parameters: {'n_estimators': 424, 'max_depth': 20, 'learning_rate': 0.02842748314862097, 'subsample': 0.7606262425131973, 'colsample_bytree': 0.7993999165165703, 'reg_alpha': 0.435272770688404, 'reg_lambda': 0.0234595260136356}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [03:00<00:00, 18.01s/it]
# [I 2025-05-17 15:21:54,539] Trial 12 finished with value: 1.0514631876052198 and parameters: {'n_estimators': 457, 'max_depth': 20, 'learning_rate': 0.030715332247364512, 'subsample': 0.7104500411193793, 'colsample_bytree': 0.6043292419194908, 'reg_alpha': 0.7021666882208004, 'reg_lambda': 0.04699168969647223}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [02:50<00:00, 17.08s/it]
# [I 2025-05-17 15:24:45,395] Trial 13 finished with value: 1.0450016596857363 and parameters: {'n_estimators': 600, 'max_depth': 20, 'learning_rate': 0.02875698563660653, 'subsample': 0.7369464637652583, 'colsample_bytree': 0.7581782397257883, 'reg_alpha': 0.06107359886046826, 'reg_lambda': 0.7401701675585702}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [01:44<00:00, 10.45s/it]
# [I 2025-05-17 15:26:29,958] Trial 14 finished with value: 1.0540740983885608 and parameters: {'n_estimators': 580, 'max_depth': 13, 'learning_rate': 0.04065093272117766, 'subsample': 0.6967453606202997, 'colsample_bytree': 0.7231263696562702, 'reg_alpha': 0.192448988995113, 'reg_lambda': 0.7523283132150088}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [01:20<00:00,  8.04s/it]
# [I 2025-05-17 15:27:50,416] Trial 15 finished with value: 1.0953736680838932 and parameters: {'n_estimators': 590, 'max_depth': 8, 'learning_rate': 0.019929641049459334, 'subsample': 0.8434518585074704, 'colsample_bytree': 0.7841936287728407, 'reg_alpha': 0.004967202741750061, 'reg_lambda': 0.47116923319603277}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [00:44<00:00,  4.42s/it]
# [I 2025-05-17 15:28:34,669] Trial 16 finished with value: 1.0696971420568222 and parameters: {'n_estimators': 106, 'max_depth': 20, 'learning_rate': 0.11011330754510874, 'subsample': 0.7078858400093723, 'colsample_bytree': 0.6713073407398421, 'reg_alpha': 0.9972773042586534, 'reg_lambda': 0.9967922024924042}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [01:26<00:00,  8.66s/it]
# [I 2025-05-17 15:30:01,265] Trial 17 finished with value: 1.0534268773634876 and parameters: {'n_estimators': 284, 'max_depth': 18, 'learning_rate': 0.035908473274777794, 'subsample': 0.8918235160818148, 'colsample_bytree': 0.6138342302463158, 'reg_alpha': 0.006863207683015599, 'reg_lambda': 0.7688941265551607}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [02:21<00:00, 14.17s/it]
# [I 2025-05-17 15:32:22,993] Trial 18 finished with value: 1.0491474878766753 and parameters: {'n_estimators': 522, 'max_depth': 15, 'learning_rate': 0.02034752142128113, 'subsample': 0.7933403665905226, 'colsample_bytree': 0.7406218082866726, 'reg_alpha': 0.743842158467015, 'reg_lambda': 0.6070932871332266}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [01:03<00:00,  6.33s/it]
# [I 2025-05-17 15:33:26,325] Trial 19 finished with value: 1.05993981395627 and parameters: {'n_estimators': 406, 'max_depth': 12, 'learning_rate': 0.06425374888170723, 'subsample': 0.9718189103723409, 'colsample_bytree': 0.8415898106603471, 'reg_alpha': 0.11386495119553165, 'reg_lambda': 0.768902449460435}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [03:06<00:00, 18.68s/it]
# [I 2025-05-17 15:36:33,107] Trial 20 finished with value: 1.0453704345694048 and parameters: {'n_estimators': 523, 'max_depth': 18, 'learning_rate': 0.014530287337638233, 'subsample': 0.7502947977583777, 'colsample_bytree': 0.6986355356976881, 'reg_alpha': 0.5395994801409378, 'reg_lambda': 0.4890995648486157}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [03:13<00:00, 19.37s/it]
# [I 2025-05-17 15:39:46,864] Trial 21 finished with value: 1.0451594387570213 and parameters: {'n_estimators': 522, 'max_depth': 18, 'learning_rate': 0.014467819325087792, 'subsample': 0.7444944485910183, 'colsample_bytree': 0.6955637176780289, 'reg_alpha': 0.5310597820715673, 'reg_lambda': 0.46520686040619275}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [02:26<00:00, 14.69s/it]
# [I 2025-05-17 15:42:13,840] Trial 22 finished with value: 1.0487414352869084 and parameters: {'n_estimators': 551, 'max_depth': 16, 'learning_rate': 0.021950752724639037, 'subsample': 0.6778303094170759, 'colsample_bytree': 0.6451956507059566, 'reg_alpha': 0.33208284198830934, 'reg_lambda': 0.4135230275968148}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [03:19<00:00, 19.95s/it]
# [I 2025-05-17 15:45:33,400] Trial 23 finished with value: 1.0444032006522646 and parameters: {'n_estimators': 494, 'max_depth': 19, 'learning_rate': 0.013752278160733478, 'subsample': 0.7245365816930178, 'colsample_bytree': 0.7722117278470807, 'reg_alpha': 0.798732645576287, 'reg_lambda': 0.682292100095295}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [03:35<00:00, 21.56s/it]
# [I 2025-05-17 15:49:08,980] Trial 24 finished with value: 1.0502743985120724 and parameters: {'n_estimators': 434, 'max_depth': 20, 'learning_rate': 0.010169611685696195, 'subsample': 0.8116023992590566, 'colsample_bytree': 0.7760703744923102, 'reg_alpha': 0.9989531423007504, 'reg_lambda': 0.6973732620817362}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [03:03<00:00, 18.35s/it]
# [I 2025-05-17 15:52:12,541] Trial 25 finished with value: 1.0453891830994242 and parameters: {'n_estimators': 497, 'max_depth': 19, 'learning_rate': 0.02386493423113864, 'subsample': 0.6506517994674373, 'colsample_bytree': 0.7663542314939302, 'reg_alpha': 0.8140050029926718, 'reg_lambda': 0.8573298413111995}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [03:02<00:00, 18.21s/it]
# [I 2025-05-17 15:55:14,667] Trial 26 finished with value: 1.0480656050918262 and parameters: {'n_estimators': 598, 'max_depth': 16, 'learning_rate': 0.032859821304827536, 'subsample': 0.7211024362792221, 'colsample_bytree': 0.8377691532078491, 'reg_alpha': 0.8181114015233814, 'reg_lambda': 0.5652663257315539}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [02:01<00:00, 12.12s/it]
# [I 2025-05-17 15:57:15,855] Trial 27 finished with value: 1.046682398621662 and parameters: {'n_estimators': 328, 'max_depth': 19, 'learning_rate': 0.04350674097782529, 'subsample': 0.7746581150060025, 'colsample_bytree': 0.7518988331170903, 'reg_alpha': 0.6463092645009675, 'reg_lambda': 0.6722721347401709}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [02:21<00:00, 14.15s/it]
# [I 2025-05-17 15:59:37,377] Trial 28 finished with value: 1.0463878019486204 and parameters: {'n_estimators': 394, 'max_depth': 17, 'learning_rate': 0.01870710908489567, 'subsample': 0.8678525375640183, 'colsample_bytree': 0.7142241946897605, 'reg_alpha': 0.801738014298077, 'reg_lambda': 0.8583963339713027}. Best is trial 0 with value: 1.04289747699804.
# Training XGBoost: 100%|██████████| 10/10 [00:54<00:00,  5.41s/it]
# [I 2025-05-17 16:00:31,474] Trial 29 finished with value: 1.180007069112213 and parameters: {'n_estimators': 450, 'max_depth': 5, 'learning_rate': 0.012510639259483045, 'subsample': 0.9347218824096177, 'colsample_bytree': 0.6544659876908464, 'reg_alpha': 0.9384308031063877, 'reg_lambda': 0.548446627914283}. Best is trial 0 with value: 1.04289747699804.
# Best parameters for XGBoost: {'n_estimators': 385, 'max_depth': 18, 'learning_rate': 0.020403411600968313, 'subsample': 0.8096104113580094, 'colsample_bytree': 0.6393818710768454, 'reg_alpha': 0.947674265756803, 'reg_lambda': 0.6609484861443922}
# Best mean MAE: 1.0429

# %%
from lightgbm import LGBMRegressor

def lgbm_param_func(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 100, 600),
        'max_depth': trial.suggest_int('max_depth', 5, 20),
        'num_leaves': trial.suggest_int('num_leaves', 20, 300),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
        'verbose': -1
    }

print("Training LightGBM (Poisson)...")
train_evaluate_regression_model_with_optuna(
    "LightGBM",
    lambda **params: LGBMRegressor(objective="poisson", **params),  # ✅ 加入 Poisson 目标
    lgbm_param_func,
    X, y, groups
)
# Out:
# [I 2025-05-17 16:00:31,482] A new study created in memory with name: no-name-9fca0456-62cf-49c9-95ed-21da17175234
# Training LightGBM (Poisson)...
# Training LightGBM: 100%|██████████| 10/10 [00:12<00:00,  1.24s/it]
# [I 2025-05-17 16:00:43,951] Trial 0 finished with value: 1.0903387324659461 and parameters: {'n_estimators': 557, 'max_depth': 8, 'num_leaves': 188, 'learning_rate': 0.13908199292349302, 'feature_fraction': 0.6402156300551995, 'bagging_fraction': 0.8782302172974572, 'bagging_freq': 6, 'reg_alpha': 0.8652132044897708, 'reg_lambda': 0.7594088174490806}. Best is trial 0 with value: 1.0903387324659461.
# Training LightGBM: 100%|██████████| 10/10 [00:03<00:00,  2.77it/s]
# [I 2025-05-17 16:00:47,571] Trial 1 finished with value: 1.181908068844106 and parameters: {'n_estimators': 104, 'max_depth': 5, 'num_leaves': 216, 'learning_rate': 0.14358103444353248, 'feature_fraction': 0.7128822533033546, 'bagging_fraction': 0.9613385104503117, 'bagging_freq': 2, 'reg_alpha': 0.04417660396532319, 'reg_lambda': 0.546813506188574}. Best is trial 0 with value: 1.0903387324659461.
# Training LightGBM: 100%|██████████| 10/10 [00:15<00:00,  1.52s/it]
# [I 2025-05-17 16:01:02,758] Trial 2 finished with value: 1.079884084838906 and parameters: {'n_estimators': 267, 'max_depth': 19, 'num_leaves': 112, 'learning_rate': 0.20723779650616575, 'feature_fraction': 0.9243948257857464, 'bagging_fraction': 0.8084812126759164, 'bagging_freq': 2, 'reg_alpha': 0.3035153632720978, 'reg_lambda': 0.5163538384727236}. Best is trial 2 with value: 1.079884084838906.
# Training LightGBM: 100%|██████████| 10/10 [00:15<00:00,  1.53s/it]
# [I 2025-05-17 16:01:18,039] Trial 3 finished with value: 1.1599334898352855 and parameters: {'n_estimators': 465, 'max_depth': 8, 'num_leaves': 223, 'learning_rate': 0.015668813120695575, 'feature_fraction': 0.807896471990495, 'bagging_fraction': 0.6182009558375661, 'bagging_freq': 2, 'reg_alpha': 0.6340222725899436, 'reg_lambda': 0.6100919073135556}. Best is trial 2 with value: 1.079884084838906.
# Training LightGBM: 100%|██████████| 10/10 [00:19<00:00,  1.96s/it]
# [I 2025-05-17 16:01:37,645] Trial 4 finished with value: 1.0858893782940677 and parameters: {'n_estimators': 495, 'max_depth': 15, 'num_leaves': 63, 'learning_rate': 0.0329243892492626, 'feature_fraction': 0.7409477671126545, 'bagging_fraction': 0.9416925820686477, 'bagging_freq': 1, 'reg_alpha': 0.8770932179904365, 'reg_lambda': 0.007985310133948209}. Best is trial 2 with value: 1.079884084838906.
# Training LightGBM: 100%|██████████| 10/10 [00:10<00:00,  1.07s/it]
# [I 2025-05-17 16:01:48,353] Trial 5 finished with value: 1.1091580736787696 and parameters: {'n_estimators': 252, 'max_depth': 10, 'num_leaves': 277, 'learning_rate': 0.04728005765004113, 'feature_fraction': 0.7826007347644746, 'bagging_fraction': 0.8897156475224766, 'bagging_freq': 4, 'reg_alpha': 0.3632738474190119, 'reg_lambda': 0.7989905318422795}. Best is trial 2 with value: 1.079884084838906.
# Training LightGBM: 100%|██████████| 10/10 [00:39<00:00,  3.96s/it]
# [I 2025-05-17 16:02:27,985] Trial 6 finished with value: 1.1196006296542043 and parameters: {'n_estimators': 525, 'max_depth': 19, 'num_leaves': 106, 'learning_rate': 0.010084839362216902, 'feature_fraction': 0.7630186117878627, 'bagging_fraction': 0.940399931642411, 'bagging_freq': 5, 'reg_alpha': 0.011904257471290647, 'reg_lambda': 0.4953659376496933}. Best is trial 2 with value: 1.079884084838906.
# Training LightGBM: 100%|██████████| 10/10 [00:08<00:00,  1.17it/s]
# [I 2025-05-17 16:02:36,566] Trial 7 finished with value: 1.0955722723631929 and parameters: {'n_estimators': 214, 'max_depth': 14, 'num_leaves': 163, 'learning_rate': 0.23038250145618763, 'feature_fraction': 0.8714248283498623, 'bagging_fraction': 0.6409011465969747, 'bagging_freq': 7, 'reg_alpha': 0.35953009277336045, 'reg_lambda': 0.2817247553704739}. Best is trial 2 with value: 1.079884084838906.
# Training LightGBM: 100%|██████████| 10/10 [00:07<00:00,  1.31it/s]
# [I 2025-05-17 16:02:44,236] Trial 8 finished with value: 1.0906805777289381 and parameters: {'n_estimators': 193, 'max_depth': 13, 'num_leaves': 208, 'learning_rate': 0.2561897721004034, 'feature_fraction': 0.661724499662561, 'bagging_fraction': 0.7445530963072308, 'bagging_freq': 6, 'reg_alpha': 0.2088780176062014, 'reg_lambda': 0.9719689244875894}. Best is trial 2 with value: 1.079884084838906.
# Training LightGBM: 100%|██████████| 10/10 [00:14<00:00,  1.49s/it]
# [I 2025-05-17 16:02:59,120] Trial 9 finished with value: 1.1090944415914719 and parameters: {'n_estimators': 588, 'max_depth': 8, 'num_leaves': 269, 'learning_rate': 0.03347269598452749, 'feature_fraction': 0.7166855387680926, 'bagging_fraction': 0.7427765593521425, 'bagging_freq': 3, 'reg_alpha': 0.0321649875725557, 'reg_lambda': 0.35672383479988234}. Best is trial 2 with value: 1.079884084838906.
# Training LightGBM: 100%|██████████| 10/10 [00:12<00:00,  1.20s/it]
# [I 2025-05-17 16:03:11,176] Trial 10 finished with value: 1.090872673728169 and parameters: {'n_estimators': 382, 'max_depth': 20, 'num_leaves': 33, 'learning_rate': 0.0929805389884721, 'feature_fraction': 0.9887527515965958, 'bagging_fraction': 0.8093334986530205, 'bagging_freq': 1, 'reg_alpha': 0.6184638593856164, 'reg_lambda': 0.03371838428983387}. Best is trial 2 with value: 1.079884084838906.
# Training LightGBM: 100%|██████████| 10/10 [00:19<00:00,  1.97s/it]
# [I 2025-05-17 16:03:30,900] Trial 11 finished with value: 1.0900300848518776 and parameters: {'n_estimators': 345, 'max_depth': 17, 'num_leaves': 93, 'learning_rate': 0.026845521133003414, 'feature_fraction': 0.968542379640466, 'bagging_fraction': 0.9995358028389602, 'bagging_freq': 1, 'reg_alpha': 0.8522726035900252, 'reg_lambda': 0.02933706879120468}. Best is trial 2 with value: 1.079884084838906.
# Training LightGBM: 100%|██████████| 10/10 [00:17<00:00,  1.70s/it]
# [I 2025-05-17 16:03:47,981] Trial 12 finished with value: 1.070275097276612 and parameters: {'n_estimators': 367, 'max_depth': 16, 'num_leaves': 96, 'learning_rate': 0.07563310131921679, 'feature_fraction': 0.8930604400483821, 'bagging_fraction': 0.8285857798170756, 'bagging_freq': 3, 'reg_alpha': 0.9828754894277818, 'reg_lambda': 0.21252400413584804}. Best is trial 12 with value: 1.070275097276612.
# Training LightGBM: 100%|██████████| 10/10 [00:16<00:00,  1.67s/it]
# [I 2025-05-17 16:04:04,694] Trial 13 finished with value: 1.0664110542668161 and parameters: {'n_estimators': 345, 'max_depth': 17, 'num_leaves': 102, 'learning_rate': 0.07807694103088433, 'feature_fraction': 0.8972750244578594, 'bagging_fraction': 0.8140756936869245, 'bagging_freq': 3, 'reg_alpha': 0.46943450860861713, 'reg_lambda': 0.2516043724743725}. Best is trial 13 with value: 1.0664110542668161.
# Training LightGBM: 100%|██████████| 10/10 [00:18<00:00,  1.82s/it]
# [I 2025-05-17 16:04:22,941] Trial 14 finished with value: 1.0715182798471374 and parameters: {'n_estimators': 396, 'max_depth': 16, 'num_leaves': 142, 'learning_rate': 0.07440283273761243, 'feature_fraction': 0.8696594352284556, 'bagging_fraction': 0.7229953457943193, 'bagging_freq': 4, 'reg_alpha': 0.9995788319186403, 'reg_lambda': 0.2457462825353966}. Best is trial 13 with value: 1.0664110542668161.
# Training LightGBM: 100%|██████████| 10/10 [00:09<00:00,  1.10it/s]
# [I 2025-05-17 16:04:32,042] Trial 15 finished with value: 1.116331439324782 and parameters: {'n_estimators': 323, 'max_depth': 17, 'num_leaves': 21, 'learning_rate': 0.06078063084376615, 'feature_fraction': 0.8546517500241665, 'bagging_fraction': 0.8574549392440732, 'bagging_freq': 3, 'reg_alpha': 0.572563381457494, 'reg_lambda': 0.18550779951148716}. Best is trial 13 with value: 1.0664110542668161.
# Training LightGBM: 100%|██████████| 10/10 [00:13<00:00,  1.40s/it]
# [I 2025-05-17 16:04:46,046] Trial 16 finished with value: 1.08185639888436 and parameters: {'n_estimators': 426, 'max_depth': 12, 'num_leaves': 70, 'learning_rate': 0.10290349950102716, 'feature_fraction': 0.9191732863346948, 'bagging_fraction': 0.6883637219724726, 'bagging_freq': 3, 'reg_alpha': 0.724257217594702, 'reg_lambda': 0.3979854285428961}. Best is trial 13 with value: 1.0664110542668161.
# Training LightGBM: 100%|██████████| 10/10 [00:17<00:00,  1.70s/it]
# [I 2025-05-17 16:05:03,095] Trial 17 finished with value: 1.0719913350993946 and parameters: {'n_estimators': 302, 'max_depth': 18, 'num_leaves': 137, 'learning_rate': 0.05981337089118928, 'feature_fraction': 0.924059418847589, 'bagging_fraction': 0.7810098460912634, 'bagging_freq': 4, 'reg_alpha': 0.5211796513410835, 'reg_lambda': 0.1597951008963724}. Best is trial 13 with value: 1.0664110542668161.
# Training LightGBM: 100%|██████████| 10/10 [00:13<00:00,  1.35s/it]
# [I 2025-05-17 16:05:16,646] Trial 18 finished with value: 1.0872624882664197 and parameters: {'n_estimators': 449, 'max_depth': 12, 'num_leaves': 61, 'learning_rate': 0.13844679583385672, 'feature_fraction': 0.8306141183342194, 'bagging_fraction': 0.8201792888863033, 'bagging_freq': 5, 'reg_alpha': 0.4242997478150912, 'reg_lambda': 0.15057414832349345}. Best is trial 13 with value: 1.0664110542668161.
# Training LightGBM: 100%|██████████| 10/10 [00:12<00:00,  1.21s/it]
# [I 2025-05-17 16:05:28,750] Trial 19 finished with value: 1.1152224338782581 and parameters: {'n_estimators': 156, 'max_depth': 15, 'num_leaves': 127, 'learning_rate': 0.03962715220660836, 'feature_fraction': 0.9071309175627525, 'bagging_fraction': 0.8517750694295023, 'bagging_freq': 3, 'reg_alpha': 0.7072917118478422, 'reg_lambda': 0.38230050545197547}. Best is trial 13 with value: 1.0664110542668161.
# Training LightGBM: 100%|██████████| 10/10 [00:17<00:00,  1.76s/it]
# [I 2025-05-17 16:05:46,358] Trial 20 finished with value: 1.0670571461293128 and parameters: {'n_estimators': 370, 'max_depth': 16, 'num_leaves': 165, 'learning_rate': 0.08184594223489376, 'feature_fraction': 0.9632511880595256, 'bagging_fraction': 0.9027936358632405, 'bagging_freq': 5, 'reg_alpha': 0.18042358856936214, 'reg_lambda': 0.2945902450266094}. Best is trial 13 with value: 1.0664110542668161.
# Training LightGBM: 100%|██████████| 10/10 [00:17<00:00,  1.74s/it]
# [I 2025-05-17 16:06:03,773] Trial 21 finished with value: 1.0644652644875041 and parameters: {'n_estimators': 374, 'max_depth': 16, 'num_leaves': 176, 'learning_rate': 0.09597528115856235, 'feature_fraction': 0.960528871317775, 'bagging_fraction': 0.8972668410632367, 'bagging_freq': 5, 'reg_alpha': 0.17991701898042778, 'reg_lambda': 0.2771765347215814}. Best is trial 21 with value: 1.0644652644875041.
# Training LightGBM: 100%|██████████| 10/10 [00:12<00:00,  1.29s/it]
# [I 2025-05-17 16:06:16,687] Trial 22 finished with value: 1.0707393398244829 and parameters: {'n_estimators': 295, 'max_depth': 14, 'num_leaves': 171, 'learning_rate': 0.10461017766248196, 'feature_fraction': 0.9617195281743077, 'bagging_fraction': 0.9095635171024062, 'bagging_freq': 5, 'reg_alpha': 0.21732154442492224, 'reg_lambda': 0.3072035435952575}. Best is trial 21 with value: 1.0644652644875041.
# Training LightGBM: 100%|██████████| 10/10 [00:20<00:00,  2.07s/it]
# [I 2025-05-17 16:06:37,456] Trial 23 finished with value: 1.0689256207831057 and parameters: {'n_estimators': 413, 'max_depth': 18, 'num_leaves': 247, 'learning_rate': 0.08803743986692109, 'feature_fraction': 0.9985177193264556, 'bagging_fraction': 0.9112762766529399, 'bagging_freq': 6, 'reg_alpha': 0.1474585384533159, 'reg_lambda': 0.43424954751891787}. Best is trial 21 with value: 1.0644652644875041.
# Training LightGBM: 100%|██████████| 10/10 [00:19<00:00,  1.97s/it]
# [I 2025-05-17 16:06:57,157] Trial 24 finished with value: 1.0811968250471335 and parameters: {'n_estimators': 362, 'max_depth': 20, 'num_leaves': 184, 'learning_rate': 0.16155143469004785, 'feature_fraction': 0.9499044045153785, 'bagging_fraction': 0.7831466735129865, 'bagging_freq': 5, 'reg_alpha': 0.11236360209931832, 'reg_lambda': 0.1143042043805719}. Best is trial 21 with value: 1.0644652644875041.
# Training LightGBM: 100%|██████████| 10/10 [00:18<00:00,  1.84s/it]
# [I 2025-05-17 16:07:15,632] Trial 25 finished with value: 1.0720100268867523 and parameters: {'n_estimators': 331, 'max_depth': 16, 'num_leaves': 150, 'learning_rate': 0.05177481489328099, 'feature_fraction': 0.9471400981632827, 'bagging_fraction': 0.9779336440991884, 'bagging_freq': 7, 'reg_alpha': 0.2713018155423988, 'reg_lambda': 0.31379632510643435}. Best is trial 21 with value: 1.0644652644875041.
# Training LightGBM: 100%|██████████| 10/10 [00:24<00:00,  2.49s/it]
# [I 2025-05-17 16:07:40,600] Trial 26 finished with value: 1.0651258793508367 and parameters: {'n_estimators': 477, 'max_depth': 18, 'num_leaves': 239, 'learning_rate': 0.06918587137214606, 'feature_fraction': 0.8396836670003314, 'bagging_fraction': 0.8541605452188255, 'bagging_freq': 4, 'reg_alpha': 0.4462157706919719, 'reg_lambda': 0.10701112352768039}. Best is trial 21 with value: 1.0644652644875041.
# Training LightGBM: 100%|██████████| 10/10 [00:24<00:00,  2.48s/it]
# [I 2025-05-17 16:08:05,436] Trial 27 finished with value: 1.0887396832175449 and parameters: {'n_estimators': 497, 'max_depth': 18, 'num_leaves': 293, 'learning_rate': 0.18747972727063933, 'feature_fraction': 0.835223897668066, 'bagging_fraction': 0.8536097745313908, 'bagging_freq': 4, 'reg_alpha': 0.47243838867620414, 'reg_lambda': 0.09898005867727327}. Best is trial 21 with value: 1.0644652644875041.
# Training LightGBM: 100%|██████████| 10/10 [00:31<00:00,  3.14s/it]
# [I 2025-05-17 16:08:36,860] Trial 28 finished with value: 1.0710721184065592 and parameters: {'n_estimators': 465, 'max_depth': 19, 'num_leaves': 243, 'learning_rate': 0.025513285039726743, 'feature_fraction': 0.808246338302307, 'bagging_fraction': 0.7665959612681564, 'bagging_freq': 4, 'reg_alpha': 0.4111399651864273, 'reg_lambda': 0.10403205911603149}. Best is trial 21 with value: 1.0644652644875041.
# Training LightGBM: 100%|██████████| 10/10 [00:18<00:00,  1.82s/it]
# [I 2025-05-17 16:08:55,108] Trial 29 finished with value: 1.080007865276385 and parameters: {'n_estimators': 567, 'max_depth': 11, 'num_leaves': 194, 'learning_rate': 0.10744872680727263, 'feature_fraction': 0.6126398233724839, 'bagging_fraction': 0.8839128378161369, 'bagging_freq': 6, 'reg_alpha': 0.5081336359474298, 'reg_lambda': 0.654997326903952}. Best is trial 21 with value: 1.0644652644875041.
# Best parameters for LightGBM: {'n_estimators': 374, 'max_depth': 16, 'num_leaves': 176, 'learning_rate': 0.09597528115856235, 'feature_fraction': 0.960528871317775, 'bagging_fraction': 0.8972668410632367, 'bagging_freq': 5, 'reg_alpha': 0.17991701898042778, 'reg_lambda': 0.2771765347215814}
# Best mean MAE: 1.0645

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
import optuna
import numpy as np


class DNNWithSoftplus(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        act_fn = {
            'relu': nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh': nn.Tanh()
        }[activation]
        layers = []
        prev_dim = input_dim
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act_fn]
            prev_dim = h
        layers += [nn.Linear(prev_dim, 1)]
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return F.softplus(self.net(x)).squeeze(-1)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
def train_dnn_with_optuna_pytorch(X, y, groups, device=device):
    def dnn_param_func(trial):
        return {
            'hidden_layer_sizes': trial.suggest_categorical(
                'hidden_layer_sizes', [(50,), (100,), (150,), (100, 50), (150, 100, 50)]
            ),
            'activation': trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh']),
            'alpha': trial.suggest_float('alpha', 1e-5, 1e-2, log=True),
            'learning_rate': trial.suggest_float('learning_rate_init', 1e-4, 1e-2, log=True),
            'optimizer': trial.suggest_categorical('solver', ['adam', 'sgd'])
        }

    def objective(trial):
        params = dnn_param_func(trial)
        model = DNNWithSoftplus(
            input_dim=X.shape[1],
            hidden_sizes=params['hidden_layer_sizes'],
            activation=params['activation']
        ).to(device)

        optimizer = {
            'adam': torch.optim.Adam,
            'sgd': torch.optim.SGD
        }[params['optimizer']](model.parameters(), lr=params['learning_rate'], weight_decay=params['alpha'])

        loss_fn = nn.MSELoss()
        gkf = GroupKFold(n_splits=10)
        fold_maes = []

        for train_idx, val_idx in gkf.split(X, y, groups=groups):
            X_train, y_train = X[train_idx], y[train_idx]
            X_val, y_val = X[val_idx], y[val_idx]

            scaler = StandardScaler()
            X_train = scaler.fit_transform(X_train)
            X_val = scaler.transform(X_val)

            train_ds = TensorDataset(torch.tensor(X_train).float(), torch.tensor(y_train).float())
            train_loader = DataLoader(train_ds, batch_size=256, shuffle=True)

            model.train()
            for epoch in range(100):
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    pred = model(xb)
                    loss = loss_fn(pred, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            with torch.no_grad():
                val_preds = model(torch.tensor(X_val).float().to(device)).cpu().numpy()
                mae = mean_absolute_error(y_val, val_preds)
                fold_maes.append(mae)

        return np.mean(fold_maes)

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=30)
    print("\n✅ Best Parameters Found:")
    print(study.best_params)
    print(f"Mean MAE = {study.best_value:.4f}")
    return study.best_params


best_dnn_params = train_dnn_with_optuna_pytorch(X, y, groups)
# Out:
# [I 2025-05-15 22:00:31,266] A new study created in memory with name: no-name-557bf822-1c9a-4c9c-948d-b39d9098279a
# [I 2025-05-15 22:02:25,280] Trial 0 finished with value: 0.781133924419488 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 0.0010019567847363614, 'learning_rate_init': 0.0002622162707807647, 'solver': 'sgd'}. Best is trial 0 with value: 0.781133924419488.
# [I 2025-05-15 22:04:18,777] Trial 1 finished with value: 0.7442428148197497 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'alpha': 0.004454616292484832, 'learning_rate_init': 0.00019862988279309166, 'solver': 'adam'}. Best is trial 1 with value: 0.7442428148197497.
# [I 2025-05-15 22:06:07,804] Trial 2 finished with value: 1.59009237306235 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'logistic', 'alpha': 1.4875955463106727e-05, 'learning_rate_init': 0.000719795264330727, 'solver': 'sgd'}. Best is trial 1 with value: 0.7442428148197497.
# [I 2025-05-15 22:07:48,984] Trial 3 finished with value: 0.6543679429641344 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.00023613709129928864, 'learning_rate_init': 0.0005243771418390609, 'solver': 'sgd'}. Best is trial 3 with value: 0.6543679429641344.
# [I 2025-05-15 22:09:54,971] Trial 4 finished with value: 0.5094269179858187 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 7.290704428355825e-05, 'learning_rate_init': 0.000156959321494084, 'solver': 'adam'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:11:58,534] Trial 5 finished with value: 0.8262892781842559 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 0.0018326564026964172, 'learning_rate_init': 0.0006425940933121951, 'solver': 'adam'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:13:39,967] Trial 6 finished with value: 0.7793830038015602 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'logistic', 'alpha': 0.0016632946576912219, 'learning_rate_init': 0.00476731621235446, 'solver': 'sgd'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:15:26,899] Trial 7 finished with value: 0.7589290097690633 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.006121542816719543, 'learning_rate_init': 0.000130340683584034, 'solver': 'adam'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:17:08,535] Trial 8 finished with value: 0.9821600327165493 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'logistic', 'alpha': 0.006996804289413921, 'learning_rate_init': 0.0004852694817315787, 'solver': 'sgd'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:18:52,156] Trial 9 finished with value: 0.6249864180928938 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'alpha': 0.0005744430958613118, 'learning_rate_init': 0.0006510414973028577, 'solver': 'sgd'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:20:47,391] Trial 10 finished with value: 0.92774731542199 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'alpha': 6.990758141625011e-05, 'learning_rate_init': 0.0021476259567847736, 'solver': 'adam'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:22:34,586] Trial 11 finished with value: 0.9877113745651277 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'alpha': 0.00014072233094981725, 'learning_rate_init': 0.0021483438479971266, 'solver': 'adam'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:24:16,399] Trial 12 finished with value: 0.5707011626048805 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'alpha': 4.238144675697324e-05, 'learning_rate_init': 0.0015999113682629977, 'solver': 'sgd'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:26:05,772] Trial 13 finished with value: 0.6133313004044986 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'alpha': 2.793160582058388e-05, 'learning_rate_init': 0.0017795535262594303, 'solver': 'adam'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:27:52,942] Trial 14 finished with value: 0.5986025267371435 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'alpha': 5.481357423707788e-05, 'learning_rate_init': 0.006810942332748607, 'solver': 'sgd'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:29:52,441] Trial 15 finished with value: 0.5904228478265339 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 1.0066204059451357e-05, 'learning_rate_init': 0.0014823786489602385, 'solver': 'adam'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:31:53,469] Trial 16 finished with value: 0.5157544600625619 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 9.556336771480884e-05, 'learning_rate_init': 0.00010487702904813173, 'solver': 'adam'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:34:01,061] Trial 17 finished with value: 0.5115409737175917 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 0.00012606366920858426, 'learning_rate_init': 0.00011004475514498415, 'solver': 'adam'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:36:02,942] Trial 18 finished with value: 0.6551210000448529 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'alpha': 0.0002871721948229511, 'learning_rate_init': 0.00028933252764751726, 'solver': 'adam'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:38:07,357] Trial 19 finished with value: 0.6449803599696281 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'logistic', 'alpha': 0.0001538855135640247, 'learning_rate_init': 0.00018168218983770384, 'solver': 'adam'}. Best is trial 4 with value: 0.5094269179858187.
# [I 2025-05-15 22:40:10,581] Trial 20 finished with value: 0.5066162462056643 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 2.6143806061321074e-05, 'learning_rate_init': 0.0001070139012586485, 'solver': 'adam'}. Best is trial 20 with value: 0.5066162462056643.
# [I 2025-05-15 22:42:13,039] Trial 21 finished with value: 0.5104905959625179 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 1.9784817158927383e-05, 'learning_rate_init': 0.00010013235308683063, 'solver': 'adam'}. Best is trial 20 with value: 0.5066162462056643.
# [I 2025-05-15 22:44:14,050] Trial 22 finished with value: 0.5068874236275294 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 1.9847100848529988e-05, 'learning_rate_init': 0.0003252140698808532, 'solver': 'adam'}. Best is trial 20 with value: 0.5066162462056643.
# [I 2025-05-15 22:46:18,591] Trial 23 finished with value: 0.5141027510436115 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 3.1095312240507273e-05, 'learning_rate_init': 0.00035207583454811386, 'solver': 'adam'}. Best is trial 20 with value: 0.5066162462056643.
# [I 2025-05-15 22:48:21,948] Trial 24 finished with value: 0.48327168797185704 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 1.011810309253857e-05, 'learning_rate_init': 0.00016750122071688278, 'solver': 'adam'}. Best is trial 24 with value: 0.48327168797185704.
# [I 2025-05-15 22:50:09,599] Trial 25 finished with value: 0.5531185397575924 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'alpha': 1.0253240800232285e-05, 'learning_rate_init': 0.00020596908895468527, 'solver': 'adam'}. Best is trial 24 with value: 0.48327168797185704.
# [I 2025-05-15 22:51:58,283] Trial 26 finished with value: 0.5434063501621761 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 2.112981444805532e-05, 'learning_rate_init': 0.00029857042722348555, 'solver': 'adam'}. Best is trial 24 with value: 0.48327168797185704.
# [I 2025-05-15 22:53:55,183] Trial 27 finished with value: 0.565704978002585 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'alpha': 1.5672881366769157e-05, 'learning_rate_init': 0.0010435244186486657, 'solver': 'adam'}. Best is trial 24 with value: 0.48327168797185704.
# [I 2025-05-15 22:56:03,441] Trial 28 finished with value: 0.5514881850679195 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'alpha': 3.55429505457599e-05, 'learning_rate_init': 0.0004133285678905819, 'solver': 'adam'}. Best is trial 24 with value: 0.48327168797185704.
# [I 2025-05-15 22:57:54,254] Trial 29 finished with value: 0.603295013913208 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'logistic', 'alpha': 1.4403451017029787e-05, 'learning_rate_init': 0.0002277376199505652, 'solver': 'adam'}. Best is trial 24 with value: 0.48327168797185704.
# ✅ Best Parameters Found:
# {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 1.011810309253857e-05, 'learning_rate_init': 0.00016750122071688278, 'solver': 'adam'}
# Mean MAE = 0.4833
