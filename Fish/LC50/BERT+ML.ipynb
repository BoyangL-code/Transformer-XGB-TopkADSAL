# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import random

# 固定随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # for multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)  # 设置固定种子

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import optuna
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# ----------------- CONFIGURATION -----------------
n_folds    = 10
n_trials   = 30
data_dir   = "./k_folds_model/embeddings"
batch_size = 256
num_epochs = 200
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------- MODEL DEFINITION -----------------
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        layers = []
        prev_dim = input_dim
        act = {
            'relu':     nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh':     nn.Tanh()
        }[activation]
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act]
            prev_dim = h
        layers.append(nn.Linear(prev_dim, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = self.net(x).squeeze(-1)
        return F.softplus(x)  # 输出 > 0

# ----------------- OPTUNA OBJECTIVE -----------------
def objective(trial):
    hidden_sizes      = trial.suggest_categorical('hidden_layer_sizes',
                            [(50,), (100,), (150,), (100, 50), (150, 100, 50)])
    activation        = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh'])
    lr                = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    weight_decay      = trial.suggest_float('alpha', 1e-5, 1e-2, log=True)
    optimizer_choice  = trial.suggest_categorical('optimizer', ['sgd', 'adam'])

    fold_maes = []

    for fold in range(1, n_folds + 1):
        X_train = np.load(f"{data_dir}/train_fold_{fold}.npy")
        y_train = np.load(f"{data_dir}/train_labels_fold_{fold}.npy")
        X_val   = np.load(f"{data_dir}/val_fold_{fold}.npy")
        y_val   = np.load(f"{data_dir}/val_labels_fold_{fold}.npy")

        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val   = scaler.transform(X_val)

        train_ds = TensorDataset(torch.from_numpy(X_train).float(),
                                 torch.from_numpy(y_train).float())
        val_ds = TensorDataset(torch.from_numpy(X_val).float(),
                               torch.from_numpy(y_val).float())
        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        model = MLP(input_dim=X_train.shape[1],
                    hidden_sizes=hidden_sizes,
                    activation=activation).to(device)
        criterion = nn.MSELoss()
        optimizer = {
            'sgd': torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay),
            'adam': torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        }[optimizer_choice]

        try:
            for epoch in range(num_epochs):
                model.train()
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    preds = model(xb)
                    loss = criterion(preds, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            all_preds = []
            with torch.no_grad():
                for xb, _ in val_loader:
                    xb = xb.to(device)
                    batch_pred = model(xb).cpu().numpy()
                    all_preds.append(batch_pred)
            all_preds = np.concatenate(all_preds)

            mae = mean_absolute_error(y_val, all_preds)
            fold_maes.append(mae)

        except Exception:
            return np.inf

    return float(np.mean(fold_maes))

# ----------------- RUN OPTUNA -----------------
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)

    print("\n=== Best Hyperparameters ===")
    print(study.best_params)
    print(f"Best Mean MAE: {study.best_value:.4f}")
# Out:
# [I 2025-05-16 10:02:40,759] A new study created in memory with name: no-name-3abc58aa-6909-44b7-8b5f-1f4556752bb8
# [I 2025-05-16 10:05:42,839] Trial 0 finished with value: 0.7644741535186768 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.0015930522616241021, 'alpha': 0.001331121608073689, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7644741535186768.
# [I 2025-05-16 10:08:49,608] Trial 1 finished with value: 0.7703007459640503 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0016738085788752138, 'alpha': 2.621087878265438e-05, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7644741535186768.
# [I 2025-05-16 10:11:42,371] Trial 2 finished with value: 1.0304467678070068 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00013492834268013249, 'alpha': 0.007025166339242158, 'optimizer': 'sgd'}. Best is trial 0 with value: 0.7644741535186768.
# [I 2025-05-16 10:14:49,507] Trial 3 finished with value: 0.7573596239089966 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00032927591344236165, 'alpha': 0.0009717775305059633, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7573596239089966.
# [I 2025-05-16 10:17:53,982] Trial 4 finished with value: 0.7574137449264526 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00015030900645056822, 'alpha': 3.872118032174584e-05, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7573596239089966.
# [I 2025-05-16 10:20:46,672] Trial 5 finished with value: 0.8434934616088867 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00014096175149815865, 'alpha': 0.009133995846860976, 'optimizer': 'sgd'}. Best is trial 3 with value: 0.7573596239089966.
# [I 2025-05-16 10:23:37,653] Trial 6 finished with value: 0.7645535469055176 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.005323617594751502, 'alpha': 0.0007411299781083245, 'optimizer': 'sgd'}. Best is trial 3 with value: 0.7573596239089966.
# [I 2025-05-16 10:26:19,796] Trial 7 finished with value: 0.7611785531044006 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0033233042062267943, 'alpha': 0.00048287152161792117, 'optimizer': 'sgd'}. Best is trial 3 with value: 0.7573596239089966.
# [I 2025-05-16 10:28:54,785] Trial 8 finished with value: 1.0673919916152954 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.006533305220227739, 'alpha': 5.59598687800608e-05, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7573596239089966.
# [I 2025-05-16 10:31:39,714] Trial 9 finished with value: 0.7571436762809753 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.004048966222584676, 'alpha': 3.6283583803549155e-05, 'optimizer': 'sgd'}. Best is trial 9 with value: 0.7571436762809753.
# [I 2025-05-16 10:34:17,446] Trial 10 finished with value: 0.7847009301185608 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0005463331403485196, 'alpha': 1.1321021804230373e-05, 'optimizer': 'sgd'}. Best is trial 9 with value: 0.7571436762809753.
# [I 2025-05-16 10:37:11,552] Trial 11 finished with value: 0.7616556882858276 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0004584030853373771, 'alpha': 0.00016705006134455682, 'optimizer': 'adam'}. Best is trial 9 with value: 0.7571436762809753.
# [I 2025-05-16 10:40:03,791] Trial 12 finished with value: 0.7694277763366699 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0003932362707959252, 'alpha': 0.00015363382008012154, 'optimizer': 'adam'}. Best is trial 9 with value: 0.7571436762809753.
# [I 2025-05-16 10:42:26,624] Trial 13 finished with value: 0.7644112706184387 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00990120075444166, 'alpha': 0.001975986659997066, 'optimizer': 'sgd'}. Best is trial 9 with value: 0.7571436762809753.
# [I 2025-05-16 10:45:07,578] Trial 14 finished with value: 0.7702821493148804 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.0008657857585898337, 'alpha': 0.00013566969734149178, 'optimizer': 'adam'}. Best is trial 9 with value: 0.7571436762809753.
# [I 2025-05-16 10:47:30,913] Trial 15 finished with value: 0.9729007482528687 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'logistic', 'learning_rate': 0.0002714696616467186, 'alpha': 0.002498932588459663, 'optimizer': 'sgd'}. Best is trial 9 with value: 0.7571436762809753.
# [I 2025-05-16 10:50:14,896] Trial 16 finished with value: 0.7727416753768921 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0022483178904872027, 'alpha': 0.00022704255894210598, 'optimizer': 'sgd'}. Best is trial 9 with value: 0.7571436762809753.
# [I 2025-05-16 10:53:05,188] Trial 17 finished with value: 0.763245701789856 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0008968339015098238, 'alpha': 1.2166938734917365e-05, 'optimizer': 'adam'}. Best is trial 9 with value: 0.7571436762809753.
# [I 2025-05-16 10:55:29,047] Trial 18 finished with value: 0.7732990980148315 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.0038254854599428993, 'alpha': 7.633519183320513e-05, 'optimizer': 'sgd'}. Best is trial 9 with value: 0.7571436762809753.
# [I 2025-05-16 10:58:11,503] Trial 19 finished with value: 0.7630707621574402 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.00024541413044110166, 'alpha': 0.0004599355675791596, 'optimizer': 'adam'}. Best is trial 9 with value: 0.7571436762809753.
# [I 2025-05-16 11:00:33,909] Trial 20 finished with value: 0.763401210308075 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'learning_rate': 0.0007249152639023248, 'alpha': 0.004438217512617065, 'optimizer': 'sgd'}. Best is trial 9 with value: 0.7571436762809753.
# [I 2025-05-16 11:03:07,196] Trial 21 finished with value: 0.7560314536094666 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00010765379736386514, 'alpha': 3.268064390070332e-05, 'optimizer': 'adam'}. Best is trial 21 with value: 0.7560314536094666.
# [I 2025-05-16 11:05:39,820] Trial 22 finished with value: 0.7584590911865234 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00010625721497327504, 'alpha': 2.2822170256941147e-05, 'optimizer': 'adam'}. Best is trial 21 with value: 0.7560314536094666.
# [I 2025-05-16 11:08:12,035] Trial 23 finished with value: 0.7560609579086304 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00023572882732252252, 'alpha': 7.22574195233586e-05, 'optimizer': 'adam'}. Best is trial 21 with value: 0.7560314536094666.
# [I 2025-05-16 11:10:43,758] Trial 24 finished with value: 0.7622839212417603 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00021575323958428249, 'alpha': 7.192986461282522e-05, 'optimizer': 'adam'}. Best is trial 21 with value: 0.7560314536094666.
# [I 2025-05-16 11:16:10,246] Trial 26 finished with value: 0.7563248872756958 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00010507596646187499, 'alpha': 4.018748820180411e-05, 'optimizer': 'adam'}. Best is trial 21 with value: 0.7560314536094666.
# [I 2025-05-16 11:18:43,169] Trial 27 finished with value: 0.7629498839378357 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00010710892694386419, 'alpha': 8.741204139134167e-05, 'optimizer': 'adam'}. Best is trial 21 with value: 0.7560314536094666.
# [I 2025-05-16 11:21:14,852] Trial 28 finished with value: 0.763393759727478 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.0001970256274929137, 'alpha': 4.4486745089721e-05, 'optimizer': 'adam'}. Best is trial 21 with value: 0.7560314536094666.
# [I 2025-05-16 11:23:47,982] Trial 29 finished with value: 0.7604308128356934 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'logistic', 'learning_rate': 0.00010549744050522123, 'alpha': 0.00010799623291717006, 'optimizer': 'adam'}. Best is trial 21 with value: 0.7560314536094666.
# === Best Hyperparameters ===
# {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00010765379736386514, 'alpha': 3.268064390070332e-05, 'optimizer': 'adam'}
# Best Mean MAE: 0.7560

# %%
import os
import optuna
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    # 采样超参数
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        model = XGBRegressor(n_jobs=-1, verbosity=0, **params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 以 MAE 为优化目标


# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best XGBoost Hyperparameters via Optuna ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 18:14:09,734] A new study created in memory with name: no-name-6bf483d6-52e5-4091-b713-9c97e9d70b10
# [I 2025-05-16 18:16:42,286] Trial 0 finished with value: 0.8755074739456177 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 8, 'subsample': 0.8795975452591109, 'colsample_bytree': 0.6624074561769746}. Best is trial 0 with value: 0.8755074739456177.
# [I 2025-05-16 18:18:59,813] Trial 1 finished with value: 0.8041971921920776 and parameters: {'n_estimators': 200, 'learning_rate': 0.011900590783184251, 'max_depth': 9, 'subsample': 0.8803345035229626, 'colsample_bytree': 0.8832290311184181}. Best is trial 1 with value: 0.8041971921920776.
# [I 2025-05-16 18:19:41,940] Trial 2 finished with value: 0.8121288418769836 and parameters: {'n_estimators': 100, 'learning_rate': 0.18276027831785724, 'max_depth': 8, 'subsample': 0.7637017332034828, 'colsample_bytree': 0.6727299868828402}. Best is trial 1 with value: 0.8041971921920776.
# [I 2025-05-16 18:20:42,767] Trial 3 finished with value: 0.7650039792060852 and parameters: {'n_estimators': 200, 'learning_rate': 0.024878734419814436, 'max_depth': 6, 'subsample': 0.8295835055926347, 'colsample_bytree': 0.7164916560792167}. Best is trial 3 with value: 0.7650039792060852.
# [I 2025-05-16 18:23:16,976] Trial 4 finished with value: 0.7657937407493591 and parameters: {'n_estimators': 700, 'learning_rate': 0.01518747922672247, 'max_depth': 5, 'subsample': 0.8099085529881075, 'colsample_bytree': 0.7824279936868144}. Best is trial 3 with value: 0.7650039792060852.
# [I 2025-05-16 18:26:37,353] Trial 5 finished with value: 0.7784322500228882 and parameters: {'n_estimators': 800, 'learning_rate': 0.018187859051288217, 'max_depth': 6, 'subsample': 0.8777243706586128, 'colsample_bytree': 0.6185801650879991}. Best is trial 3 with value: 0.7650039792060852.
# [I 2025-05-16 18:28:10,003] Trial 6 finished with value: 0.7579494714736938 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'subsample': 0.984665661176, 'colsample_bytree': 0.9862528132298237}. Best is trial 6 with value: 0.7579494714736938.
# [I 2025-05-16 18:30:01,652] Trial 7 finished with value: 0.7614899277687073 and parameters: {'n_estimators': 900, 'learning_rate': 0.0249064396938244, 'max_depth': 3, 'subsample': 0.905269907953647, 'colsample_bytree': 0.7760609974958406}. Best is trial 6 with value: 0.7579494714736938.
# [I 2025-05-16 18:30:28,270] Trial 8 finished with value: 0.7568485140800476 and parameters: {'n_estimators': 200, 'learning_rate': 0.04407984038169244, 'max_depth': 3, 'subsample': 0.9727961206236346, 'colsample_bytree': 0.7035119926400067}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:33:23,226] Trial 9 finished with value: 0.7828168869018555 and parameters: {'n_estimators': 700, 'learning_rate': 0.02544166090938368, 'max_depth': 6, 'subsample': 0.8640130838029838, 'colsample_bytree': 0.6739417822102108}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:34:28,555] Trial 10 finished with value: 0.7740398645401001 and parameters: {'n_estimators': 400, 'learning_rate': 0.08074732196639918, 'max_depth': 4, 'subsample': 0.9864906201399816, 'colsample_bytree': 0.8607466203112714}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:35:32,070] Trial 11 finished with value: 0.7637519240379333 and parameters: {'n_estimators': 500, 'learning_rate': 0.05243600136835885, 'max_depth': 3, 'subsample': 0.9944677871984587, 'colsample_bytree': 0.9926743653872057}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:38:18,152] Trial 12 finished with value: 0.784260094165802 and parameters: {'n_estimators': 1000, 'learning_rate': 0.053291436624982674, 'max_depth': 4, 'subsample': 0.9539327148024781, 'colsample_bytree': 0.9976023236378931}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:39:56,499] Trial 13 finished with value: 0.7907800674438477 and parameters: {'n_estimators': 600, 'learning_rate': 0.09953202087035609, 'max_depth': 4, 'subsample': 0.9407239274525441, 'colsample_bytree': 0.9020148628201681}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:40:34,869] Trial 14 finished with value: 0.7577779293060303 and parameters: {'n_estimators': 300, 'learning_rate': 0.038239324422150126, 'max_depth': 3, 'subsample': 0.9368431198958393, 'colsample_bytree': 0.7390533721986331}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:41:39,437] Trial 15 finished with value: 0.7660666704177856 and parameters: {'n_estimators': 300, 'learning_rate': 0.03899905819947883, 'max_depth': 5, 'subsample': 0.9315600003651645, 'colsample_bytree': 0.7378423507455648}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:42:04,430] Trial 16 finished with value: 0.7666320204734802 and parameters: {'n_estimators': 100, 'learning_rate': 0.038104301423020376, 'max_depth': 5, 'subsample': 0.917567982214315, 'colsample_bytree': 0.7265423468756215}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:42:42,703] Trial 17 finished with value: 0.7623015642166138 and parameters: {'n_estimators': 300, 'learning_rate': 0.07724415360160086, 'max_depth': 3, 'subsample': 0.7416438512657763, 'colsample_bytree': 0.8282460599148197}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:43:33,100] Trial 18 finished with value: 0.7606580257415771 and parameters: {'n_estimators': 300, 'learning_rate': 0.03572357921230152, 'max_depth': 4, 'subsample': 0.9607281971329612, 'colsample_bytree': 0.6254990995378304}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:45:21,970] Trial 19 finished with value: 0.8126810193061829 and parameters: {'n_estimators': 500, 'learning_rate': 0.1256478539029311, 'max_depth': 5, 'subsample': 0.7032967567731313, 'colsample_bytree': 0.753242765688537}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:46:27,975] Trial 20 finished with value: 0.7830346822738647 and parameters: {'n_estimators': 200, 'learning_rate': 0.06492756759888016, 'max_depth': 7, 'subsample': 0.9024806460174593, 'colsample_bytree': 0.8138539263936048}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:47:50,172] Trial 21 finished with value: 0.7590082883834839 and parameters: {'n_estimators': 600, 'learning_rate': 0.010095488676031493, 'max_depth': 3, 'subsample': 0.9743300314096723, 'colsample_bytree': 0.9438599500782205}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:48:41,129] Trial 22 finished with value: 0.7578684687614441 and parameters: {'n_estimators': 400, 'learning_rate': 0.02916466022067098, 'max_depth': 3, 'subsample': 0.996505431608083, 'colsample_bytree': 0.6945553655705927}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:49:47,575] Trial 23 finished with value: 0.76149582862854 and parameters: {'n_estimators': 400, 'learning_rate': 0.029587484553880206, 'max_depth': 4, 'subsample': 0.9993916746916552, 'colsample_bytree': 0.6997108097658562}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:50:24,776] Trial 24 finished with value: 0.7584077715873718 and parameters: {'n_estimators': 300, 'learning_rate': 0.05318370656869129, 'max_depth': 3, 'subsample': 0.9545031951339454, 'colsample_bytree': 0.6463211377384472}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:50:44,391] Trial 25 finished with value: 0.7729644179344177 and parameters: {'n_estimators': 100, 'learning_rate': 0.03298959116595086, 'max_depth': 4, 'subsample': 0.9359591675998831, 'colsample_bytree': 0.6992200944493252}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:51:37,318] Trial 26 finished with value: 0.757768452167511 and parameters: {'n_estimators': 400, 'learning_rate': 0.019533663464387528, 'max_depth': 3, 'subsample': 0.963850238766421, 'colsample_bytree': 0.7599454328981453}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:52:15,452] Trial 27 finished with value: 0.7637789845466614 and parameters: {'n_estimators': 200, 'learning_rate': 0.020637684058314745, 'max_depth': 4, 'subsample': 0.9643510036539449, 'colsample_bytree': 0.7600021376081741}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:53:18,167] Trial 28 finished with value: 0.7619496583938599 and parameters: {'n_estimators': 500, 'learning_rate': 0.047173266906116625, 'max_depth': 3, 'subsample': 0.9153383679814886, 'colsample_bytree': 0.8316811790281434}. Best is trial 8 with value: 0.7568485140800476.
# [I 2025-05-16 18:54:30,142] Trial 29 finished with value: 0.7652555108070374 and parameters: {'n_estimators': 300, 'learning_rate': 0.013769444514230185, 'max_depth': 5, 'subsample': 0.8395479929838886, 'colsample_bytree': 0.6008542553201073}. Best is trial 8 with value: 0.7568485140800476.
# === Best XGBoost Hyperparameters via Optuna ===
# {'n_estimators': 200, 'learning_rate': 0.04407984038169244, 'max_depth': 3, 'subsample': 0.9727961206236346, 'colsample_bytree': 0.7035119926400067}
# 10-Fold Mean MAE = 0.7568

# %%
import os
import optuna
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'objective': 'poisson',         # ✅ 强制正输出
        'n_jobs': -1,
        'verbose': -1
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        # Poisson 回归要求标签必须大于 0
        if np.any(y_train <= 0) or np.any(y_val <= 0):
            return np.inf

        model = LGBMRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 使用 MAE 作为优化目标

# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 18:54:30,237] A new study created in memory with name: no-name-a566cfd1-ecd1-430a-8221-6a188e564230
# [I 2025-05-16 18:54:58,577] Trial 0 finished with value: 0.7861998622952979 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 10, 'num_leaves': 68, 'feature_fraction': 0.6624074561769746, 'bagging_fraction': 0.662397808134481}. Best is trial 0 with value: 0.7861998622952979.
# [I 2025-05-16 18:55:10,701] Trial 1 finished with value: 0.7703381864488373 and parameters: {'n_estimators': 100, 'learning_rate': 0.13394334706750485, 'max_depth': 9, 'num_leaves': 77, 'feature_fraction': 0.608233797718321, 'bagging_fraction': 0.9879639408647978}. Best is trial 1 with value: 0.7703381864488373.
# [I 2025-05-16 18:55:45,303] Trial 2 finished with value: 0.7577264365369574 and parameters: {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 18:56:22,714] Trial 3 finished with value: 0.7621588364488112 and parameters: {'n_estimators': 500, 'learning_rate': 0.023927528765580644, 'max_depth': 9, 'num_leaves': 31, 'feature_fraction': 0.7168578594140873, 'bagging_fraction': 0.7465447373174767}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 18:56:41,281] Trial 4 finished with value: 0.7663504903657676 and parameters: {'n_estimators': 500, 'learning_rate': 0.10508421338691762, 'max_depth': 4, 'num_leaves': 61, 'feature_fraction': 0.836965827544817, 'bagging_fraction': 0.6185801650879991}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 18:57:11,042] Trial 5 finished with value: 0.7600176339217091 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'num_leaves': 96, 'feature_fraction': 0.9862528132298237, 'bagging_fraction': 0.9233589392465844}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 18:57:54,313] Trial 6 finished with value: 0.7859242500845575 and parameters: {'n_estimators': 400, 'learning_rate': 0.013399060561509796, 'max_depth': 9, 'num_leaves': 55, 'feature_fraction': 0.6488152939379115, 'bagging_fraction': 0.798070764044508}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 18:58:01,698] Trial 7 finished with value: 0.7589228600904359 and parameters: {'n_estimators': 100, 'learning_rate': 0.15242391728466367, 'max_depth': 5, 'num_leaves': 73, 'feature_fraction': 0.7246844304357644, 'bagging_fraction': 0.8080272084711243}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 18:59:35,789] Trial 8 finished with value: 0.768344628926657 and parameters: {'n_estimators': 600, 'learning_rate': 0.017398074711291726, 'max_depth': 12, 'num_leaves': 82, 'feature_fraction': 0.9757995766256756, 'bagging_fraction': 0.9579309401710595}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 18:59:50,396] Trial 9 finished with value: 0.7673609160460957 and parameters: {'n_estimators': 600, 'learning_rate': 0.15826541904647565, 'max_depth': 3, 'num_leaves': 35, 'feature_fraction': 0.6180909155642152, 'bagging_fraction': 0.7301321323053057}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:00:37,804] Trial 10 finished with value: 0.7690584405781429 and parameters: {'n_estimators': 1000, 'learning_rate': 0.041286972973122775, 'max_depth': 6, 'num_leaves': 21, 'feature_fraction': 0.8423486893732017, 'bagging_fraction': 0.876098829427658}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:01:23,291] Trial 11 finished with value: 0.7759065484272357 and parameters: {'n_estimators': 1000, 'learning_rate': 0.06761147179060022, 'max_depth': 6, 'num_leaves': 48, 'feature_fraction': 0.759327832364161, 'bagging_fraction': 0.8469817891972083}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:01:32,275] Trial 12 finished with value: 0.8448072324974616 and parameters: {'n_estimators': 100, 'learning_rate': 0.03448509229937973, 'max_depth': 5, 'num_leaves': 45, 'feature_fraction': 0.7389917503278137, 'bagging_fraction': 0.7957386374412774}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:02:17,896] Trial 13 finished with value: 0.7789394539044296 and parameters: {'n_estimators': 800, 'learning_rate': 0.06922749265952521, 'max_depth': 7, 'num_leaves': 91, 'feature_fraction': 0.7874820875551369, 'bagging_fraction': 0.8630011610888938}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:02:32,652] Trial 14 finished with value: 0.960433026574368 and parameters: {'n_estimators': 200, 'learning_rate': 0.011058500546306225, 'max_depth': 5, 'num_leaves': 72, 'feature_fraction': 0.6975499843454273, 'bagging_fraction': 0.727828023050229}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:03:01,868] Trial 15 finished with value: 0.7656136762858305 and parameters: {'n_estimators': 800, 'learning_rate': 0.06294173699450725, 'max_depth': 4, 'num_leaves': 39, 'feature_fraction': 0.8762695696311745, 'bagging_fraction': 0.8108076649175742}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:03:36,762] Trial 16 finished with value: 0.7625820206633867 and parameters: {'n_estimators': 300, 'learning_rate': 0.02981229465853, 'max_depth': 7, 'num_leaves': 58, 'feature_fraction': 0.9110846414027765, 'bagging_fraction': 0.9006453699263156}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:04:08,282] Trial 17 finished with value: 0.7760299963991717 and parameters: {'n_estimators': 900, 'learning_rate': 0.09514304141838337, 'max_depth': 5, 'num_leaves': 85, 'feature_fraction': 0.6772876502180768, 'bagging_fraction': 0.765354826674926}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:04:24,660] Trial 18 finished with value: 0.7727473350974954 and parameters: {'n_estimators': 300, 'learning_rate': 0.02154636144117931, 'max_depth': 4, 'num_leaves': 65, 'feature_fraction': 0.7839069453230693, 'bagging_fraction': 0.6735390759594541}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:04:57,683] Trial 19 finished with value: 0.7678990605752668 and parameters: {'n_estimators': 700, 'learning_rate': 0.049212596873501845, 'max_depth': 6, 'num_leaves': 22, 'feature_fraction': 0.737415887737509, 'bagging_fraction': 0.8307796695558712}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:05:22,681] Trial 20 finished with value: 0.7689993974046476 and parameters: {'n_estimators': 900, 'learning_rate': 0.11178113803323297, 'max_depth': 3, 'num_leaves': 51, 'feature_fraction': 0.8343872902276027, 'bagging_fraction': 0.690165187143056}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:05:52,648] Trial 21 finished with value: 0.7596454220495994 and parameters: {'n_estimators': 700, 'learning_rate': 0.016960359675882164, 'max_depth': 3, 'num_leaves': 97, 'feature_fraction': 0.999433404153256, 'bagging_fraction': 0.9214349579584764}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:06:28,233] Trial 22 finished with value: 0.7584999887558724 and parameters: {'n_estimators': 800, 'learning_rate': 0.023590055403627994, 'max_depth': 4, 'num_leaves': 94, 'feature_fraction': 0.9329040053459869, 'bagging_fraction': 0.9223669533420212}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:07:15,480] Trial 23 finished with value: 0.7599907187793691 and parameters: {'n_estimators': 900, 'learning_rate': 0.024520096439092087, 'max_depth': 5, 'num_leaves': 88, 'feature_fraction': 0.9298528902087924, 'bagging_fraction': 0.779456275831762}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:07:45,568] Trial 24 finished with value: 0.7592493935123287 and parameters: {'n_estimators': 800, 'learning_rate': 0.030662551901074194, 'max_depth': 4, 'num_leaves': 76, 'feature_fraction': 0.7597657415901483, 'bagging_fraction': 0.9923490226463897}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:09:05,204] Trial 25 finished with value: 0.7602605703003518 and parameters: {'n_estimators': 1000, 'learning_rate': 0.010094219347431287, 'max_depth': 6, 'num_leaves': 99, 'feature_fraction': 0.8069410260856267, 'bagging_fraction': 0.8873473103266313}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:09:31,791] Trial 26 finished with value: 0.7623437528820685 and parameters: {'n_estimators': 800, 'learning_rate': 0.05072321648466125, 'max_depth': 4, 'num_leaves': 80, 'feature_fraction': 0.7049681190836985, 'bagging_fraction': 0.8365295293478016}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:11:19,369] Trial 27 finished with value: 0.7651848193650164 and parameters: {'n_estimators': 900, 'learning_rate': 0.013210182324154208, 'max_depth': 8, 'num_leaves': 92, 'feature_fraction': 0.8928378866779805, 'bagging_fraction': 0.9507908458105159}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:11:36,909] Trial 28 finished with value: 0.8104622287089184 and parameters: {'n_estimators': 200, 'learning_rate': 0.02024039140249267, 'max_depth': 5, 'num_leaves': 28, 'feature_fraction': 0.9369398214163245, 'bagging_fraction': 0.816555961260595}. Best is trial 2 with value: 0.7577264365369574.
# [I 2025-05-16 19:12:08,637] Trial 29 finished with value: 0.7923753328668408 and parameters: {'n_estimators': 400, 'learning_rate': 0.19848978742652873, 'max_depth': 12, 'num_leaves': 69, 'feature_fraction': 0.6657374610104676, 'bagging_fraction': 0.7078517802470756}. Best is trial 2 with value: 0.7577264365369574.
# === Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===
# {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}
# 10-Fold Mean MAE = 0.7577
