# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import random
import numpy as np
import torch


# 固定随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # for multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)  # 设置固定种子

# %%
import os

import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import optuna
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# ----------------- CONFIGURATION -----------------
n_folds    = 10
n_trials   = 30
data_dir   = "./k_folds_model/embeddings"
batch_size = 256
num_epochs = 200
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------- MODEL DEFINITION -----------------
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        layers = []
        prev_dim = input_dim
        act = {
            'relu':     nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh':     nn.Tanh()
        }[activation]
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act]
            prev_dim = h
        layers.append(nn.Linear(prev_dim, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = self.net(x).squeeze(-1)
        return F.softplus(x)  # 输出 > 0

# ----------------- OPTUNA OBJECTIVE -----------------
def objective(trial):
    hidden_sizes      = trial.suggest_categorical('hidden_layer_sizes',
                            [(50,), (100,), (150,), (100, 50), (150, 100, 50)])
    activation        = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh'])
    lr                = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    weight_decay      = trial.suggest_float('alpha', 1e-5, 1e-2, log=True)
    optimizer_choice  = trial.suggest_categorical('optimizer', ['sgd', 'adam'])

    fold_maes = []

    for fold in range(1, n_folds + 1):
        X_train = np.load(f"{data_dir}/train_fold_{fold}.npy")
        y_train = np.load(f"{data_dir}/train_labels_fold_{fold}.npy")
        X_val   = np.load(f"{data_dir}/val_fold_{fold}.npy")
        y_val   = np.load(f"{data_dir}/val_labels_fold_{fold}.npy")

        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val   = scaler.transform(X_val)

        train_ds = TensorDataset(torch.from_numpy(X_train).float(),
                                 torch.from_numpy(y_train).float())
        val_ds = TensorDataset(torch.from_numpy(X_val).float(),
                               torch.from_numpy(y_val).float())
        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        model = MLP(input_dim=X_train.shape[1],
                    hidden_sizes=hidden_sizes,
                    activation=activation).to(device)
        criterion = nn.MSELoss()
        optimizer = {
            'sgd': torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay),
            'adam': torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        }[optimizer_choice]

        try:
            for epoch in range(num_epochs):
                model.train()
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    preds = model(xb)
                    loss = criterion(preds, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            all_preds = []
            with torch.no_grad():
                for xb, _ in val_loader:
                    xb = xb.to(device)
                    batch_pred = model(xb).cpu().numpy()
                    all_preds.append(batch_pred)
            all_preds = np.concatenate(all_preds)

            mae = mean_absolute_error(y_val, all_preds)
            fold_maes.append(mae)

        except Exception:
            return np.inf

    return float(np.mean(fold_maes))

# ----------------- RUN OPTUNA -----------------
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)

    print("\n=== Best Hyperparameters ===")
    print(study.best_params)
    print(f"Best Mean MAE: {study.best_value:.4f}")
# Out:
# [I 2025-05-18 10:15:55,207] A new study created in memory with name: no-name-970bc7bd-8f13-4ef5-9b85-836683ba8ce3
# [I 2025-05-18 10:24:08,875] Trial 0 finished with value: 0.6461864113807678 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.0015930522616241021, 'alpha': 0.001331121608073689, 'optimizer': 'adam'}. Best is trial 0 with value: 0.6461864113807678.
# [I 2025-05-18 10:32:27,033] Trial 1 finished with value: 0.6321486234664917 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0016738085788752138, 'alpha': 2.621087878265438e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 10:40:08,076] Trial 2 finished with value: 0.7433528304100037 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00013492834268013249, 'alpha': 0.007025166339242158, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 10:48:26,963] Trial 3 finished with value: 0.63221275806427 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00032927591344236165, 'alpha': 0.0009717775305059633, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 10:56:45,963] Trial 4 finished with value: 0.6346284747123718 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00015030900645056822, 'alpha': 3.872118032174584e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 11:03:58,903] Trial 5 finished with value: 0.6535571217536926 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00014096175149815865, 'alpha': 0.009133995846860976, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 11:11:08,407] Trial 6 finished with value: 0.6533529162406921 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.005323617594751502, 'alpha': 0.0007411299781083245, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 11:19:16,898] Trial 7 finished with value: 0.6404980421066284 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0033233042062267943, 'alpha': 0.00048287152161792117, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 11:27:01,204] Trial 8 finished with value: 0.7604507803916931 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.006533305220227739, 'alpha': 5.59598687800608e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 11:35:13,549] Trial 9 finished with value: 0.6548281311988831 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.004048966222584676, 'alpha': 3.6283583803549155e-05, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 11:43:34,398] Trial 10 finished with value: 0.6366621851921082 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0007543742609082392, 'alpha': 1.1321021804230373e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 11:51:18,311] Trial 11 finished with value: 0.6343563795089722 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.00044742474159205944, 'alpha': 0.00014323501853214898, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 11:59:04,584] Trial 12 finished with value: 0.6465816497802734 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.00037299981541424096, 'alpha': 0.0026610627497018185, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 12:06:49,295] Trial 13 finished with value: 0.6345210671424866 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0015638768604166154, 'alpha': 0.0001597542678081087, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 12:15:08,384] Trial 14 finished with value: 0.6341606378555298 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.0003335702943784386, 'alpha': 1.3793595835333514e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 12:22:56,179] Trial 15 finished with value: 0.6395391225814819 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0008476798466510087, 'alpha': 0.00018481808409566043, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 12:30:42,961] Trial 16 finished with value: 0.6422162652015686 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0020708264689518023, 'alpha': 0.0020483979604209125, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6321486234664917.
# [I 2025-05-18 12:38:29,501] Trial 17 finished with value: 0.6300029158592224 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.000246630356777206, 'alpha': 0.0003388354529043932, 'optimizer': 'adam'}. Best is trial 17 with value: 0.6300029158592224.
# [I 2025-05-18 12:46:12,709] Trial 18 finished with value: 0.635185182094574 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.000604073691234022, 'alpha': 7.633519183320513e-05, 'optimizer': 'adam'}. Best is trial 17 with value: 0.6300029158592224.
# [I 2025-05-18 12:54:29,995] Trial 19 finished with value: 0.6358819603919983 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00021683283978983164, 'alpha': 0.0002869928717181293, 'optimizer': 'adam'}. Best is trial 17 with value: 0.6300029158592224.
# [I 2025-05-18 13:03:18,635] Trial 20 finished with value: 1.3577698469161987 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'learning_rate': 0.009808647884075292, 'alpha': 0.0004102634703435194, 'optimizer': 'adam'}. Best is trial 17 with value: 0.6300029158592224.
# [I 2025-05-18 13:10:59,298] Trial 21 finished with value: 0.6335037350654602 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.0002616242015563841, 'alpha': 0.0009589539171042828, 'optimizer': 'adam'}. Best is trial 17 with value: 0.6300029158592224.
# [I 2025-05-18 13:18:36,724] Trial 22 finished with value: 0.6345344185829163 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0005209314402340293, 'alpha': 0.0006292470958757622, 'optimizer': 'adam'}. Best is trial 17 with value: 0.6300029158592224.
# [I 2025-05-18 13:26:13,570] Trial 23 finished with value: 0.654636025428772 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'logistic', 'learning_rate': 0.0013312836442206395, 'alpha': 0.0024413628451599415, 'optimizer': 'adam'}. Best is trial 17 with value: 0.6300029158592224.
# [I 2025-05-18 13:33:51,793] Trial 24 finished with value: 0.63765549659729 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.00022504504926531763, 'alpha': 0.00027467893632616817, 'optimizer': 'adam'}. Best is trial 17 with value: 0.6300029158592224.
# [I 2025-05-18 13:41:28,270] Trial 25 finished with value: 0.6446548104286194 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'learning_rate': 0.0027310723570995875, 'alpha': 1.9775900430007732e-05, 'optimizer': 'adam'}. Best is trial 17 with value: 0.6300029158592224.
# [I 2025-05-18 13:49:08,082] Trial 26 finished with value: 0.6414340734481812 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.00010580637504288371, 'alpha': 0.0043501315223943935, 'optimizer': 'adam'}. Best is trial 17 with value: 0.6300029158592224.
# [I 2025-05-18 13:56:20,819] Trial 27 finished with value: 0.6542728543281555 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.0010339786108632357, 'alpha': 8.83483993087177e-05, 'optimizer': 'sgd'}. Best is trial 17 with value: 0.6300029158592224.
# [I 2025-05-18 14:04:02,435] Trial 28 finished with value: 0.637916088104248 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'learning_rate': 0.00031750846525708816, 'alpha': 0.0012489252055172032, 'optimizer': 'adam'}. Best is trial 17 with value: 0.6300029158592224.
# [I 2025-05-18 14:11:43,149] Trial 29 finished with value: 0.6512578129768372 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.0012037048051913354, 'alpha': 0.0014130490232818751, 'optimizer': 'adam'}. Best is trial 17 with value: 0.6300029158592224.
# === Best Hyperparameters ===
# {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.000246630356777206, 'alpha': 0.0003388354529043932, 'optimizer': 'adam'}
# Best Mean MAE: 0.6300

# %%
import os
import optuna
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    # 采样超参数
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        model = XGBRegressor(n_jobs=-1, verbosity=0, **params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 以 MAE 为优化目标


# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best XGBoost Hyperparameters via Optuna ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-17 20:13:19,704] A new study created in memory with name: no-name-7c4f9658-adb8-48ed-af56-7f1ca89f6013
# [I 2025-05-17 20:16:03,095] Trial 0 finished with value: 0.6146806478500366 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 8, 'subsample': 0.8795975452591109, 'colsample_bytree': 0.6624074561769746}. Best is trial 0 with value: 0.6146806478500366.
# [I 2025-05-17 20:19:23,018] Trial 1 finished with value: 0.6568997502326965 and parameters: {'n_estimators': 200, 'learning_rate': 0.011900590783184251, 'max_depth': 9, 'subsample': 0.8803345035229626, 'colsample_bytree': 0.8832290311184181}. Best is trial 0 with value: 0.6146806478500366.
# [I 2025-05-17 20:20:13,186] Trial 2 finished with value: 0.6145306825637817 and parameters: {'n_estimators': 100, 'learning_rate': 0.18276027831785724, 'max_depth': 8, 'subsample': 0.7637017332034828, 'colsample_bytree': 0.6727299868828402}. Best is trial 2 with value: 0.6145306825637817.
# [I 2025-05-17 20:21:39,867] Trial 3 finished with value: 0.6225680708885193 and parameters: {'n_estimators': 200, 'learning_rate': 0.024878734419814436, 'max_depth': 6, 'subsample': 0.8295835055926347, 'colsample_bytree': 0.7164916560792167}. Best is trial 2 with value: 0.6145306825637817.
# [I 2025-05-17 20:25:03,477] Trial 4 finished with value: 0.6199666261672974 and parameters: {'n_estimators': 700, 'learning_rate': 0.01518747922672247, 'max_depth': 5, 'subsample': 0.8099085529881075, 'colsample_bytree': 0.7824279936868144}. Best is trial 2 with value: 0.6145306825637817.
# [I 2025-05-17 20:29:15,952] Trial 5 finished with value: 0.6174415349960327 and parameters: {'n_estimators': 800, 'learning_rate': 0.018187859051288217, 'max_depth': 6, 'subsample': 0.8777243706586128, 'colsample_bytree': 0.6185801650879991}. Best is trial 2 with value: 0.6145306825637817.
# [I 2025-05-17 20:31:30,029] Trial 6 finished with value: 0.6260048151016235 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'subsample': 0.984665661176, 'colsample_bytree': 0.9862528132298237}. Best is trial 2 with value: 0.6145306825637817.
# [I 2025-05-17 20:34:07,100] Trial 7 finished with value: 0.6229755282402039 and parameters: {'n_estimators': 900, 'learning_rate': 0.0249064396938244, 'max_depth': 3, 'subsample': 0.905269907953647, 'colsample_bytree': 0.7760609974958406}. Best is trial 2 with value: 0.6145306825637817.
# [I 2025-05-17 20:34:48,299] Trial 8 finished with value: 0.6274216175079346 and parameters: {'n_estimators': 200, 'learning_rate': 0.04407984038169244, 'max_depth': 3, 'subsample': 0.9727961206236346, 'colsample_bytree': 0.7035119926400067}. Best is trial 2 with value: 0.6145306825637817.
# [I 2025-05-17 20:38:26,129] Trial 9 finished with value: 0.616507887840271 and parameters: {'n_estimators': 700, 'learning_rate': 0.02544166090938368, 'max_depth': 6, 'subsample': 0.8640130838029838, 'colsample_bytree': 0.6739417822102108}. Best is trial 2 with value: 0.6145306825637817.
# [I 2025-05-17 20:41:32,890] Trial 10 finished with value: 0.6169224381446838 and parameters: {'n_estimators': 400, 'learning_rate': 0.16348976180438474, 'max_depth': 8, 'subsample': 0.7088816251071088, 'colsample_bytree': 0.8607466203112714}. Best is trial 2 with value: 0.6145306825637817.
# [I 2025-05-17 20:44:24,958] Trial 11 finished with value: 0.6206346750259399 and parameters: {'n_estimators': 400, 'learning_rate': 0.1924287005865255, 'max_depth': 8, 'subsample': 0.7539498451855433, 'colsample_bytree': 0.6030122553146291}. Best is trial 2 with value: 0.6145306825637817.
# [I 2025-05-17 20:47:16,176] Trial 12 finished with value: 0.6158305406570435 and parameters: {'n_estimators': 400, 'learning_rate': 0.10214870595042393, 'max_depth': 8, 'subsample': 0.785056912410558, 'colsample_bytree': 0.6630805404110562}. Best is trial 2 with value: 0.6145306825637817.
# [I 2025-05-17 20:48:30,821] Trial 13 finished with value: 0.6127041578292847 and parameters: {'n_estimators': 100, 'learning_rate': 0.07898927623865826, 'max_depth': 9, 'subsample': 0.9361665076233798, 'colsample_bytree': 0.7372114918378742}. Best is trial 13 with value: 0.6127041578292847.
# [I 2025-05-17 20:49:45,340] Trial 14 finished with value: 0.6136549711227417 and parameters: {'n_estimators': 100, 'learning_rate': 0.07890559538527207, 'max_depth': 9, 'subsample': 0.9368431198958393, 'colsample_bytree': 0.7390533721986331}. Best is trial 13 with value: 0.6127041578292847.
# [I 2025-05-17 20:51:03,733] Trial 15 finished with value: 0.6122262477874756 and parameters: {'n_estimators': 100, 'learning_rate': 0.07139691708827019, 'max_depth': 9, 'subsample': 0.9540988370165996, 'colsample_bytree': 0.7462381324313869}. Best is trial 15 with value: 0.6122262477874756.
# [I 2025-05-17 20:53:48,024] Trial 16 finished with value: 0.606808066368103 and parameters: {'n_estimators': 300, 'learning_rate': 0.06462118968257823, 'max_depth': 9, 'subsample': 0.9385529941067923, 'colsample_bytree': 0.8229872676790884}. Best is trial 16 with value: 0.606808066368103.
# [I 2025-05-17 20:55:47,728] Trial 17 finished with value: 0.6151589155197144 and parameters: {'n_estimators': 300, 'learning_rate': 0.04735007586769925, 'max_depth': 7, 'subsample': 0.9424198103341492, 'colsample_bytree': 0.8476252531965371}. Best is trial 16 with value: 0.606808066368103.
# [I 2025-05-17 20:58:48,758] Trial 18 finished with value: 0.6116976141929626 and parameters: {'n_estimators': 500, 'learning_rate': 0.04909172524476062, 'max_depth': 7, 'subsample': 0.9965442091065285, 'colsample_bytree': 0.9281889012746769}. Best is trial 16 with value: 0.606808066368103.
# [I 2025-05-17 21:01:24,706] Trial 19 finished with value: 0.6162487268447876 and parameters: {'n_estimators': 600, 'learning_rate': 0.050367186389949796, 'max_depth': 5, 'subsample': 0.9826799998934048, 'colsample_bytree': 0.9364434206636546}. Best is trial 16 with value: 0.606808066368103.
# [I 2025-05-17 21:04:38,785] Trial 20 finished with value: 0.6139322519302368 and parameters: {'n_estimators': 500, 'learning_rate': 0.03393934330736704, 'max_depth': 7, 'subsample': 0.9104283464964039, 'colsample_bytree': 0.9139687153925942}. Best is trial 16 with value: 0.606808066368103.
# [I 2025-05-17 21:06:27,107] Trial 21 finished with value: 0.6135831475257874 and parameters: {'n_estimators': 300, 'learning_rate': 0.07774496045778508, 'max_depth': 7, 'subsample': 0.9581107680242466, 'colsample_bytree': 0.8149231637213306}. Best is trial 16 with value: 0.606808066368103.
# [I 2025-05-17 21:10:45,760] Trial 22 finished with value: 0.6054092049598694 and parameters: {'n_estimators': 500, 'learning_rate': 0.05979968743356431, 'max_depth': 9, 'subsample': 0.9934768410124981, 'colsample_bytree': 0.9800162565445346}. Best is trial 22 with value: 0.6054092049598694.
# [I 2025-05-17 21:14:40,504] Trial 23 finished with value: 0.6063835620880127 and parameters: {'n_estimators': 500, 'learning_rate': 0.12037691667562572, 'max_depth': 9, 'subsample': 0.9997780398553425, 'colsample_bytree': 0.9887951858661111}. Best is trial 22 with value: 0.6054092049598694.
# [I 2025-05-17 21:19:58,811] Trial 24 finished with value: 0.6077645421028137 and parameters: {'n_estimators': 600, 'learning_rate': 0.12321285914917385, 'max_depth': 9, 'subsample': 0.9108231671996795, 'colsample_bytree': 0.9945577898356083}. Best is trial 22 with value: 0.6054092049598694.
# [I 2025-05-17 21:27:30,548] Trial 25 finished with value: 0.602581799030304 and parameters: {'n_estimators': 1000, 'learning_rate': 0.11631379477381698, 'max_depth': 9, 'subsample': 0.9984049548909061, 'colsample_bytree': 0.958942788663857}. Best is trial 25 with value: 0.602581799030304.
# [I 2025-05-17 21:36:35,970] Trial 26 finished with value: 0.6076729893684387 and parameters: {'n_estimators': 1000, 'learning_rate': 0.12265546910455541, 'max_depth': 8, 'subsample': 0.9687406177706662, 'colsample_bytree': 0.9631876104442124}. Best is trial 25 with value: 0.602581799030304.
# [I 2025-05-17 21:45:48,671] Trial 27 finished with value: 0.6202059388160706 and parameters: {'n_estimators': 1000, 'learning_rate': 0.1043090623445081, 'max_depth': 4, 'subsample': 0.9998302567001737, 'colsample_bytree': 0.9592737954667538}. Best is trial 25 with value: 0.602581799030304.
# [I 2025-05-17 21:57:04,083] Trial 28 finished with value: 0.6068497896194458 and parameters: {'n_estimators': 800, 'learning_rate': 0.14789994776764576, 'max_depth': 9, 'subsample': 0.9955042753546609, 'colsample_bytree': 0.9035509865706368}. Best is trial 25 with value: 0.602581799030304.
# [I 2025-05-17 22:00:35,348] Trial 29 finished with value: 0.6050949692726135 and parameters: {'n_estimators': 500, 'learning_rate': 0.09439532626949458, 'max_depth': 8, 'subsample': 0.964429647248459, 'colsample_bytree': 0.9488356644498858}. Best is trial 25 with value: 0.602581799030304.
# === Best XGBoost Hyperparameters via Optuna ===
# {'n_estimators': 1000, 'learning_rate': 0.11631379477381698, 'max_depth': 9, 'subsample': 0.9984049548909061, 'colsample_bytree': 0.958942788663857}
# 10-Fold Mean MAE = 0.6026

# %%
import os
import optuna
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'objective': 'poisson',         # ✅ 强制正输出
        'n_jobs': -1,
        'verbose': -1
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        # Poisson 回归要求标签必须大于 0
        if np.any(y_train <= 0) or np.any(y_val <= 0):
            return np.inf

        model = LGBMRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 使用 MAE 作为优化目标

# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-18 10:16:07,453] A new study created in memory with name: no-name-8ba62cc9-6704-42dd-81af-259aa5b085ed
# [I 2025-05-18 10:17:13,661] Trial 0 finished with value: 0.6067302212561918 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 10, 'num_leaves': 68, 'feature_fraction': 0.6624074561769746, 'bagging_fraction': 0.662397808134481}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:17:39,109] Trial 1 finished with value: 0.6153237151879505 and parameters: {'n_estimators': 100, 'learning_rate': 0.13394334706750485, 'max_depth': 9, 'num_leaves': 77, 'feature_fraction': 0.608233797718321, 'bagging_fraction': 0.9879639408647978}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:18:59,177] Trial 2 finished with value: 0.6242226002607142 and parameters: {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:20:17,515] Trial 3 finished with value: 0.6205451043990008 and parameters: {'n_estimators': 500, 'learning_rate': 0.023927528765580644, 'max_depth': 9, 'num_leaves': 31, 'feature_fraction': 0.7168578594140873, 'bagging_fraction': 0.7465447373174767}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:21:00,540] Trial 4 finished with value: 0.6173789691430771 and parameters: {'n_estimators': 500, 'learning_rate': 0.10508421338691762, 'max_depth': 4, 'num_leaves': 61, 'feature_fraction': 0.836965827544817, 'bagging_fraction': 0.6185801650879991}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:22:17,311] Trial 5 finished with value: 0.6351506196673959 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'num_leaves': 96, 'feature_fraction': 0.9862528132298237, 'bagging_fraction': 0.9233589392465844}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:23:44,488] Trial 6 finished with value: 0.6564226036185788 and parameters: {'n_estimators': 400, 'learning_rate': 0.013399060561509796, 'max_depth': 9, 'num_leaves': 55, 'feature_fraction': 0.6488152939379115, 'bagging_fraction': 0.798070764044508}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:24:03,018] Trial 7 finished with value: 0.6213693147422081 and parameters: {'n_estimators': 100, 'learning_rate': 0.15242391728466367, 'max_depth': 5, 'num_leaves': 73, 'feature_fraction': 0.7246844304357644, 'bagging_fraction': 0.8080272084711243}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:27:03,684] Trial 8 finished with value: 0.6156386172653184 and parameters: {'n_estimators': 600, 'learning_rate': 0.017398074711291726, 'max_depth': 12, 'num_leaves': 82, 'feature_fraction': 0.9757995766256756, 'bagging_fraction': 0.9579309401710595}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:27:38,225] Trial 9 finished with value: 0.620578509931663 and parameters: {'n_estimators': 600, 'learning_rate': 0.15826541904647565, 'max_depth': 3, 'num_leaves': 35, 'feature_fraction': 0.6180909155642152, 'bagging_fraction': 0.7301321323053057}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:28:41,301] Trial 10 finished with value: 0.6143824251008935 and parameters: {'n_estimators': 300, 'learning_rate': 0.053343533692271884, 'max_depth': 12, 'num_leaves': 50, 'feature_fraction': 0.8560354009870226, 'bagging_fraction': 0.6154900799844731}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:29:41,487] Trial 11 finished with value: 0.6124064554565869 and parameters: {'n_estimators': 300, 'learning_rate': 0.06485618348127573, 'max_depth': 12, 'num_leaves': 50, 'feature_fraction': 0.8690317996453045, 'bagging_fraction': 0.6036909492513651}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:30:40,396] Trial 12 finished with value: 0.6130457361882644 and parameters: {'n_estimators': 300, 'learning_rate': 0.06671560659504719, 'max_depth': 11, 'num_leaves': 46, 'feature_fraction': 0.9122818026480826, 'bagging_fraction': 0.6727772199560298}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:31:56,504] Trial 13 finished with value: 0.6195314839585973 and parameters: {'n_estimators': 300, 'learning_rate': 0.03193535039712928, 'max_depth': 10, 'num_leaves': 67, 'feature_fraction': 0.7874820875551369, 'bagging_fraction': 0.6680633496871942}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:33:21,418] Trial 14 finished with value: 0.6096391797446801 and parameters: {'n_estimators': 800, 'learning_rate': 0.08205075446114399, 'max_depth': 7, 'num_leaves': 87, 'feature_fraction': 0.7910204473093045, 'bagging_fraction': 0.6012585093919083}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:34:57,784] Trial 15 finished with value: 0.6077699786340027 and parameters: {'n_estimators': 1000, 'learning_rate': 0.088432899799542, 'max_depth': 7, 'num_leaves': 90, 'feature_fraction': 0.7660493707377272, 'bagging_fraction': 0.689589490361874}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:36:25,811] Trial 16 finished with value: 0.6083818713378121 and parameters: {'n_estimators': 1000, 'learning_rate': 0.10106650620464261, 'max_depth': 7, 'num_leaves': 100, 'feature_fraction': 0.6758999353054022, 'bagging_fraction': 0.6939618982898758}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:37:39,318] Trial 17 finished with value: 0.6088465550394013 and parameters: {'n_estimators': 1000, 'learning_rate': 0.19232657370549136, 'max_depth': 6, 'num_leaves': 89, 'feature_fraction': 0.6772876502180768, 'bagging_fraction': 0.7444775143909506}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:39:20,595] Trial 18 finished with value: 0.6120179527528182 and parameters: {'n_estimators': 700, 'learning_rate': 0.03833314717042216, 'max_depth': 8, 'num_leaves': 68, 'feature_fraction': 0.7530729379429902, 'bagging_fraction': 0.8628432231923119}. Best is trial 0 with value: 0.6067302212561918.
# [I 2025-05-18 10:40:58,075] Trial 19 finished with value: 0.604447544356801 and parameters: {'n_estimators': 800, 'learning_rate': 0.11015595740688355, 'max_depth': 10, 'num_leaves': 87, 'feature_fraction': 0.7542634747230326, 'bagging_fraction': 0.7043117425385296}. Best is trial 19 with value: 0.604447544356801.
# [I 2025-05-18 10:42:23,205] Trial 20 finished with value: 0.6051698303478112 and parameters: {'n_estimators': 800, 'learning_rate': 0.19531736613757855, 'max_depth': 10, 'num_leaves': 80, 'feature_fraction': 0.6858954195507433, 'bagging_fraction': 0.6494433806468152}. Best is trial 19 with value: 0.604447544356801.
# [I 2025-05-18 10:43:47,646] Trial 21 finished with value: 0.6045747703139679 and parameters: {'n_estimators': 800, 'learning_rate': 0.1818743004089775, 'max_depth': 10, 'num_leaves': 79, 'feature_fraction': 0.6701310463624248, 'bagging_fraction': 0.657739154463979}. Best is trial 19 with value: 0.604447544356801.
# [I 2025-05-18 10:45:19,151] Trial 22 finished with value: 0.6051814421838905 and parameters: {'n_estimators': 800, 'learning_rate': 0.12085678289752427, 'max_depth': 10, 'num_leaves': 80, 'feature_fraction': 0.7006158895369182, 'bagging_fraction': 0.6392681258596059}. Best is trial 19 with value: 0.604447544356801.
# [I 2025-05-18 10:46:46,307] Trial 23 finished with value: 0.6042352763375648 and parameters: {'n_estimators': 800, 'learning_rate': 0.1899922825441999, 'max_depth': 11, 'num_leaves': 84, 'feature_fraction': 0.63970112926069, 'bagging_fraction': 0.7116941712737317}. Best is trial 23 with value: 0.6042352763375648.
# [I 2025-05-18 10:48:25,538] Trial 24 finished with value: 0.603812072530665 and parameters: {'n_estimators': 900, 'learning_rate': 0.13094342686576566, 'max_depth': 11, 'num_leaves': 94, 'feature_fraction': 0.6238777908595249, 'bagging_fraction': 0.7137440747408894}. Best is trial 24 with value: 0.603812072530665.
# [I 2025-05-18 10:50:07,298] Trial 25 finished with value: 0.6050200096951317 and parameters: {'n_estimators': 900, 'learning_rate': 0.11632845351289002, 'max_depth': 11, 'num_leaves': 94, 'feature_fraction': 0.6216207952857727, 'bagging_fraction': 0.7147770181681148}. Best is trial 24 with value: 0.603812072530665.
# [I 2025-05-18 10:51:57,758] Trial 26 finished with value: 0.6052659286969622 and parameters: {'n_estimators': 900, 'learning_rate': 0.07723616920542306, 'max_depth': 11, 'num_leaves': 87, 'feature_fraction': 0.6372206838044818, 'bagging_fraction': 0.7636997461111724}. Best is trial 24 with value: 0.603812072530665.
# [I 2025-05-18 10:53:30,331] Trial 27 finished with value: 0.6041506038934948 and parameters: {'n_estimators': 700, 'learning_rate': 0.13064463924533823, 'max_depth': 11, 'num_leaves': 99, 'feature_fraction': 0.7526597646391255, 'bagging_fraction': 0.7819807295871029}. Best is trial 24 with value: 0.603812072530665.
# [I 2025-05-18 10:55:06,519] Trial 28 finished with value: 0.6036072749742385 and parameters: {'n_estimators': 700, 'learning_rate': 0.13826023188190403, 'max_depth': 11, 'num_leaves': 100, 'feature_fraction': 0.8285730836244073, 'bagging_fraction': 0.777798300562369}. Best is trial 28 with value: 0.6036072749742385.
# [I 2025-05-18 10:56:48,089] Trial 29 finished with value: 0.6096254834883111 and parameters: {'n_estimators': 700, 'learning_rate': 0.05069738180014875, 'max_depth': 8, 'num_leaves': 99, 'feature_fraction': 0.8168920604031373, 'bagging_fraction': 0.8672335505971374}. Best is trial 28 with value: 0.6036072749742385.
# === Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===
# {'n_estimators': 700, 'learning_rate': 0.13826023188190403, 'max_depth': 11, 'num_leaves': 100, 'feature_fraction': 0.8285730836244073, 'bagging_fraction': 0.777798300562369}
# 10-Fold Mean MAE = 0.6036
