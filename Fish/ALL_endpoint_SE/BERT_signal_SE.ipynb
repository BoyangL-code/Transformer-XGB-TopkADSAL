# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import random
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error
from transformers import RobertaTokenizer, RobertaModel
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from torch.utils.data import DataLoader, Subset
from scipy.stats import pearsonr
from tqdm import tqdm
from sklearn.exceptions import FitFailedWarning
import warnings
from sklearn.model_selection import ParameterSampler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import RandomizedSearchCV
import matplotlib.pyplot as plt
from scipy.stats import norm
import matplotlib
from sklearn.base import clone

# %%
data=pd.read_excel("./fish_unique.xlsx")
data=data.dropna()
smiles_data = data['SMILES_Canonical_RDKit'].tolist()
mgperL = data['mgperL'].values
Duration_Value= data['Duration_Value'].values

# %%
enpoint = data['endpoint'].tolist()

# %%
mgperL=np.log1p(mgperL)

# %%
# 检查需要One-Hot编码的列，并进行编码（如果类别超过一种）
def encode_column(data, column_name):
    unique_values = data[column_name].unique()
    if len(unique_values) > 1:
        encoder = OneHotEncoder(sparse_output=False)
        return encoder.fit_transform(data[[column_name]])
    else:
        return None  # 只有一种类别时忽略

# 编码 effect、endpoint 和 species_group 列
effect_encoded = encode_column(data, 'effect')
endpoint_encoded = encode_column(data, 'endpoint')
species_encoded = encode_column(data, 'species_group')

# 将需要的列拼接成输入 X
extra_features = data['Duration_Value'].values.reshape(-1, 1)

# 拼接编码后的列（如果存在）
for encoded_feature in [effect_encoded, endpoint_encoded, species_encoded]:
    if encoded_feature is not None:
        extra_features = np.hstack((extra_features, encoded_feature))

# %%
extra_features.shape
# Out:
# (26909, 10)

# %%
extra_dim = extra_features.shape[1]

# %%
extra_dim = extra_features.shape[1]
data_extra_features = extra_features

# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from transformers import BertTokenizerFast, BertModel
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
import optuna

# -------------------------------
# 1. 数据增强与 Dataset 修改：支持额外特征 extra_features
# -------------------------------
def augment_smiles(smiles):
    """简单的数据增强方法：50% 的概率翻转 SMILES 字符串"""
    if random.random() > 0.5:
        return smiles[::-1]
    return smiles

class SMILES_Dataset(Dataset):
    def __init__(self, smiles, reg_labels, extra_features=None, use_augmentation=False):
        self.smiles = smiles
        self.reg_labels = reg_labels
        self.extra_features = extra_features  # 额外特征，要求为数组或列表（每个元素是一个数值向量）
        self.use_augmentation = use_augmentation

    def __len__(self):
        return len(self.smiles)

    def __getitem__(self, idx):
        s = self.smiles[idx]
        if self.use_augmentation:
            s = augment_smiles(s)
        reg_label = self.reg_labels[idx]
        tokens = tokenizer(s, padding='max_length', truncation=True, max_length=128, return_tensors="pt")
        # squeeze 扁平化 batch 维度（例如变为 [seq_len]）
        tokens = {key: val.squeeze(0) for key, val in tokens.items()}
        if self.extra_features is not None:
            extra_feat = self.extra_features[idx]
            extra_feat = torch.tensor(extra_feat, dtype=torch.float32)
            return tokens, torch.tensor(reg_label, dtype=torch.float32), extra_feat
        else:
            return tokens, torch.tensor(reg_label, dtype=torch.float32)

# %%
# -------------------------------
# 2. 加载本地 BERT 模型（BERT for SMILES）
# -------------------------------
# 请将 checkpoint 指向你的本地模型目录（此处示例使用 'unikei/bert-base-smiles'）
checkpoint = '../models/base_bert'
tokenizer = BertTokenizerFast.from_pretrained(checkpoint)
bert_model = BertModel.from_pretrained(checkpoint)

# -------------------------------
# 3. 模型定义：BERT_Regression
# -------------------------------
class Bert_Regression(nn.Module):
    def __init__(self, dropout_rate, fc1_size, fc2_size, fc3_size, extra_dim=0):
        """
        :param extra_dim: 额外特征维度，如果为 0 则不拼接额外特征
        """
        super(Bert_Regression, self).__init__()
        self.bert = bert_model  # 使用加载好的 BERT 模型
        hidden_size = self.bert.config.hidden_size  # 通常为768
        self.extra_dim = extra_dim
        # 拼接后的维度
        input_dim = hidden_size + extra_dim
        self.regressor = nn.Sequential(
            nn.Linear(input_dim, fc1_size),
            nn.ReLU(),
            nn.BatchNorm1d(fc1_size),
            nn.Dropout(dropout_rate),
            nn.Linear(fc1_size, fc2_size),
            nn.ReLU(),
            nn.BatchNorm1d(fc2_size),
            nn.Dropout(dropout_rate),
            nn.Linear(fc2_size, fc3_size),
            nn.ReLU(),
            nn.BatchNorm1d(fc3_size),
            nn.Dropout(dropout_rate),
            nn.Linear(fc3_size, 1),
            nn.Softplus()
        )
    
    def forward(self, tokens, extra_features=None):
        outputs = self.bert(**tokens)
        cls_embedding = outputs.last_hidden_state[:, 0, :]  # [CLS] token 嵌入，形状 [batch_size, 768]
        if self.extra_dim > 0 and extra_features is not None:
            # 拼接额外特征，要求 extra_features 的形状为 [batch_size, extra_dim]
            x = torch.cat([cls_embedding, extra_features], dim=1)
        else:
            x = cls_embedding
        reg_output = self.regressor(x)
        return reg_output

# %%
data_smiles = smiles_data
data_labels = mgperL
endpoints = enpoint
# 使用 SMILES 作为组依据，确保同一 SMILES 不出现在不同折中

# 1. 创建 SMILES + Endpoint 的组合键
smiles_endpoint_combined = [f"{sm}_{ep}" for sm, ep in zip(data_smiles, endpoints)]
   

groups = smiles_endpoint_combined

# 如果数据量较大，可根据需要提前封装为 Dataset
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from torch.cuda.amp import autocast, GradScaler

# %%
import os
import pickle
import numpy as np
import optuna
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.model_selection import GroupKFold
from torch.utils.data import DataLoader
from tqdm import tqdm
import torch
import torch.optim as optim
from torch.cuda.amp import autocast, GradScaler

# 假设以下变量已定义：
# data_smiles, data_labels, data_extra_features, groups, device, extra_dim
# Bert_Regression, SMILES_Dataset

os.makedirs("./optuna_model_set_1", exist_ok=True)
os.makedirs("./optuna_model_set_2", exist_ok=True)

model_sets = ["./optuna_model_set_1", "./optuna_model_set_2"]
set_errors = [float('inf'), float('inf')]
model_save_counter = 0  # 控制保存路径的交替轮换

# =============== 超参数搜索目标函数 ================
def objective(trial):
    global model_save_counter, model_sets, set_errors

    dropout_rate  = trial.suggest_float('dropout_rate', 0.1, 0.5)
    fc1_size      = trial.suggest_int('fc1_size', 256, 1024, step=64)
    fc2_size      = trial.suggest_int('fc2_size', 128, 512, step=32)
    fc3_size      = trial.suggest_int('fc3_size', 64, 256, step=32)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 5e-5, log=True)
    weight_decay  = trial.suggest_float('weight_decay', 0.0, 0.1)


    
 
    # 2. 创建 GroupKFold 分组器
    gkf = GroupKFold(n_splits=10)
    fold_errors = []
    model_set_dir = model_sets[model_save_counter % 2]
    
    # 3. 进行分组划分
    for fold, (train_idx, val_idx) in enumerate(
        tqdm(gkf.split(data_smiles, data_labels, groups=smiles_endpoint_combined), total=10, desc=f"Trial {trial.number}")
    ):
        # 分出训练/验证 SMILES、标签、额外特征
        train_smiles = [data_smiles[i] for i in train_idx]
        val_smiles = [data_smiles[i] for i in val_idx]
        train_labels = [data_labels[i] for i in train_idx]
        val_labels = [data_labels[i] for i in val_idx]
        train_extra = data_extra_features[train_idx]
        val_extra = data_extra_features[val_idx]
    
        # 构建 Dataset 和 DataLoader
        train_dataset = SMILES_Dataset(train_smiles, train_labels, extra_features=train_extra)
        val_dataset = SMILES_Dataset(val_smiles, val_labels, extra_features=val_extra)
    
        train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True, drop_last=True, num_workers=8, pin_memory=True)
        val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False, num_workers=8, pin_memory=True)
    
        

        model = Bert_Regression(dropout_rate, fc1_size, fc2_size, fc3_size, extra_dim=extra_dim).to(device)
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        criterion = torch.nn.L1Loss()
        scaler = GradScaler()

        for epoch in range(30):
            model.train()
            for tokens, labels_tensor, extra_feats in train_loader:
                tokens = {k: v.to(device) for k, v in tokens.items()}
                extra_feats = extra_feats.to(device)
                labels_tensor = labels_tensor.to(device)

                optimizer.zero_grad()
                with autocast():
                    outputs = model(tokens, extra_feats)
                    loss = criterion(outputs.squeeze(), labels_tensor)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

        # 验证并保存模型
        model.eval()
        preds, targets = [], []
        with torch.no_grad():
            for tokens, labels_tensor, extra_feats in val_loader:
                tokens = {k: v.to(device) for k, v in tokens.items()}
                extra_feats = extra_feats.to(device)
                labels_tensor = labels_tensor.to(device)
                outputs = model(tokens, extra_feats)
                preds.extend(outputs.squeeze().cpu().numpy())
                targets.extend(labels_tensor.cpu().numpy())

        error = np.maximum(targets, preds) / np.minimum(targets, preds)
        median_error = np.median(error)
        fold_errors.append(median_error)

        torch.save(model.state_dict(), f"{model_set_dir}/bert_reg_fold_{fold+1}.pth")

    avg_median_error = np.mean(fold_errors)
    set_errors[model_save_counter % 2] = avg_median_error

    # 判断是否更新替换文件夹指针
    if set_errors[0] > set_errors[1]:
        model_save_counter = 0
    else:
        model_save_counter = 1

    return avg_median_error

# ================ 启动 Optuna 搜索 ===================
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=30)

# 输出结果
best_trial = study.best_trial
best_dir = model_sets[0] if set_errors[0] < set_errors[1] else model_sets[1]
print("Best hyperparameters:", best_trial.params)
print("Best model set directory:", best_dir)
print("Best cross-validated median error:", min(set_errors))
# Out:
# [I 2025-04-26 20:01:54,997] A new study created in memory with name: no-name-e6e8adbb-bd2a-4c1f-bf5e-55a643628a86
# Trial 0: 100%|██████████| 10/10 [1:58:49<00:00, 712.90s/it]
# [I 2025-04-26 22:00:44,047] Trial 0 finished with value: 1.732410192489624 and parameters: {'dropout_rate': 0.17019295085971298, 'fc1_size': 960, 'fc2_size': 512, 'fc3_size': 128, 'learning_rate': 1.6172920770372874e-05, 'weight_decay': 0.02361093177541226}. Best is trial 0 with value: 1.732410192489624.
# Trial 1: 100%|██████████| 10/10 [1:58:47<00:00, 712.75s/it]
# [I 2025-04-26 23:59:31,527] Trial 1 finished with value: 1.5325050354003906 and parameters: {'dropout_rate': 0.13225734408096723, 'fc1_size': 512, 'fc2_size': 128, 'fc3_size': 192, 'learning_rate': 1.7477566692630917e-05, 'weight_decay': 0.0019403558818067324}. Best is trial 1 with value: 1.5325050354003906.
# Trial 2: 100%|██████████| 10/10 [1:58:57<00:00, 713.80s/it]
# [I 2025-04-27 01:58:29,504] Trial 2 finished with value: 1.5831753015518188 and parameters: {'dropout_rate': 0.2855747171445435, 'fc1_size': 896, 'fc2_size': 512, 'fc3_size': 256, 'learning_rate': 2.6552034849188337e-05, 'weight_decay': 0.02246845172402552}. Best is trial 1 with value: 1.5325050354003906.
# Trial 3: 100%|██████████| 10/10 [1:58:53<00:00, 713.33s/it]
# [I 2025-04-27 03:57:22,789] Trial 3 finished with value: 1.7610137462615967 and parameters: {'dropout_rate': 0.24313253093730425, 'fc1_size': 256, 'fc2_size': 512, 'fc3_size': 224, 'learning_rate': 4.61031942799248e-05, 'weight_decay': 0.08385039310073605}. Best is trial 1 with value: 1.5325050354003906.
# Trial 4: 100%|██████████| 10/10 [1:58:51<00:00, 713.11s/it]
# [I 2025-04-27 05:56:13,912] Trial 4 finished with value: 1.6784671545028687 and parameters: {'dropout_rate': 0.12676696312296284, 'fc1_size': 320, 'fc2_size': 384, 'fc3_size': 64, 'learning_rate': 3.269945556392083e-05, 'weight_decay': 0.05158211462186429}. Best is trial 1 with value: 1.5325050354003906.
# Trial 5: 100%|██████████| 10/10 [1:58:52<00:00, 713.22s/it]
# [I 2025-04-27 07:55:06,079] Trial 5 finished with value: 1.641079306602478 and parameters: {'dropout_rate': 0.38301534236435464, 'fc1_size': 704, 'fc2_size': 448, 'fc3_size': 96, 'learning_rate': 1.9386996719638726e-05, 'weight_decay': 0.01721212518987978}. Best is trial 1 with value: 1.5325050354003906.
# Trial 6: 100%|██████████| 10/10 [1:58:53<00:00, 713.31s/it]
# [I 2025-04-27 09:53:59,204] Trial 6 finished with value: 1.6863508224487305 and parameters: {'dropout_rate': 0.4064138609312614, 'fc1_size': 448, 'fc2_size': 160, 'fc3_size': 192, 'learning_rate': 4.482735773609875e-05, 'weight_decay': 0.07638614396042234}. Best is trial 1 with value: 1.5325050354003906.
# Trial 7: 100%|██████████| 10/10 [1:58:57<00:00, 713.77s/it]
# [I 2025-04-27 11:52:56,874] Trial 7 finished with value: 1.598952054977417 and parameters: {'dropout_rate': 0.46141999501487774, 'fc1_size': 768, 'fc2_size': 416, 'fc3_size': 256, 'learning_rate': 4.876185680396453e-05, 'weight_decay': 0.02191007705071918}. Best is trial 1 with value: 1.5325050354003906.
# Trial 8: 100%|██████████| 10/10 [1:58:57<00:00, 713.74s/it]
# [I 2025-04-27 13:51:54,244] Trial 8 finished with value: 1.5770576000213623 and parameters: {'dropout_rate': 0.15315279067914137, 'fc1_size': 640, 'fc2_size': 192, 'fc3_size': 224, 'learning_rate': 4.406513782627468e-05, 'weight_decay': 0.027941899058956644}. Best is trial 1 with value: 1.5325050354003906.
# Trial 9: 100%|██████████| 10/10 [1:58:54<00:00, 713.45s/it]
# [I 2025-04-27 15:50:48,773] Trial 9 finished with value: 1.570908546447754 and parameters: {'dropout_rate': 0.4300216288219606, 'fc1_size': 576, 'fc2_size': 256, 'fc3_size': 256, 'learning_rate': 1.445452659935777e-05, 'weight_decay': 0.062865724931661}. Best is trial 1 with value: 1.5325050354003906.
# Trial 10: 100%|██████████| 10/10 [1:59:09<00:00, 714.93s/it]
# [I 2025-04-27 17:49:58,157] Trial 10 finished with value: 1.5796821117401123 and parameters: {'dropout_rate': 0.21505219389834296, 'fc1_size': 512, 'fc2_size': 128, 'fc3_size': 160, 'learning_rate': 1.2108707036276203e-05, 'weight_decay': 0.00337241300435296}. Best is trial 1 with value: 1.5325050354003906.
# Trial 11: 100%|██████████| 10/10 [1:59:37<00:00, 717.75s/it]
# [I 2025-04-27 19:49:35,665] Trial 11 finished with value: 1.5881308317184448 and parameters: {'dropout_rate': 0.343689252241428, 'fc1_size': 512, 'fc2_size': 256, 'fc3_size': 192, 'learning_rate': 1.0515735201593464e-05, 'weight_decay': 0.0578402543184159}. Best is trial 1 with value: 1.5325050354003906.
# Trial 12: 100%|██████████| 10/10 [2:00:04<00:00, 720.41s/it]
# [I 2025-04-27 21:49:39,794] Trial 12 finished with value: 1.610418677330017 and parameters: {'dropout_rate': 0.4841650753520802, 'fc1_size': 448, 'fc2_size': 288, 'fc3_size': 192, 'learning_rate': 1.538606931183435e-05, 'weight_decay': 0.06581693201028685}. Best is trial 1 with value: 1.5325050354003906.
# Trial 13: 100%|██████████| 10/10 [2:00:35<00:00, 723.54s/it]
# [I 2025-04-27 23:50:15,177] Trial 13 finished with value: 1.6250860691070557 and parameters: {'dropout_rate': 0.3111818433022425, 'fc1_size': 576, 'fc2_size': 224, 'fc3_size': 256, 'learning_rate': 1.4437596223634487e-05, 'weight_decay': 0.09792016001409332}. Best is trial 1 with value: 1.5325050354003906.
# Trial 14: 100%|██████████| 10/10 [2:00:34<00:00, 723.45s/it]
# [I 2025-04-28 01:50:49,756] Trial 14 finished with value: 1.6428133249282837 and parameters: {'dropout_rate': 0.42963288266334726, 'fc1_size': 832, 'fc2_size': 352, 'fc3_size': 160, 'learning_rate': 2.14765783742723e-05, 'weight_decay': 0.04018019471325376}. Best is trial 1 with value: 1.5325050354003906.
# Trial 15: 100%|██████████| 10/10 [2:00:36<00:00, 723.66s/it]
# [I 2025-04-28 03:51:26,395] Trial 15 finished with value: 1.5752520561218262 and parameters: {'dropout_rate': 0.3669784065886182, 'fc1_size': 384, 'fc2_size': 128, 'fc3_size': 224, 'learning_rate': 2.677951809596111e-05, 'weight_decay': 0.0027990628797523315}. Best is trial 1 with value: 1.5325050354003906.
# Trial 16: 100%|██████████| 10/10 [2:00:37<00:00, 723.77s/it]
# [I 2025-04-28 05:52:04,134] Trial 16 finished with value: 1.5399720668792725 and parameters: {'dropout_rate': 0.10447502197716997, 'fc1_size': 640, 'fc2_size': 320, 'fc3_size': 128, 'learning_rate': 1.780397334510355e-05, 'weight_decay': 0.041849226208788504}. Best is trial 1 with value: 1.5325050354003906.
# Trial 17: 100%|██████████| 10/10 [2:00:38<00:00, 723.87s/it]
# [I 2025-04-28 07:52:42,888] Trial 17 finished with value: 1.5424582958221436 and parameters: {'dropout_rate': 0.10477551060590072, 'fc1_size': 704, 'fc2_size': 320, 'fc3_size': 128, 'learning_rate': 1.851617017999063e-05, 'weight_decay': 0.03961584363278198}. Best is trial 1 with value: 1.5325050354003906.
# Trial 18: 100%|██████████| 10/10 [2:00:24<00:00, 722.46s/it]
# [I 2025-04-28 09:53:07,546] Trial 18 finished with value: 1.5529429912567139 and parameters: {'dropout_rate': 0.19220878894842042, 'fc1_size': 1024, 'fc2_size': 320, 'fc3_size': 128, 'learning_rate': 2.4735996495053336e-05, 'weight_decay': 0.03675038721490128}. Best is trial 1 with value: 1.5325050354003906.
# Trial 19: 100%|██████████| 10/10 [1:58:54<00:00, 713.46s/it]
# [I 2025-04-28 11:52:02,145] Trial 19 finished with value: 1.55057692527771 and parameters: {'dropout_rate': 0.25247263884727444, 'fc1_size': 704, 'fc2_size': 192, 'fc3_size': 64, 'learning_rate': 3.119079533225972e-05, 'weight_decay': 0.004667635518842687}. Best is trial 1 with value: 1.5325050354003906.
# Trial 20: 100%|██████████| 10/10 [1:58:54<00:00, 713.41s/it]
# [I 2025-04-28 13:50:56,316] Trial 20 finished with value: 1.5102766752243042 and parameters: {'dropout_rate': 0.10465610071486098, 'fc1_size': 576, 'fc2_size': 416, 'fc3_size': 96, 'learning_rate': 1.2291311487145698e-05, 'weight_decay': 0.01358025587155674}. Best is trial 20 with value: 1.5102766752243042.
# Trial 21: 100%|██████████| 10/10 [1:58:53<00:00, 713.38s/it]
# [I 2025-04-28 15:49:50,142] Trial 21 finished with value: 1.4956543445587158 and parameters: {'dropout_rate': 0.1063382996878906, 'fc1_size': 576, 'fc2_size': 448, 'fc3_size': 96, 'learning_rate': 1.2520753647750288e-05, 'weight_decay': 0.011957101871483413}. Best is trial 21 with value: 1.4956543445587158.
# Trial 22: 100%|██████████| 10/10 [1:58:55<00:00, 713.52s/it]
# [I 2025-04-28 17:48:45,382] Trial 22 finished with value: 1.5071780681610107 and parameters: {'dropout_rate': 0.14801821522836892, 'fc1_size': 512, 'fc2_size': 448, 'fc3_size': 96, 'learning_rate': 1.2475139966847831e-05, 'weight_decay': 0.013453275984701184}. Best is trial 21 with value: 1.4956543445587158.
# Trial 23: 100%|██████████| 10/10 [1:58:55<00:00, 713.52s/it]
# [I 2025-04-28 19:47:40,637] Trial 23 finished with value: 1.521593689918518 and parameters: {'dropout_rate': 0.17254946563778711, 'fc1_size': 384, 'fc2_size': 448, 'fc3_size': 96, 'learning_rate': 1.205114714043473e-05, 'weight_decay': 0.013758844393357561}. Best is trial 21 with value: 1.4956543445587158.
# Trial 24: 100%|██████████| 10/10 [1:58:59<00:00, 713.92s/it]
# [I 2025-04-28 21:46:39,877] Trial 24 finished with value: 1.54398512840271 and parameters: {'dropout_rate': 0.1416555553884994, 'fc1_size': 576, 'fc2_size': 448, 'fc3_size': 96, 'learning_rate': 1.0183997895993074e-05, 'weight_decay': 0.011662016991196388}. Best is trial 21 with value: 1.4956543445587158.
# Trial 25: 100%|██████████| 10/10 [1:58:54<00:00, 713.45s/it]
# [I 2025-04-28 23:45:34,418] Trial 25 finished with value: 1.564328670501709 and parameters: {'dropout_rate': 0.20197648871417637, 'fc1_size': 448, 'fc2_size': 384, 'fc3_size': 64, 'learning_rate': 1.176645826647814e-05, 'weight_decay': 0.030394937830609543}. Best is trial 21 with value: 1.4956543445587158.
# Trial 26: 100%|██████████| 10/10 [1:58:58<00:00, 713.82s/it]
# [I 2025-04-29 01:44:32,609] Trial 26 finished with value: 1.537187933921814 and parameters: {'dropout_rate': 0.10367755481102216, 'fc1_size': 768, 'fc2_size': 480, 'fc3_size': 96, 'learning_rate': 1.3125481973673868e-05, 'weight_decay': 0.012689396875473604}. Best is trial 21 with value: 1.4956543445587158.
# Trial 27: 100%|██████████| 10/10 [1:58:56<00:00, 713.70s/it]
# [I 2025-04-29 03:43:29,620] Trial 27 finished with value: 1.491973876953125 and parameters: {'dropout_rate': 0.2287887800541986, 'fc1_size': 576, 'fc2_size': 416, 'fc3_size': 96, 'learning_rate': 1.3304385368033439e-05, 'weight_decay': 0.031030349928899054}. Best is trial 27 with value: 1.491973876953125.
# Trial 28: 100%|██████████| 10/10 [1:58:55<00:00, 713.52s/it]
# [I 2025-04-29 05:42:24,810] Trial 28 finished with value: 1.5488603115081787 and parameters: {'dropout_rate': 0.23426674923211424, 'fc1_size': 384, 'fc2_size': 384, 'fc3_size': 64, 'learning_rate': 1.356920894744355e-05, 'weight_decay': 0.030793549233657482}. Best is trial 27 with value: 1.491973876953125.
# Trial 29: 100%|██████████| 10/10 [1:58:54<00:00, 713.42s/it]
# [I 2025-04-29 07:41:19,068] Trial 29 finished with value: 1.51905357837677 and parameters: {'dropout_rate': 0.17798246184537758, 'fc1_size': 640, 'fc2_size': 480, 'fc3_size': 128, 'learning_rate': 1.5839143071790165e-05, 'weight_decay': 0.02057782883151231}. Best is trial 27 with value: 1.491973876953125.
# Best hyperparameters: {'dropout_rate': 0.2287887800541986, 'fc1_size': 576, 'fc2_size': 416, 'fc3_size': 96, 'learning_rate': 1.3304385368033439e-05, 'weight_decay': 0.031030349928899054}
# Best model set directory: ./optuna_model_set_1
# Best cross-validated median error: 1.4919739

# %%
#smiles_embeddings=np.load('./embedding/fish_EC10_smiles_embeddings.npy')////

# %%
#val_r2 = r2_score(np.expm1(all_labels), np.expm1(all_preds))  # 还原 log1p 的值
