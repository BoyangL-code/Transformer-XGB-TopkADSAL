# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import random
import numpy as np
import torch


# 固定随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # for multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)  # 设置固定种子

# %%
import os

import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import optuna
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# ----------------- CONFIGURATION -----------------
n_folds    = 10
n_trials   = 30
data_dir   = "./k_folds_model/embeddings"
batch_size = 256
num_epochs = 200
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------- MODEL DEFINITION -----------------
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        layers = []
        prev_dim = input_dim
        act = {
            'relu':     nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh':     nn.Tanh()
        }[activation]
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act]
            prev_dim = h
        layers.append(nn.Linear(prev_dim, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = self.net(x).squeeze(-1)
        return F.softplus(x)  # 输出 > 0

# ----------------- OPTUNA OBJECTIVE -----------------
def objective(trial):
    hidden_sizes      = trial.suggest_categorical('hidden_layer_sizes',
                            [(50,), (100,), (150,), (100, 50), (150, 100, 50)])
    activation        = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh'])
    lr                = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    weight_decay      = trial.suggest_float('alpha', 1e-5, 1e-2, log=True)
    optimizer_choice  = trial.suggest_categorical('optimizer', ['sgd', 'adam'])

    fold_maes = []

    for fold in range(1, n_folds + 1):
        X_train = np.load(f"{data_dir}/train_fold_{fold}.npy")
        y_train = np.load(f"{data_dir}/train_labels_fold_{fold}.npy")
        X_val   = np.load(f"{data_dir}/val_fold_{fold}.npy")
        y_val   = np.load(f"{data_dir}/val_labels_fold_{fold}.npy")

        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val   = scaler.transform(X_val)

        train_ds = TensorDataset(torch.from_numpy(X_train).float(),
                                 torch.from_numpy(y_train).float())
        val_ds = TensorDataset(torch.from_numpy(X_val).float(),
                               torch.from_numpy(y_val).float())
        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        model = MLP(input_dim=X_train.shape[1],
                    hidden_sizes=hidden_sizes,
                    activation=activation).to(device)
        criterion = nn.MSELoss()
        optimizer = {
            'sgd': torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay),
            'adam': torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        }[optimizer_choice]

        try:
            for epoch in range(num_epochs):
                model.train()
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    preds = model(xb)
                    loss = criterion(preds, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            all_preds = []
            with torch.no_grad():
                for xb, _ in val_loader:
                    xb = xb.to(device)
                    batch_pred = model(xb).cpu().numpy()
                    all_preds.append(batch_pred)
            all_preds = np.concatenate(all_preds)

            mae = mean_absolute_error(y_val, all_preds)
            fold_maes.append(mae)

        except Exception:
            return np.inf

    return float(np.mean(fold_maes))

# ----------------- RUN OPTUNA -----------------
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)

    print("\n=== Best Hyperparameters ===")
    print(study.best_params)
    print(f"Best Mean MAE: {study.best_value:.4f}")
# Out:
# [I 2025-05-16 17:48:32,263] A new study created in memory with name: no-name-4f03f1cd-dd91-4f08-b73f-62aad3556299
# [I 2025-05-16 17:57:37,898] Trial 0 finished with value: 0.7224807739257812 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.0015930522616241021, 'alpha': 0.001331121608073689, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7224807739257812.
# [I 2025-05-16 18:06:41,539] Trial 1 finished with value: 0.7187864780426025 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0016738085788752138, 'alpha': 2.621087878265438e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7187864780426025.
# [I 2025-05-16 18:14:42,107] Trial 2 finished with value: 0.8135694265365601 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00013492834268013249, 'alpha': 0.007025166339242158, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.7187864780426025.
# [I 2025-05-16 18:23:59,816] Trial 3 finished with value: 0.719698429107666 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00032927591344236165, 'alpha': 0.0009717775305059633, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7187864780426025.
# [I 2025-05-16 18:33:14,003] Trial 4 finished with value: 0.7164376378059387 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00015030900645056822, 'alpha': 3.872118032174584e-05, 'optimizer': 'adam'}. Best is trial 4 with value: 0.7164376378059387.
# [I 2025-05-16 18:41:46,749] Trial 5 finished with value: 0.737701416015625 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00014096175149815865, 'alpha': 0.009133995846860976, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.7164376378059387.
# [I 2025-05-16 18:50:19,385] Trial 6 finished with value: 0.732045590877533 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.005323617594751502, 'alpha': 0.0007411299781083245, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.7164376378059387.
# [I 2025-05-16 18:59:51,001] Trial 7 finished with value: 0.7217637896537781 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0033233042062267943, 'alpha': 0.00048287152161792117, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.7164376378059387.
# [I 2025-05-16 19:08:56,137] Trial 8 finished with value: 0.8362410664558411 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.006533305220227739, 'alpha': 5.59598687800608e-05, 'optimizer': 'adam'}. Best is trial 4 with value: 0.7164376378059387.
# [I 2025-05-16 19:17:41,349] Trial 9 finished with value: 0.7276520729064941 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.004048966222584676, 'alpha': 3.6283583803549155e-05, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.7164376378059387.
# [I 2025-05-16 19:26:09,751] Trial 10 finished with value: 0.7133455276489258 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0004216644107007115, 'alpha': 0.00012956995794619435, 'optimizer': 'adam'}. Best is trial 10 with value: 0.7133455276489258.
# [I 2025-05-16 19:34:37,986] Trial 11 finished with value: 0.712583065032959 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00043921744489397506, 'alpha': 0.00012081462091873585, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 19:43:09,282] Trial 12 finished with value: 0.7157770395278931 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0005091759021708353, 'alpha': 0.00013950787556636112, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 19:51:37,812] Trial 13 finished with value: 0.7140557765960693 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0005075538006137699, 'alpha': 0.0001597542678081087, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 20:00:10,089] Trial 14 finished with value: 0.7128168344497681 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0003013414410470946, 'alpha': 0.0001376827057426005, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 20:08:38,923] Trial 15 finished with value: 0.7177050709724426 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00025723317930606717, 'alpha': 1.719440511600405e-05, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 20:17:13,375] Trial 16 finished with value: 0.7178778648376465 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00098581024255934, 'alpha': 0.00027565138813147473, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 20:25:47,799] Trial 17 finished with value: 0.7289237976074219 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.0008049792264369226, 'alpha': 0.0026558167359917455, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 20:34:18,351] Trial 18 finished with value: 0.716506838798523 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00020064345207277854, 'alpha': 7.633519183320513e-05, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 20:42:47,768] Trial 19 finished with value: 0.7146705389022827 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0001029117414292438, 'alpha': 1.0788661515919524e-05, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 20:51:49,820] Trial 20 finished with value: 0.7198232412338257 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'learning_rate': 0.0007430782020391944, 'alpha': 0.0003028268220404633, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 21:00:22,422] Trial 21 finished with value: 0.7199059724807739 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00040279857639542206, 'alpha': 0.0001136425659310589, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 21:08:58,225] Trial 22 finished with value: 0.7216495275497437 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0002796789633618822, 'alpha': 0.00022090433275523728, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 21:17:29,260] Trial 23 finished with value: 0.7196956872940063 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0005706903689853978, 'alpha': 8.219682204772123e-05, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 21:25:28,470] Trial 24 finished with value: 0.7187684774398804 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.001302192011803902, 'alpha': 0.0004174551766417107, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 21:34:00,137] Trial 25 finished with value: 0.7177255749702454 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.00021924139515389331, 'alpha': 0.00016916462529772592, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 21:42:33,821] Trial 26 finished with value: 0.7212336659431458 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00037766409684739484, 'alpha': 6.383740911071794e-05, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 21:50:36,448] Trial 27 finished with value: 0.7248831987380981 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0023338558278921573, 'alpha': 0.00010575614807965788, 'optimizer': 'sgd'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 21:58:59,793] Trial 28 finished with value: 1.0318284034729004 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.009827674611457334, 'alpha': 0.0004945283659355492, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# [I 2025-05-16 22:06:39,046] Trial 29 finished with value: 0.7226409912109375 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.0006571890003467408, 'alpha': 0.0014130490232818751, 'optimizer': 'adam'}. Best is trial 11 with value: 0.712583065032959.
# === Best Hyperparameters ===
# {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00043921744489397506, 'alpha': 0.00012081462091873585, 'optimizer': 'adam'}
# Best Mean MAE: 0.7126

# %%
import os
import optuna
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    # 采样超参数
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        model = XGBRegressor(n_jobs=-1, verbosity=0, **params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 以 MAE 为优化目标


# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best XGBoost Hyperparameters via Optuna ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 22:06:39,094] A new study created in memory with name: no-name-296f829a-d735-40f4-8318-72e8df6f8cc4
# [I 2025-05-16 22:09:12,902] Trial 0 finished with value: 0.7672367095947266 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 8, 'subsample': 0.8795975452591109, 'colsample_bytree': 0.6624074561769746}. Best is trial 0 with value: 0.7672367095947266.
# [I 2025-05-16 22:12:18,055] Trial 1 finished with value: 0.7609155774116516 and parameters: {'n_estimators': 200, 'learning_rate': 0.011900590783184251, 'max_depth': 9, 'subsample': 0.8803345035229626, 'colsample_bytree': 0.8832290311184181}. Best is trial 1 with value: 0.7609155774116516.
# [I 2025-05-16 22:13:05,629] Trial 2 finished with value: 0.7329373359680176 and parameters: {'n_estimators': 100, 'learning_rate': 0.18276027831785724, 'max_depth': 8, 'subsample': 0.7637017332034828, 'colsample_bytree': 0.6727299868828402}. Best is trial 2 with value: 0.7329373359680176.
# [I 2025-05-16 22:14:25,594] Trial 3 finished with value: 0.71660315990448 and parameters: {'n_estimators': 200, 'learning_rate': 0.024878734419814436, 'max_depth': 6, 'subsample': 0.8295835055926347, 'colsample_bytree': 0.7164916560792167}. Best is trial 3 with value: 0.71660315990448.
# [I 2025-05-16 22:17:34,533] Trial 4 finished with value: 0.7137130498886108 and parameters: {'n_estimators': 700, 'learning_rate': 0.01518747922672247, 'max_depth': 5, 'subsample': 0.8099085529881075, 'colsample_bytree': 0.7824279936868144}. Best is trial 4 with value: 0.7137130498886108.
# [I 2025-05-16 22:21:30,148] Trial 5 finished with value: 0.7163985967636108 and parameters: {'n_estimators': 800, 'learning_rate': 0.018187859051288217, 'max_depth': 6, 'subsample': 0.8777243706586128, 'colsample_bytree': 0.6185801650879991}. Best is trial 4 with value: 0.7137130498886108.
# [I 2025-05-16 22:23:34,927] Trial 6 finished with value: 0.7148202061653137 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'subsample': 0.984665661176, 'colsample_bytree': 0.9862528132298237}. Best is trial 4 with value: 0.7137130498886108.
# [I 2025-05-16 22:26:00,797] Trial 7 finished with value: 0.7141213417053223 and parameters: {'n_estimators': 900, 'learning_rate': 0.0249064396938244, 'max_depth': 3, 'subsample': 0.905269907953647, 'colsample_bytree': 0.7760609974958406}. Best is trial 4 with value: 0.7137130498886108.
# [I 2025-05-16 22:26:38,520] Trial 8 finished with value: 0.7149197459220886 and parameters: {'n_estimators': 200, 'learning_rate': 0.04407984038169244, 'max_depth': 3, 'subsample': 0.9727961206236346, 'colsample_bytree': 0.7035119926400067}. Best is trial 4 with value: 0.7137130498886108.
# [I 2025-05-16 22:29:59,395] Trial 9 finished with value: 0.7172262668609619 and parameters: {'n_estimators': 700, 'learning_rate': 0.02544166090938368, 'max_depth': 6, 'subsample': 0.8640130838029838, 'colsample_bytree': 0.6739417822102108}. Best is trial 4 with value: 0.7137130498886108.
# [I 2025-05-16 22:33:59,809] Trial 10 finished with value: 0.7342023849487305 and parameters: {'n_estimators': 1000, 'learning_rate': 0.08138762607805286, 'max_depth': 5, 'subsample': 0.7053885626844458, 'colsample_bytree': 0.8560354009870226}. Best is trial 4 with value: 0.7137130498886108.
# [I 2025-05-16 22:37:17,259] Trial 11 finished with value: 0.7180932760238647 and parameters: {'n_estimators': 1000, 'learning_rate': 0.042799942130332856, 'max_depth': 4, 'subsample': 0.8004385528669709, 'colsample_bytree': 0.784894991903791}. Best is trial 4 with value: 0.7137130498886108.
# [I 2025-05-16 22:40:27,720] Trial 12 finished with value: 0.7131475210189819 and parameters: {'n_estimators': 800, 'learning_rate': 0.010227614236539206, 'max_depth': 4, 'subsample': 0.9464056138332538, 'colsample_bytree': 0.7890856026631795}. Best is trial 12 with value: 0.7131475210189819.
# [I 2025-05-16 22:43:13,941] Trial 13 finished with value: 0.7155488729476929 and parameters: {'n_estimators': 500, 'learning_rate': 0.010343031939583617, 'max_depth': 5, 'subsample': 0.9407667563426924, 'colsample_bytree': 0.8583425762812965}. Best is trial 12 with value: 0.7131475210189819.
# [I 2025-05-16 22:46:04,163] Trial 14 finished with value: 0.7134581804275513 and parameters: {'n_estimators': 600, 'learning_rate': 0.014147233548123672, 'max_depth': 5, 'subsample': 0.7729629237947951, 'colsample_bytree': 0.7473945810686194}. Best is trial 12 with value: 0.7131475210189819.
# [I 2025-05-16 22:48:16,156] Trial 15 finished with value: 0.7145901918411255 and parameters: {'n_estimators': 500, 'learning_rate': 0.010180482972578007, 'max_depth': 4, 'subsample': 0.7504724447454525, 'colsample_bytree': 0.7431096284362038}. Best is trial 12 with value: 0.7131475210189819.
# [I 2025-05-16 22:50:13,411] Trial 16 finished with value: 0.7213281393051147 and parameters: {'n_estimators': 600, 'learning_rate': 0.09338454203975513, 'max_depth': 4, 'subsample': 0.9396996063779983, 'colsample_bytree': 0.9191979476316068}. Best is trial 12 with value: 0.7131475210189819.
# [I 2025-05-16 22:52:01,380] Trial 17 finished with value: 0.714103102684021 and parameters: {'n_estimators': 400, 'learning_rate': 0.029336165409058357, 'max_depth': 5, 'subsample': 0.7555779218152252, 'colsample_bytree': 0.8295938297953025}. Best is trial 12 with value: 0.7131475210189819.
# [I 2025-05-16 22:57:14,905] Trial 18 finished with value: 0.7196074724197388 and parameters: {'n_estimators': 800, 'learning_rate': 0.015097796464439173, 'max_depth': 7, 'subsample': 0.9251702744329219, 'colsample_bytree': 0.9281889012746769}. Best is trial 12 with value: 0.7131475210189819.
# [I 2025-05-16 22:59:16,277] Trial 19 finished with value: 0.7184717655181885 and parameters: {'n_estimators': 600, 'learning_rate': 0.07260773672404375, 'max_depth': 4, 'subsample': 0.7032967567731313, 'colsample_bytree': 0.7459953174686462}. Best is trial 12 with value: 0.7131475210189819.
# [I 2025-05-16 23:04:06,848] Trial 20 finished with value: 0.7315853238105774 and parameters: {'n_estimators': 900, 'learning_rate': 0.036016467750220535, 'max_depth': 7, 'subsample': 0.7813262969021736, 'colsample_bytree': 0.6018960478612356}. Best is trial 12 with value: 0.7131475210189819.
# [I 2025-05-16 23:07:22,605] Trial 21 finished with value: 0.7135934233665466 and parameters: {'n_estimators': 700, 'learning_rate': 0.014078354179059355, 'max_depth': 5, 'subsample': 0.8333780097946052, 'colsample_bytree': 0.8110592036796673}. Best is trial 12 with value: 0.7131475210189819.
# [I 2025-05-16 23:10:49,472] Trial 22 finished with value: 0.7150834798812866 and parameters: {'n_estimators': 800, 'learning_rate': 0.019560632504406383, 'max_depth': 5, 'subsample': 0.8316638834101604, 'colsample_bytree': 0.8284003651945829}. Best is trial 12 with value: 0.7131475210189819.
# [I 2025-05-16 23:13:13,591] Trial 23 finished with value: 0.7124072313308716 and parameters: {'n_estimators': 600, 'learning_rate': 0.01331546869561849, 'max_depth': 4, 'subsample': 0.8404256119011844, 'colsample_bytree': 0.8119620829907164}. Best is trial 23 with value: 0.7124072313308716.
# [I 2025-05-16 23:15:40,359] Trial 24 finished with value: 0.71235591173172 and parameters: {'n_estimators': 600, 'learning_rate': 0.011957526124170934, 'max_depth': 4, 'subsample': 0.7322209714249547, 'colsample_bytree': 0.7507983883065513}. Best is trial 24 with value: 0.71235591173172.
# [I 2025-05-16 23:16:56,823] Trial 25 finished with value: 0.7132848501205444 and parameters: {'n_estimators': 400, 'learning_rate': 0.02081746226557753, 'max_depth': 3, 'subsample': 0.7297378883672854, 'colsample_bytree': 0.7618604198603434}. Best is trial 24 with value: 0.71235591173172.

# %%
import os
import optuna
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'objective': 'poisson',         # ✅ 强制正输出
        'n_jobs': -1,
        'verbose': -1
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        # Poisson 回归要求标签必须大于 0
        if np.any(y_train <= 0) or np.any(y_val <= 0):
            return np.inf

        model = LGBMRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 使用 MAE 作为优化目标

# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-17 16:12:19,623] A new study created in memory with name: no-name-2d4d52cc-d1df-4414-80ad-84806d5358ba
# [I 2025-05-17 16:13:13,269] Trial 0 finished with value: 0.7196788837654218 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 10, 'num_leaves': 68, 'feature_fraction': 0.6624074561769746, 'bagging_fraction': 0.662397808134481}. Best is trial 0 with value: 0.7196788837654218.
# [I 2025-05-17 16:14:00,271] Trial 1 finished with value: 0.7102973128923274 and parameters: {'n_estimators': 100, 'learning_rate': 0.13394334706750485, 'max_depth': 9, 'num_leaves': 77, 'feature_fraction': 0.608233797718321, 'bagging_fraction': 0.9879639408647978}. Best is trial 1 with value: 0.7102973128923274.
# [I 2025-05-17 16:16:41,649] Trial 2 finished with value: 0.7093882976105269 and parameters: {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}. Best is trial 2 with value: 0.7093882976105269.
# [I 2025-05-17 16:19:20,584] Trial 3 finished with value: 0.7090115897195248 and parameters: {'n_estimators': 500, 'learning_rate': 0.023927528765580644, 'max_depth': 9, 'num_leaves': 31, 'feature_fraction': 0.7168578594140873, 'bagging_fraction': 0.7465447373174767}. Best is trial 3 with value: 0.7090115897195248.
# [I 2025-05-17 16:20:00,426] Trial 4 finished with value: 0.7088723251828499 and parameters: {'n_estimators': 500, 'learning_rate': 0.10508421338691762, 'max_depth': 4, 'num_leaves': 61, 'feature_fraction': 0.836965827544817, 'bagging_fraction': 0.6185801650879991}. Best is trial 4 with value: 0.7088723251828499.
# [I 2025-05-17 16:21:11,347] Trial 5 finished with value: 0.7172939340526432 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'num_leaves': 96, 'feature_fraction': 0.9862528132298237, 'bagging_fraction': 0.9233589392465844}. Best is trial 4 with value: 0.7088723251828499.
# [I 2025-05-17 16:22:31,533] Trial 6 finished with value: 0.7413996427728454 and parameters: {'n_estimators': 400, 'learning_rate': 0.013399060561509796, 'max_depth': 9, 'num_leaves': 55, 'feature_fraction': 0.6488152939379115, 'bagging_fraction': 0.798070764044508}. Best is trial 4 with value: 0.7088723251828499.
# [I 2025-05-17 16:22:48,808] Trial 7 finished with value: 0.7095553871223401 and parameters: {'n_estimators': 100, 'learning_rate': 0.15242391728466367, 'max_depth': 5, 'num_leaves': 73, 'feature_fraction': 0.7246844304357644, 'bagging_fraction': 0.8080272084711243}. Best is trial 4 with value: 0.7088723251828499.
# [I 2025-05-17 16:25:34,925] Trial 8 finished with value: 0.7092687655822644 and parameters: {'n_estimators': 600, 'learning_rate': 0.017398074711291726, 'max_depth': 12, 'num_leaves': 82, 'feature_fraction': 0.9757995766256756, 'bagging_fraction': 0.9579309401710595}. Best is trial 4 with value: 0.7088723251828499.
# [I 2025-05-17 16:26:07,500] Trial 9 finished with value: 0.7103076182038225 and parameters: {'n_estimators': 600, 'learning_rate': 0.15826541904647565, 'max_depth': 3, 'num_leaves': 35, 'feature_fraction': 0.6180909155642152, 'bagging_fraction': 0.7301321323053057}. Best is trial 4 with value: 0.7088723251828499.
# [I 2025-05-17 16:27:36,106] Trial 10 finished with value: 0.7119511865825843 and parameters: {'n_estimators': 1000, 'learning_rate': 0.07549726627694736, 'max_depth': 6, 'num_leaves': 54, 'feature_fraction': 0.8676285972451436, 'bagging_fraction': 0.6154900799844731}. Best is trial 4 with value: 0.7088723251828499.
# [I 2025-05-17 16:28:32,587] Trial 11 finished with value: 0.7100391488983883 and parameters: {'n_estimators': 400, 'learning_rate': 0.032403579261005684, 'max_depth': 7, 'num_leaves': 21, 'feature_fraction': 0.8242173679510726, 'bagging_fraction': 0.7133116818879434}. Best is trial 4 with value: 0.7088723251828499.
# [I 2025-05-17 16:29:28,281] Trial 12 finished with value: 0.7076372331301922 and parameters: {'n_estimators': 300, 'learning_rate': 0.04900549114886041, 'max_depth': 8, 'num_leaves': 45, 'feature_fraction': 0.8896513152322078, 'bagging_fraction': 0.6023582266276172}. Best is trial 12 with value: 0.7076372331301922.
# [I 2025-05-17 16:30:08,741] Trial 13 finished with value: 0.7086019071323693 and parameters: {'n_estimators': 200, 'learning_rate': 0.06569307960726345, 'max_depth': 7, 'num_leaves': 47, 'feature_fraction': 0.896295851710854, 'bagging_fraction': 0.6181400084793356}. Best is trial 12 with value: 0.7076372331301922.
# [I 2025-05-17 16:31:00,846] Trial 14 finished with value: 0.7085683080088334 and parameters: {'n_estimators': 200, 'learning_rate': 0.06083820653502644, 'max_depth': 7, 'num_leaves': 47, 'feature_fraction': 0.9369715881524885, 'bagging_fraction': 0.669481598371347}. Best is trial 12 with value: 0.7076372331301922.
# [I 2025-05-17 16:32:02,967] Trial 15 finished with value: 0.7073418242014697 and parameters: {'n_estimators': 300, 'learning_rate': 0.044404298367573765, 'max_depth': 11, 'num_leaves': 46, 'feature_fraction': 0.9238315673412458, 'bagging_fraction': 0.6698318541689912}. Best is trial 15 with value: 0.7073418242014697.
# [I 2025-05-17 16:33:06,372] Trial 16 finished with value: 0.7082944276274212 and parameters: {'n_estimators': 300, 'learning_rate': 0.03904966833702238, 'max_depth': 12, 'num_leaves': 43, 'feature_fraction': 0.9150441360954309, 'bagging_fraction': 0.6663688023459295}. Best is trial 15 with value: 0.7073418242014697.
# [I 2025-05-17 16:33:49,707] Trial 17 finished with value: 0.7089074835560398 and parameters: {'n_estimators': 300, 'learning_rate': 0.047160051180196776, 'max_depth': 11, 'num_leaves': 23, 'feature_fraction': 0.7896456028268091, 'bagging_fraction': 0.6007031270319011}. Best is trial 15 with value: 0.7073418242014697.
# [I 2025-05-17 16:35:59,066] Trial 18 finished with value: 0.7086433806480705 and parameters: {'n_estimators': 700, 'learning_rate': 0.028664226134463386, 'max_depth': 10, 'num_leaves': 63, 'feature_fraction': 0.9454218220233528, 'bagging_fraction': 0.8778200365979032}. Best is trial 15 with value: 0.7073418242014697.
# [I 2025-05-17 16:36:55,886] Trial 19 finished with value: 0.7084659350313601 and parameters: {'n_estimators': 300, 'learning_rate': 0.04572883635962787, 'max_depth': 8, 'num_leaves': 45, 'feature_fraction': 0.8807748828156938, 'bagging_fraction': 0.6990612890109106}. Best is trial 15 with value: 0.7073418242014697.
# [I 2025-05-17 16:37:30,062] Trial 20 finished with value: 0.707782318415463 and parameters: {'n_estimators': 200, 'learning_rate': 0.09520281262231418, 'max_depth': 11, 'num_leaves': 39, 'feature_fraction': 0.7747981352314053, 'bagging_fraction': 0.7636853800534704}. Best is trial 15 with value: 0.7073418242014697.
# [I 2025-05-17 16:38:04,456] Trial 21 finished with value: 0.7081265981340126 and parameters: {'n_estimators': 200, 'learning_rate': 0.09052457062022039, 'max_depth': 11, 'num_leaves': 39, 'feature_fraction': 0.7666963223679517, 'bagging_fraction': 0.7739931614969642}. Best is trial 15 with value: 0.7073418242014697.
# [I 2025-05-17 16:38:42,061] Trial 22 finished with value: 0.7382153576790483 and parameters: {'n_estimators': 100, 'learning_rate': 0.05393868396375098, 'max_depth': 11, 'num_leaves': 52, 'feature_fraction': 0.8523479072741699, 'bagging_fraction': 0.8556241533397022}. Best is trial 15 with value: 0.7073418242014697.
# [I 2025-05-17 16:39:20,339] Trial 23 finished with value: 0.7087022956320163 and parameters: {'n_estimators': 300, 'learning_rate': 0.10682703463584299, 'max_depth': 10, 'num_leaves': 30, 'feature_fraction': 0.771611160540024, 'bagging_fraction': 0.6494306895161425}. Best is trial 15 with value: 0.7073418242014697.
# [I 2025-05-17 16:40:03,845] Trial 24 finished with value: 0.7217442624148319 and parameters: {'n_estimators': 200, 'learning_rate': 0.03486002235543167, 'max_depth': 8, 'num_leaves': 39, 'feature_fraction': 0.8084507274911495, 'bagging_fraction': 0.6942647815813217}. Best is trial 15 with value: 0.7073418242014697.
# [I 2025-05-17 16:41:10,016] Trial 25 finished with value: 0.7107354751387959 and parameters: {'n_estimators': 400, 'learning_rate': 0.08020254370662916, 'max_depth': 12, 'num_leaves': 51, 'feature_fraction': 0.9365746581237374, 'bagging_fraction': 0.7590602526122234}. Best is trial 15 with value: 0.7073418242014697.
# [I 2025-05-17 16:41:55,741] Trial 26 finished with value: 0.9487127397205463 and parameters: {'n_estimators': 200, 'learning_rate': 0.010354263660840603, 'max_depth': 11, 'num_leaves': 26, 'feature_fraction': 0.9066676588746955, 'bagging_fraction': 0.6361733049873189}. Best is trial 15 with value: 0.7073418242014697.
# [I 2025-05-17 16:43:17,455] Trial 27 finished with value: 0.7086178798320499 and parameters: {'n_estimators': 500, 'learning_rate': 0.025152126801614622, 'max_depth': 10, 'num_leaves': 39, 'feature_fraction': 0.7526597646391255, 'bagging_fraction': 0.6869385406471685}. Best is trial 15 with value: 0.7073418242014697.
# [I 2025-05-17 16:44:05,030] Trial 28 finished with value: 0.708493066271106 and parameters: {'n_estimators': 300, 'learning_rate': 0.053435813337592515, 'max_depth': 6, 'num_leaves': 60, 'feature_fraction': 0.8658611736024172, 'bagging_fraction': 0.7246844869937318}. Best is trial 15 with value: 0.7073418242014697.
# [I 2025-05-17 16:44:58,264] Trial 29 finished with value: 0.7188574070809464 and parameters: {'n_estimators': 400, 'learning_rate': 0.19848978742652873, 'max_depth': 9, 'num_leaves': 66, 'feature_fraction': 0.9604597210982896, 'bagging_fraction': 0.8672335505971374}. Best is trial 15 with value: 0.7073418242014697.
# === Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===
# {'n_estimators': 300, 'learning_rate': 0.044404298367573765, 'max_depth': 11, 'num_leaves': 46, 'feature_fraction': 0.9238315673412458, 'bagging_fraction': 0.6698318541689912}
# 10-Fold Mean MAE = 0.7073
