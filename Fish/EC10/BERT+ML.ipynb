# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
from sklearn.metrics import mean_absolute_error

# %%
import random

# 固定随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # for multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)  # 设置固定种子

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import optuna
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# ----------------- CONFIGURATION -----------------
n_folds    = 10
n_trials   = 30
data_dir   = "./k_folds_model/embeddings"
batch_size = 256
num_epochs = 200
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------- MODEL DEFINITION -----------------
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        layers = []
        prev_dim = input_dim
        act = {
            'relu':     nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh':     nn.Tanh()
        }[activation]
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act]
            prev_dim = h
        layers.append(nn.Linear(prev_dim, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = self.net(x).squeeze(-1)
        return F.softplus(x)  # 输出 > 0

# ----------------- OPTUNA OBJECTIVE -----------------
def objective(trial):
    hidden_sizes      = trial.suggest_categorical('hidden_layer_sizes',
                            [(50,), (100,), (150,), (100, 50), (150, 100, 50)])
    activation        = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh'])
    lr                = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    weight_decay      = trial.suggest_float('alpha', 1e-5, 1e-2, log=True)
    optimizer_choice  = trial.suggest_categorical('optimizer', ['sgd', 'adam'])

    fold_maes = []

    for fold in range(1, n_folds + 1):
        X_train = np.load(f"{data_dir}/train_fold_{fold}.npy")
        y_train = np.load(f"{data_dir}/train_labels_fold_{fold}.npy")
        X_val   = np.load(f"{data_dir}/val_fold_{fold}.npy")
        y_val   = np.load(f"{data_dir}/val_labels_fold_{fold}.npy")

        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val   = scaler.transform(X_val)

        train_ds = TensorDataset(torch.from_numpy(X_train).float(),
                                 torch.from_numpy(y_train).float())
        val_ds = TensorDataset(torch.from_numpy(X_val).float(),
                               torch.from_numpy(y_val).float())
        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        model = MLP(input_dim=X_train.shape[1],
                    hidden_sizes=hidden_sizes,
                    activation=activation).to(device)
        criterion = nn.MSELoss()
        optimizer = {
            'sgd': torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay),
            'adam': torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        }[optimizer_choice]

        try:
            for epoch in range(num_epochs):
                model.train()
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    preds = model(xb)
                    loss = criterion(preds, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            all_preds = []
            with torch.no_grad():
                for xb, _ in val_loader:
                    xb = xb.to(device)
                    batch_pred = model(xb).cpu().numpy()
                    all_preds.append(batch_pred)
            all_preds = np.concatenate(all_preds)

            mae = mean_absolute_error(y_val, all_preds)
            fold_maes.append(mae)

        except Exception:
            return np.inf

    return float(np.mean(fold_maes))

# ----------------- RUN OPTUNA -----------------
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)

    print("\n=== Best Hyperparameters ===")
    print(study.best_params)
    print(f"Best Mean MAE: {study.best_value:.4f}")
# Out:
# [I 2025-05-16 10:03:09,364] A new study created in memory with name: no-name-44eb4624-6e72-4e4a-9b15-993755b285a7
# [I 2025-05-16 10:06:36,359] Trial 0 finished with value: 0.6663442850112915 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.0015930522616241021, 'alpha': 0.001331121608073689, 'optimizer': 'adam'}. Best is trial 0 with value: 0.6663442850112915.
# [I 2025-05-16 10:10:05,605] Trial 1 finished with value: 0.6505294442176819 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0016738085788752138, 'alpha': 2.621087878265438e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6505294442176819.
# [I 2025-05-16 10:13:21,169] Trial 2 finished with value: 0.7720128893852234 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00013492834268013249, 'alpha': 0.007025166339242158, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.6505294442176819.
# [I 2025-05-16 10:16:54,257] Trial 3 finished with value: 0.657499372959137 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00032927591344236165, 'alpha': 0.0009717775305059633, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6505294442176819.
# [I 2025-05-16 10:20:23,991] Trial 4 finished with value: 0.6451753377914429 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00015030900645056822, 'alpha': 3.872118032174584e-05, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6451753377914429.
# [I 2025-05-16 10:23:37,103] Trial 5 finished with value: 0.7033079266548157 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00014096175149815865, 'alpha': 0.009133995846860976, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.6451753377914429.
# [I 2025-05-16 10:26:20,777] Trial 6 finished with value: 0.6753016710281372 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.005323617594751502, 'alpha': 0.0007411299781083245, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.6451753377914429.
# [I 2025-05-16 10:29:28,357] Trial 7 finished with value: 0.7241013050079346 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0033233042062267943, 'alpha': 0.00048287152161792117, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.6451753377914429.
# [I 2025-05-16 10:32:22,416] Trial 8 finished with value: 0.6733612418174744 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.006533305220227739, 'alpha': 5.59598687800608e-05, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6451753377914429.
# [I 2025-05-16 10:35:29,056] Trial 9 finished with value: 0.7993682622909546 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.004048966222584676, 'alpha': 3.6283583803549155e-05, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.6451753377914429.
# [I 2025-05-16 10:38:34,055] Trial 10 finished with value: 0.6453502774238586 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0004216644107007115, 'alpha': 0.00012956995794619435, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6451753377914429.
# [I 2025-05-16 10:41:36,338] Trial 11 finished with value: 0.6444005966186523 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00043921744489397506, 'alpha': 0.00012081462091873585, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6444005966186523.
# [I 2025-05-16 10:44:39,235] Trial 12 finished with value: 0.6550934910774231 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00039983761884014867, 'alpha': 0.00013950787556636112, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6444005966186523.
# [I 2025-05-16 10:47:43,557] Trial 13 finished with value: 0.6329541802406311 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0002439187104733081, 'alpha': 1.0609009340206071e-05, 'optimizer': 'adam'}. Best is trial 13 with value: 0.6329541802406311.
# [I 2025-05-16 10:50:47,297] Trial 14 finished with value: 0.6480401158332825 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0007581240170071042, 'alpha': 1.7671958099311213e-05, 'optimizer': 'adam'}. Best is trial 13 with value: 0.6329541802406311.
# [I 2025-05-16 10:53:52,138] Trial 15 finished with value: 0.6330102682113647 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00025723317930606717, 'alpha': 0.00016684313340780606, 'optimizer': 'adam'}. Best is trial 13 with value: 0.6329541802406311.
# [I 2025-05-16 10:56:55,871] Trial 16 finished with value: 0.6348199844360352 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00024042923525840847, 'alpha': 1.2319984042781342e-05, 'optimizer': 'adam'}. Best is trial 13 with value: 0.6329541802406311.
# [I 2025-05-16 10:59:58,553] Trial 17 finished with value: 0.6953926682472229 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.0008017312467210907, 'alpha': 0.0026558167359917455, 'optimizer': 'adam'}. Best is trial 13 with value: 0.6329541802406311.
# [I 2025-05-16 11:02:59,452] Trial 18 finished with value: 0.6396573781967163 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0013032402241314354, 'alpha': 0.0002676587375863138, 'optimizer': 'adam'}. Best is trial 13 with value: 0.6329541802406311.
# [I 2025-05-16 11:06:02,448] Trial 19 finished with value: 0.6381653547286987 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00010167753516540069, 'alpha': 1.0788661515919524e-05, 'optimizer': 'adam'}. Best is trial 13 with value: 0.6329541802406311.
# [I 2025-05-16 11:09:18,368] Trial 20 finished with value: 0.630099892616272 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'learning_rate': 0.0002692889210118106, 'alpha': 6.463547709130229e-05, 'optimizer': 'adam'}. Best is trial 20 with value: 0.630099892616272.
# [I 2025-05-16 11:12:34,668] Trial 21 finished with value: 0.6463707089424133 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'learning_rate': 0.00020391470296242433, 'alpha': 7.204221834911267e-05, 'optimizer': 'adam'}. Best is trial 20 with value: 0.630099892616272.
# [I 2025-05-16 11:15:50,059] Trial 22 finished with value: 0.6328468918800354 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'learning_rate': 0.00025446641681341865, 'alpha': 0.0002518736477353989, 'optimizer': 'adam'}. Best is trial 20 with value: 0.630099892616272.
# [I 2025-05-16 11:19:01,926] Trial 23 finished with value: 0.6488136053085327 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'learning_rate': 0.0007625475851341595, 'alpha': 0.0002935729434629046, 'optimizer': 'adam'}. Best is trial 20 with value: 0.630099892616272.
# [I 2025-05-16 11:22:17,144] Trial 24 finished with value: 0.6397290229797363 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'learning_rate': 0.0006201239774302556, 'alpha': 7.192986461282522e-05, 'optimizer': 'adam'}. Best is trial 20 with value: 0.630099892616272.
# [I 2025-05-16 11:25:30,000] Trial 25 finished with value: 0.6482436060905457 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'logistic', 'learning_rate': 0.00021924139515389331, 'alpha': 1.9252020311848504e-05, 'optimizer': 'adam'}. Best is trial 20 with value: 0.630099892616272.
# [I 2025-05-16 11:28:46,160] Trial 26 finished with value: 0.6463378071784973 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'learning_rate': 0.0005740122018683208, 'alpha': 0.0004678393646259114, 'optimizer': 'adam'}. Best is trial 20 with value: 0.630099892616272.
# [I 2025-05-16 11:31:46,112] Trial 27 finished with value: 0.824566662311554 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'learning_rate': 0.0003036266308784793, 'alpha': 4.877384722803914e-05, 'optimizer': 'sgd'}. Best is trial 20 with value: 0.630099892616272.
# [I 2025-05-16 11:34:35,721] Trial 28 finished with value: 1.0720317363739014 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.009827674611457334, 'alpha': 0.0021191458823493583, 'optimizer': 'adam'}. Best is trial 20 with value: 0.630099892616272.
# [I 2025-05-16 11:37:22,912] Trial 29 finished with value: 0.6549190878868103 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.0001818116216264556, 'alpha': 0.00021837166651839308, 'optimizer': 'adam'}. Best is trial 20 with value: 0.630099892616272.
# === Best Hyperparameters ===
# {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'learning_rate': 0.0002692889210118106, 'alpha': 6.463547709130229e-05, 'optimizer': 'adam'}
# Best Mean MAE: 0.6301

# %%
import os
import optuna
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    # 采样超参数
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        model = XGBRegressor(n_jobs=-1, verbosity=0, **params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 以 MAE 为优化目标


# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best XGBoost Hyperparameters via Optuna ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 14:20:23,873] A new study created in memory with name: no-name-0761a311-7be5-49aa-8805-f9496e5a72e1
# [I 2025-05-16 14:22:33,822] Trial 0 finished with value: 0.7064856290817261 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 8, 'subsample': 0.8795975452591109, 'colsample_bytree': 0.6624074561769746}. Best is trial 0 with value: 0.7064856290817261.
# [I 2025-05-16 14:24:42,207] Trial 1 finished with value: 0.6713321208953857 and parameters: {'n_estimators': 200, 'learning_rate': 0.011900590783184251, 'max_depth': 9, 'subsample': 0.8803345035229626, 'colsample_bytree': 0.8832290311184181}. Best is trial 1 with value: 0.6713321208953857.
# [I 2025-05-16 14:25:20,208] Trial 2 finished with value: 0.6561864018440247 and parameters: {'n_estimators': 100, 'learning_rate': 0.18276027831785724, 'max_depth': 8, 'subsample': 0.7637017332034828, 'colsample_bytree': 0.6727299868828402}. Best is trial 2 with value: 0.6561864018440247.
# [I 2025-05-16 14:26:16,544] Trial 3 finished with value: 0.629952073097229 and parameters: {'n_estimators': 200, 'learning_rate': 0.024878734419814436, 'max_depth': 6, 'subsample': 0.8295835055926347, 'colsample_bytree': 0.7164916560792167}. Best is trial 3 with value: 0.629952073097229.
# [I 2025-05-16 14:28:39,660] Trial 4 finished with value: 0.6273737549781799 and parameters: {'n_estimators': 700, 'learning_rate': 0.01518747922672247, 'max_depth': 5, 'subsample': 0.8099085529881075, 'colsample_bytree': 0.7824279936868144}. Best is trial 4 with value: 0.6273737549781799.
# [I 2025-05-16 14:31:47,840] Trial 5 finished with value: 0.6305997371673584 and parameters: {'n_estimators': 800, 'learning_rate': 0.018187859051288217, 'max_depth': 6, 'subsample': 0.8777243706586128, 'colsample_bytree': 0.6185801650879991}. Best is trial 4 with value: 0.6273737549781799.
# [I 2025-05-16 14:33:12,523] Trial 6 finished with value: 0.6262723803520203 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'subsample': 0.984665661176, 'colsample_bytree': 0.9862528132298237}. Best is trial 6 with value: 0.6262723803520203.
# [I 2025-05-16 14:34:55,837] Trial 7 finished with value: 0.6254624128341675 and parameters: {'n_estimators': 900, 'learning_rate': 0.0249064396938244, 'max_depth': 3, 'subsample': 0.905269907953647, 'colsample_bytree': 0.7760609974958406}. Best is trial 7 with value: 0.6254624128341675.
# [I 2025-05-16 14:35:20,647] Trial 8 finished with value: 0.6272273063659668 and parameters: {'n_estimators': 200, 'learning_rate': 0.04407984038169244, 'max_depth': 3, 'subsample': 0.9727961206236346, 'colsample_bytree': 0.7035119926400067}. Best is trial 7 with value: 0.6254624128341675.
# [I 2025-05-16 14:38:00,212] Trial 9 finished with value: 0.6335340738296509 and parameters: {'n_estimators': 700, 'learning_rate': 0.02544166090938368, 'max_depth': 6, 'subsample': 0.8640130838029838, 'colsample_bytree': 0.6739417822102108}. Best is trial 7 with value: 0.6254624128341675.
# [I 2025-05-16 14:40:36,951] Trial 10 finished with value: 0.6496659517288208 and parameters: {'n_estimators': 1000, 'learning_rate': 0.08138762607805286, 'max_depth': 4, 'subsample': 0.7053885626844458, 'colsample_bytree': 0.8560354009870226}. Best is trial 7 with value: 0.6254624128341675.
# [I 2025-05-16 14:42:32,326] Trial 11 finished with value: 0.6279860734939575 and parameters: {'n_estimators': 1000, 'learning_rate': 0.03962196116773197, 'max_depth': 3, 'subsample': 0.9941994740078894, 'colsample_bytree': 0.9926743653872057}. Best is trial 7 with value: 0.6254624128341675.
# [I 2025-05-16 14:44:46,191] Trial 12 finished with value: 0.6248492002487183 and parameters: {'n_estimators': 800, 'learning_rate': 0.010259443333354297, 'max_depth': 4, 'subsample': 0.9465244376887645, 'colsample_bytree': 0.9976023236378931}. Best is trial 12 with value: 0.6248492002487183.
# [I 2025-05-16 14:47:10,088] Trial 13 finished with value: 0.6254997253417969 and parameters: {'n_estimators': 900, 'learning_rate': 0.010571183495838844, 'max_depth': 4, 'subsample': 0.9338716506768701, 'colsample_bytree': 0.8028657451835427}. Best is trial 12 with value: 0.6248492002487183.
# [I 2025-05-16 14:48:27,403] Trial 14 finished with value: 0.6323952674865723 and parameters: {'n_estimators': 500, 'learning_rate': 0.07890559538527207, 'max_depth': 4, 'subsample': 0.9313750894119706, 'colsample_bytree': 0.9186002849408451}. Best is trial 12 with value: 0.6248492002487183.
# [I 2025-05-16 14:51:00,868] Trial 15 finished with value: 0.6297604441642761 and parameters: {'n_estimators': 800, 'learning_rate': 0.025484174238745907, 'max_depth': 5, 'subsample': 0.9155157609016997, 'colsample_bytree': 0.7811150356967275}. Best is trial 12 with value: 0.6248492002487183.
# [I 2025-05-16 14:53:56,399] Trial 16 finished with value: 0.6478786468505859 and parameters: {'n_estimators': 900, 'learning_rate': 0.06008276753205654, 'max_depth': 5, 'subsample': 0.9458094791882845, 'colsample_bytree': 0.9375920406844779}. Best is trial 12 with value: 0.6248492002487183.
# [I 2025-05-16 14:55:14,753] Trial 17 finished with value: 0.626231849193573 and parameters: {'n_estimators': 500, 'learning_rate': 0.031676989527899345, 'max_depth': 4, 'subsample': 0.9034171950968508, 'colsample_bytree': 0.8390095246107369}. Best is trial 12 with value: 0.6248492002487183.
# [I 2025-05-16 14:56:28,599] Trial 18 finished with value: 0.6269291639328003 and parameters: {'n_estimators': 600, 'learning_rate': 0.013287880046329383, 'max_depth': 3, 'subsample': 0.9530007978442809, 'colsample_bytree': 0.733440490092321}. Best is trial 12 with value: 0.6248492002487183.
# [I 2025-05-16 14:59:24,856] Trial 19 finished with value: 0.6293400526046753 and parameters: {'n_estimators': 900, 'learning_rate': 0.018924333660360795, 'max_depth': 5, 'subsample': 0.8308944730385497, 'colsample_bytree': 0.7492569728287382}. Best is trial 12 with value: 0.6248492002487183.
# [I 2025-05-16 15:03:32,966] Trial 20 finished with value: 0.7172730565071106 and parameters: {'n_estimators': 800, 'learning_rate': 0.1326460524236043, 'max_depth': 7, 'subsample': 0.7930203791848457, 'colsample_bytree': 0.8258276851789318}. Best is trial 12 with value: 0.6248492002487183.
# [I 2025-05-16 15:05:58,578] Trial 21 finished with value: 0.6254274845123291 and parameters: {'n_estimators': 900, 'learning_rate': 0.010015324673924167, 'max_depth': 4, 'subsample': 0.9140826077285644, 'colsample_bytree': 0.8064114554738082}. Best is trial 12 with value: 0.6248492002487183.
# [I 2025-05-16 15:08:40,111] Trial 22 finished with value: 0.6247394680976868 and parameters: {'n_estimators': 1000, 'learning_rate': 0.010191401002039057, 'max_depth': 4, 'subsample': 0.904510523471445, 'colsample_bytree': 0.8850164594778455}. Best is trial 22 with value: 0.6247394680976868.
# [I 2025-05-16 15:11:20,356] Trial 23 finished with value: 0.6252375841140747 and parameters: {'n_estimators': 1000, 'learning_rate': 0.01129147592530779, 'max_depth': 4, 'subsample': 0.9614007456601016, 'colsample_bytree': 0.9397679525668923}. Best is trial 22 with value: 0.6247394680976868.
# [I 2025-05-16 15:14:40,451] Trial 24 finished with value: 0.6281934380531311 and parameters: {'n_estimators': 1000, 'learning_rate': 0.01367374929022683, 'max_depth': 5, 'subsample': 0.9785929321297663, 'colsample_bytree': 0.9462838903904975}. Best is trial 22 with value: 0.6247394680976868.
# [I 2025-05-16 15:17:21,559] Trial 25 finished with value: 0.6254458427429199 and parameters: {'n_estimators': 1000, 'learning_rate': 0.010148597693759642, 'max_depth': 4, 'subsample': 0.9672487781039704, 'colsample_bytree': 0.892693725219762}. Best is trial 22 with value: 0.6247394680976868.
# [I 2025-05-16 15:20:39,040] Trial 26 finished with value: 0.6326248049736023 and parameters: {'n_estimators': 800, 'learning_rate': 0.020612963638015458, 'max_depth': 6, 'subsample': 0.9498255829901643, 'colsample_bytree': 0.9585031877086172}. Best is trial 22 with value: 0.6247394680976868.
# [I 2025-05-16 15:25:31,278] Trial 27 finished with value: 0.6379034519195557 and parameters: {'n_estimators': 1000, 'learning_rate': 0.013294598563590682, 'max_depth': 7, 'subsample': 0.9988829967043511, 'colsample_bytree': 0.9056931020312987}. Best is trial 22 with value: 0.6247394680976868.
# [I 2025-05-16 15:27:12,023] Trial 28 finished with value: 0.6245108842849731 and parameters: {'n_estimators': 600, 'learning_rate': 0.012129665137079693, 'max_depth': 4, 'subsample': 0.8962924079585348, 'colsample_bytree': 0.966016691669086}. Best is trial 28 with value: 0.6245108842849731.
# [I 2025-05-16 15:28:41,643] Trial 29 finished with value: 0.6264652609825134 and parameters: {'n_estimators': 400, 'learning_rate': 0.01568982136234925, 'max_depth': 5, 'subsample': 0.8854849891485131, 'colsample_bytree': 0.9952155156788184}. Best is trial 28 with value: 0.6245108842849731.
# === Best XGBoost Hyperparameters via Optuna ===
# {'n_estimators': 600, 'learning_rate': 0.012129665137079693, 'max_depth': 4, 'subsample': 0.8962924079585348, 'colsample_bytree': 0.966016691669086}
# 10-Fold Mean MAE = 0.6245

# %%
import os
import optuna
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'objective': 'poisson',         # ✅ 强制正输出
        'n_jobs': -1,
        'verbose': -1
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        # Poisson 回归要求标签必须大于 0
        if np.any(y_train <= 0) or np.any(y_val <= 0):
            return np.inf

        model = LGBMRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 使用 MAE 作为优化目标

# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 15:28:41,732] A new study created in memory with name: no-name-82912cff-9fcb-4c25-9b5b-d2d2c40ed900
# [I 2025-05-16 15:29:10,919] Trial 0 finished with value: 0.6262039910588009 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 10, 'num_leaves': 68, 'feature_fraction': 0.6624074561769746, 'bagging_fraction': 0.662397808134481}. Best is trial 0 with value: 0.6262039910588009.
# [I 2025-05-16 15:29:24,020] Trial 1 finished with value: 0.6198996447685847 and parameters: {'n_estimators': 100, 'learning_rate': 0.13394334706750485, 'max_depth': 9, 'num_leaves': 77, 'feature_fraction': 0.608233797718321, 'bagging_fraction': 0.9879639408647978}. Best is trial 1 with value: 0.6198996447685847.
# [I 2025-05-16 15:29:59,616] Trial 2 finished with value: 0.6224811708979743 and parameters: {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}. Best is trial 1 with value: 0.6198996447685847.
# [I 2025-05-16 15:30:39,073] Trial 3 finished with value: 0.6203660416403499 and parameters: {'n_estimators': 500, 'learning_rate': 0.023927528765580644, 'max_depth': 9, 'num_leaves': 31, 'feature_fraction': 0.7168578594140873, 'bagging_fraction': 0.7465447373174767}. Best is trial 1 with value: 0.6198996447685847.
# [I 2025-05-16 15:30:57,974] Trial 4 finished with value: 0.6194201298015911 and parameters: {'n_estimators': 500, 'learning_rate': 0.10508421338691762, 'max_depth': 4, 'num_leaves': 61, 'feature_fraction': 0.836965827544817, 'bagging_fraction': 0.6185801650879991}. Best is trial 4 with value: 0.6194201298015911.
# [I 2025-05-16 15:31:28,435] Trial 5 finished with value: 0.6328378190630275 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'num_leaves': 96, 'feature_fraction': 0.9862528132298237, 'bagging_fraction': 0.9233589392465844}. Best is trial 4 with value: 0.6194201298015911.
# [I 2025-05-16 15:32:13,521] Trial 6 finished with value: 0.6490396002914847 and parameters: {'n_estimators': 400, 'learning_rate': 0.013399060561509796, 'max_depth': 9, 'num_leaves': 55, 'feature_fraction': 0.6488152939379115, 'bagging_fraction': 0.798070764044508}. Best is trial 4 with value: 0.6194201298015911.
# [I 2025-05-16 15:32:21,380] Trial 7 finished with value: 0.6201544078227215 and parameters: {'n_estimators': 100, 'learning_rate': 0.15242391728466367, 'max_depth': 5, 'num_leaves': 73, 'feature_fraction': 0.7246844304357644, 'bagging_fraction': 0.8080272084711243}. Best is trial 4 with value: 0.6194201298015911.
# [I 2025-05-16 15:34:02,819] Trial 8 finished with value: 0.6231018614164209 and parameters: {'n_estimators': 600, 'learning_rate': 0.017398074711291726, 'max_depth': 12, 'num_leaves': 82, 'feature_fraction': 0.9757995766256756, 'bagging_fraction': 0.9579309401710595}. Best is trial 4 with value: 0.6194201298015911.
# [I 2025-05-16 15:34:17,565] Trial 9 finished with value: 0.6182425284178816 and parameters: {'n_estimators': 600, 'learning_rate': 0.15826541904647565, 'max_depth': 3, 'num_leaves': 35, 'feature_fraction': 0.6180909155642152, 'bagging_fraction': 0.7301321323053057}. Best is trial 9 with value: 0.6182425284178816.
# [I 2025-05-16 15:35:03,836] Trial 10 finished with value: 0.6182025864419428 and parameters: {'n_estimators': 1000, 'learning_rate': 0.05448786658934785, 'max_depth': 6, 'num_leaves': 21, 'feature_fraction': 0.8548368194215872, 'bagging_fraction': 0.7157844251723191}. Best is trial 10 with value: 0.6182025864419428.
# [I 2025-05-16 15:35:49,377] Trial 11 finished with value: 0.6191802240605062 and parameters: {'n_estimators': 1000, 'learning_rate': 0.06485618348127573, 'max_depth': 6, 'num_leaves': 20, 'feature_fraction': 0.8681046418020243, 'bagging_fraction': 0.7082975218910191}. Best is trial 10 with value: 0.6182025864419428.
# [I 2025-05-16 15:36:43,336] Trial 12 finished with value: 0.6194243661669068 and parameters: {'n_estimators': 800, 'learning_rate': 0.03994605885086644, 'max_depth': 7, 'num_leaves': 45, 'feature_fraction': 0.9026965984059031, 'bagging_fraction': 0.7225330368110788}. Best is trial 10 with value: 0.6182025864419428.
# [I 2025-05-16 15:37:10,291] Trial 13 finished with value: 0.6199536607206522 and parameters: {'n_estimators': 1000, 'learning_rate': 0.07333691634108609, 'max_depth': 3, 'num_leaves': 20, 'feature_fraction': 0.7874820875551369, 'bagging_fraction': 0.870727223238246}. Best is trial 10 with value: 0.6182025864419428.
# [I 2025-05-16 15:37:36,144] Trial 14 finished with value: 0.6223294125824211 and parameters: {'n_estimators': 300, 'learning_rate': 0.035495356577202666, 'max_depth': 6, 'num_leaves': 38, 'feature_fraction': 0.7852406079009062, 'bagging_fraction': 0.6025560028366576}. Best is trial 10 with value: 0.6182025864419428.
# [I 2025-05-16 15:38:24,845] Trial 15 finished with value: 0.62093985297452 and parameters: {'n_estimators': 800, 'learning_rate': 0.06473192596401635, 'max_depth': 7, 'num_leaves': 48, 'feature_fraction': 0.9191979476316068, 'bagging_fraction': 0.6810632231251451}. Best is trial 10 with value: 0.6182025864419428.
# [I 2025-05-16 15:38:54,092] Trial 16 finished with value: 0.6190994197880981 and parameters: {'n_estimators': 700, 'learning_rate': 0.09784782950094346, 'max_depth': 5, 'num_leaves': 30, 'feature_fraction': 0.8278164017309051, 'bagging_fraction': 0.7562081961001288}. Best is trial 10 with value: 0.6182025864419428.
# [I 2025-05-16 15:39:15,658] Trial 17 finished with value: 0.6254401053999766 and parameters: {'n_estimators': 300, 'learning_rate': 0.02987464605830181, 'max_depth': 5, 'num_leaves': 42, 'feature_fraction': 0.7542313773209322, 'bagging_fraction': 0.6589195473341727}. Best is trial 10 with value: 0.6182025864419428.
# [I 2025-05-16 15:40:14,163] Trial 18 finished with value: 0.6196694566256824 and parameters: {'n_estimators': 900, 'learning_rate': 0.060768736016854986, 'max_depth': 12, 'num_leaves': 27, 'feature_fraction': 0.928283895005019, 'bagging_fraction': 0.8569448224557981}. Best is trial 10 with value: 0.6182025864419428.
# [I 2025-05-16 15:40:35,285] Trial 19 finished with value: 0.6532806315738496 and parameters: {'n_estimators': 600, 'learning_rate': 0.010646556846278058, 'max_depth': 3, 'num_leaves': 55, 'feature_fraction': 0.6028913625119565, 'bagging_fraction': 0.7629360550481512}. Best is trial 10 with value: 0.6182025864419428.
# [I 2025-05-16 15:41:17,014] Trial 20 finished with value: 0.6269701950426123 and parameters: {'n_estimators': 800, 'learning_rate': 0.19329314119373361, 'max_depth': 8, 'num_leaves': 24, 'feature_fraction': 0.8783392425058643, 'bagging_fraction': 0.8575285513628134}. Best is trial 10 with value: 0.6182025864419428.
# [I 2025-05-16 15:41:46,366] Trial 21 finished with value: 0.6186255377103808 and parameters: {'n_estimators': 700, 'learning_rate': 0.0946631159749368, 'max_depth': 5, 'num_leaves': 33, 'feature_fraction': 0.8294757870022368, 'bagging_fraction': 0.7645404901067385}. Best is trial 10 with value: 0.6182025864419428.
# [I 2025-05-16 15:42:10,903] Trial 22 finished with value: 0.6180093205340776 and parameters: {'n_estimators': 700, 'learning_rate': 0.1003288963824364, 'max_depth': 4, 'num_leaves': 32, 'feature_fraction': 0.830492967184296, 'bagging_fraction': 0.7132814630715303}. Best is trial 22 with value: 0.6180093205340776.
# [I 2025-05-16 15:42:41,880] Trial 23 finished with value: 0.6190236367643089 and parameters: {'n_estimators': 900, 'learning_rate': 0.12766428013373454, 'max_depth': 4, 'num_leaves': 41, 'feature_fraction': 0.865756581698276, 'bagging_fraction': 0.7030527868583896}. Best is trial 22 with value: 0.6180093205340776.
# [I 2025-05-16 15:43:15,666] Trial 24 finished with value: 0.620762034825624 and parameters: {'n_estimators': 600, 'learning_rate': 0.09088359044392683, 'max_depth': 6, 'num_leaves': 49, 'feature_fraction': 0.9506404929898924, 'bagging_fraction': 0.6452686703593588}. Best is trial 22 with value: 0.6180093205340776.
# [I 2025-05-16 15:43:48,849] Trial 25 finished with value: 0.6188713685326709 and parameters: {'n_estimators': 1000, 'learning_rate': 0.04959162020048189, 'max_depth': 4, 'num_leaves': 26, 'feature_fraction': 0.7616675016944651, 'bagging_fraction': 0.7274970383984627}. Best is trial 22 with value: 0.6180093205340776.
# [I 2025-05-16 15:44:10,205] Trial 26 finished with value: 0.6234217329229242 and parameters: {'n_estimators': 700, 'learning_rate': 0.049298743322260086, 'max_depth': 3, 'num_leaves': 36, 'feature_fraction': 0.8118007026627917, 'bagging_fraction': 0.688511497563122}. Best is trial 22 with value: 0.6180093205340776.
# [I 2025-05-16 15:44:26,678] Trial 27 finished with value: 0.6185810754025881 and parameters: {'n_estimators': 500, 'learning_rate': 0.11385230893307342, 'max_depth': 4, 'num_leaves': 20, 'feature_fraction': 0.6685168246065908, 'bagging_fraction': 0.7879259337101082}. Best is trial 22 with value: 0.6180093205340776.
# [I 2025-05-16 15:45:05,740] Trial 28 finished with value: 0.6181613921353016 and parameters: {'n_estimators': 800, 'learning_rate': 0.08104471099277216, 'max_depth': 6, 'num_leaves': 27, 'feature_fraction': 0.8887228613774588, 'bagging_fraction': 0.6346722751970895}. Best is trial 22 with value: 0.6180093205340776.
# [I 2025-05-16 15:45:53,281] Trial 29 finished with value: 0.6214793760603404 and parameters: {'n_estimators': 900, 'learning_rate': 0.07899810265324177, 'max_depth': 7, 'num_leaves': 27, 'feature_fraction': 0.8923933664059664, 'bagging_fraction': 0.6395029715062411}. Best is trial 22 with value: 0.6180093205340776.
# === Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===
# {'n_estimators': 700, 'learning_rate': 0.1003288963824364, 'max_depth': 4, 'num_leaves': 32, 'feature_fraction': 0.830492967184296, 'bagging_fraction': 0.7132814630715303}
# 10-Fold Mean MAE = 0.6180
