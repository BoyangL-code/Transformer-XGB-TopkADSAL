# %%
import numpy as np
import pickle
from sklearn.metrics import (
    mean_absolute_error,
    root_mean_squared_error,
    r2_score
)
from scipy.stats import pearsonr

def evaluate_regression_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = root_mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    pearson_r, _ = pearsonr(y_true, y_pred)

    print("✅ 总体评估指标：")
    print(f"MAE      = {mae:.4f}")
    print(f"RMSE     = {rmse:.4f}")
    print(f"R²       = {r2:.4f}")
    print(f"PearsonR = {pearson_r:.4f}")

    return {
        'MAE': mae,
        'RMSE': rmse,
        'R2': r2,
        'PearsonR': pearson_r
    }

# %% [markdown]
# #LGB

# %%
errors=[]
all_val =  []
all_pred = []
for i in range(10):
    val = np.load(f'./lgbm_cv_results/fold_{i}_y_true.npy')
    preds = np.load(f'./lgbm_cv_results/fold_{i}_y_pred.npy')
    error = np.maximum(val, preds) / np.minimum(val, preds)
    
    errors.append(error)
    all_val.append(val)
    all_pred.append(preds)
errors = np.concatenate(errors)

all_val = np.concatenate(all_val)
all_pred = np.concatenate(all_pred)

# %%
evaluate_regression_metrics(all_val, all_pred)
# Out:
# ✅ 总体评估指标：
# MAE      = 0.8810
# RMSE     = 1.2641
# R²       = 0.4920
# PearsonR = 0.7067
# {'MAE': 0.8809505549514193,
#  'RMSE': 1.2640761276226504,
#  'R2': 0.4920364051728926,
#  'PearsonR': 0.7066911543612373}

# %% [markdown]
# #XGB

# %%
errors=[]
all_val =  []
all_pred = []
for i in range(10):
    val = np.load(f'./xgb_cv_results/fold_{i}_y_true.npy')
    preds = np.load(f'./xgb_cv_results/fold_{i}_y_pred.npy')
    error = np.maximum(val, preds) / np.minimum(val, preds)
    
    errors.append(error)
    all_val.append(val)
    all_pred.append(preds)
errors = np.concatenate(errors)

all_val = np.concatenate(all_val)
all_pred = np.concatenate(all_pred)
evaluate_regression_metrics(all_val, all_pred)
# Out:
# ✅ 总体评估指标：
# MAE      = 0.9095
# RMSE     = 1.2273
# R²       = 0.5211
# PearsonR = 0.7240
# {'MAE': 0.9095498657460724,
#  'RMSE': 1.2273396784857598,
#  'R2': 0.5211321527401628,
#  'PearsonR': 0.724004506982753}

# %% [markdown]
# #DNN

# %%
errors=[]
all_val =  []
all_pred = []
for i in range(10):
    val = np.load(f'./dnn_cv_results/fold_{i}_y_true.npy')
    preds = np.load(f'./dnn_cv_results/fold_{i}_y_pred.npy')
    error = np.maximum(val, preds) / np.minimum(val, preds)
    
    errors.append(error)
    all_val.append(val)
    all_pred.append(preds)
errors = np.concatenate(errors)

all_val = np.concatenate(all_val)
all_pred = np.concatenate(all_pred)

# %%
evaluate_regression_metrics(all_val, all_pred)
# Out:
# ✅ 总体评估指标：
# MAE      = 1.1037
# RMSE     = 1.5783
# R²       = 0.2081
# PearsonR = 0.5733
# {'MAE': 1.1037167540338064,
#  'RMSE': 1.5783216674185476,
#  'R2': 0.20808755879074814,
#  'PearsonR': 0.5732531725386597}
