# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import torch
from sklearn.model_selection import StratifiedKFold
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.metrics import precision_recall_curve, auc
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import joblib
import optuna
from rdkit.Chem import Descriptors, AllChem
from tqdm import tqdm  # 导入tqdm
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GroupKFold

# %%
# 函数：将SMILES转换为分子描述符和指纹
def smiles_to_features(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None
    # 提取描述符
    descriptors = [
        Descriptors.MolWt(mol),  # 分子量
        Descriptors.MolLogP(mol),  # LogP
        Descriptors.NumHDonors(mol),  # 氢键供体数量
        Descriptors.NumHAcceptors(mol)  # 氢键受体数量
    ]
    # 生成Morgan指纹
    fingerprint = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=2048)
    fingerprint_array = np.zeros((2048,))
    Chem.DataStructs.ConvertToNumpyArray(fingerprint, fingerprint_array)
    # 合并描述符和指纹
    features = np.concatenate([descriptors, fingerprint_array])
    return features

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold
from tqdm import tqdm
import optuna
import numpy as np

def train_evaluate_regression_model_with_optuna(model_name, model_class, param_func, X, y, groups):
    def objective(trial):
        params = param_func(trial)
        model = model_class(**params)

        gkf = GroupKFold(n_splits=10)
        maes = []

        for train_idx, val_idx in tqdm(gkf.split(X, y, groups=groups), total=10, desc=f"Training {model_name}"):
            X_train, X_val = X[train_idx], X[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            model.fit(X_train, y_train)
            y_pred = model.predict(X_val)

            # ✅ 计算 MAE
            mae = mean_absolute_error(y_val, y_pred)
            maes.append(mae)

        return np.mean(maes)

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=30)

    print(f'Best parameters for {model_name}: {study.best_params}')
    print(f'Best mean MAE: {study.best_value:.4f}')

# %%
# 数据预处理
df = pd.read_excel('../invertebrates_unique.xlsx')
labels = df['mgperL'].values
smiles_list = df['SMILES_Canonical_RDKit'].tolist()
endpoints_a = df['endpoint']
Duration_Values_a = df['Duration_Value'].values
effects_a = df['effect']

# %%
features = []
new_labels = []
new_smiles_list = []
endpoints = []
Duration_Values = []
effects =[]


for smiles, label,a,b,c in zip(smiles_list, labels,Duration_Values_a,effects_a,endpoints_a):
    feature = smiles_to_features(smiles)
    if feature is not None:
        features.append(feature)
        new_labels.append(label)
        new_smiles_list.append(smiles)
        Duration_Values.append(a)
        effects.append(b)
        endpoints.append(c)

X = np.array(features)
y = np.array(new_labels)
groups = new_smiles_list  # 可直接用于 GroupKFold

# %%
def encode_column(zz):
    zz_series = pd.Series(zz)  # 转换为 Series
    unique_values = zz_series.unique()
    if len(unique_values) > 1:
        encoder = OneHotEncoder(sparse_output=False)
        return encoder.fit_transform(zz_series.values.reshape(-1, 1))
    else:
        return None  # 只有一种类别时忽略

Duration_Values =pd.Series(Duration_Values)


# 编码 effect、endpoint 和 species_group 列
effect_encoded = encode_column(effects)
endpoint_encoded = encode_column(endpoints)
#species_encoded = encode_column(df, 'species_group')

# # 将需要的列拼接成输入 X
X = np.hstack((X, Duration_Values.values.reshape(-1, 1)))

# # 拼接编码后的列（如果存在）
for encoded_feature in [effect_encoded, endpoint_encoded]:
     if encoded_feature is not None:
         X = np.hstack((X, encoded_feature))



y=np.log1p(y)

# %%
def xgb_param_func(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 100, 600),
        'max_depth': trial.suggest_int('max_depth', 5, 20),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),   # L1 正则
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0)  # L2 正则
    }
from xgboost import XGBRegressor

train_evaluate_regression_model_with_optuna(
    "XGBoost",
    XGBRegressor,
    xgb_param_func,
    X, y, groups
)
# Out:
# [I 2025-05-15 19:53:09,640] A new study created in memory with name: no-name-8458f978-e543-440e-a76e-68491b6bbf2a
# Training XGBoost: 100%|██████████| 10/10 [01:36<00:00,  9.61s/it]
# [I 2025-05-15 19:54:45,754] Trial 0 finished with value: 1.068989110033044 and parameters: {'n_estimators': 148, 'max_depth': 12, 'learning_rate': 0.01272139960858167, 'subsample': 0.6077221072658487, 'colsample_bytree': 0.7072883838822673, 'reg_alpha': 0.5320370731192986, 'reg_lambda': 0.052667274292307664}. Best is trial 0 with value: 1.068989110033044.
# Training XGBoost: 100%|██████████| 10/10 [04:20<00:00, 26.00s/it]
# [I 2025-05-15 19:59:05,802] Trial 1 finished with value: 0.9355130698054952 and parameters: {'n_estimators': 537, 'max_depth': 16, 'learning_rate': 0.13984682640905033, 'subsample': 0.8075755896973895, 'colsample_bytree': 0.8451122976486564, 'reg_alpha': 0.03768996775773148, 'reg_lambda': 0.40652033485851136}. Best is trial 1 with value: 0.9355130698054952.
# Training XGBoost: 100%|██████████| 10/10 [03:27<00:00, 20.76s/it]
# [I 2025-05-15 20:02:33,364] Trial 2 finished with value: 0.9175755615730496 and parameters: {'n_estimators': 472, 'max_depth': 13, 'learning_rate': 0.09433523010134905, 'subsample': 0.7209559041354683, 'colsample_bytree': 0.9073778754014833, 'reg_alpha': 0.3570610559181603, 'reg_lambda': 0.11004846681747094}. Best is trial 2 with value: 0.9175755615730496.
# Training XGBoost: 100%|██████████| 10/10 [02:21<00:00, 14.16s/it]
# [I 2025-05-15 20:04:54,999] Trial 3 finished with value: 0.9373674437699583 and parameters: {'n_estimators': 266, 'max_depth': 13, 'learning_rate': 0.04333405446617826, 'subsample': 0.91118443559897, 'colsample_bytree': 0.9747562833584857, 'reg_alpha': 0.0027807984933684304, 'reg_lambda': 0.31337576375508935}. Best is trial 2 with value: 0.9175755615730496.
# Training XGBoost: 100%|██████████| 10/10 [03:38<00:00, 21.83s/it]
# [I 2025-05-15 20:08:33,307] Trial 4 finished with value: 0.9518967449635435 and parameters: {'n_estimators': 382, 'max_depth': 13, 'learning_rate': 0.27934435344023656, 'subsample': 0.7907803411169625, 'colsample_bytree': 0.9567107317081955, 'reg_alpha': 0.9271295766139714, 'reg_lambda': 0.25887604865402647}. Best is trial 2 with value: 0.9175755615730496.
# Training XGBoost: 100%|██████████| 10/10 [04:25<00:00, 26.54s/it]
# [I 2025-05-15 21:53:12,178] Trial 27 finished with value: 0.9169129424526824 and parameters: {'n_estimators': 419, 'max_depth': 18, 'learning_rate': 0.07861588945822712, 'subsample': 0.6401626663710436, 'colsample_bytree': 0.7962361525207483, 'reg_alpha': 0.733697816944639, 'reg_lambda': 0.5772420711105393}. Best is trial 21 with value: 0.9086763432659992.
# Training XGBoost: 100%|██████████| 10/10 [05:34<00:00, 33.44s/it]
# [I 2025-05-15 21:58:46,595] Trial 28 finished with value: 0.9197995861310229 and parameters: {'n_estimators': 479, 'max_depth': 19, 'learning_rate': 0.020338208738871422, 'subsample': 0.7483676129394798, 'colsample_bytree': 0.6251175387475609, 'reg_alpha': 0.8902827957289103, 'reg_lambda': 0.9926183831313098}. Best is trial 21 with value: 0.9086763432659992.
# Training XGBoost: 100%|██████████| 10/10 [01:56<00:00, 11.62s/it]
# [I 2025-05-15 22:00:42,806] Trial 29 finished with value: 1.0179643406440435 and parameters: {'n_estimators': 195, 'max_depth': 11, 'learning_rate': 0.015087385650742824, 'subsample': 0.7676991142358713, 'colsample_bytree': 0.7283945575452901, 'reg_alpha': 0.5522266845315008, 'reg_lambda': 0.7916051658523374}. Best is trial 21 with value: 0.9086763432659992.
# Best parameters for XGBoost: {'n_estimators': 507, 'max_depth': 18, 'learning_rate': 0.035566003197944014, 'subsample': 0.7674765798808308, 'colsample_bytree': 0.6045176250255039, 'reg_alpha': 0.8512966597578948, 'reg_lambda': 0.7564083362754037}
# Best mean MAE: 0.9087

# %%
from lightgbm import LGBMRegressor

def lgbm_param_func(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 100, 600),
        'max_depth': trial.suggest_int('max_depth', 5, 20),
        'num_leaves': trial.suggest_int('num_leaves', 20, 300),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
        'verbose': -1
    }

print("Training LightGBM (Poisson)...")
train_evaluate_regression_model_with_optuna(
    "LightGBM",
    lambda **params: LGBMRegressor(objective="poisson", **params),  # ✅ 加入 Poisson 目标
    lgbm_param_func,
    X, y, groups
)
# Out:
# [I 2025-05-15 22:00:42,815] A new study created in memory with name: no-name-a00e0575-f4bc-4b78-ad68-26c919a4a30d
# Training LightGBM (Poisson)...
# Training LightGBM: 100%|██████████| 10/10 [00:31<00:00,  3.14s/it]
# [I 2025-05-15 22:01:14,221] Trial 0 finished with value: 1.0082677116849692 and parameters: {'n_estimators': 336, 'max_depth': 10, 'num_leaves': 89, 'learning_rate': 0.024542132352145828, 'feature_fraction': 0.8300296706304368, 'bagging_fraction': 0.9439651203802403, 'bagging_freq': 3, 'reg_alpha': 0.5432974480300146, 'reg_lambda': 0.9435679403686943}. Best is trial 0 with value: 1.0082677116849692.
# Training LightGBM: 100%|██████████| 10/10 [00:46<00:00,  4.67s/it]
# [I 2025-05-15 22:02:00,943] Trial 1 finished with value: 0.8826137157692472 and parameters: {'n_estimators': 528, 'max_depth': 16, 'num_leaves': 230, 'learning_rate': 0.08378642200533595, 'feature_fraction': 0.8978635371118994, 'bagging_fraction': 0.9135792268292235, 'bagging_freq': 5, 'reg_alpha': 0.19051878718537374, 'reg_lambda': 0.49907801862168455}. Best is trial 1 with value: 0.8826137157692472.
# Training LightGBM: 100%|██████████| 10/10 [00:41<00:00,  4.17s/it]
# [I 2025-05-15 22:02:42,652] Trial 2 finished with value: 0.9299943302120234 and parameters: {'n_estimators': 451, 'max_depth': 15, 'num_leaves': 103, 'learning_rate': 0.03562585806319073, 'feature_fraction': 0.8153608453238075, 'bagging_fraction': 0.8489657861162928, 'bagging_freq': 3, 'reg_alpha': 0.6990655794271262, 'reg_lambda': 0.6685631404728624}. Best is trial 1 with value: 0.8826137157692472.
# Training LightGBM: 100%|██████████| 10/10 [00:18<00:00,  1.82s/it]
# [I 2025-05-15 22:03:00,876] Trial 3 finished with value: 1.1370393221467885 and parameters: {'n_estimators': 130, 'max_depth': 15, 'num_leaves': 111, 'learning_rate': 0.02015580149629352, 'feature_fraction': 0.9904368902671573, 'bagging_fraction': 0.6720054174931345, 'bagging_freq': 5, 'reg_alpha': 0.5959369613683171, 'reg_lambda': 0.33733042702752924}. Best is trial 1 with value: 0.8826137157692472.
# Training LightGBM: 100%|██████████| 10/10 [00:31<00:00,  3.20s/it]
# [I 2025-05-15 22:03:32,900] Trial 4 finished with value: 0.9095341512929412 and parameters: {'n_estimators': 536, 'max_depth': 10, 'num_leaves': 55, 'learning_rate': 0.0906026524982312, 'feature_fraction': 0.9131868792651374, 'bagging_fraction': 0.8871587653086896, 'bagging_freq': 2, 'reg_alpha': 0.1261299320879007, 'reg_lambda': 0.9354795194078548}. Best is trial 1 with value: 0.8826137157692472.
# Training LightGBM: 100%|██████████| 10/10 [00:33<00:00,  3.40s/it]
# [I 2025-05-15 22:04:06,919] Trial 5 finished with value: 0.9225596551658197 and parameters: {'n_estimators': 295, 'max_depth': 20, 'num_leaves': 123, 'learning_rate': 0.048881247873648934, 'feature_fraction': 0.7489568907383475, 'bagging_fraction': 0.8844913942346866, 'bagging_freq': 4, 'reg_alpha': 0.841604459786281, 'reg_lambda': 0.9137247687533733}. Best is trial 1 with value: 0.8826137157692472.
# Training LightGBM: 100%|██████████| 10/10 [00:29<00:00,  2.96s/it]
# [I 2025-05-15 22:04:36,574] Trial 6 finished with value: 0.8959771664129346 and parameters: {'n_estimators': 595, 'max_depth': 10, 'num_leaves': 106, 'learning_rate': 0.10774208678152626, 'feature_fraction': 0.6603016646111525, 'bagging_fraction': 0.9988757922211976, 'bagging_freq': 7, 'reg_alpha': 0.8634542333233708, 'reg_lambda': 0.20866232874215251}. Best is trial 1 with value: 0.8826137157692472.
# Training LightGBM: 100%|██████████| 10/10 [00:34<00:00,  3.46s/it]
# [I 2025-05-15 22:05:11,241] Trial 7 finished with value: 1.1533599073207619 and parameters: {'n_estimators': 233, 'max_depth': 13, 'num_leaves': 144, 'learning_rate': 0.010207452804264435, 'feature_fraction': 0.8783947318727783, 'bagging_fraction': 0.7752504111035774, 'bagging_freq': 4, 'reg_alpha': 0.18881532772057974, 'reg_lambda': 0.06241829384110609}. Best is trial 1 with value: 0.8826137157692472.
# Training LightGBM: 100%|██████████| 10/10 [00:45<00:00,  4.54s/it]
# [I 2025-05-15 22:05:56,713] Trial 8 finished with value: 0.9479503308743678 and parameters: {'n_estimators': 402, 'max_depth': 16, 'num_leaves': 131, 'learning_rate': 0.02650823368999087, 'feature_fraction': 0.9262404083887723, 'bagging_fraction': 0.7607550651447152, 'bagging_freq': 3, 'reg_alpha': 0.25398150134193576, 'reg_lambda': 0.6918023847342482}. Best is trial 1 with value: 0.8826137157692472.
# Training LightGBM: 100%|██████████| 10/10 [00:37<00:00,  3.79s/it]
# [I 2025-05-15 22:06:34,693] Trial 9 finished with value: 1.0434066545973724 and parameters: {'n_estimators': 210, 'max_depth': 19, 'num_leaves': 187, 'learning_rate': 0.018699007577805144, 'feature_fraction': 0.8575738248734741, 'bagging_fraction': 0.7459051103195228, 'bagging_freq': 5, 'reg_alpha': 0.1949984405640931, 'reg_lambda': 0.39035999442646097}. Best is trial 1 with value: 0.8826137157692472.
# Training LightGBM: 100%|██████████| 10/10 [00:38<00:00,  3.84s/it]
# [I 2025-05-15 22:07:13,188] Trial 10 finished with value: 0.902250194734119 and parameters: {'n_estimators': 496, 'max_depth': 18, 'num_leaves': 270, 'learning_rate': 0.23317440744047727, 'feature_fraction': 0.7280899333819375, 'bagging_fraction': 0.6005588268605386, 'bagging_freq': 7, 'reg_alpha': 0.00014601697182356488, 'reg_lambda': 0.5954395294289694}. Best is trial 1 with value: 0.8826137157692472.
# Training LightGBM: 100%|██████████| 10/10 [00:17<00:00,  1.76s/it]
# [I 2025-05-15 22:07:30,833] Trial 11 finished with value: 0.9625720003412018 and parameters: {'n_estimators': 600, 'max_depth': 5, 'num_leaves': 217, 'learning_rate': 0.1088325158643791, 'feature_fraction': 0.6212622974469402, 'bagging_fraction': 0.9849997422794533, 'bagging_freq': 7, 'reg_alpha': 0.9055508287646227, 'reg_lambda': 0.11564564071219723}. Best is trial 1 with value: 0.8826137157692472.
# Training LightGBM: 100%|██████████| 10/10 [00:28<00:00,  2.82s/it]
# [I 2025-05-15 22:07:59,113] Trial 12 finished with value: 0.9057126633104782 and parameters: {'n_estimators': 580, 'max_depth': 9, 'num_leaves': 294, 'learning_rate': 0.11521582926108596, 'feature_fraction': 0.6081824836906662, 'bagging_fraction': 0.9834157437411827, 'bagging_freq': 6, 'reg_alpha': 0.416334986844901, 'reg_lambda': 0.2524860806355822}. Best is trial 1 with value: 0.8826137157692472.
# Training LightGBM: 100%|██████████| 10/10 [00:18<00:00,  1.86s/it]
# [I 2025-05-15 22:08:17,809] Trial 13 finished with value: 0.9137011532678091 and parameters: {'n_estimators': 483, 'max_depth': 12, 'num_leaves': 21, 'learning_rate': 0.20598690134678715, 'feature_fraction': 0.70141326180882, 'bagging_fraction': 0.9329013095797619, 'bagging_freq': 6, 'reg_alpha': 0.36959329156219867, 'reg_lambda': 0.49264068728283017}. Best is trial 1 with value: 0.8826137157692472.
# [I 2025-05-15 22:12:03,809] Trial 20 finished with value: 0.8932454613308687 and parameters: {'n_estimators': 440, 'max_depth': 17, 'num_leaves': 255, 'learning_rate': 0.0794754419297599, 'feature_fraction': 0.8807955831244132, 'bagging_fraction': 0.7149565345243495, 'bagging_freq': 4, 'reg_alpha': 0.29347380158793746, 'reg_lambda': 0.7965228838484271}. Best is trial 17 with value: 0.8767407678602442.
# Training LightGBM: 100%|██████████| 10/10 [00:29<00:00,  2.96s/it]
# [I 2025-05-15 22:12:33,453] Trial 21 finished with value: 0.8894935640926007 and parameters: {'n_estimators': 362, 'max_depth': 14, 'num_leaves': 283, 'learning_rate': 0.14805478725108573, 'feature_fraction': 0.9421229452307124, 'bagging_fraction': 0.878746552622661, 'bagging_freq': 5, 'reg_alpha': 0.09066948265904784, 'reg_lambda': 0.543951864659725}. Best is trial 17 with value: 0.8767407678602442.
# Training LightGBM: 100%|██████████| 10/10 [00:28<00:00,  2.81s/it]
# [I 2025-05-15 22:13:01,624] Trial 22 finished with value: 0.8845725482319711 and parameters: {'n_estimators': 291, 'max_depth': 16, 'num_leaves': 298, 'learning_rate': 0.16806692153385844, 'feature_fraction': 0.9545258069229539, 'bagging_fraction': 0.9158610029487676, 'bagging_freq': 6, 'reg_alpha': 0.0990466147603885, 'reg_lambda': 0.7147098336574174}. Best is trial 17 with value: 0.8767407678602442.
# Training LightGBM: 100%|██████████| 10/10 [00:29<00:00,  2.94s/it]
# [I 2025-05-15 22:13:31,090] Trial 23 finished with value: 0.8904274763505307 and parameters: {'n_estimators': 275, 'max_depth': 18, 'num_leaves': 249, 'learning_rate': 0.14480076058218913, 'feature_fraction': 0.9571837824260476, 'bagging_fraction': 0.9226490015677545, 'bagging_freq': 6, 'reg_alpha': 0.162258066068928, 'reg_lambda': 0.79670655011075}. Best is trial 17 with value: 0.8767407678602442.
# Training LightGBM: 100%|██████████| 10/10 [00:29<00:00,  2.97s/it]
# [I 2025-05-15 22:14:00,898] Trial 24 finished with value: 0.9567428355980079 and parameters: {'n_estimators': 162, 'max_depth': 20, 'num_leaves': 205, 'learning_rate': 0.04756941490162333, 'feature_fraction': 0.8936925055005499, 'bagging_fraction': 0.8473462989095876, 'bagging_freq': 6, 'reg_alpha': 0.29050379055524744, 'reg_lambda': 0.6546443263745965}. Best is trial 17 with value: 0.8767407678602442.
# Training LightGBM: 100%|██████████| 10/10 [00:26<00:00,  2.69s/it]
# [I 2025-05-15 22:14:27,900] Trial 25 finished with value: 0.890578501020545 and parameters: {'n_estimators': 319, 'max_depth': 16, 'num_leaves': 241, 'learning_rate': 0.2814607225582859, 'feature_fraction': 0.8477868750540594, 'bagging_fraction': 0.9478788706301806, 'bagging_freq': 5, 'reg_alpha': 0.1006162589540301, 'reg_lambda': 0.7439748605388911}. Best is trial 17 with value: 0.8767407678602442.
# Training LightGBM: 100%|██████████| 10/10 [00:25<00:00,  2.54s/it]
# [I 2025-05-15 22:14:53,348] Trial 26 finished with value: 0.8893507861266375 and parameters: {'n_estimators': 238, 'max_depth': 18, 'num_leaves': 268, 'learning_rate': 0.20311126363711543, 'feature_fraction': 0.6474288328801099, 'bagging_fraction': 0.9097133113540365, 'bagging_freq': 4, 'reg_alpha': 0.23212704516553984, 'reg_lambda': 0.8761329908359847}. Best is trial 17 with value: 0.8767407678602442.
# Training LightGBM: 100%|██████████| 10/10 [00:40<00:00,  4.04s/it]
# [I 2025-05-15 22:15:33,776] Trial 27 finished with value: 0.8836589625207241 and parameters: {'n_estimators': 481, 'max_depth': 16, 'num_leaves': 169, 'learning_rate': 0.08810835041969851, 'feature_fraction': 0.7167417181179622, 'bagging_fraction': 0.9572578052402552, 'bagging_freq': 6, 'reg_alpha': 0.00351354260158325, 'reg_lambda': 0.6272646043407364}. Best is trial 17 with value: 0.8767407678602442.
# Training LightGBM: 100%|██████████| 10/10 [00:36<00:00,  3.66s/it]
# [I 2025-05-15 22:16:10,470] Trial 28 finished with value: 0.8880548346506222 and parameters: {'n_estimators': 477, 'max_depth': 14, 'num_leaves': 166, 'learning_rate': 0.08723945923433431, 'feature_fraction': 0.7009989660822691, 'bagging_fraction': 0.9655970226986926, 'bagging_freq': 5, 'reg_alpha': 0.020408779085674573, 'reg_lambda': 0.6221246467174485}. Best is trial 17 with value: 0.8767407678602442.
# Training LightGBM: 100%|██████████| 10/10 [00:58<00:00,  5.86s/it]
# [I 2025-05-15 22:17:09,145] Trial 29 finished with value: 0.9073649977638389 and parameters: {'n_estimators': 556, 'max_depth': 17, 'num_leaves': 186, 'learning_rate': 0.036148809443790134, 'feature_fraction': 0.75280805730229, 'bagging_fraction': 0.948747379142055, 'bagging_freq': 6, 'reg_alpha': 0.5126601419265359, 'reg_lambda': 0.4791250600837551}. Best is trial 17 with value: 0.8767407678602442.
# Best parameters for LightGBM: {'n_estimators': 539, 'max_depth': 17, 'num_leaves': 258, 'learning_rate': 0.16591285497839334, 'feature_fraction': 0.6728806969840969, 'bagging_fraction': 0.8935096925122699, 'bagging_freq': 5, 'reg_alpha': 0.020446784102263638, 'reg_lambda': 0.7921506205908129}
# Best mean MAE: 0.8767

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
import optuna
import numpy as np


class DNNWithSoftplus(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        act_fn = {
            'relu': nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh': nn.Tanh()
        }[activation]
        layers = []
        prev_dim = input_dim
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act_fn]
            prev_dim = h
        layers += [nn.Linear(prev_dim, 1)]
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return F.softplus(self.net(x)).squeeze(-1)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
def train_dnn_with_optuna_pytorch(X, y, groups, device=device):
    def dnn_param_func(trial):
        return {
            'hidden_layer_sizes': trial.suggest_categorical(
                'hidden_layer_sizes', [(50,), (100,), (150,), (100, 50), (150, 100, 50)]
            ),
            'activation': trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh']),
            'alpha': trial.suggest_float('alpha', 1e-5, 1e-2, log=True),
            'learning_rate': trial.suggest_float('learning_rate_init', 1e-4, 1e-2, log=True),
            'optimizer': trial.suggest_categorical('solver', ['adam', 'sgd'])
        }

    def objective(trial):
        params = dnn_param_func(trial)
        model = DNNWithSoftplus(
            input_dim=X.shape[1],
            hidden_sizes=params['hidden_layer_sizes'],
            activation=params['activation']
        ).to(device)

        optimizer = {
            'adam': torch.optim.Adam,
            'sgd': torch.optim.SGD
        }[params['optimizer']](model.parameters(), lr=params['learning_rate'], weight_decay=params['alpha'])

        loss_fn = nn.MSELoss()
        gkf = GroupKFold(n_splits=10)
        fold_maes = []

        for train_idx, val_idx in gkf.split(X, y, groups=groups):
            X_train, y_train = X[train_idx], y[train_idx]
            X_val, y_val = X[val_idx], y[val_idx]

            scaler = StandardScaler()
            X_train = scaler.fit_transform(X_train)
            X_val = scaler.transform(X_val)

            train_ds = TensorDataset(torch.tensor(X_train).float(), torch.tensor(y_train).float())
            train_loader = DataLoader(train_ds, batch_size=256, shuffle=True)

            model.train()
            for epoch in range(100):
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    pred = model(xb)
                    loss = loss_fn(pred, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            with torch.no_grad():
                val_preds = model(torch.tensor(X_val).float().to(device)).cpu().numpy()
                mae = mean_absolute_error(y_val, val_preds)
                fold_maes.append(mae)

        return np.mean(fold_maes)

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=30)
    print("\n✅ Best Parameters Found:")
    print(study.best_params)
    print(f"Mean MAE = {study.best_value:.4f}")
    return study.best_params


best_dnn_params = train_dnn_with_optuna_pytorch(X, y, groups)
# Out:
# [I 2025-05-15 16:44:22,896] A new study created in memory with name: no-name-dfd25c1a-5cf6-4071-8233-769a1f671662
# [I 2025-05-15 16:48:48,570] Trial 0 finished with value: 0.8266779462358235 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'alpha': 0.00028129418233882424, 'learning_rate_init': 0.0016792464795671474, 'solver': 'adam'}. Best is trial 0 with value: 0.8266779462358235.
# [I 2025-05-15 16:53:22,285] Trial 1 finished with value: 0.4330471533778829 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 2.7928254873023556e-05, 'learning_rate_init': 0.000105225400681654, 'solver': 'adam'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 16:57:15,905] Trial 2 finished with value: 0.812817461535077 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'alpha': 1.599737625833397e-05, 'learning_rate_init': 0.0001301758253117947, 'solver': 'sgd'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:01:51,972] Trial 3 finished with value: 0.5718826174369713 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 3.930922141271239e-05, 'learning_rate_init': 0.0008652605118570764, 'solver': 'adam'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:06:11,707] Trial 4 finished with value: 1.0352416721760305 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'alpha': 0.004343016310366699, 'learning_rate_init': 0.002074452854260066, 'solver': 'adam'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:10:04,049] Trial 5 finished with value: 0.6513339204347799 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.0001552789756050316, 'learning_rate_init': 0.00033995134983414474, 'solver': 'sgd'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:14:06,669] Trial 6 finished with value: 0.5370582745441405 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'alpha': 0.00013800227114164627, 'learning_rate_init': 0.0030718694764632023, 'solver': 'sgd'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:18:27,279] Trial 7 finished with value: 0.5637113998533396 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'alpha': 4.4917410018465886e-05, 'learning_rate_init': 0.00135422162832867, 'solver': 'sgd'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:22:18,684] Trial 8 finished with value: 0.5134816481920651 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'alpha': 0.00011100828239296793, 'learning_rate_init': 0.005555749842581349, 'solver': 'sgd'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:26:05,093] Trial 9 finished with value: 0.5315403564952628 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'alpha': 0.0002838812655427502, 'learning_rate_init': 0.0031456407824620703, 'solver': 'sgd'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:30:08,575] Trial 10 finished with value: 0.5684865988406951 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'alpha': 0.0015159261117476059, 'learning_rate_init': 0.00011587976428828668, 'solver': 'adam'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:33:58,674] Trial 11 finished with value: 1.0178836928450021 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'logistic', 'alpha': 1.3776019654882473e-05, 'learning_rate_init': 0.008098031599408816, 'solver': 'adam'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:37:21,345] Trial 12 finished with value: 0.4778360271060144 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'alpha': 5.3312960458655046e-05, 'learning_rate_init': 0.009105216268877402, 'solver': 'sgd'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:41:21,051] Trial 13 finished with value: 0.4969496443531054 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 4.2800878206566364e-05, 'learning_rate_init': 0.0004596824770168221, 'solver': 'adam'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:45:08,554] Trial 14 finished with value: 0.6763994645063114 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'alpha': 0.0009186285054842079, 'learning_rate_init': 0.00031408273990508005, 'solver': 'sgd'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:49:27,513] Trial 15 finished with value: 0.48524182077738764 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'alpha': 1.0412248299254287e-05, 'learning_rate_init': 0.0006552204628212548, 'solver': 'adam'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:53:40,663] Trial 16 finished with value: 0.48495547909659475 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'alpha': 2.9695340479164407e-05, 'learning_rate_init': 0.00019413247306539574, 'solver': 'adam'}. Best is trial 1 with value: 0.4330471533778829.
# [I 2025-05-15 17:58:11,815] Trial 17 finished with value: 0.4283051115039462 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 6.728148441319557e-05, 'learning_rate_init': 0.008226267663377968, 'solver': 'sgd'}. Best is trial 17 with value: 0.4283051115039462.
# [I 2025-05-15 18:02:41,703] Trial 18 finished with value: 0.8339405948805277 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'logistic', 'alpha': 0.0008245896225991924, 'learning_rate_init': 0.004309579721377977, 'solver': 'sgd'}. Best is trial 17 with value: 0.4283051115039462.
# [I 2025-05-15 18:07:33,153] Trial 19 finished with value: 0.47221363705086095 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 0.00010724536116232924, 'learning_rate_init': 0.0001828201365580117, 'solver': 'adam'}. Best is trial 17 with value: 0.4283051115039462.
# [I 2025-05-15 18:12:22,416] Trial 20 finished with value: 0.9578072246067313 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 0.008427267934240621, 'learning_rate_init': 0.0011536176435670658, 'solver': 'adam'}. Best is trial 17 with value: 0.4283051115039462.
# [I 2025-05-15 18:17:12,453] Trial 21 finished with value: 0.46083983788865784 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 8.378809198959707e-05, 'learning_rate_init': 0.00022733363389421747, 'solver': 'adam'}. Best is trial 17 with value: 0.4283051115039462.
# [I 2025-05-15 18:22:09,427] Trial 22 finished with value: 0.4609551880596493 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 6.891602433462537e-05, 'learning_rate_init': 0.00021769290998174712, 'solver': 'adam'}. Best is trial 17 with value: 0.4283051115039462.
# [I 2025-05-15 18:27:12,478] Trial 23 finished with value: 0.43668413406251394 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 2.4449830613258633e-05, 'learning_rate_init': 0.00010347816763286207, 'solver': 'adam'}. Best is trial 17 with value: 0.4283051115039462.
# [I 2025-05-15 18:31:56,409] Trial 24 finished with value: 0.42885823976364923 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 2.170306526033979e-05, 'learning_rate_init': 0.00010276764204564147, 'solver': 'adam'}. Best is trial 17 with value: 0.4283051115039462.
# [I 2025-05-15 18:36:40,274] Trial 25 finished with value: 0.5129129804168977 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'logistic', 'alpha': 2.1008771710474382e-05, 'learning_rate_init': 0.000591129446753981, 'solver': 'adam'}. Best is trial 17 with value: 0.4283051115039462.
# [I 2025-05-15 18:41:04,503] Trial 26 finished with value: 0.8086092583145609 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 2.621911544336318e-05, 'learning_rate_init': 0.00014707706651168962, 'solver': 'sgd'}. Best is trial 17 with value: 0.4283051115039462.
# [I 2025-05-15 18:45:16,467] Trial 27 finished with value: 0.4569958286561306 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'alpha': 1.1000860441051511e-05, 'learning_rate_init': 0.00031686083885182185, 'solver': 'adam'}. Best is trial 17 with value: 0.4283051115039462.
# [I 2025-05-15 18:49:42,490] Trial 28 finished with value: 0.4719244260363517 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 0.00019355891697566744, 'learning_rate_init': 0.0022986306911570225, 'solver': 'sgd'}. Best is trial 17 with value: 0.4283051115039462.
# [I 2025-05-15 18:53:57,657] Trial 29 finished with value: 0.5534404854563983 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'alpha': 1.7850612511559204e-05, 'learning_rate_init': 0.00010086961265749719, 'solver': 'adam'}. Best is trial 17 with value: 0.4283051115039462.
# ✅ Best Parameters Found:
# {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 6.728148441319557e-05, 'learning_rate_init': 0.008226267663377968, 'solver': 'sgd'}
# Mean MAE = 0.4283
