# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import random
import torch
import numpy as np
# 固定随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # for multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)  # 设置固定种子

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import optuna
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# ----------------- CONFIGURATION -----------------
n_folds    = 10
n_trials   = 30
data_dir   = "./k_folds_model/embeddings"
batch_size = 256
num_epochs = 200
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------- MODEL DEFINITION -----------------
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        layers = []
        prev_dim = input_dim
        act = {
            'relu':     nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh':     nn.Tanh()
        }[activation]
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act]
            prev_dim = h
        layers.append(nn.Linear(prev_dim, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = self.net(x).squeeze(-1)
        return F.softplus(x)  # 输出 > 0

# ----------------- OPTUNA OBJECTIVE -----------------
def objective(trial):
    hidden_sizes      = trial.suggest_categorical('hidden_layer_sizes',
                            [(50,), (100,), (150,), (100, 50), (150, 100, 50)])
    activation        = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh'])
    lr                = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    weight_decay      = trial.suggest_float('alpha', 1e-5, 1e-2, log=True)
    optimizer_choice  = trial.suggest_categorical('optimizer', ['sgd', 'adam'])

    fold_maes = []

    for fold in range(1, n_folds + 1):
        X_train = np.load(f"{data_dir}/train_fold_{fold}.npy")
        y_train = np.load(f"{data_dir}/train_labels_fold_{fold}.npy")
        X_val   = np.load(f"{data_dir}/val_fold_{fold}.npy")
        y_val   = np.load(f"{data_dir}/val_labels_fold_{fold}.npy")

        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val   = scaler.transform(X_val)

        train_ds = TensorDataset(torch.from_numpy(X_train).float(),
                                 torch.from_numpy(y_train).float())
        val_ds = TensorDataset(torch.from_numpy(X_val).float(),
                               torch.from_numpy(y_val).float())
        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        model = MLP(input_dim=X_train.shape[1],
                    hidden_sizes=hidden_sizes,
                    activation=activation).to(device)
        criterion = nn.MSELoss()
        optimizer = {
            'sgd': torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay),
            'adam': torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        }[optimizer_choice]

        try:
            for epoch in range(num_epochs):
                model.train()
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    preds = model(xb)
                    loss = criterion(preds, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            all_preds = []
            with torch.no_grad():
                for xb, _ in val_loader:
                    xb = xb.to(device)
                    batch_pred = model(xb).cpu().numpy()
                    all_preds.append(batch_pred)
            all_preds = np.concatenate(all_preds)

            mae = mean_absolute_error(y_val, all_preds)
            fold_maes.append(mae)

        except Exception:
            return np.inf

    return float(np.mean(fold_maes))

# ----------------- RUN OPTUNA -----------------
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)

    print("\n=== Best Hyperparameters ===")
    print(study.best_params)
    print(f"Best Mean MAE: {study.best_value:.4f}")
# Out:
# [I 2025-05-16 10:07:35,534] A new study created in memory with name: no-name-b582e3ac-41b0-4db3-9804-41c1598c9c0c
# [I 2025-05-16 10:15:32,783] Trial 0 finished with value: 0.6766974925994873 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.0015930522616241021, 'alpha': 0.001331121608073689, 'optimizer': 'adam'}. Best is trial 0 with value: 0.6766974925994873.
# [I 2025-05-16 10:22:01,421] Trial 1 finished with value: 0.6646719574928284 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0016738085788752138, 'alpha': 2.621087878265438e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6646719574928284.
# [I 2025-05-16 10:28:16,200] Trial 2 finished with value: 0.7489737272262573 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00013492834268013249, 'alpha': 0.007025166339242158, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.6646719574928284.
# [I 2025-05-16 10:34:47,631] Trial 3 finished with value: 0.6621683835983276 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00032927591344236165, 'alpha': 0.0009717775305059633, 'optimizer': 'adam'}. Best is trial 3 with value: 0.6621683835983276.
# [I 2025-05-16 10:41:17,647] Trial 4 finished with value: 0.6628078818321228 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00015030900645056822, 'alpha': 3.872118032174584e-05, 'optimizer': 'adam'}. Best is trial 3 with value: 0.6621683835983276.
# [I 2025-05-16 10:47:28,170] Trial 5 finished with value: 0.6592065095901489 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00014096175149815865, 'alpha': 0.009133995846860976, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.6592065095901489.
# [I 2025-05-16 10:53:38,348] Trial 6 finished with value: 0.6707043051719666 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.005323617594751502, 'alpha': 0.0007411299781083245, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.6592065095901489.
# [I 2025-05-16 11:00:39,590] Trial 7 finished with value: 0.6638967394828796 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0033233042062267943, 'alpha': 0.00048287152161792117, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.6592065095901489.
# [I 2025-05-16 11:07:16,452] Trial 8 finished with value: 1.0677855014801025 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.006533305220227739, 'alpha': 5.59598687800608e-05, 'optimizer': 'adam'}. Best is trial 5 with value: 0.6592065095901489.
# [I 2025-05-16 11:20:48,943] Trial 10 finished with value: 0.6914248466491699 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0004260009910618965, 'alpha': 0.007328013762901325, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.6592065095901489.
# [I 2025-05-16 11:27:25,564] Trial 11 finished with value: 0.6647030711174011 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00037808421942081566, 'alpha': 0.0023449337014671344, 'optimizer': 'adam'}. Best is trial 5 with value: 0.6592065095901489.
# [I 2025-05-16 11:34:02,708] Trial 12 finished with value: 0.6622151136398315 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00037299981541424096, 'alpha': 0.00017856206876245905, 'optimizer': 'adam'}. Best is trial 5 with value: 0.6592065095901489.
# [I 2025-05-16 11:40:10,156] Trial 13 finished with value: 0.6694808006286621 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00010246033752665343, 'alpha': 0.0029155216747925833, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.6592065095901489.
# [I 2025-05-16 11:46:42,954] Trial 14 finished with value: 0.6608191728591919 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00021328511312591468, 'alpha': 0.0001942944509587067, 'optimizer': 'adam'}. Best is trial 5 with value: 0.6592065095901489.
# [I 2025-05-16 11:53:11,244] Trial 15 finished with value: 0.8044212460517883 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.0002033072497097523, 'alpha': 0.00016629224521024245, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.6592065095901489.
# [I 2025-05-16 11:59:47,158] Trial 16 finished with value: 0.6659060716629028 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0006579152757994545, 'alpha': 0.00011468235069034269, 'optimizer': 'adam'}. Best is trial 5 with value: 0.6592065095901489.
# [I 2025-05-16 12:05:58,500] Trial 17 finished with value: 0.6545370221138 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00022462374069261932, 'alpha': 0.0003278228155766154, 'optimizer': 'sgd'}. Best is trial 17 with value: 0.6545370221138.
# [I 2025-05-16 12:12:07,081] Trial 18 finished with value: 0.6762669086456299 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.0007906646978924588, 'alpha': 0.003020999350690039, 'optimizer': 'sgd'}. Best is trial 17 with value: 0.6545370221138.
# [I 2025-05-16 12:18:40,355] Trial 19 finished with value: 0.7899581789970398 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.00023718756293829345, 'alpha': 1.0788661515919524e-05, 'optimizer': 'sgd'}. Best is trial 17 with value: 0.6545370221138.
# [I 2025-05-16 12:25:38,620] Trial 20 finished with value: 0.6743505001068115 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.00010166041993082317, 'alpha': 0.008546718436668535, 'optimizer': 'sgd'}. Best is trial 17 with value: 0.6545370221138.
# [I 2025-05-16 12:31:46,006] Trial 21 finished with value: 0.6539360284805298 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00020391470296242433, 'alpha': 0.000318941611585572, 'optimizer': 'sgd'}. Best is trial 21 with value: 0.6539360284805298.
# [I 2025-05-16 12:37:57,766] Trial 22 finished with value: 0.6599558591842651 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0005209314402340293, 'alpha': 0.0004899603734665594, 'optimizer': 'sgd'}. Best is trial 21 with value: 0.6539360284805298.
# [I 2025-05-16 12:44:05,664] Trial 23 finished with value: 0.6555444002151489 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0002589786980330497, 'alpha': 0.00036786251898570955, 'optimizer': 'sgd'}. Best is trial 21 with value: 0.6539360284805298.
# [I 2025-05-16 12:50:20,676] Trial 24 finished with value: 0.6550077199935913 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0002669228855204217, 'alpha': 0.00031044201897620745, 'optimizer': 'sgd'}. Best is trial 21 with value: 0.6539360284805298.
# [I 2025-05-16 12:56:27,343] Trial 25 finished with value: 0.6652543544769287 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'learning_rate': 0.001180628798359809, 'alpha': 8.68323247249837e-05, 'optimizer': 'sgd'}. Best is trial 21 with value: 0.6539360284805298.
# [I 2025-05-16 13:02:43,986] Trial 26 finished with value: 0.6659244894981384 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0005740122018683208, 'alpha': 0.00023481587378840934, 'optimizer': 'sgd'}. Best is trial 21 with value: 0.6539360284805298.
# [I 2025-05-16 13:09:00,428] Trial 27 finished with value: 0.6550194025039673 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0001754357193333551, 'alpha': 0.000334011861813181, 'optimizer': 'sgd'}. Best is trial 21 with value: 0.6539360284805298.
# [I 2025-05-16 13:15:11,277] Trial 28 finished with value: 0.6790549159049988 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.009827674611457334, 'alpha': 0.0007297457203392668, 'optimizer': 'sgd'}. Best is trial 21 with value: 0.6539360284805298.
# [I 2025-05-16 13:21:20,048] Trial 29 finished with value: 0.7240464687347412 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00028445370828613167, 'alpha': 0.0014130490232818751, 'optimizer': 'sgd'}. Best is trial 21 with value: 0.6539360284805298.
# === Best Hyperparameters ===
# {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00020391470296242433, 'alpha': 0.000318941611585572, 'optimizer': 'sgd'}
# Best Mean MAE: 0.6539

# %%
import os
import optuna
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    # 采样超参数
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        model = XGBRegressor(n_jobs=-1, verbosity=0, **params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 以 MAE 为优化目标


# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best XGBoost Hyperparameters via Optuna ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 14:18:39,669] A new study created in memory with name: no-name-e5a730e7-83b5-4a79-9190-3d8c3956a1b0
# [I 2025-05-16 14:21:27,856] Trial 0 finished with value: 0.7128766775131226 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 8, 'subsample': 0.8795975452591109, 'colsample_bytree': 0.6624074561769746}. Best is trial 0 with value: 0.7128766775131226.
# [I 2025-05-16 14:24:21,420] Trial 1 finished with value: 0.7056335210800171 and parameters: {'n_estimators': 200, 'learning_rate': 0.011900590783184251, 'max_depth': 9, 'subsample': 0.8803345035229626, 'colsample_bytree': 0.8832290311184181}. Best is trial 1 with value: 0.7056335210800171.
# [I 2025-05-16 14:25:08,093] Trial 2 finished with value: 0.677908718585968 and parameters: {'n_estimators': 100, 'learning_rate': 0.18276027831785724, 'max_depth': 8, 'subsample': 0.7637017332034828, 'colsample_bytree': 0.6727299868828402}. Best is trial 2 with value: 0.677908718585968.
# [I 2025-05-16 14:26:23,692] Trial 3 finished with value: 0.6591135859489441 and parameters: {'n_estimators': 200, 'learning_rate': 0.024878734419814436, 'max_depth': 6, 'subsample': 0.8295835055926347, 'colsample_bytree': 0.7164916560792167}. Best is trial 3 with value: 0.6591135859489441.
# [I 2025-05-16 14:29:24,605] Trial 4 finished with value: 0.6558490991592407 and parameters: {'n_estimators': 700, 'learning_rate': 0.01518747922672247, 'max_depth': 5, 'subsample': 0.8099085529881075, 'colsample_bytree': 0.7824279936868144}. Best is trial 4 with value: 0.6558490991592407.
# [I 2025-05-16 14:33:12,544] Trial 5 finished with value: 0.6591823697090149 and parameters: {'n_estimators': 800, 'learning_rate': 0.018187859051288217, 'max_depth': 6, 'subsample': 0.8777243706586128, 'colsample_bytree': 0.6185801650879991}. Best is trial 4 with value: 0.6558490991592407.
# [I 2025-05-16 14:35:02,183] Trial 6 finished with value: 0.6583057641983032 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'subsample': 0.984665661176, 'colsample_bytree': 0.9862528132298237}. Best is trial 4 with value: 0.6558490991592407.
# [I 2025-05-16 14:37:13,673] Trial 7 finished with value: 0.6580500602722168 and parameters: {'n_estimators': 900, 'learning_rate': 0.0249064396938244, 'max_depth': 3, 'subsample': 0.905269907953647, 'colsample_bytree': 0.7760609974958406}. Best is trial 4 with value: 0.6558490991592407.
# [I 2025-05-16 14:37:47,569] Trial 8 finished with value: 0.6589776873588562 and parameters: {'n_estimators': 200, 'learning_rate': 0.04407984038169244, 'max_depth': 3, 'subsample': 0.9727961206236346, 'colsample_bytree': 0.7035119926400067}. Best is trial 4 with value: 0.6558490991592407.
# [I 2025-05-16 14:41:05,605] Trial 9 finished with value: 0.6608268022537231 and parameters: {'n_estimators': 700, 'learning_rate': 0.02544166090938368, 'max_depth': 6, 'subsample': 0.8640130838029838, 'colsample_bytree': 0.6739417822102108}. Best is trial 4 with value: 0.6558490991592407.
# [I 2025-05-16 14:45:06,782] Trial 10 finished with value: 0.6772363781929016 and parameters: {'n_estimators': 1000, 'learning_rate': 0.08138762607805286, 'max_depth': 5, 'subsample': 0.7053885626844458, 'colsample_bytree': 0.8560354009870226}. Best is trial 4 with value: 0.6558490991592407.
# [I 2025-05-16 14:48:12,293] Trial 11 finished with value: 0.6616776585578918 and parameters: {'n_estimators': 1000, 'learning_rate': 0.042799942130332856, 'max_depth': 4, 'subsample': 0.8004385528669709, 'colsample_bytree': 0.784894991903791}. Best is trial 4 with value: 0.6558490991592407.
# [I 2025-05-16 14:51:03,258] Trial 12 finished with value: 0.6559056639671326 and parameters: {'n_estimators': 800, 'learning_rate': 0.010227614236539206, 'max_depth': 4, 'subsample': 0.9464056138332538, 'colsample_bytree': 0.7890856026631795}. Best is trial 4 with value: 0.6558490991592407.
# [I 2025-05-16 14:53:35,269] Trial 13 finished with value: 0.6575857996940613 and parameters: {'n_estimators': 500, 'learning_rate': 0.010343031939583617, 'max_depth': 5, 'subsample': 0.9407667563426924, 'colsample_bytree': 0.8583425762812965}. Best is trial 4 with value: 0.6558490991592407.
# [I 2025-05-16 14:56:14,843] Trial 14 finished with value: 0.6556652784347534 and parameters: {'n_estimators': 600, 'learning_rate': 0.014147233548123672, 'max_depth': 5, 'subsample': 0.7729629237947951, 'colsample_bytree': 0.7473945810686194}. Best is trial 14 with value: 0.6556652784347534.
# [I 2025-05-16 14:58:27,794] Trial 15 finished with value: 0.6556137800216675 and parameters: {'n_estimators': 500, 'learning_rate': 0.016801336615415576, 'max_depth': 5, 'subsample': 0.7562597894300102, 'colsample_bytree': 0.7444044561405618}. Best is trial 15 with value: 0.6556137800216675.
# [I 2025-05-16 15:00:50,342] Trial 16 finished with value: 0.6803125739097595 and parameters: {'n_estimators': 400, 'learning_rate': 0.08301865896031742, 'max_depth': 7, 'subsample': 0.7407423907315297, 'colsample_bytree': 0.7306354740411783}. Best is trial 15 with value: 0.6556137800216675.
# [I 2025-05-16 15:02:24,439] Trial 17 finished with value: 0.6566070318222046 and parameters: {'n_estimators': 500, 'learning_rate': 0.031146087193306544, 'max_depth': 4, 'subsample': 0.7555779218152252, 'colsample_bytree': 0.6033410376337281}. Best is trial 15 with value: 0.6556137800216675.
# [I 2025-05-16 15:06:05,824] Trial 18 finished with value: 0.684904932975769 and parameters: {'n_estimators': 600, 'learning_rate': 0.07035048118838953, 'max_depth': 7, 'subsample': 0.7828499588778128, 'colsample_bytree': 0.9281889012746769}. Best is trial 15 with value: 0.6556137800216675.
# [I 2025-05-16 15:08:02,602] Trial 19 finished with value: 0.6572050452232361 and parameters: {'n_estimators': 400, 'learning_rate': 0.013729353575854366, 'max_depth': 5, 'subsample': 0.7032967567731313, 'colsample_bytree': 0.7406086632532847}. Best is trial 15 with value: 0.6556137800216675.
# [I 2025-05-16 15:11:52,010] Trial 20 finished with value: 0.6629249453544617 and parameters: {'n_estimators': 600, 'learning_rate': 0.01982814925888827, 'max_depth': 7, 'subsample': 0.7375054092688033, 'colsample_bytree': 0.8312746179461202}. Best is trial 15 with value: 0.6556137800216675.
# [I 2025-05-16 15:14:51,270] Trial 21 finished with value: 0.6556644439697266 and parameters: {'n_estimators': 700, 'learning_rate': 0.014832445545973013, 'max_depth': 5, 'subsample': 0.8333780097946052, 'colsample_bytree': 0.7665962768019671}. Best is trial 15 with value: 0.6556137800216675.
# [I 2025-05-16 15:16:47,331] Trial 22 finished with value: 0.6568621397018433 and parameters: {'n_estimators': 600, 'learning_rate': 0.03204795955082687, 'max_depth': 4, 'subsample': 0.8316638834101604, 'colsample_bytree': 0.8127790027073113}. Best is trial 15 with value: 0.6556137800216675.
# [I 2025-05-16 15:19:39,560] Trial 23 finished with value: 0.6575716733932495 and parameters: {'n_estimators': 500, 'learning_rate': 0.01343623462834426, 'max_depth': 6, 'subsample': 0.7771048855458003, 'colsample_bytree': 0.7534686916018998}. Best is trial 15 with value: 0.6556137800216675.
# [I 2025-05-16 15:22:52,132] Trial 24 finished with value: 0.6568081378936768 and parameters: {'n_estimators': 800, 'learning_rate': 0.01863131359901439, 'max_depth': 5, 'subsample': 0.8082037591016669, 'colsample_bytree': 0.6965293929333529}. Best is trial 15 with value: 0.6556137800216675.
# [I 2025-05-16 15:24:00,003] Trial 25 finished with value: 0.6564332246780396 and parameters: {'n_estimators': 300, 'learning_rate': 0.02081746226557753, 'max_depth': 4, 'subsample': 0.8403192493234877, 'colsample_bytree': 0.7602532340306248}. Best is trial 15 with value: 0.6556137800216675.
# [I 2025-05-16 15:26:49,541] Trial 26 finished with value: 0.6597468256950378 and parameters: {'n_estimators': 700, 'learning_rate': 0.03355131256102361, 'max_depth': 5, 'subsample': 0.7326178439489445, 'colsample_bytree': 0.8217497924678846}. Best is trial 15 with value: 0.6556137800216675.
# [I 2025-05-16 15:30:09,110] Trial 27 finished with value: 0.6570091247558594 and parameters: {'n_estimators': 600, 'learning_rate': 0.012314114352872768, 'max_depth': 6, 'subsample': 0.7894519665356655, 'colsample_bytree': 0.6476411653824887}. Best is trial 15 with value: 0.6556137800216675.
# [I 2025-05-16 15:33:37,588] Trial 28 finished with value: 0.6695917248725891 and parameters: {'n_estimators': 900, 'learning_rate': 0.060672893233968725, 'max_depth': 5, 'subsample': 0.7593122627521882, 'colsample_bytree': 0.7363135149630605}. Best is trial 15 with value: 0.6556137800216675.
# [I 2025-05-16 15:34:50,982] Trial 29 finished with value: 0.6648988723754883 and parameters: {'n_estimators': 400, 'learning_rate': 0.13390499764355235, 'max_depth': 4, 'subsample': 0.8152802796286539, 'colsample_bytree': 0.6442327782804015}. Best is trial 15 with value: 0.6556137800216675.
# === Best XGBoost Hyperparameters via Optuna ===
# {'n_estimators': 500, 'learning_rate': 0.016801336615415576, 'max_depth': 5, 'subsample': 0.7562597894300102, 'colsample_bytree': 0.7444044561405618}
# 10-Fold Mean MAE = 0.6556

# %%
import os
import optuna
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'objective': 'poisson',         # ✅ 强制正输出
        'n_jobs': -1,
        'verbose': -1
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        # Poisson 回归要求标签必须大于 0
        if np.any(y_train <= 0) or np.any(y_val <= 0):
            return np.inf

        model = LGBMRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 使用 MAE 作为优化目标

# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 15:34:51,065] A new study created in memory with name: no-name-9443e138-7d50-4c0c-83c0-7132bf3efb48
# [I 2025-05-16 15:35:32,441] Trial 0 finished with value: 0.6658504752725263 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 10, 'num_leaves': 68, 'feature_fraction': 0.6624074561769746, 'bagging_fraction': 0.662397808134481}. Best is trial 0 with value: 0.6658504752725263.
# [I 2025-05-16 15:35:53,111] Trial 1 finished with value: 0.6552872704576809 and parameters: {'n_estimators': 100, 'learning_rate': 0.13394334706750485, 'max_depth': 9, 'num_leaves': 77, 'feature_fraction': 0.608233797718321, 'bagging_fraction': 0.9879639408647978}. Best is trial 1 with value: 0.6552872704576809.
# [I 2025-05-16 15:36:58,203] Trial 2 finished with value: 0.65369055774071 and parameters: {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}. Best is trial 2 with value: 0.65369055774071.
# [I 2025-05-16 15:38:01,948] Trial 3 finished with value: 0.6547519947991012 and parameters: {'n_estimators': 500, 'learning_rate': 0.023927528765580644, 'max_depth': 9, 'num_leaves': 31, 'feature_fraction': 0.7168578594140873, 'bagging_fraction': 0.7465447373174767}. Best is trial 2 with value: 0.65369055774071.
# [I 2025-05-16 15:38:37,276] Trial 4 finished with value: 0.6569049091759245 and parameters: {'n_estimators': 500, 'learning_rate': 0.10508421338691762, 'max_depth': 4, 'num_leaves': 61, 'feature_fraction': 0.836965827544817, 'bagging_fraction': 0.6185801650879991}. Best is trial 2 with value: 0.65369055774071.
# [I 2025-05-16 15:39:34,931] Trial 5 finished with value: 0.6628487461246768 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'num_leaves': 96, 'feature_fraction': 0.9862528132298237, 'bagging_fraction': 0.9233589392465844}. Best is trial 2 with value: 0.65369055774071.
# [I 2025-05-16 15:40:41,101] Trial 6 finished with value: 0.6895110259767363 and parameters: {'n_estimators': 400, 'learning_rate': 0.013399060561509796, 'max_depth': 9, 'num_leaves': 55, 'feature_fraction': 0.6488152939379115, 'bagging_fraction': 0.798070764044508}. Best is trial 2 with value: 0.65369055774071.
# [I 2025-05-16 15:40:56,114] Trial 7 finished with value: 0.6548817270191485 and parameters: {'n_estimators': 100, 'learning_rate': 0.15242391728466367, 'max_depth': 5, 'num_leaves': 73, 'feature_fraction': 0.7246844304357644, 'bagging_fraction': 0.8080272084711243}. Best is trial 2 with value: 0.65369055774071.
# [I 2025-05-16 15:43:15,624] Trial 8 finished with value: 0.6560274116274165 and parameters: {'n_estimators': 600, 'learning_rate': 0.017398074711291726, 'max_depth': 12, 'num_leaves': 82, 'feature_fraction': 0.9757995766256756, 'bagging_fraction': 0.9579309401710595}. Best is trial 2 with value: 0.65369055774071.
# [I 2025-05-16 15:43:42,912] Trial 9 finished with value: 0.6593782987799253 and parameters: {'n_estimators': 600, 'learning_rate': 0.15826541904647565, 'max_depth': 3, 'num_leaves': 35, 'feature_fraction': 0.6180909155642152, 'bagging_fraction': 0.7301321323053057}. Best is trial 2 with value: 0.65369055774071.
# [I 2025-05-16 15:45:01,599] Trial 10 finished with value: 0.6568220153087128 and parameters: {'n_estimators': 1000, 'learning_rate': 0.041286972973122775, 'max_depth': 6, 'num_leaves': 21, 'feature_fraction': 0.8423486893732017, 'bagging_fraction': 0.876098829427658}. Best is trial 2 with value: 0.65369055774071.
# [I 2025-05-16 15:46:28,393] Trial 11 finished with value: 0.6556992639675896 and parameters: {'n_estimators': 900, 'learning_rate': 0.032403579261005684, 'max_depth': 7, 'num_leaves': 42, 'feature_fraction': 0.7532336562338404, 'bagging_fraction': 0.7628900279921988}. Best is trial 2 with value: 0.65369055774071.
# [I 2025-05-16 15:47:39,758] Trial 12 finished with value: 0.6532327681989496 and parameters: {'n_estimators': 800, 'learning_rate': 0.026160308927601773, 'max_depth': 7, 'num_leaves': 21, 'feature_fraction': 0.7331336920786393, 'bagging_fraction': 0.7212450905180019}. Best is trial 12 with value: 0.6532327681989496.
# [I 2025-05-16 15:48:37,105] Trial 13 finished with value: 0.6586351293461439 and parameters: {'n_estimators': 800, 'learning_rate': 0.06922749265952521, 'max_depth': 6, 'num_leaves': 20, 'feature_fraction': 0.7874820875551369, 'bagging_fraction': 0.8523404036540022}. Best is trial 12 with value: 0.6532327681989496.
# [I 2025-05-16 15:50:32,147] Trial 14 finished with value: 0.6573373208139989 and parameters: {'n_estimators': 1000, 'learning_rate': 0.011058500546306225, 'max_depth': 5, 'num_leaves': 47, 'feature_fraction': 0.9101034589253748, 'bagging_fraction': 0.6939291155454744}. Best is trial 12 with value: 0.6532327681989496.
# [I 2025-05-16 15:51:46,594] Trial 15 finished with value: 0.6540769155137645 and parameters: {'n_estimators': 800, 'learning_rate': 0.027963250740103997, 'max_depth': 7, 'num_leaves': 32, 'feature_fraction': 0.6915690760370046, 'bagging_fraction': 0.8374820761833434}. Best is trial 12 with value: 0.6532327681989496.
# [I 2025-05-16 15:53:15,212] Trial 16 finished with value: 0.6576357991323623 and parameters: {'n_estimators': 800, 'learning_rate': 0.04727977588816647, 'max_depth': 12, 'num_leaves': 45, 'feature_fraction': 0.7779099617209466, 'bagging_fraction': 0.6775754585481975}. Best is trial 12 with value: 0.6532327681989496.
# [I 2025-05-16 15:54:42,332] Trial 17 finished with value: 0.6550939155596274 and parameters: {'n_estimators': 900, 'learning_rate': 0.019522814385520795, 'max_depth': 5, 'num_leaves': 27, 'feature_fraction': 0.8358394007383037, 'bagging_fraction': 0.6034710656644141}. Best is trial 12 with value: 0.6532327681989496.
# [I 2025-05-16 15:55:55,070] Trial 18 finished with value: 0.6587561713716447 and parameters: {'n_estimators': 700, 'learning_rate': 0.06776056869906319, 'max_depth': 8, 'num_leaves': 38, 'feature_fraction': 0.9044243675990947, 'bagging_fraction': 0.8948333186331161}. Best is trial 12 with value: 0.6532327681989496.
# [I 2025-05-16 15:57:10,339] Trial 19 finished with value: 0.6624963180454684 and parameters: {'n_estimators': 900, 'learning_rate': 0.010316475004898525, 'max_depth': 4, 'num_leaves': 55, 'feature_fraction': 0.743899530298724, 'bagging_fraction': 0.8028945379132197}. Best is trial 12 with value: 0.6532327681989496.
# [I 2025-05-16 15:58:07,111] Trial 20 finished with value: 0.6550997124099478 and parameters: {'n_estimators': 700, 'learning_rate': 0.04035517885782127, 'max_depth': 6, 'num_leaves': 27, 'feature_fraction': 0.6889385427604511, 'bagging_fraction': 0.7249100494885865}. Best is trial 12 with value: 0.6532327681989496.
# [I 2025-05-16 15:59:26,872] Trial 21 finished with value: 0.6542645725627738 and parameters: {'n_estimators': 800, 'learning_rate': 0.02759430046599591, 'max_depth': 7, 'num_leaves': 33, 'feature_fraction': 0.7026827755877711, 'bagging_fraction': 0.840941963206565}. Best is trial 12 with value: 0.6532327681989496.
# [I 2025-05-16 16:00:48,903] Trial 22 finished with value: 0.6527224112366804 and parameters: {'n_estimators': 1000, 'learning_rate': 0.02291335908739726, 'max_depth': 8, 'num_leaves': 20, 'feature_fraction': 0.6725163005566686, 'bagging_fraction': 0.7810422350572688}. Best is trial 22 with value: 0.6527224112366804.
# [I 2025-05-16 16:02:09,996] Trial 23 finished with value: 0.6526638536581261 and parameters: {'n_estimators': 1000, 'learning_rate': 0.020464819969881125, 'max_depth': 11, 'num_leaves': 20, 'feature_fraction': 0.6736327285171761, 'bagging_fraction': 0.7670714850409899}. Best is trial 23 with value: 0.6526638536581261.
# [I 2025-05-16 16:03:27,525] Trial 24 finished with value: 0.6529212766029702 and parameters: {'n_estimators': 1000, 'learning_rate': 0.0223413839379049, 'max_depth': 10, 'num_leaves': 20, 'feature_fraction': 0.6527856388176553, 'bagging_fraction': 0.763083846591417}. Best is trial 23 with value: 0.6526638536581261.
# [I 2025-05-16 16:05:04,371] Trial 25 finished with value: 0.6535414472602256 and parameters: {'n_estimators': 1000, 'learning_rate': 0.014054410369960836, 'max_depth': 11, 'num_leaves': 26, 'feature_fraction': 0.6432650285228018, 'bagging_fraction': 0.7636004284281295}. Best is trial 23 with value: 0.6526638536581261.
# [I 2025-05-16 16:06:49,826] Trial 26 finished with value: 0.6533273181110436 and parameters: {'n_estimators': 1000, 'learning_rate': 0.02299505538962598, 'max_depth': 11, 'num_leaves': 40, 'feature_fraction': 0.6706896433718292, 'bagging_fraction': 0.7868874109118528}. Best is trial 23 with value: 0.6526638536581261.
# [I 2025-05-16 16:08:05,313] Trial 27 finished with value: 0.6541393831248964 and parameters: {'n_estimators': 1000, 'learning_rate': 0.03248236650444182, 'max_depth': 10, 'num_leaves': 25, 'feature_fraction': 0.6069433614023075, 'bagging_fraction': 0.6460264449507471}. Best is trial 23 with value: 0.6526638536581261.
# [I 2025-05-16 16:08:37,918] Trial 28 finished with value: 0.6560394346373626 and parameters: {'n_estimators': 200, 'learning_rate': 0.052104343690409366, 'max_depth': 10, 'num_leaves': 48, 'feature_fraction': 0.6394196376519892, 'bagging_fraction': 0.6997735240645564}. Best is trial 23 with value: 0.6526638536581261.
# [I 2025-05-16 16:09:37,222] Trial 29 finished with value: 0.7221763403911956 and parameters: {'n_estimators': 300, 'learning_rate': 0.013934090165767587, 'max_depth': 10, 'num_leaves': 66, 'feature_fraction': 0.6706933409683885, 'bagging_fraction': 0.759994587020959}. Best is trial 23 with value: 0.6526638536581261.
# === Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===
# {'n_estimators': 1000, 'learning_rate': 0.020464819969881125, 'max_depth': 11, 'num_leaves': 20, 'feature_fraction': 0.6736327285171761, 'bagging_fraction': 0.7670714850409899}
# 10-Fold Mean MAE = 0.6527
