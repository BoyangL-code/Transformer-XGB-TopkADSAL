# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import random
from torch.utils.data import Dataset, DataLoader
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error
from transformers import RobertaTokenizer, RobertaModel
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from collections import Counter
from imblearn.over_sampling import RandomOverSampler
from torch.utils.data import DataLoader, Subset
from scipy.stats import pearsonr
from tqdm import tqdm
from sklearn.exceptions import FitFailedWarning
import warnings
from sklearn.model_selection import ParameterSampler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.neural_network import MLPRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import RandomizedSearchCV
import matplotlib.pyplot as plt
from scipy.stats import norm
import matplotlib
from sklearn.base import clone

# %%
data=pd.read_excel("./invertebrates_LC50_unique.xlsx")
data=data.dropna()
smiles_data = data['SMILES_Canonical_RDKit'].tolist()
mgperL = data['mgperL'].values
Duration_Value= data['Duration_Value'].values

# %%
mgperL=np.log1p(mgperL)

# %%
# 检查需要One-Hot编码的列，并进行编码（如果类别超过一种）
def encode_column(data, column_name):
    unique_values = data[column_name].unique()
    if len(unique_values) > 1:
        encoder = OneHotEncoder(sparse_output=False)
        return encoder.fit_transform(data[[column_name]])
    else:
        return None  # 只有一种类别时忽略

# 编码 effect、endpoint 和 species_group 列
effect_encoded = encode_column(data, 'effect')
endpoint_encoded = encode_column(data, 'endpoint')
species_encoded = encode_column(data, 'species_group')

# 将需要的列拼接成输入 X
extra_features = data['Duration_Value'].values.reshape(-1, 1)

# 拼接编码后的列（如果存在）
for encoded_feature in [effect_encoded, endpoint_encoded, species_encoded]:
    if encoded_feature is not None:
        extra_features = np.hstack((extra_features, encoded_feature))

# %%
extra_features.shape
# Out:
# (4187, 1)

# %%
extra_dim = extra_features.shape[1]

# %%
extra_dim = extra_features.shape[1]
data_extra_features = extra_features

# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from transformers import BertTokenizerFast, BertModel
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
import optuna

# -------------------------------
# 1. 数据增强与 Dataset 修改：支持额外特征 extra_features
# -------------------------------
def augment_smiles(smiles):
    """简单的数据增强方法：50% 的概率翻转 SMILES 字符串"""
    if random.random() > 0.5:
        return smiles[::-1]
    return smiles

class SMILES_Dataset(Dataset):
    def __init__(self, smiles, reg_labels, extra_features=None, use_augmentation=False):
        self.smiles = smiles
        self.reg_labels = reg_labels
        self.extra_features = extra_features  # 额外特征，要求为数组或列表（每个元素是一个数值向量）
        self.use_augmentation = use_augmentation

    def __len__(self):
        return len(self.smiles)

    def __getitem__(self, idx):
        s = self.smiles[idx]
        if self.use_augmentation:
            s = augment_smiles(s)
        reg_label = self.reg_labels[idx]
        tokens = tokenizer(s, padding='max_length', truncation=True, max_length=128, return_tensors="pt")
        # squeeze 扁平化 batch 维度（例如变为 [seq_len]）
        tokens = {key: val.squeeze(0) for key, val in tokens.items()}
        if self.extra_features is not None:
            extra_feat = self.extra_features[idx]
            extra_feat = torch.tensor(extra_feat, dtype=torch.float32)
            return tokens, torch.tensor(reg_label, dtype=torch.float32), extra_feat
        else:
            return tokens, torch.tensor(reg_label, dtype=torch.float32)

# %%
# -------------------------------
# 2. 加载本地 BERT 模型（BERT for SMILES）
# -------------------------------
# 请将 checkpoint 指向你的本地模型目录（此处示例使用 'unikei/bert-base-smiles'）
checkpoint = '../models/base_bert'
tokenizer = BertTokenizerFast.from_pretrained(checkpoint)
bert_model = BertModel.from_pretrained(checkpoint)

# -------------------------------
# 3. 模型定义：BERT_Regression
# -------------------------------
class Bert_Regression(nn.Module):
    def __init__(self, dropout_rate, fc1_size, fc2_size, fc3_size, extra_dim=0):
        """
        :param extra_dim: 额外特征维度，如果为 0 则不拼接额外特征
        """
        super(Bert_Regression, self).__init__()
        self.bert = bert_model  # 使用加载好的 BERT 模型
        hidden_size = self.bert.config.hidden_size  # 通常为768
        self.extra_dim = extra_dim
        # 拼接后的维度
        input_dim = hidden_size + extra_dim
        self.regressor = nn.Sequential(
            nn.Linear(input_dim, fc1_size),
            nn.ReLU(),
            nn.BatchNorm1d(fc1_size),
            nn.Dropout(dropout_rate),
            nn.Linear(fc1_size, fc2_size),
            nn.ReLU(),
            nn.BatchNorm1d(fc2_size),
            nn.Dropout(dropout_rate),
            nn.Linear(fc2_size, fc3_size),
            nn.ReLU(),
            nn.BatchNorm1d(fc3_size),
            nn.Dropout(dropout_rate),
            nn.Linear(fc3_size, 1),
            nn.Softplus()
        )
    
    def forward(self, tokens, extra_features=None):
        outputs = self.bert(**tokens)
        cls_embedding = outputs.last_hidden_state[:, 0, :]  # [CLS] token 嵌入，形状 [batch_size, 768]
        if self.extra_dim > 0 and extra_features is not None:
            # 拼接额外特征，要求 extra_features 的形状为 [batch_size, extra_dim]
            x = torch.cat([cls_embedding, extra_features], dim=1)
        else:
            x = cls_embedding
        reg_output = self.regressor(x)
        return reg_output

# %%
data_smiles = smiles_data
data_labels = mgperL

# 使用 SMILES 作为组依据，确保同一 SMILES 不出现在不同折中
groups = data_smiles

# 如果数据量较大，可根据需要提前封装为 Dataset
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
from torch.cuda.amp import autocast, GradScaler

# %%
import os
import pickle
import numpy as np
import optuna
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.model_selection import GroupKFold
from torch.utils.data import DataLoader
from tqdm import tqdm
import torch
import torch.optim as optim
from torch.cuda.amp import autocast, GradScaler

# 假设以下变量已定义：
# data_smiles, data_labels, data_extra_features, groups, device, extra_dim
# Bert_Regression, SMILES_Dataset

os.makedirs("./optuna_model_set_1", exist_ok=True)
os.makedirs("./optuna_model_set_2", exist_ok=True)

model_sets = ["./optuna_model_set_1", "./optuna_model_set_2"]
set_errors = [float('inf'), float('inf')]
model_save_counter = 0  # 控制保存路径的交替轮换

# =============== 超参数搜索目标函数 ================
def objective(trial):
    global model_save_counter, model_sets, set_errors

    dropout_rate  = trial.suggest_float('dropout_rate', 0.1, 0.5)
    fc1_size      = trial.suggest_int('fc1_size', 256, 1024, step=64)
    fc2_size      = trial.suggest_int('fc2_size', 128, 512, step=32)
    fc3_size      = trial.suggest_int('fc3_size', 64, 256, step=32)
    learning_rate = trial.suggest_float('learning_rate', 1e-5, 5e-5, log=True)
    weight_decay  = trial.suggest_float('weight_decay', 0.0, 0.1)

    gkf = GroupKFold(n_splits=10)
    fold_errors = []
    model_set_dir = model_sets[model_save_counter % 2]

    for fold, (train_idx, val_idx) in enumerate(tqdm(gkf.split(data_smiles, data_labels, groups), total=10, desc=f"Trial {trial.number}")):
        train_smiles = [data_smiles[i] for i in train_idx]
        val_smiles = [data_smiles[i] for i in val_idx]
        train_labels = [data_labels[i] for i in train_idx]
        val_labels = [data_labels[i] for i in val_idx]
        train_extra = data_extra_features[train_idx]
        val_extra = data_extra_features[val_idx]

        train_dataset = SMILES_Dataset(train_smiles, train_labels, extra_features=train_extra)
        val_dataset = SMILES_Dataset(val_smiles, val_labels, extra_features=val_extra)

        train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True, drop_last=True, num_workers=8, pin_memory=True)
        val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False, num_workers=8, pin_memory=True)

        model = Bert_Regression(dropout_rate, fc1_size, fc2_size, fc3_size, extra_dim=extra_dim).to(device)
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
        criterion = torch.nn.L1Loss()
        scaler = GradScaler()

        for epoch in range(30):
            model.train()
            for tokens, labels_tensor, extra_feats in train_loader:
                tokens = {k: v.to(device) for k, v in tokens.items()}
                extra_feats = extra_feats.to(device)
                labels_tensor = labels_tensor.to(device)

                optimizer.zero_grad()
                with autocast():
                    outputs = model(tokens, extra_feats)
                    loss = criterion(outputs.squeeze(), labels_tensor)
                scaler.scale(loss).backward()
                scaler.step(optimizer)
                scaler.update()

        # 验证并保存模型
        model.eval()
        preds, targets = [], []
        with torch.no_grad():
            for tokens, labels_tensor, extra_feats in val_loader:
                tokens = {k: v.to(device) for k, v in tokens.items()}
                extra_feats = extra_feats.to(device)
                labels_tensor = labels_tensor.to(device)
                outputs = model(tokens, extra_feats)
                preds.extend(outputs.squeeze().cpu().numpy())
                targets.extend(labels_tensor.cpu().numpy())

        error = np.maximum(targets, preds) / np.minimum(targets, preds)
        median_error = np.median(error)
        fold_errors.append(median_error)

        torch.save(model.state_dict(), f"{model_set_dir}/bert_reg_fold_{fold+1}.pth")

    avg_median_error = np.mean(fold_errors)
    set_errors[model_save_counter % 2] = avg_median_error

    # 判断是否更新替换文件夹指针
    if set_errors[0] > set_errors[1]:
        model_save_counter = 0
    else:
        model_save_counter = 1

    return avg_median_error

# ================ 启动 Optuna 搜索 ===================
study = optuna.create_study(direction="minimize")
study.optimize(objective, n_trials=30)

# 输出结果
best_trial = study.best_trial
best_dir = model_sets[0] if set_errors[0] < set_errors[1] else model_sets[1]
print("Best hyperparameters:", best_trial.params)
print("Best model set directory:", best_dir)
print("Best cross-validated median error:", min(set_errors))
# Out:
# [I 2025-04-25 09:18:34,706] A new study created in memory with name: no-name-ce1d85de-6314-479b-a498-2ba65d533684
# Trial 0: 100%|██████████| 10/10 [20:06<00:00, 120.69s/it]
# [I 2025-04-25 09:38:41,644] Trial 0 finished with value: 2.1379799842834473 and parameters: {'dropout_rate': 0.36661570191311166, 'fc1_size': 256, 'fc2_size': 512, 'fc3_size': 96, 'learning_rate': 3.092244175884014e-05, 'weight_decay': 0.016701015675485608}. Best is trial 0 with value: 2.1379799842834473.
# Trial 1: 100%|██████████| 10/10 [20:04<00:00, 120.45s/it]
# [I 2025-04-25 09:58:46,175] Trial 1 finished with value: 2.372208595275879 and parameters: {'dropout_rate': 0.27617960742667846, 'fc1_size': 704, 'fc2_size': 160, 'fc3_size': 224, 'learning_rate': 1.619066128098815e-05, 'weight_decay': 0.09938384286931667}. Best is trial 0 with value: 2.1379799842834473.
# Trial 2: 100%|██████████| 10/10 [20:09<00:00, 120.92s/it]
# [I 2025-04-25 10:18:55,390] Trial 2 finished with value: 2.1575191020965576 and parameters: {'dropout_rate': 0.2548669791122212, 'fc1_size': 832, 'fc2_size': 448, 'fc3_size': 256, 'learning_rate': 4.5727384064511854e-05, 'weight_decay': 0.05450410600915504}. Best is trial 0 with value: 2.1379799842834473.
# Trial 3: 100%|██████████| 10/10 [20:06<00:00, 120.63s/it]
# [I 2025-04-25 10:39:01,717] Trial 3 finished with value: 2.3479390144348145 and parameters: {'dropout_rate': 0.4472734382964697, 'fc1_size': 320, 'fc2_size': 288, 'fc3_size': 256, 'learning_rate': 2.2255064963637808e-05, 'weight_decay': 0.07659920927039751}. Best is trial 0 with value: 2.1379799842834473.
# Trial 4: 100%|██████████| 10/10 [20:10<00:00, 121.03s/it]
# [I 2025-04-25 10:59:12,048] Trial 4 finished with value: 2.176673412322998 and parameters: {'dropout_rate': 0.11506640190954993, 'fc1_size': 896, 'fc2_size': 384, 'fc3_size': 128, 'learning_rate': 3.414243042082779e-05, 'weight_decay': 0.09416765074862286}. Best is trial 0 with value: 2.1379799842834473.
# Trial 5: 100%|██████████| 10/10 [20:21<00:00, 122.12s/it]
# [I 2025-04-25 11:19:33,223] Trial 5 finished with value: 2.422421455383301 and parameters: {'dropout_rate': 0.29492730487282826, 'fc1_size': 704, 'fc2_size': 256, 'fc3_size': 224, 'learning_rate': 2.137675705499389e-05, 'weight_decay': 0.07976888315964396}. Best is trial 0 with value: 2.1379799842834473.
# Trial 6: 100%|██████████| 10/10 [20:21<00:00, 122.18s/it]
# [I 2025-04-25 11:39:55,039] Trial 6 finished with value: 2.662381410598755 and parameters: {'dropout_rate': 0.3602809546476903, 'fc1_size': 960, 'fc2_size': 160, 'fc3_size': 160, 'learning_rate': 1.2169144629985192e-05, 'weight_decay': 0.043742074611400276}. Best is trial 0 with value: 2.1379799842834473.
# Trial 7: 100%|██████████| 10/10 [20:21<00:00, 122.18s/it]
# [I 2025-04-25 12:00:16,829] Trial 7 finished with value: 2.285583734512329 and parameters: {'dropout_rate': 0.13373387532892314, 'fc1_size': 576, 'fc2_size': 448, 'fc3_size': 256, 'learning_rate': 2.7768004071305524e-05, 'weight_decay': 0.028946485724467376}. Best is trial 0 with value: 2.1379799842834473.
# Trial 8: 100%|██████████| 10/10 [20:20<00:00, 122.10s/it]
# [I 2025-04-25 12:20:37,816] Trial 8 finished with value: 2.2567179203033447 and parameters: {'dropout_rate': 0.398293566655297, 'fc1_size': 1024, 'fc2_size': 224, 'fc3_size': 96, 'learning_rate': 3.9958188501393096e-05, 'weight_decay': 0.005966648693282251}. Best is trial 0 with value: 2.1379799842834473.
# Trial 9: 100%|██████████| 10/10 [20:21<00:00, 122.19s/it]
# [I 2025-04-25 12:40:59,676] Trial 9 finished with value: 2.113330125808716 and parameters: {'dropout_rate': 0.42508000327514706, 'fc1_size': 896, 'fc2_size': 320, 'fc3_size': 128, 'learning_rate': 1.2490841405870961e-05, 'weight_decay': 0.018384916579292487}. Best is trial 9 with value: 2.113330125808716.
# Trial 10: 100%|██████████| 10/10 [20:19<00:00, 121.99s/it]
# [I 2025-04-25 13:01:19,579] Trial 10 finished with value: 2.1991841793060303 and parameters: {'dropout_rate': 0.47571619624490363, 'fc1_size': 512, 'fc2_size': 352, 'fc3_size': 64, 'learning_rate': 1.1898219298103648e-05, 'weight_decay': 0.0009426759169606433}. Best is trial 9 with value: 2.113330125808716.
# Trial 11: 100%|██████████| 10/10 [20:20<00:00, 122.09s/it]
# [I 2025-04-25 13:21:40,521] Trial 11 finished with value: 2.2580270767211914 and parameters: {'dropout_rate': 0.37608406057940563, 'fc1_size': 256, 'fc2_size': 512, 'fc3_size': 128, 'learning_rate': 1.6620722023656785e-05, 'weight_decay': 0.022471750563315997}. Best is trial 9 with value: 2.113330125808716.
# Trial 12: 100%|██████████| 10/10 [20:22<00:00, 122.21s/it]
# [I 2025-04-25 13:42:02,638] Trial 12 finished with value: 2.2584855556488037 and parameters: {'dropout_rate': 0.42305583833914445, 'fc1_size': 448, 'fc2_size': 384, 'fc3_size': 64, 'learning_rate': 1.0054557247213262e-05, 'weight_decay': 0.021241211122905414}. Best is trial 9 with value: 2.113330125808716.
# Trial 13: 100%|██████████| 10/10 [20:21<00:00, 122.14s/it]
# [I 2025-04-25 14:02:24,102] Trial 13 finished with value: 2.3602657318115234 and parameters: {'dropout_rate': 0.49967221642398674, 'fc1_size': 384, 'fc2_size': 512, 'fc3_size': 160, 'learning_rate': 2.8884762485822653e-05, 'weight_decay': 0.03743373365476889}. Best is trial 9 with value: 2.113330125808716.
# Trial 14: 100%|██████████| 10/10 [20:21<00:00, 122.20s/it]
# [I 2025-04-25 14:22:46,091] Trial 14 finished with value: 2.0637965202331543 and parameters: {'dropout_rate': 0.337751916085851, 'fc1_size': 768, 'fc2_size': 320, 'fc3_size': 96, 'learning_rate': 1.8018158116899547e-05, 'weight_decay': 0.013229973791397079}. Best is trial 14 with value: 2.0637965202331543.
# Trial 15: 100%|██████████| 10/10 [20:24<00:00, 122.41s/it]
# [I 2025-04-25 14:43:10,253] Trial 15 finished with value: 2.2009832859039307 and parameters: {'dropout_rate': 0.21542468716229868, 'fc1_size': 768, 'fc2_size': 320, 'fc3_size': 128, 'learning_rate': 1.5964308417661376e-05, 'weight_decay': 0.05963243528271231}. Best is trial 14 with value: 2.0637965202331543.
# Trial 16: 100%|██████████| 10/10 [20:27<00:00, 122.75s/it]
# [I 2025-04-25 15:03:37,802] Trial 16 finished with value: 2.108276605606079 and parameters: {'dropout_rate': 0.3510846369016798, 'fc1_size': 832, 'fc2_size': 224, 'fc3_size': 160, 'learning_rate': 1.8928296173771403e-05, 'weight_decay': 0.011658789521295985}. Best is trial 14 with value: 2.0637965202331543.
# Trial 17: 100%|██████████| 10/10 [20:23<00:00, 122.32s/it]
# [I 2025-04-25 15:24:01,071] Trial 17 finished with value: 1.9623839855194092 and parameters: {'dropout_rate': 0.32795300652340814, 'fc1_size': 640, 'fc2_size': 224, 'fc3_size': 192, 'learning_rate': 1.948389136911805e-05, 'weight_decay': 0.009333399303891083}. Best is trial 17 with value: 1.9623839855194092.
# Trial 18: 100%|██████████| 10/10 [20:23<00:00, 122.37s/it]
# [I 2025-04-25 15:44:24,843] Trial 18 finished with value: 2.0665268898010254 and parameters: {'dropout_rate': 0.1985347905623494, 'fc1_size': 640, 'fc2_size': 128, 'fc3_size': 192, 'learning_rate': 2.4567202230514822e-05, 'weight_decay': 0.0339965874238154}. Best is trial 17 with value: 1.9623839855194092.
# Trial 19: 100%|██████████| 10/10 [20:21<00:00, 122.13s/it]
# [I 2025-04-25 16:04:46,208] Trial 19 finished with value: 2.1758036613464355 and parameters: {'dropout_rate': 0.3275504846484966, 'fc1_size': 576, 'fc2_size': 224, 'fc3_size': 192, 'learning_rate': 1.9010664725417267e-05, 'weight_decay': 0.06483100031016518}. Best is trial 17 with value: 1.9623839855194092.
# Trial 20: 100%|██████████| 10/10 [20:10<00:00, 121.02s/it]
# [I 2025-04-25 16:24:56,458] Trial 20 finished with value: 2.1055893898010254 and parameters: {'dropout_rate': 0.22898484996639262, 'fc1_size': 704, 'fc2_size': 288, 'fc3_size': 192, 'learning_rate': 1.4259154570569957e-05, 'weight_decay': 0.04578962468229494}. Best is trial 17 with value: 1.9623839855194092.
# Trial 21: 100%|██████████| 10/10 [19:38<00:00, 117.90s/it]
# [I 2025-04-25 16:44:35,461] Trial 21 finished with value: 2.2223458290100098 and parameters: {'dropout_rate': 0.16944219445291012, 'fc1_size': 640, 'fc2_size': 128, 'fc3_size': 192, 'learning_rate': 2.4541526622023656e-05, 'weight_decay': 0.031378986525941954}. Best is trial 17 with value: 1.9623839855194092.
# Trial 22: 100%|██████████| 10/10 [19:38<00:00, 117.81s/it]
# [I 2025-04-25 17:04:13,573] Trial 22 finished with value: 2.135355234146118 and parameters: {'dropout_rate': 0.320509101937047, 'fc1_size': 576, 'fc2_size': 128, 'fc3_size': 224, 'learning_rate': 1.936063903959238e-05, 'weight_decay': 0.0069025257488121074}. Best is trial 17 with value: 1.9623839855194092.
# Trial 23: 100%|██████████| 10/10 [19:43<00:00, 118.30s/it]
# [I 2025-04-25 17:23:56,644] Trial 23 finished with value: 2.0248067378997803 and parameters: {'dropout_rate': 0.19293913062576043, 'fc1_size': 640, 'fc2_size': 192, 'fc3_size': 192, 'learning_rate': 2.6351678034796415e-05, 'weight_decay': 0.02948079313211222}. Best is trial 17 with value: 1.9623839855194092.
# Trial 24: 100%|██████████| 10/10 [19:40<00:00, 118.06s/it]
# [I 2025-04-25 17:43:37,247] Trial 24 finished with value: 2.0395967960357666 and parameters: {'dropout_rate': 0.25501346920824214, 'fc1_size': 768, 'fc2_size': 192, 'fc3_size': 96, 'learning_rate': 2.5591537876077563e-05, 'weight_decay': 0.025645419783047414}. Best is trial 17 with value: 1.9623839855194092.
# Trial 25: 100%|██████████| 10/10 [19:42<00:00, 118.27s/it]
# [I 2025-04-25 18:03:19,929] Trial 25 finished with value: 1.8518880605697632 and parameters: {'dropout_rate': 0.1629200229500026, 'fc1_size': 512, 'fc2_size': 192, 'fc3_size': 224, 'learning_rate': 3.5983610126581986e-05, 'weight_decay': 0.026149719182912808}. Best is trial 25 with value: 1.8518880605697632.
# Trial 26: 100%|██████████| 10/10 [19:41<00:00, 118.12s/it]
# [I 2025-04-25 18:23:01,129] Trial 26 finished with value: 1.9121322631835938 and parameters: {'dropout_rate': 0.16097500958242897, 'fc1_size': 448, 'fc2_size': 192, 'fc3_size': 224, 'learning_rate': 3.4144829253037464e-05, 'weight_decay': 0.03784918872181743}. Best is trial 25 with value: 1.8518880605697632.
# Trial 27: 100%|██████████| 10/10 [19:41<00:00, 118.14s/it]
# [I 2025-04-25 18:42:42,590] Trial 27 finished with value: 1.8557841777801514 and parameters: {'dropout_rate': 0.15388594697741242, 'fc1_size': 448, 'fc2_size': 256, 'fc3_size': 224, 'learning_rate': 3.8693010753893595e-05, 'weight_decay': 0.03989464382855058}. Best is trial 25 with value: 1.8518880605697632.
# Trial 28: 100%|██████████| 10/10 [19:40<00:00, 118.06s/it]
# [I 2025-04-25 19:02:23,244] Trial 28 finished with value: 1.8431857824325562 and parameters: {'dropout_rate': 0.15610099313061404, 'fc1_size': 448, 'fc2_size': 256, 'fc3_size': 224, 'learning_rate': 3.824271084357759e-05, 'weight_decay': 0.03994975338612639}. Best is trial 28 with value: 1.8431857824325562.
# Trial 29: 100%|██████████| 10/10 [19:40<00:00, 118.07s/it]
# [I 2025-04-25 19:22:04,021] Trial 29 finished with value: 1.845717191696167 and parameters: {'dropout_rate': 0.10370441653601477, 'fc1_size': 384, 'fc2_size': 256, 'fc3_size': 224, 'learning_rate': 4.614003913818042e-05, 'weight_decay': 0.0510003008805686}. Best is trial 28 with value: 1.8431857824325562.
# Best hyperparameters: {'dropout_rate': 0.15610099313061404, 'fc1_size': 448, 'fc2_size': 256, 'fc3_size': 224, 'learning_rate': 3.824271084357759e-05, 'weight_decay': 0.03994975338612639}
# Best model set directory: ./optuna_model_set_2
# Best cross-validated median error: 1.8431858

# %%
# import os
# import pickle
# import numpy as np
# import optuna
# from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
# from sklearn.model_selection import GroupKFold
# from torch.utils.data import DataLoader
# import torch
# import torch.optim as optim
# from torch.cuda.amp import autocast, GradScaler

# # 假设以下变量已定义：
# # data_smiles, data_labels, data_extra_features, groups, device, extra_dim
# # Bert_Regression, SMILES_Dataset

# os.makedirs("./optuna_model_set_1", exist_ok=True)
# os.makedirs("./optuna_model_set_2", exist_ok=True)

# model_sets = ["./optuna_model_set_1", "./optuna_model_set_2"]
# set_errors = [float('inf'), float('inf')]

# model_save_counter = 0  # 控制保存路径的交替轮换

# # =============== 超参数搜索目标函数 ================
# def objective(trial):
#     global model_save_counter, model_sets, set_errors

#     dropout_rate  = trial.suggest_float('dropout_rate', 0.1, 0.5)
#     fc1_size      = trial.suggest_int('fc1_size', 256, 1024, step=64)
#     fc2_size      = trial.suggest_int('fc2_size', 128, 512, step=32)
#     fc3_size      = trial.suggest_int('fc3_size', 64, 256, step=32)
#     learning_rate = trial.suggest_float('learning_rate', 1e-5, 5e-5, log=True)
#     weight_decay  = trial.suggest_float('weight_decay', 0.0, 0.1)

#     gkf = GroupKFold(n_splits=10)
#     fold_errors = []
#     model_set_dir = model_sets[model_save_counter % 2]

#     for fold, (train_idx, val_idx) in enumerate(gkf.split(data_smiles, data_labels, groups)):
#         train_smiles = [data_smiles[i] for i in train_idx]
#         val_smiles = [data_smiles[i] for i in val_idx]
#         train_labels = [data_labels[i] for i in train_idx]
#         val_labels = [data_labels[i] for i in val_idx]
#         train_extra = data_extra_features[train_idx]
#         val_extra = data_extra_features[val_idx]

#         train_dataset = SMILES_Dataset(train_smiles, train_labels, extra_features=train_extra)
#         val_dataset = SMILES_Dataset(val_smiles, val_labels, extra_features=val_extra)

#         train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True, drop_last=True, num_workers=8, pin_memory=True)
#         val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False, num_workers=8, pin_memory=True)

#         model = Bert_Regression(dropout_rate, fc1_size, fc2_size, fc3_size, extra_dim=extra_dim).to(device)
#         optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=weight_decay)
#         criterion = torch.nn.L1Loss()
#         scaler = GradScaler()

#         for epoch in range(30):
#             model.train()
#             for tokens, labels_tensor, extra_feats in train_loader:
#                 tokens = {k: v.to(device) for k, v in tokens.items()}
#                 extra_feats = extra_feats.to(device)
#                 labels_tensor = labels_tensor.to(device)

#                 optimizer.zero_grad()
#                 with autocast():
#                     outputs = model(tokens, extra_feats)
#                     loss = criterion(outputs.squeeze(), labels_tensor)
#                 scaler.scale(loss).backward()
#                 scaler.step(optimizer)
#                 scaler.update()

#         # 验证并保存模型
#         model.eval()
#         preds, targets = [], []
#         with torch.no_grad():
#             for tokens, labels_tensor, extra_feats in val_loader:
#                 tokens = {k: v.to(device) for k, v in tokens.items()}
#                 extra_feats = extra_feats.to(device)
#                 labels_tensor = labels_tensor.to(device)
#                 outputs = model(tokens, extra_feats)
#                 preds.extend(outputs.squeeze().cpu().numpy())
#                 targets.extend(labels_tensor.cpu().numpy())

#         error = np.maximum(targets, preds) / np.minimum(targets, preds)
#         median_error = np.median(error)
#         fold_errors.append(median_error)

#         torch.save(model.state_dict(), f"{model_set_dir}/bert_reg_fold_{fold+1}.pth")

#     avg_median_error = np.mean(fold_errors)
#     set_errors[model_save_counter % 2] = avg_median_error

#     # 判断是否更新替换文件夹指针
#     if set_errors[0] > set_errors[1]:
#         model_save_counter = 0
#     else:
#         model_save_counter = 1

#     return avg_median_error

# # ================ 启动 Optuna 搜索 ===================
# study = optuna.create_study(direction="minimize")
# study.optimize(objective, n_trials=30)

# # 输出结果
# best_trial = study.best_trial
# best_dir = model_sets[0] if set_errors[0] < set_errors[1] else model_sets[1]
# print("Best hyperparameters:", best_trial.params)
# print("Best model set directory:", best_dir)
# print("Best cross-validated median error:", min(set_errors))
# Out:
# [I 2025-04-24 11:19:40,280] A new study created in memory with name: no-name-f2bc011a-1ca7-462a-a401-c34a2181fa8c
# [W 2025-04-24 11:22:20,873] Trial 0 failed with parameters: {'dropout_rate': 0.43189899176859714, 'fc1_size': 256, 'fc2_size': 416, 'fc3_size': 192, 'learning_rate': 3.501906664857436e-05, 'weight_decay': 0.013908855167164358} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.10/site-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_1822/4084301454.py", line 70, in objective
#     scaler.step(optimizer)
#   File "/root/miniconda3/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py", line 416, in step
#     retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#   File "/root/miniconda3/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py", line 314, in _maybe_opt_step
#     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#   File "/root/miniconda3/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py", line 314, in <genexpr>
#     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
# KeyboardInterrupt
# [W 2025-04-24 11:22:20,876] Trial 0 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 104
#     102 # ================ 启动 Optuna 搜索 ===================
#     103 study = optuna.create_study(direction="minimize")
# --> 104 study.optimize(objective, n_trials=30)
#     106 # 输出结果
#     107 best_trial = study.best_trial
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/study/study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/study/_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File ~/miniconda3/lib/python3.10/site-packages/optuna/study/_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[19], line 70, in objective(trial)
#      68             loss = criterion(outputs.squeeze(), labels_tensor)
#      69         scaler.scale(loss).backward()
# ---> 70         scaler.step(optimizer)
#      71         scaler.update()
#      73 # 验证并保存模型
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py:416, in GradScaler.step(self, optimizer, *args, **kwargs)
#     410     self.unscale_(optimizer)
#     412 assert (
#     413     len(optimizer_state["found_inf_per_device"]) > 0
#     414 ), "No inf checks were recorded for this optimizer."
# --> 416 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     418 optimizer_state["stage"] = OptState.STEPPED
#     420 return retval
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py:314, in GradScaler._maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     312 def _maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs):
#     313     retval = None
# --> 314     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     315         retval = optimizer.step(*args, **kwargs)
#     316     return retval
#
# File ~/miniconda3/lib/python3.10/site-packages/torch/cuda/amp/grad_scaler.py:314, in <genexpr>(.0)
#     312 def _maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs):
#     313     retval = None
# --> 314     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     315         retval = optimizer.step(*args, **kwargs)
#     316     return retval
#
# KeyboardInterrupt:

# %%
#smiles_embeddings=np.load('./embedding/fish_EC10_smiles_embeddings.npy')

# %%
#val_r2 = r2_score(np.expm1(all_labels), np.expm1(all_preds))  # 还原 log1p 的值
