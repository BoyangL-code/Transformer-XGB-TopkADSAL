# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import random
import numpy as np
import torch
# 固定随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # for multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)  # 设置固定种子

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import optuna
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# ----------------- CONFIGURATION -----------------
n_folds    = 10
n_trials   = 30
data_dir   = "./k_folds_model/embeddings"
batch_size = 256
num_epochs = 200
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------- MODEL DEFINITION -----------------
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        layers = []
        prev_dim = input_dim
        act = {
            'relu':     nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh':     nn.Tanh()
        }[activation]
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act]
            prev_dim = h
        layers.append(nn.Linear(prev_dim, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = self.net(x).squeeze(-1)
        return F.softplus(x)  # 输出 > 0

# ----------------- OPTUNA OBJECTIVE -----------------
def objective(trial):
    hidden_sizes      = trial.suggest_categorical('hidden_layer_sizes',
                            [(50,), (100,), (150,), (100, 50), (150, 100, 50)])
    activation        = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh'])
    lr                = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    weight_decay      = trial.suggest_float('alpha', 1e-5, 1e-2, log=True)
    optimizer_choice  = trial.suggest_categorical('optimizer', ['sgd', 'adam'])

    fold_maes = []

    for fold in range(1, n_folds + 1):
        X_train = np.load(f"{data_dir}/train_fold_{fold}.npy")
        y_train = np.load(f"{data_dir}/train_labels_fold_{fold}.npy")
        X_val   = np.load(f"{data_dir}/val_fold_{fold}.npy")
        y_val   = np.load(f"{data_dir}/val_labels_fold_{fold}.npy")

        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val   = scaler.transform(X_val)

        train_ds = TensorDataset(torch.from_numpy(X_train).float(),
                                 torch.from_numpy(y_train).float())
        val_ds = TensorDataset(torch.from_numpy(X_val).float(),
                               torch.from_numpy(y_val).float())
        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        model = MLP(input_dim=X_train.shape[1],
                    hidden_sizes=hidden_sizes,
                    activation=activation).to(device)
        criterion = nn.MSELoss()
        optimizer = {
            'sgd': torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay),
            'adam': torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        }[optimizer_choice]

        try:
            for epoch in range(num_epochs):
                model.train()
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    preds = model(xb)
                    loss = criterion(preds, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            all_preds = []
            with torch.no_grad():
                for xb, _ in val_loader:
                    xb = xb.to(device)
                    batch_pred = model(xb).cpu().numpy()
                    all_preds.append(batch_pred)
            all_preds = np.concatenate(all_preds)

            mae = mean_absolute_error(y_val, all_preds)
            fold_maes.append(mae)

        except Exception:
            return np.inf

    return float(np.mean(fold_maes))

# ----------------- RUN OPTUNA -----------------
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)

    print("\n=== Best Hyperparameters ===")
    print(study.best_params)
    print(f"Best Mean MAE: {study.best_value:.4f}")
# Out:
# [I 2025-05-17 09:32:32,698] A new study created in memory with name: no-name-50992c5f-a787-4664-af55-89e09c99bfde
# [I 2025-05-17 09:33:46,756] Trial 0 finished with value: 0.7128510475158691 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.0015930522616241021, 'alpha': 0.001331121608073689, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7128510475158691.
# [I 2025-05-17 09:34:59,399] Trial 1 finished with value: 0.7050887942314148 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0016738085788752138, 'alpha': 2.621087878265438e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7050887942314148.
# [I 2025-05-17 09:36:09,385] Trial 2 finished with value: 0.8464428186416626 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00013492834268013249, 'alpha': 0.007025166339242158, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.7050887942314148.
# [I 2025-05-17 09:37:23,829] Trial 3 finished with value: 0.7091854214668274 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00032927591344236165, 'alpha': 0.0009717775305059633, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7050887942314148.
# [I 2025-05-17 09:38:41,036] Trial 4 finished with value: 0.707973301410675 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00015030900645056822, 'alpha': 3.872118032174584e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7050887942314148.
# [I 2025-05-17 09:39:51,440] Trial 5 finished with value: 0.7516982555389404 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00014096175149815865, 'alpha': 0.009133995846860976, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.7050887942314148.
# [I 2025-05-17 09:40:58,956] Trial 6 finished with value: 0.7223266363143921 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.005323617594751502, 'alpha': 0.0007411299781083245, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.7050887942314148.
# [I 2025-05-17 09:42:15,557] Trial 7 finished with value: 0.729937732219696 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0033233042062267943, 'alpha': 0.00048287152161792117, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.7050887942314148.
# [I 2025-05-17 09:43:27,193] Trial 8 finished with value: 0.711603581905365 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.006533305220227739, 'alpha': 5.59598687800608e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7050887942314148.
# [I 2025-05-17 09:44:44,467] Trial 9 finished with value: 0.7190943956375122 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.004048966222584676, 'alpha': 3.6283583803549155e-05, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.7050887942314148.
# [I 2025-05-17 09:46:03,647] Trial 10 finished with value: 0.7021980285644531 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0007543742609082392, 'alpha': 1.1321021804230373e-05, 'optimizer': 'adam'}. Best is trial 10 with value: 0.7021980285644531.
# [I 2025-05-17 09:47:20,648] Trial 11 finished with value: 0.6965304017066956 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0006998797679472042, 'alpha': 1.276783108350025e-05, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 09:48:39,934] Trial 12 finished with value: 0.7044458389282227 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0005482726058821447, 'alpha': 1.2624770806470424e-05, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 09:49:58,704] Trial 13 finished with value: 0.7128361463546753 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0006481925238057803, 'alpha': 0.00013383868509740543, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 09:51:18,223] Trial 14 finished with value: 0.7011470198631287 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0003452953465396614, 'alpha': 1.190430429994302e-05, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 09:52:36,445] Trial 15 finished with value: 0.7003888487815857 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00028482904060071605, 'alpha': 0.00015251519560399154, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 09:53:55,847] Trial 16 finished with value: 0.6990181803703308 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00028577256958552165, 'alpha': 0.00015680907691639046, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 09:55:13,698] Trial 17 finished with value: 0.7250073552131653 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.0016816536861775865, 'alpha': 0.0026558167359917455, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 09:56:31,291] Trial 18 finished with value: 0.7028029561042786 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0010852673578919704, 'alpha': 0.00015846819023510034, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 09:57:50,346] Trial 19 finished with value: 0.70954430103302 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00021818494942567416, 'alpha': 9.173823209172105e-05, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 09:59:10,932] Trial 20 finished with value: 0.7037219405174255 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'learning_rate': 0.00040972127413566983, 'alpha': 0.00028125466624695804, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 10:00:22,406] Trial 21 finished with value: 0.7005046606063843 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00020391470296242433, 'alpha': 0.00027131713354741627, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 10:01:41,652] Trial 22 finished with value: 0.703041136264801 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00027238320507032846, 'alpha': 7.707511121058236e-05, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 10:03:00,471] Trial 23 finished with value: 0.7091845870018005 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0005095693907590052, 'alpha': 0.00018762603490653343, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 10:04:12,850] Trial 24 finished with value: 0.7018647193908691 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0009329077704694182, 'alpha': 2.0218860837335065e-05, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 10:05:29,744] Trial 25 finished with value: 0.7324702739715576 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.00021924139515389331, 'alpha': 0.0004653251821742929, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 10:06:48,643] Trial 26 finished with value: 0.7112633585929871 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.00010580637504288371, 'alpha': 0.002815825930935634, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 10:08:04,349] Trial 27 finished with value: 0.7713011503219604 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0004539481315389048, 'alpha': 8.874771469786953e-05, 'optimizer': 'sgd'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 10:09:25,488] Trial 28 finished with value: 1.73256516456604 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.009827674611457334, 'alpha': 5.509929811778082e-05, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# [I 2025-05-17 10:10:40,574] Trial 29 finished with value: 0.7303987741470337 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.001216147966541517, 'alpha': 0.0014130490232818751, 'optimizer': 'adam'}. Best is trial 11 with value: 0.6965304017066956.
# === Best Hyperparameters ===
# {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0006998797679472042, 'alpha': 1.276783108350025e-05, 'optimizer': 'adam'}
# Best Mean MAE: 0.6965

# %%
import os
import optuna
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    # 采样超参数
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        model = XGBRegressor(n_jobs=-1, verbosity=0, **params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 以 MAE 为优化目标


# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best XGBoost Hyperparameters via Optuna ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 21:40:05,522] A new study created in memory with name: no-name-7b85144b-f145-492c-9e87-fedd912e94d9
# [I 2025-05-16 21:42:02,168] Trial 0 finished with value: 0.8004703521728516 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 8, 'subsample': 0.8795975452591109, 'colsample_bytree': 0.6624074561769746}. Best is trial 0 with value: 0.8004703521728516.
# [I 2025-05-16 21:43:31,922] Trial 1 finished with value: 0.7566276788711548 and parameters: {'n_estimators': 200, 'learning_rate': 0.011900590783184251, 'max_depth': 9, 'subsample': 0.8803345035229626, 'colsample_bytree': 0.8832290311184181}. Best is trial 1 with value: 0.7566276788711548.
# [I 2025-05-16 21:44:03,491] Trial 2 finished with value: 0.7418551445007324 and parameters: {'n_estimators': 100, 'learning_rate': 0.18276027831785724, 'max_depth': 8, 'subsample': 0.7637017332034828, 'colsample_bytree': 0.6727299868828402}. Best is trial 2 with value: 0.7418551445007324.
# [I 2025-05-16 21:44:47,295] Trial 3 finished with value: 0.7008415460586548 and parameters: {'n_estimators': 200, 'learning_rate': 0.024878734419814436, 'max_depth': 6, 'subsample': 0.8295835055926347, 'colsample_bytree': 0.7164916560792167}. Best is trial 3 with value: 0.7008415460586548.
# [I 2025-05-16 21:46:44,423] Trial 4 finished with value: 0.6940338611602783 and parameters: {'n_estimators': 700, 'learning_rate': 0.01518747922672247, 'max_depth': 5, 'subsample': 0.8099085529881075, 'colsample_bytree': 0.7824279936868144}. Best is trial 4 with value: 0.6940338611602783.
# [I 2025-05-16 21:49:19,093] Trial 5 finished with value: 0.7049052715301514 and parameters: {'n_estimators': 800, 'learning_rate': 0.018187859051288217, 'max_depth': 6, 'subsample': 0.8777243706586128, 'colsample_bytree': 0.6185801650879991}. Best is trial 4 with value: 0.6940338611602783.
# [I 2025-05-16 21:50:25,222] Trial 6 finished with value: 0.6889470815658569 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'subsample': 0.984665661176, 'colsample_bytree': 0.9862528132298237}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 21:51:45,713] Trial 7 finished with value: 0.6902046203613281 and parameters: {'n_estimators': 900, 'learning_rate': 0.0249064396938244, 'max_depth': 3, 'subsample': 0.905269907953647, 'colsample_bytree': 0.7760609974958406}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 21:52:04,792] Trial 8 finished with value: 0.6921679377555847 and parameters: {'n_estimators': 200, 'learning_rate': 0.04407984038169244, 'max_depth': 3, 'subsample': 0.9727961206236346, 'colsample_bytree': 0.7035119926400067}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 21:54:21,631] Trial 9 finished with value: 0.7088943719863892 and parameters: {'n_estimators': 700, 'learning_rate': 0.02544166090938368, 'max_depth': 6, 'subsample': 0.8640130838029838, 'colsample_bytree': 0.6739417822102108}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 21:56:26,687] Trial 10 finished with value: 0.7225189208984375 and parameters: {'n_estimators': 1000, 'learning_rate': 0.08138762607805286, 'max_depth': 4, 'subsample': 0.9865434487124839, 'colsample_bytree': 0.9935584941681304}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 21:57:57,634] Trial 11 finished with value: 0.6969636678695679 and parameters: {'n_estimators': 1000, 'learning_rate': 0.03962196116773197, 'max_depth': 3, 'subsample': 0.935088886344705, 'colsample_bytree': 0.8654149912009428}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 21:59:44,169] Trial 12 finished with value: 0.6906626224517822 and parameters: {'n_estimators': 800, 'learning_rate': 0.010259443333354297, 'max_depth': 4, 'subsample': 0.9465244376887645, 'colsample_bytree': 0.9976023236378931}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:00:58,579] Trial 13 finished with value: 0.6927231550216675 and parameters: {'n_estimators': 600, 'learning_rate': 0.02786809880358077, 'max_depth': 4, 'subsample': 0.9237302276937214, 'colsample_bytree': 0.8002022810897866}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:02:23,339] Trial 14 finished with value: 0.7068228125572205 and parameters: {'n_estimators': 900, 'learning_rate': 0.07890559538527207, 'max_depth': 3, 'subsample': 0.725910676545781, 'colsample_bytree': 0.9087696049520285}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:03:44,141] Trial 15 finished with value: 0.694934070110321 and parameters: {'n_estimators': 500, 'learning_rate': 0.018652596014589424, 'max_depth': 5, 'subsample': 0.9964393754090888, 'colsample_bytree': 0.7826173426603852}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:05:08,183] Trial 16 finished with value: 0.6984758377075195 and parameters: {'n_estimators': 500, 'learning_rate': 0.033382725868896894, 'max_depth': 5, 'subsample': 0.920651609920626, 'colsample_bytree': 0.9375920406844779}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:06:28,812] Trial 17 finished with value: 0.7008785009384155 and parameters: {'n_estimators': 900, 'learning_rate': 0.06535551490482465, 'max_depth': 3, 'subsample': 0.9562376452982237, 'colsample_bytree': 0.8355015245784254}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:07:56,580] Trial 18 finished with value: 0.6911991834640503 and parameters: {'n_estimators': 700, 'learning_rate': 0.015009373317465317, 'max_depth': 4, 'subsample': 0.9067467468954586, 'colsample_bytree': 0.7451045414896146}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:09:05,687] Trial 19 finished with value: 0.7060226202011108 and parameters: {'n_estimators': 400, 'learning_rate': 0.0567587490088489, 'max_depth': 5, 'subsample': 0.7911562956337728, 'colsample_bytree': 0.9517503077961021}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:12:49,384] Trial 20 finished with value: 0.7231341600418091 and parameters: {'n_estimators': 900, 'learning_rate': 0.021456519315144907, 'max_depth': 7, 'subsample': 0.8394309939089588, 'colsample_bytree': 0.8549750891271488}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:14:36,885] Trial 21 finished with value: 0.6910790205001831 and parameters: {'n_estimators': 800, 'learning_rate': 0.010010525982661491, 'max_depth': 4, 'subsample': 0.9521611575184936, 'colsample_bytree': 0.9889525893907897}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:15:52,480] Trial 22 finished with value: 0.689847469329834 and parameters: {'n_estimators': 800, 'learning_rate': 0.01316806184155628, 'max_depth': 3, 'subsample': 0.9029595497769426, 'colsample_bytree': 0.9560579137354811}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:16:50,730] Trial 23 finished with value: 0.6906961798667908 and parameters: {'n_estimators': 600, 'learning_rate': 0.014479290695140846, 'max_depth': 3, 'subsample': 0.9044986942916995, 'colsample_bytree': 0.9508141402540538}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:18:06,500] Trial 24 finished with value: 0.6892379522323608 and parameters: {'n_estimators': 800, 'learning_rate': 0.013594387025048522, 'max_depth': 3, 'subsample': 0.9003377348752277, 'colsample_bytree': 0.9156527394121505}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:19:37,029] Trial 25 finished with value: 0.6910413503646851 and parameters: {'n_estimators': 700, 'learning_rate': 0.012811015822765635, 'max_depth': 4, 'subsample': 0.9708625014229788, 'colsample_bytree': 0.9206262833770952}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:20:51,901] Trial 26 finished with value: 0.6896895170211792 and parameters: {'n_estimators': 800, 'learning_rate': 0.017812503901544437, 'max_depth': 3, 'subsample': 0.8521272349496697, 'colsample_bytree': 0.8989848857663882}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:22:09,355] Trial 27 finished with value: 0.690662682056427 and parameters: {'n_estimators': 600, 'learning_rate': 0.019505914820506263, 'max_depth': 4, 'subsample': 0.8572853719490603, 'colsample_bytree': 0.9001283013329892}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:23:43,161] Trial 28 finished with value: 0.6951848268508911 and parameters: {'n_estimators': 1000, 'learning_rate': 0.03184315555804374, 'max_depth': 3, 'subsample': 0.8142062586409643, 'colsample_bytree': 0.9611294188875423}. Best is trial 6 with value: 0.6889470815658569.
# [I 2025-05-16 22:24:50,267] Trial 29 finished with value: 0.7323075532913208 and parameters: {'n_estimators': 400, 'learning_rate': 0.13390499764355235, 'max_depth': 5, 'subsample': 0.7553276345083549, 'colsample_bytree': 0.8357201337857788}. Best is trial 6 with value: 0.6889470815658569.
# === Best XGBoost Hyperparameters via Optuna ===
# {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'subsample': 0.984665661176, 'colsample_bytree': 0.9862528132298237}
# 10-Fold Mean MAE = 0.6889

# %%
import os
import optuna
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'objective': 'poisson',         # ✅ 强制正输出
        'n_jobs': -1,
        'verbose': -1
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        # Poisson 回归要求标签必须大于 0
        if np.any(y_train <= 0) or np.any(y_val <= 0):
            return np.inf

        model = LGBMRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 使用 MAE 作为优化目标

# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 22:24:50,356] A new study created in memory with name: no-name-8a45c8c1-f14c-48fc-b332-84707eb0a73f
# [I 2025-05-16 22:25:11,725] Trial 0 finished with value: 0.714897550170899 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 10, 'num_leaves': 68, 'feature_fraction': 0.6624074561769746, 'bagging_fraction': 0.662397808134481}. Best is trial 0 with value: 0.714897550170899.
# [I 2025-05-16 22:25:20,588] Trial 1 finished with value: 0.6996980639977368 and parameters: {'n_estimators': 100, 'learning_rate': 0.13394334706750485, 'max_depth': 9, 'num_leaves': 77, 'feature_fraction': 0.608233797718321, 'bagging_fraction': 0.9879639408647978}. Best is trial 1 with value: 0.6996980639977368.
# [I 2025-05-16 22:25:41,914] Trial 2 finished with value: 0.6915790956952254 and parameters: {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}. Best is trial 2 with value: 0.6915790956952254.
# [I 2025-05-16 22:26:07,995] Trial 3 finished with value: 0.6938869689577014 and parameters: {'n_estimators': 500, 'learning_rate': 0.023927528765580644, 'max_depth': 9, 'num_leaves': 31, 'feature_fraction': 0.7168578594140873, 'bagging_fraction': 0.7465447373174767}. Best is trial 2 with value: 0.6915790956952254.
# [I 2025-05-16 22:26:19,701] Trial 4 finished with value: 0.6913570079050295 and parameters: {'n_estimators': 500, 'learning_rate': 0.10508421338691762, 'max_depth': 4, 'num_leaves': 61, 'feature_fraction': 0.836965827544817, 'bagging_fraction': 0.6185801650879991}. Best is trial 4 with value: 0.6913570079050295.
# [I 2025-05-16 22:26:36,089] Trial 5 finished with value: 0.696838185898996 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'num_leaves': 96, 'feature_fraction': 0.9862528132298237, 'bagging_fraction': 0.9233589392465844}. Best is trial 4 with value: 0.6913570079050295.
# [I 2025-05-16 22:27:05,775] Trial 6 finished with value: 0.7353462409974167 and parameters: {'n_estimators': 400, 'learning_rate': 0.013399060561509796, 'max_depth': 9, 'num_leaves': 55, 'feature_fraction': 0.6488152939379115, 'bagging_fraction': 0.798070764044508}. Best is trial 4 with value: 0.6913570079050295.
# [I 2025-05-16 22:27:10,304] Trial 7 finished with value: 0.6923107484232544 and parameters: {'n_estimators': 100, 'learning_rate': 0.15242391728466367, 'max_depth': 5, 'num_leaves': 73, 'feature_fraction': 0.7246844304357644, 'bagging_fraction': 0.8080272084711243}. Best is trial 4 with value: 0.6913570079050295.
# [I 2025-05-16 22:28:14,263] Trial 8 finished with value: 0.7011040605418006 and parameters: {'n_estimators': 600, 'learning_rate': 0.017398074711291726, 'max_depth': 12, 'num_leaves': 82, 'feature_fraction': 0.9757995766256756, 'bagging_fraction': 0.9579309401710595}. Best is trial 4 with value: 0.6913570079050295.
# [I 2025-05-16 22:28:22,879] Trial 9 finished with value: 0.6945133906916541 and parameters: {'n_estimators': 600, 'learning_rate': 0.15826541904647565, 'max_depth': 3, 'num_leaves': 35, 'feature_fraction': 0.6180909155642152, 'bagging_fraction': 0.7301321323053057}. Best is trial 4 with value: 0.6913570079050295.
# [I 2025-05-16 22:28:54,774] Trial 10 finished with value: 0.7021255295851679 and parameters: {'n_estimators': 1000, 'learning_rate': 0.07549726627694736, 'max_depth': 6, 'num_leaves': 54, 'feature_fraction': 0.8676285972451436, 'bagging_fraction': 0.6154900799844731}. Best is trial 4 with value: 0.6913570079050295.
# [I 2025-05-16 22:29:18,929] Trial 11 finished with value: 0.6926467056282047 and parameters: {'n_estimators': 900, 'learning_rate': 0.043983071728850964, 'max_depth': 5, 'num_leaves': 21, 'feature_fraction': 0.8242173679510726, 'bagging_fraction': 0.8621036796927505}. Best is trial 4 with value: 0.6913570079050295.
# [I 2025-05-16 22:29:49,335] Trial 12 finished with value: 0.693734190620902 and parameters: {'n_estimators': 800, 'learning_rate': 0.03673757945485903, 'max_depth': 6, 'num_leaves': 45, 'feature_fraction': 0.8896513152322078, 'bagging_fraction': 0.6871414335345349}. Best is trial 4 with value: 0.6913570079050295.
# [I 2025-05-16 22:29:57,166] Trial 13 finished with value: 0.6922411713591827 and parameters: {'n_estimators': 300, 'learning_rate': 0.06922749265952521, 'max_depth': 4, 'num_leaves': 45, 'feature_fraction': 0.7704530199603108, 'bagging_fraction': 0.865022115212146}. Best is trial 4 with value: 0.6913570079050295.
# [I 2025-05-16 22:30:27,171] Trial 14 finished with value: 0.7095850750892134 and parameters: {'n_estimators': 800, 'learning_rate': 0.09549211889362913, 'max_depth': 7, 'num_leaves': 64, 'feature_fraction': 0.797468651479226, 'bagging_fraction': 0.6096559237192299}. Best is trial 4 with value: 0.6913570079050295.
# [I 2025-05-16 22:30:50,624] Trial 15 finished with value: 0.6895469171862182 and parameters: {'n_estimators': 1000, 'learning_rate': 0.03175444157346496, 'max_depth': 4, 'num_leaves': 45, 'feature_fraction': 0.9191979476316068, 'bagging_fraction': 0.7845619357947551}. Best is trial 15 with value: 0.6895469171862182.
# [I 2025-05-16 22:31:11,516] Trial 16 finished with value: 0.7023879694703584 and parameters: {'n_estimators': 300, 'learning_rate': 0.02908420670345017, 'max_depth': 7, 'num_leaves': 49, 'feature_fraction': 0.9212472631318983, 'bagging_fraction': 0.6938368901911588}. Best is trial 15 with value: 0.6895469171862182.
# [I 2025-05-16 22:31:33,546] Trial 17 finished with value: 0.6926025232866128 and parameters: {'n_estimators': 1000, 'learning_rate': 0.05863149571579333, 'max_depth': 4, 'num_leaves': 87, 'feature_fraction': 0.9379338151451567, 'bagging_fraction': 0.7474869904887774}. Best is trial 15 with value: 0.6895469171862182.
# [I 2025-05-16 22:31:51,707] Trial 18 finished with value: 0.6961235936456707 and parameters: {'n_estimators': 700, 'learning_rate': 0.1037898068626402, 'max_depth': 5, 'num_leaves': 61, 'feature_fraction': 0.843703982484205, 'bagging_fraction': 0.8632705182047203}. Best is trial 15 with value: 0.6895469171862182.
# [I 2025-05-16 22:32:03,570] Trial 19 finished with value: 0.7456243362275514 and parameters: {'n_estimators': 500, 'learning_rate': 0.010646556846278058, 'max_depth': 3, 'num_leaves': 20, 'feature_fraction': 0.9054989579659412, 'bagging_fraction': 0.6492601542085225}. Best is trial 15 with value: 0.6895469171862182.
# [I 2025-05-16 22:32:18,290] Trial 20 finished with value: 0.6928187944426163 and parameters: {'n_estimators': 300, 'learning_rate': 0.053465922307498796, 'max_depth': 6, 'num_leaves': 40, 'feature_fraction': 0.9487565652323114, 'bagging_fraction': 0.9117772967102288}. Best is trial 15 with value: 0.6895469171862182.
# [I 2025-05-16 22:32:37,770] Trial 21 finished with value: 0.690256128030958 and parameters: {'n_estimators': 900, 'learning_rate': 0.024285383009483585, 'max_depth': 4, 'num_leaves': 33, 'feature_fraction': 0.7026827755877711, 'bagging_fraction': 0.8009273051447362}. Best is trial 15 with value: 0.6895469171862182.
# [I 2025-05-16 22:32:57,125] Trial 22 finished with value: 0.6906415325749306 and parameters: {'n_estimators': 900, 'learning_rate': 0.02946147282554694, 'max_depth': 4, 'num_leaves': 29, 'feature_fraction': 0.772645886412852, 'bagging_fraction': 0.7752018316284149}. Best is trial 15 with value: 0.6895469171862182.
# [I 2025-05-16 22:33:22,346] Trial 23 finished with value: 0.6908651646629207 and parameters: {'n_estimators': 900, 'learning_rate': 0.02926996644711256, 'max_depth': 5, 'num_leaves': 27, 'feature_fraction': 0.771611160540024, 'bagging_fraction': 0.7792171145526098}. Best is trial 15 with value: 0.6895469171862182.
# [I 2025-05-16 22:33:37,165] Trial 24 finished with value: 0.6895758098644815 and parameters: {'n_estimators': 1000, 'learning_rate': 0.035566927470179116, 'max_depth': 3, 'num_leaves': 39, 'feature_fraction': 0.6905648467135862, 'bagging_fraction': 0.8382322760816405}. Best is trial 15 with value: 0.6895469171862182.
# [I 2025-05-16 22:33:52,430] Trial 25 finished with value: 0.6889531108880027 and parameters: {'n_estimators': 1000, 'learning_rate': 0.039008072328196516, 'max_depth': 3, 'num_leaves': 39, 'feature_fraction': 0.7116937439122395, 'bagging_fraction': 0.8373332679685861}. Best is trial 25 with value: 0.6889531108880027.
# [I 2025-05-16 22:34:07,155] Trial 26 finished with value: 0.689922646956255 and parameters: {'n_estimators': 1000, 'learning_rate': 0.0404663196009641, 'max_depth': 3, 'num_leaves': 40, 'feature_fraction': 0.68464005065899, 'bagging_fraction': 0.838817870015776}. Best is trial 25 with value: 0.6889531108880027.
# [I 2025-05-16 22:34:20,033] Trial 27 finished with value: 0.6900245859918985 and parameters: {'n_estimators': 800, 'learning_rate': 0.036258497076636594, 'max_depth': 3, 'num_leaves': 52, 'feature_fraction': 0.745755027978818, 'bagging_fraction': 0.9042967878307117}. Best is trial 25 with value: 0.6889531108880027.
# [I 2025-05-16 22:35:08,818] Trial 28 finished with value: 0.7062998437534838 and parameters: {'n_estimators': 1000, 'learning_rate': 0.05675128476701999, 'max_depth': 12, 'num_leaves': 41, 'feature_fraction': 0.6699647586517364, 'bagging_fraction': 0.8449988262554894}. Best is trial 25 with value: 0.6889531108880027.
# [I 2025-05-16 22:35:50,232] Trial 29 finished with value: 0.6944679879738518 and parameters: {'n_estimators': 700, 'learning_rate': 0.022965225691375758, 'max_depth': 11, 'num_leaves': 48, 'feature_fraction': 0.6477222880079607, 'bagging_fraction': 0.882246060586656}. Best is trial 25 with value: 0.6889531108880027.
# === Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===
# {'n_estimators': 1000, 'learning_rate': 0.039008072328196516, 'max_depth': 3, 'num_leaves': 39, 'feature_fraction': 0.7116937439122395, 'bagging_fraction': 0.8373332679685861}
# 10-Fold Mean MAE = 0.6890

# %% [markdown]
# ####
