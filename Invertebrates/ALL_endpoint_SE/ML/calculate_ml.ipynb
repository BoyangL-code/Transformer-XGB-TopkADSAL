# %%
import numpy as np
import pickle
from sklearn.metrics import (
    mean_absolute_error,
    root_mean_squared_error,
    r2_score
)
from scipy.stats import pearsonr

def evaluate_regression_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = root_mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    pearson_r, _ = pearsonr(y_true, y_pred)

    print("✅ 总体评估指标：")
    print(f"MAE      = {mae:.4f}")
    print(f"RMSE     = {rmse:.4f}")
    print(f"R²       = {r2:.4f}")
    print(f"PearsonR = {pearson_r:.4f}")

    return {
        'MAE': mae,
        'RMSE': rmse,
        'R2': r2,
        'PearsonR': pearson_r
    }

# %% [markdown]
# #LGB

# %%
errors=[]
all_val =  []
all_pred = []
for i in range(10):
    val = np.load(f'./lgbm_cv_results/fold_{i}_y_true.npy')
    preds = np.load(f'./lgbm_cv_results/fold_{i}_y_pred.npy')
    error = np.maximum(val, preds) / np.minimum(val, preds)
    
    errors.append(error)
    all_val.append(val)
    all_pred.append(preds)
errors = np.concatenate(errors)

all_val = np.concatenate(all_val)
all_pred = np.concatenate(all_pred)

# %%
evaluate_regression_metrics(all_val, all_pred)
# Out:
# ✅ 总体评估指标：
# MAE      = 0.6913
# RMSE     = 1.0560
# R²       = 0.6455
# PearsonR = 0.8062
# {'MAE': 0.6913211797600681,
#  'RMSE': 1.056014680598716,
#  'R2': 0.6454919999330382,
#  'PearsonR': 0.8062429709189574}

# %% [markdown]
# #XGB

# %%
errors=[]
all_val =  []
all_pred = []
for i in range(10):
    val = np.load(f'./xgb_cv_results/fold_{i}_y_true.npy')
    preds = np.load(f'./xgb_cv_results/fold_{i}_y_pred.npy')
    error = np.maximum(val, preds) / np.minimum(val, preds)
    
    errors.append(error)
    all_val.append(val)
    all_pred.append(preds)
errors = np.concatenate(errors)

all_val = np.concatenate(all_val)
all_pred = np.concatenate(all_pred)
evaluate_regression_metrics(all_val, all_pred)
# Out:
# ✅ 总体评估指标：
# MAE      = 0.6765
# RMSE     = 1.0122
# R²       = 0.6743
# PearsonR = 0.8212
# {'MAE': 0.6765479316134234,
#  'RMSE': 1.0122014236023378,
#  'R2': 0.6742983068239353,
#  'PearsonR': 0.8212358095702152}

# %% [markdown]
# #DNN

# %%
errors=[]
all_val =  []
all_pred = []
for i in range(10):
    val = np.load(f'./dnn_cv_results/fold_{i}_y_true.npy')
    preds = np.load(f'./dnn_cv_results/fold_{i}_y_pred.npy')
    error = np.maximum(val, preds) / np.minimum(val, preds)
    
    errors.append(error)
    all_val.append(val)
    all_pred.append(preds)
errors = np.concatenate(errors)

all_val = np.concatenate(all_val)
all_pred = np.concatenate(all_pred)

# %%
evaluate_regression_metrics(all_val, all_pred)
# Out:
# ✅ 总体评估指标：
# MAE      = 0.8126
# RMSE     = 1.2754
# R²       = 0.4829
# PearsonR = 0.7254
# {'MAE': 0.8125532436344611,
#  'RMSE': 1.2753912018627043,
#  'R2': 0.4829018760146656,
#  'PearsonR': 0.725445492635729}
