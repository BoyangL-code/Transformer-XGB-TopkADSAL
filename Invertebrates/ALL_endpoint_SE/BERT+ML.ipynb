# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import random

# 固定随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # for multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)  # 设置固定种子

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import optuna
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# ----------------- CONFIGURATION -----------------
n_folds    = 10
n_trials   = 30
data_dir   = "./k_folds_model/embeddings"
batch_size = 256
num_epochs = 200
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------- MODEL DEFINITION -----------------
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        layers = []
        prev_dim = input_dim
        act = {
            'relu':     nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh':     nn.Tanh()
        }[activation]
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act]
            prev_dim = h
        layers.append(nn.Linear(prev_dim, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = self.net(x).squeeze(-1)
        return F.softplus(x)  # 输出 > 0

# ----------------- OPTUNA OBJECTIVE -----------------
def objective(trial):
    hidden_sizes      = trial.suggest_categorical('hidden_layer_sizes',
                            [(50,), (100,), (150,), (100, 50), (150, 100, 50)])
    activation        = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh'])
    lr                = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    weight_decay      = trial.suggest_float('alpha', 1e-5, 1e-2, log=True)
    optimizer_choice  = trial.suggest_categorical('optimizer', ['sgd', 'adam'])

    fold_maes = []

    for fold in range(1, n_folds + 1):
        X_train = np.load(f"{data_dir}/train_fold_{fold}.npy")
        y_train = np.load(f"{data_dir}/train_labels_fold_{fold}.npy")
        X_val   = np.load(f"{data_dir}/val_fold_{fold}.npy")
        y_val   = np.load(f"{data_dir}/val_labels_fold_{fold}.npy")

        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val   = scaler.transform(X_val)

        train_ds = TensorDataset(torch.from_numpy(X_train).float(),
                                 torch.from_numpy(y_train).float())
        val_ds = TensorDataset(torch.from_numpy(X_val).float(),
                               torch.from_numpy(y_val).float())
        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        model = MLP(input_dim=X_train.shape[1],
                    hidden_sizes=hidden_sizes,
                    activation=activation).to(device)
        criterion = nn.MSELoss()
        optimizer = {
            'sgd': torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay),
            'adam': torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        }[optimizer_choice]

        try:
            for epoch in range(num_epochs):
                model.train()
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    preds = model(xb)
                    loss = criterion(preds, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            all_preds = []
            with torch.no_grad():
                for xb, _ in val_loader:
                    xb = xb.to(device)
                    batch_pred = model(xb).cpu().numpy()
                    all_preds.append(batch_pred)
            all_preds = np.concatenate(all_preds)

            mae = mean_absolute_error(y_val, all_preds)
            fold_maes.append(mae)

        except Exception:
            return np.inf

    return float(np.mean(fold_maes))

# ----------------- RUN OPTUNA -----------------
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)

    print("\n=== Best Hyperparameters ===")
    print(study.best_params)
    print(f"Best Mean MAE: {study.best_value:.4f}")
# Out:
# [I 2025-05-16 10:07:45,064] A new study created in memory with name: no-name-bf7a2194-a9b1-4845-a68d-52e3a2c65b54
# [I 2025-05-16 10:15:39,150] Trial 0 finished with value: 0.5795766115188599 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.0015930522616241021, 'alpha': 0.001331121608073689, 'optimizer': 'adam'}. Best is trial 0 with value: 0.5795766115188599.
# [I 2025-05-16 10:22:06,707] Trial 1 finished with value: 0.5500322580337524 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0016738085788752138, 'alpha': 2.621087878265438e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.5500322580337524.
# [I 2025-05-16 10:28:21,711] Trial 2 finished with value: 0.7732638120651245 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00013492834268013249, 'alpha': 0.007025166339242158, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.5500322580337524.
# [I 2025-05-16 10:34:50,095] Trial 3 finished with value: 0.5546783804893494 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00032927591344236165, 'alpha': 0.0009717775305059633, 'optimizer': 'adam'}. Best is trial 1 with value: 0.5500322580337524.
# [I 2025-05-16 10:41:19,215] Trial 4 finished with value: 0.5472882390022278 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00015030900645056822, 'alpha': 3.872118032174584e-05, 'optimizer': 'adam'}. Best is trial 4 with value: 0.5472882390022278.
# [I 2025-05-16 10:47:28,367] Trial 5 finished with value: 0.5458558201789856 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00014096175149815865, 'alpha': 0.009133995846860976, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.5458558201789856.
# [I 2025-05-16 10:53:39,469] Trial 6 finished with value: 0.5507456064224243 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.005323617594751502, 'alpha': 0.0007411299781083245, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.5458558201789856.
# [I 2025-05-16 11:00:32,724] Trial 7 finished with value: 0.5472058057785034 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0033233042062267943, 'alpha': 0.00048287152161792117, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.5458558201789856.
# [I 2025-05-16 11:07:04,229] Trial 8 finished with value: 0.5537620782852173 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.006533305220227739, 'alpha': 5.59598687800608e-05, 'optimizer': 'adam'}. Best is trial 5 with value: 0.5458558201789856.
# [I 2025-05-16 11:20:34,532] Trial 10 finished with value: 0.5693286061286926 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0004260009910618965, 'alpha': 0.007328013762901325, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.5458558201789856.
# [I 2025-05-16 11:27:25,954] Trial 11 finished with value: 0.5499249696731567 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0006359692454265627, 'alpha': 0.00028112236163557156, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.5458558201789856.
# [I 2025-05-16 11:34:17,617] Trial 12 finished with value: 0.5611032247543335 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0025595271717911575, 'alpha': 0.00017888562948289706, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.5458558201789856.
# [I 2025-05-16 11:40:23,217] Trial 13 finished with value: 0.5591787099838257 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.009883865086061896, 'alpha': 0.0029335409283014037, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.5458558201789856.
# [I 2025-05-16 11:46:52,650] Trial 14 finished with value: 0.5470749735832214 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.0009008101872788536, 'alpha': 0.00011486518462839184, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.5458558201789856.
# [I 2025-05-16 11:53:13,221] Trial 15 finished with value: 1.0233380794525146 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.0002846282635669909, 'alpha': 0.00010849578995850742, 'optimizer': 'sgd'}. Best is trial 5 with value: 0.5458558201789856.
# [I 2025-05-16 11:59:42,453] Trial 16 finished with value: 0.5429457426071167 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.0008995877337027043, 'alpha': 0.00010400217777958222, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.5429457426071167.
# [I 2025-05-16 12:06:09,125] Trial 17 finished with value: 0.5524717569351196 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.0002007782126093262, 'alpha': 1.4476185669187095e-05, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.5429457426071167.
# [I 2025-05-16 12:12:11,095] Trial 18 finished with value: 0.5547235012054443 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.0006767265768662899, 'alpha': 0.0023436732632306206, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.5429457426071167.
# [I 2025-05-16 12:18:38,284] Trial 19 finished with value: 1.3629844188690186 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.00010147405680975709, 'alpha': 1.0788661515919524e-05, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.5429457426071167.
# [I 2025-05-16 12:24:45,928] Trial 20 finished with value: 0.5551980137825012 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0016539406162826053, 'alpha': 0.0030118471741926176, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.5429457426071167.
# [I 2025-05-16 12:31:09,867] Trial 21 finished with value: 0.5529164671897888 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.0009467849942903482, 'alpha': 9.637313004562953e-05, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.5429457426071167.
# [I 2025-05-16 12:37:36,270] Trial 22 finished with value: 0.5461572408676147 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.0005209314402340293, 'alpha': 0.00020656313425169686, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.5429457426071167.
# [I 2025-05-16 12:44:04,409] Trial 23 finished with value: 0.5472612380981445 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.00047884438800384083, 'alpha': 0.00024752893311830995, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.5429457426071167.
# [I 2025-05-16 12:50:36,060] Trial 24 finished with value: 0.5530783534049988 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.00025655703474665193, 'alpha': 0.00047109941983546267, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.5429457426071167.
# [I 2025-05-16 12:56:37,800] Trial 25 finished with value: 0.5487891435623169 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'learning_rate': 0.0004991234041800156, 'alpha': 6.656177425784043e-05, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.5429457426071167.
# [I 2025-05-16 13:03:13,371] Trial 26 finished with value: 0.5662258863449097 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0010942358524497339, 'alpha': 0.0001595506996451525, 'optimizer': 'adam'}. Best is trial 16 with value: 0.5429457426071167.
# [I 2025-05-16 13:09:45,395] Trial 27 finished with value: 0.5536226034164429 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.00019699263996958354, 'alpha': 0.0005066911149859133, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.5429457426071167.
# [I 2025-05-16 13:16:12,787] Trial 28 finished with value: 0.5832549929618835 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.0007226817855402445, 'alpha': 0.0016836375571527306, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.5429457426071167.
# [I 2025-05-16 13:22:39,949] Trial 29 finished with value: 0.5603953003883362 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'learning_rate': 0.001216147966541517, 'alpha': 0.004399926300387226, 'optimizer': 'adam'}. Best is trial 16 with value: 0.5429457426071167.
# === Best Hyperparameters ===
# {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.0008995877337027043, 'alpha': 0.00010400217777958222, 'optimizer': 'sgd'}
# Best Mean MAE: 0.5429

# %%
import os
import optuna
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    # 采样超参数
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        model = XGBRegressor(n_jobs=-1, verbosity=0, **params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 以 MAE 为优化目标


# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best XGBoost Hyperparameters via Optuna ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 16:17:01,537] A new study created in memory with name: no-name-6ccba772-d5d2-4993-83cf-4a1dd9f69b06
# [I 2025-05-16 16:20:48,483] Trial 0 finished with value: 0.5971556901931763 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 8, 'subsample': 0.8795975452591109, 'colsample_bytree': 0.6624074561769746}. Best is trial 0 with value: 0.5971556901931763.
# [I 2025-05-16 16:24:39,708] Trial 1 finished with value: 0.5910816192626953 and parameters: {'n_estimators': 200, 'learning_rate': 0.011900590783184251, 'max_depth': 9, 'subsample': 0.8803345035229626, 'colsample_bytree': 0.8832290311184181}. Best is trial 1 with value: 0.5910816192626953.
# [I 2025-05-16 16:25:40,780] Trial 2 finished with value: 0.5787621736526489 and parameters: {'n_estimators': 100, 'learning_rate': 0.18276027831785724, 'max_depth': 8, 'subsample': 0.7637017332034828, 'colsample_bytree': 0.6727299868828402}. Best is trial 2 with value: 0.5787621736526489.
# [I 2025-05-16 16:27:03,710] Trial 3 finished with value: 0.533167839050293 and parameters: {'n_estimators': 200, 'learning_rate': 0.024878734419814436, 'max_depth': 6, 'subsample': 0.8295835055926347, 'colsample_bytree': 0.7164916560792167}. Best is trial 3 with value: 0.533167839050293.
# [I 2025-05-16 16:30:23,891] Trial 4 finished with value: 0.5299971103668213 and parameters: {'n_estimators': 700, 'learning_rate': 0.01518747922672247, 'max_depth': 5, 'subsample': 0.8099085529881075, 'colsample_bytree': 0.7824279936868144}. Best is trial 4 with value: 0.5299971103668213.
# [I 2025-05-16 16:34:52,229] Trial 5 finished with value: 0.5369375348091125 and parameters: {'n_estimators': 800, 'learning_rate': 0.018187859051288217, 'max_depth': 6, 'subsample': 0.8777243706586128, 'colsample_bytree': 0.6185801650879991}. Best is trial 4 with value: 0.5299971103668213.
# [I 2025-05-16 16:36:55,398] Trial 6 finished with value: 0.5316320657730103 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'subsample': 0.984665661176, 'colsample_bytree': 0.9862528132298237}. Best is trial 4 with value: 0.5299971103668213.
# [I 2025-05-16 16:39:20,763] Trial 7 finished with value: 0.5317771434783936 and parameters: {'n_estimators': 900, 'learning_rate': 0.0249064396938244, 'max_depth': 3, 'subsample': 0.905269907953647, 'colsample_bytree': 0.7760609974958406}. Best is trial 4 with value: 0.5299971103668213.
# [I 2025-05-16 16:39:56,272] Trial 8 finished with value: 0.5334756970405579 and parameters: {'n_estimators': 200, 'learning_rate': 0.04407984038169244, 'max_depth': 3, 'subsample': 0.9727961206236346, 'colsample_bytree': 0.7035119926400067}. Best is trial 4 with value: 0.5299971103668213.
# [I 2025-05-16 16:43:51,051] Trial 9 finished with value: 0.5398117303848267 and parameters: {'n_estimators': 700, 'learning_rate': 0.02544166090938368, 'max_depth': 6, 'subsample': 0.8640130838029838, 'colsample_bytree': 0.6739417822102108}. Best is trial 4 with value: 0.5299971103668213.
# [I 2025-05-16 16:48:32,051] Trial 10 finished with value: 0.5728704333305359 and parameters: {'n_estimators': 1000, 'learning_rate': 0.08138762607805286, 'max_depth': 5, 'subsample': 0.7053885626844458, 'colsample_bytree': 0.8560354009870226}. Best is trial 4 with value: 0.5299971103668213.
# [I 2025-05-16 16:50:58,507] Trial 11 finished with value: 0.5297567844390869 and parameters: {'n_estimators': 600, 'learning_rate': 0.010397685413855193, 'max_depth': 4, 'subsample': 0.9840885629170447, 'colsample_bytree': 0.9983196520526199}. Best is trial 11 with value: 0.5297567844390869.
# [I 2025-05-16 16:54:09,075] Trial 12 finished with value: 0.5291194915771484 and parameters: {'n_estimators': 600, 'learning_rate': 0.010274892564820053, 'max_depth': 5, 'subsample': 0.7876715396505959, 'colsample_bytree': 0.9831318134671313}. Best is trial 12 with value: 0.5291194915771484.
# [I 2025-05-16 16:56:14,427] Trial 13 finished with value: 0.5316068530082703 and parameters: {'n_estimators': 500, 'learning_rate': 0.010329411633362245, 'max_depth': 4, 'subsample': 0.7782643257499605, 'colsample_bytree': 0.9891169946375697}. Best is trial 12 with value: 0.5291194915771484.
# [I 2025-05-16 16:58:32,860] Trial 14 finished with value: 0.538949191570282 and parameters: {'n_estimators': 500, 'learning_rate': 0.04544111895879342, 'max_depth': 5, 'subsample': 0.9368431198958393, 'colsample_bytree': 0.9247157523670118}. Best is trial 12 with value: 0.5291194915771484.
# [I 2025-05-16 17:00:20,441] Trial 15 finished with value: 0.5394027233123779 and parameters: {'n_estimators': 400, 'learning_rate': 0.010094846033199373, 'max_depth': 4, 'subsample': 0.7235387154900341, 'colsample_bytree': 0.9330680918404882}. Best is trial 12 with value: 0.5291194915771484.
# [I 2025-05-16 17:02:30,360] Trial 16 finished with value: 0.5348014831542969 and parameters: {'n_estimators': 600, 'learning_rate': 0.04040150752118332, 'max_depth': 4, 'subsample': 0.7906703876981188, 'colsample_bytree': 0.9375920406844779}. Best is trial 12 with value: 0.5291194915771484.
# [I 2025-05-16 17:04:20,777] Trial 17 finished with value: 0.5490432977676392 and parameters: {'n_estimators': 400, 'learning_rate': 0.08903012950316415, 'max_depth': 5, 'subsample': 0.7416438512657763, 'colsample_bytree': 0.8424675077059609}. Best is trial 12 with value: 0.5291194915771484.
# [I 2025-05-16 17:09:25,955] Trial 18 finished with value: 0.5368312001228333 and parameters: {'n_estimators': 600, 'learning_rate': 0.015509765241146611, 'max_depth': 7, 'subsample': 0.9369897065593998, 'colsample_bytree': 0.9624449629014714}. Best is trial 12 with value: 0.5291194915771484.
# [I 2025-05-16 17:12:16,551] Trial 19 finished with value: 0.5335472226142883 and parameters: {'n_estimators': 800, 'learning_rate': 0.03246335679545026, 'max_depth': 4, 'subsample': 0.8320516587296894, 'colsample_bytree': 0.8975185857020822}. Best is trial 12 with value: 0.5291194915771484.
# [I 2025-05-16 17:20:12,595] Trial 20 finished with value: 0.5417383313179016 and parameters: {'n_estimators': 1000, 'learning_rate': 0.013106597630095652, 'max_depth': 7, 'subsample': 0.9485797127787471, 'colsample_bytree': 0.9956875428734134}. Best is trial 12 with value: 0.5291194915771484.
# [I 2025-05-16 17:23:31,770] Trial 21 finished with value: 0.5298639535903931 and parameters: {'n_estimators': 700, 'learning_rate': 0.014829124468372003, 'max_depth': 5, 'subsample': 0.8022949454546673, 'colsample_bytree': 0.7827465638071519}. Best is trial 12 with value: 0.5291194915771484.
# [I 2025-05-16 17:27:12,774] Trial 22 finished with value: 0.5324786901473999 and parameters: {'n_estimators': 800, 'learning_rate': 0.01972823492062141, 'max_depth': 5, 'subsample': 0.8031375958741598, 'colsample_bytree': 0.8281640640191558}. Best is trial 12 with value: 0.5291194915771484.
# [I 2025-05-16 17:29:32,743] Trial 23 finished with value: 0.5285450220108032 and parameters: {'n_estimators': 600, 'learning_rate': 0.01296870259204731, 'max_depth': 4, 'subsample': 0.7520222923517417, 'colsample_bytree': 0.7686109034318961}. Best is trial 23 with value: 0.5285450220108032.
# [I 2025-05-16 17:31:38,102] Trial 24 finished with value: 0.5304896831512451 and parameters: {'n_estimators': 500, 'learning_rate': 0.011998115248658927, 'max_depth': 4, 'subsample': 0.7538433593999668, 'colsample_bytree': 0.7507983883065513}. Best is trial 23 with value: 0.5285450220108032.
# [I 2025-05-16 17:33:18,471] Trial 25 finished with value: 0.5306453108787537 and parameters: {'n_estimators': 600, 'learning_rate': 0.02081746226557753, 'max_depth': 3, 'subsample': 0.7327172439246283, 'colsample_bytree': 0.8123067757501935}. Best is trial 23 with value: 0.5285450220108032.
# [I 2025-05-16 17:34:38,427] Trial 26 finished with value: 0.560511589050293 and parameters: {'n_estimators': 300, 'learning_rate': 0.0101158175091771, 'max_depth': 4, 'subsample': 0.7737089520438631, 'colsample_bytree': 0.870443990178826}. Best is trial 23 with value: 0.5285450220108032.
# [I 2025-05-16 17:38:11,332] Trial 27 finished with value: 0.5577285289764404 and parameters: {'n_estimators': 600, 'learning_rate': 0.06412123661311248, 'max_depth': 6, 'subsample': 0.8360981607250861, 'colsample_bytree': 0.9609766997592947}. Best is trial 23 with value: 0.5285450220108032.
# [I 2025-05-16 17:39:42,518] Trial 28 finished with value: 0.5333631634712219 and parameters: {'n_estimators': 500, 'learning_rate': 0.012889989471399766, 'max_depth': 3, 'subsample': 0.7011333343528019, 'colsample_bytree': 0.8996808313584834}. Best is trial 23 with value: 0.5285450220108032.
# [I 2025-05-16 17:41:05,175] Trial 29 finished with value: 0.5550922155380249 and parameters: {'n_estimators': 400, 'learning_rate': 0.13390499764355235, 'max_depth': 4, 'subsample': 0.9981528355149126, 'colsample_bytree': 0.7344984789779685}. Best is trial 23 with value: 0.5285450220108032.
# === Best XGBoost Hyperparameters via Optuna ===
# {'n_estimators': 600, 'learning_rate': 0.01296870259204731, 'max_depth': 4, 'subsample': 0.7520222923517417, 'colsample_bytree': 0.7686109034318961}
# 10-Fold Mean MAE = 0.5285

# %%
import os
import optuna
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'objective': 'poisson',         # ✅ 强制正输出
        'n_jobs': -1,
        'verbose': -1
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        # Poisson 回归要求标签必须大于 0
        if np.any(y_train <= 0) or np.any(y_val <= 0):
            return np.inf

        model = LGBMRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 使用 MAE 作为优化目标

# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 17:41:05,265] A new study created in memory with name: no-name-c21b74f6-2ccf-4e35-9249-29b9a2d4ea74
# [I 2025-05-16 17:41:58,144] Trial 0 finished with value: 0.5227754911924237 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 10, 'num_leaves': 68, 'feature_fraction': 0.6624074561769746, 'bagging_fraction': 0.662397808134481}. Best is trial 0 with value: 0.5227754911924237.
# [I 2025-05-16 17:42:20,347] Trial 1 finished with value: 0.5203370498579347 and parameters: {'n_estimators': 100, 'learning_rate': 0.13394334706750485, 'max_depth': 9, 'num_leaves': 77, 'feature_fraction': 0.608233797718321, 'bagging_fraction': 0.9879639408647978}. Best is trial 1 with value: 0.5203370498579347.
# [I 2025-05-16 17:43:24,543] Trial 2 finished with value: 0.5277646748684232 and parameters: {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}. Best is trial 1 with value: 0.5203370498579347.
# [I 2025-05-16 17:44:29,121] Trial 3 finished with value: 0.5257619571530048 and parameters: {'n_estimators': 500, 'learning_rate': 0.023927528765580644, 'max_depth': 9, 'num_leaves': 31, 'feature_fraction': 0.7168578594140873, 'bagging_fraction': 0.7465447373174767}. Best is trial 1 with value: 0.5203370498579347.
# [I 2025-05-16 17:45:06,108] Trial 4 finished with value: 0.5254419525013465 and parameters: {'n_estimators': 500, 'learning_rate': 0.10508421338691762, 'max_depth': 4, 'num_leaves': 61, 'feature_fraction': 0.836965827544817, 'bagging_fraction': 0.6185801650879991}. Best is trial 1 with value: 0.5203370498579347.
# [I 2025-05-16 17:46:04,239] Trial 5 finished with value: 0.5390898510771968 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'num_leaves': 96, 'feature_fraction': 0.9862528132298237, 'bagging_fraction': 0.9233589392465844}. Best is trial 1 with value: 0.5203370498579347.
# [I 2025-05-16 17:47:16,170] Trial 6 finished with value: 0.5685596441640438 and parameters: {'n_estimators': 400, 'learning_rate': 0.013399060561509796, 'max_depth': 9, 'num_leaves': 55, 'feature_fraction': 0.6488152939379115, 'bagging_fraction': 0.798070764044508}. Best is trial 1 with value: 0.5203370498579347.
# [I 2025-05-16 17:47:31,482] Trial 7 finished with value: 0.5278694296244011 and parameters: {'n_estimators': 100, 'learning_rate': 0.15242391728466367, 'max_depth': 5, 'num_leaves': 73, 'feature_fraction': 0.7246844304357644, 'bagging_fraction': 0.8080272084711243}. Best is trial 1 with value: 0.5203370498579347.
# [I 2025-05-16 17:50:05,508] Trial 8 finished with value: 0.5229753104244563 and parameters: {'n_estimators': 600, 'learning_rate': 0.017398074711291726, 'max_depth': 12, 'num_leaves': 82, 'feature_fraction': 0.9757995766256756, 'bagging_fraction': 0.9579309401710595}. Best is trial 1 with value: 0.5203370498579347.
# [I 2025-05-16 17:50:34,619] Trial 9 finished with value: 0.5284429129132454 and parameters: {'n_estimators': 600, 'learning_rate': 0.15826541904647565, 'max_depth': 3, 'num_leaves': 35, 'feature_fraction': 0.6180909155642152, 'bagging_fraction': 0.7301321323053057}. Best is trial 1 with value: 0.5203370498579347.
# [I 2025-05-16 17:51:02,840] Trial 10 finished with value: 0.5568370473042212 and parameters: {'n_estimators': 100, 'learning_rate': 0.05713366692489479, 'max_depth': 7, 'num_leaves': 95, 'feature_fraction': 0.8560354009870226, 'bagging_fraction': 0.8932793377618082}. Best is trial 1 with value: 0.5203370498579347.
# [I 2025-05-16 17:51:47,658] Trial 11 finished with value: 0.5166952332188998 and parameters: {'n_estimators': 300, 'learning_rate': 0.0751994531279191, 'max_depth': 11, 'num_leaves': 65, 'feature_fraction': 0.6035287286931397, 'bagging_fraction': 0.6036909492513651}. Best is trial 11 with value: 0.5166952332188998.
# [I 2025-05-16 17:52:20,050] Trial 12 finished with value: 0.5208451055361298 and parameters: {'n_estimators': 200, 'learning_rate': 0.068767153101851, 'max_depth': 12, 'num_leaves': 51, 'feature_fraction': 0.6043252749557178, 'bagging_fraction': 0.9944287934623489}. Best is trial 11 with value: 0.5166952332188998.
# [I 2025-05-16 17:53:29,916] Trial 13 finished with value: 0.5213198350994159 and parameters: {'n_estimators': 300, 'learning_rate': 0.03587109248015199, 'max_depth': 10, 'num_leaves': 80, 'feature_fraction': 0.7734183770766646, 'bagging_fraction': 0.8715419679037293}. Best is trial 11 with value: 0.5166952332188998.
# [I 2025-05-16 17:54:00,294] Trial 14 finished with value: 0.5212145745159626 and parameters: {'n_estimators': 200, 'learning_rate': 0.08925600898417844, 'max_depth': 7, 'num_leaves': 47, 'feature_fraction': 0.6750130525733469, 'bagging_fraction': 0.6094125138914135}. Best is trial 11 with value: 0.5166952332188998.
# [I 2025-05-16 17:55:18,766] Trial 15 finished with value: 0.518572093944527 and parameters: {'n_estimators': 300, 'learning_rate': 0.04247745431040181, 'max_depth': 11, 'num_leaves': 86, 'feature_fraction': 0.9191979476316068, 'bagging_fraction': 0.689589490361874}. Best is trial 11 with value: 0.5166952332188998.
# [I 2025-05-16 17:56:33,350] Trial 16 finished with value: 0.5183014133317708 and parameters: {'n_estimators': 300, 'learning_rate': 0.04454955907730772, 'max_depth': 11, 'num_leaves': 88, 'feature_fraction': 0.9143980839275896, 'bagging_fraction': 0.666865645823424}. Best is trial 11 with value: 0.5166952332188998.
# [I 2025-05-16 17:59:05,985] Trial 17 finished with value: 0.5164329694814801 and parameters: {'n_estimators': 900, 'learning_rate': 0.03168507863861446, 'max_depth': 11, 'num_leaves': 66, 'feature_fraction': 0.9146511487079994, 'bagging_fraction': 0.6609508406337413}. Best is trial 17 with value: 0.5164329694814801.
# [I 2025-05-16 18:01:24,940] Trial 18 finished with value: 0.517128980730092 and parameters: {'n_estimators': 1000, 'learning_rate': 0.02954096249101368, 'max_depth': 8, 'num_leaves': 64, 'feature_fraction': 0.8029637396652722, 'bagging_fraction': 0.6092636793320954}. Best is trial 17 with value: 0.5164329694814801.
# [I 2025-05-16 18:03:55,330] Trial 19 finished with value: 0.5336409167674128 and parameters: {'n_estimators': 800, 'learning_rate': 0.010646556846278058, 'max_depth': 11, 'num_leaves': 44, 'feature_fraction': 0.9054989579659412, 'bagging_fraction': 0.703293114846303}. Best is trial 17 with value: 0.5164329694814801.
# [I 2025-05-16 18:05:23,963] Trial 20 finished with value: 0.5212299869198126 and parameters: {'n_estimators': 1000, 'learning_rate': 0.06851184832434272, 'max_depth': 6, 'num_leaves': 70, 'feature_fraction': 0.774482468414814, 'bagging_fraction': 0.6490431374149848}. Best is trial 17 with value: 0.5164329694814801.
# [I 2025-05-16 18:07:43,583] Trial 21 finished with value: 0.5176200670877473 and parameters: {'n_estimators': 1000, 'learning_rate': 0.027559314360984122, 'max_depth': 8, 'num_leaves': 63, 'feature_fraction': 0.8294757870022368, 'bagging_fraction': 0.6058616705610163}. Best is trial 17 with value: 0.5164329694814801.
# [I 2025-05-16 18:09:06,753] Trial 22 finished with value: 0.5226664724514279 and parameters: {'n_estimators': 800, 'learning_rate': 0.02946147282554694, 'max_depth': 10, 'num_leaves': 21, 'feature_fraction': 0.8785096115699897, 'bagging_fraction': 0.6392681258596059}. Best is trial 17 with value: 0.5164329694814801.
# [I 2025-05-16 18:10:56,084] Trial 23 finished with value: 0.5176441372212179 and parameters: {'n_estimators': 900, 'learning_rate': 0.053943563922360174, 'max_depth': 8, 'num_leaves': 57, 'feature_fraction': 0.7966417896760819, 'bagging_fraction': 0.6972141841034083}. Best is trial 17 with value: 0.5164329694814801.
# [I 2025-05-16 18:13:31,996] Trial 24 finished with value: 0.5169776591314443 and parameters: {'n_estimators': 900, 'learning_rate': 0.034175043388805226, 'max_depth': 12, 'num_leaves': 66, 'feature_fraction': 0.9506404929898924, 'bagging_fraction': 0.7571211180728075}. Best is trial 17 with value: 0.5164329694814801.
# [I 2025-05-16 18:16:05,967] Trial 25 finished with value: 0.5158664134856814 and parameters: {'n_estimators': 800, 'learning_rate': 0.03757049150907209, 'max_depth': 12, 'num_leaves': 73, 'feature_fraction': 0.9487499158065338, 'bagging_fraction': 0.7636004284281295}. Best is trial 25 with value: 0.5158664134856814.
# [I 2025-05-16 18:17:57,999] Trial 26 finished with value: 0.5177116403345711 and parameters: {'n_estimators': 700, 'learning_rate': 0.07318314276208568, 'max_depth': 11, 'num_leaves': 72, 'feature_fraction': 0.8738445964974808, 'bagging_fraction': 0.838817870015776}. Best is trial 25 with value: 0.5158664134856814.
# [I 2025-05-16 18:20:19,418] Trial 27 finished with value: 0.5177474641236814 and parameters: {'n_estimators': 800, 'learning_rate': 0.02203529537066855, 'max_depth': 12, 'num_leaves': 54, 'feature_fraction': 0.9389258310026652, 'bagging_fraction': 0.778642726564302}. Best is trial 25 with value: 0.5158664134856814.
# [I 2025-05-16 18:22:20,271] Trial 28 finished with value: 0.517389146543127 and parameters: {'n_estimators': 700, 'learning_rate': 0.05086039059507653, 'max_depth': 10, 'num_leaves': 74, 'feature_fraction': 0.9576601530750674, 'bagging_fraction': 0.7233922100497086}. Best is trial 25 with value: 0.5158664134856814.
# [I 2025-05-16 18:23:28,838] Trial 29 finished with value: 0.5238205840159568 and parameters: {'n_estimators': 400, 'learning_rate': 0.19848978742652873, 'max_depth': 11, 'num_leaves': 68, 'feature_fraction': 0.9931073776669301, 'bagging_fraction': 0.6746783277976361}. Best is trial 25 with value: 0.5158664134856814.
# === Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===
# {'n_estimators': 800, 'learning_rate': 0.03757049150907209, 'max_depth': 12, 'num_leaves': 73, 'feature_fraction': 0.9487499158065338, 'bagging_fraction': 0.7636004284281295}
# 10-Fold Mean MAE = 0.5159
