# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import random
import numpy as np
import torch

# 固定随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # for multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)  # 设置固定种子

# %%
import os

import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import optuna
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# ----------------- CONFIGURATION -----------------
n_folds    = 10
n_trials   = 30
data_dir   = "./k_folds_model/embeddings"
batch_size = 256
num_epochs = 200
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------- MODEL DEFINITION -----------------
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        layers = []
        prev_dim = input_dim
        act = {
            'relu':     nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh':     nn.Tanh()
        }[activation]
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act]
            prev_dim = h
        layers.append(nn.Linear(prev_dim, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = self.net(x).squeeze(-1)
        return F.softplus(x)  # 输出 > 0

# ----------------- OPTUNA OBJECTIVE -----------------
def objective(trial):
    hidden_sizes      = trial.suggest_categorical('hidden_layer_sizes',
                            [(50,), (100,), (150,), (100, 50), (150, 100, 50)])
    activation        = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh'])
    lr                = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    weight_decay      = trial.suggest_float('alpha', 1e-5, 1e-2, log=True)
    optimizer_choice  = trial.suggest_categorical('optimizer', ['sgd', 'adam'])

    fold_maes = []

    for fold in range(1, n_folds + 1):
        X_train = np.load(f"{data_dir}/train_fold_{fold}.npy")
        y_train = np.load(f"{data_dir}/train_labels_fold_{fold}.npy")
        X_val   = np.load(f"{data_dir}/val_fold_{fold}.npy")
        y_val   = np.load(f"{data_dir}/val_labels_fold_{fold}.npy")

        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val   = scaler.transform(X_val)

        train_ds = TensorDataset(torch.from_numpy(X_train).float(),
                                 torch.from_numpy(y_train).float())
        val_ds = TensorDataset(torch.from_numpy(X_val).float(),
                               torch.from_numpy(y_val).float())
        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        model = MLP(input_dim=X_train.shape[1],
                    hidden_sizes=hidden_sizes,
                    activation=activation).to(device)
        criterion = nn.MSELoss()
        optimizer = {
            'sgd': torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay),
            'adam': torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        }[optimizer_choice]

        try:
            for epoch in range(num_epochs):
                model.train()
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    preds = model(xb)
                    loss = criterion(preds, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            all_preds = []
            with torch.no_grad():
                for xb, _ in val_loader:
                    xb = xb.to(device)
                    batch_pred = model(xb).cpu().numpy()
                    all_preds.append(batch_pred)
            all_preds = np.concatenate(all_preds)

            mae = mean_absolute_error(y_val, all_preds)
            fold_maes.append(mae)

        except Exception:
            return np.inf

    return float(np.mean(fold_maes))

# ----------------- RUN OPTUNA -----------------
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)

    print("\n=== Best Hyperparameters ===")
    print(study.best_params)
    print(f"Best Mean MAE: {study.best_value:.4f}")
# Out:
# [I 2025-05-16 10:09:05,859] A new study created in memory with name: no-name-a0bf89fb-824f-431e-9916-205132f8d5a7
# [I 2025-05-16 10:12:45,869] Trial 0 finished with value: 0.7256377339363098 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.0015930522616241021, 'alpha': 0.001331121608073689, 'optimizer': 'adam'}. Best is trial 0 with value: 0.7256377339363098.
# [I 2025-05-16 10:16:06,287] Trial 1 finished with value: 0.7113450169563293 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0016738085788752138, 'alpha': 2.621087878265438e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7113450169563293.
# [I 2025-05-16 10:18:49,059] Trial 2 finished with value: 0.7864809036254883 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00013492834268013249, 'alpha': 0.007025166339242158, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.7113450169563293.
# [I 2025-05-16 10:21:45,005] Trial 3 finished with value: 0.7151244282722473 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00032927591344236165, 'alpha': 0.0009717775305059633, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7113450169563293.
# [I 2025-05-16 10:24:38,442] Trial 4 finished with value: 0.7158433794975281 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00015030900645056822, 'alpha': 3.872118032174584e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7113450169563293.
# [I 2025-05-16 10:27:26,520] Trial 5 finished with value: 0.7461221218109131 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00014096175149815865, 'alpha': 0.009133995846860976, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.7113450169563293.
# [I 2025-05-16 10:30:13,754] Trial 6 finished with value: 0.7273975610733032 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.005323617594751502, 'alpha': 0.0007411299781083245, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.7113450169563293.
# [I 2025-05-16 10:33:17,872] Trial 7 finished with value: 0.7220142483711243 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0033233042062267943, 'alpha': 0.00048287152161792117, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.7113450169563293.
# [I 2025-05-16 10:36:12,750] Trial 8 finished with value: 0.8583537340164185 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.006533305220227739, 'alpha': 5.59598687800608e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7113450169563293.
# [I 2025-05-16 10:39:15,871] Trial 9 finished with value: 0.7238904237747192 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.004048966222584676, 'alpha': 3.6283583803549155e-05, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.7113450169563293.
# [I 2025-05-16 10:42:22,426] Trial 10 finished with value: 0.7192148566246033 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0007543742609082392, 'alpha': 1.1321021804230373e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7113450169563293.
# [I 2025-05-16 10:45:15,271] Trial 11 finished with value: 0.7119775414466858 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.00044742474159205944, 'alpha': 0.00014323501853214898, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7113450169563293.
# [I 2025-05-16 10:48:14,709] Trial 12 finished with value: 0.7185965776443481 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0008407931655574886, 'alpha': 0.00012622581476157325, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7113450169563293.
# [I 2025-05-16 10:51:15,057] Trial 13 finished with value: 0.7127007246017456 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0004387608268999757, 'alpha': 0.0001597542678081087, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7113450169563293.
# [I 2025-05-16 10:54:09,314] Trial 14 finished with value: 0.7096229195594788 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0018112940680520416, 'alpha': 1.3013964280289444e-05, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 10:57:04,722] Trial 15 finished with value: 0.7139068841934204 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0019480005358814758, 'alpha': 1.3752012631639771e-05, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 11:00:17,915] Trial 16 finished with value: 0.7204197645187378 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0020708264689518023, 'alpha': 2.0663760556442107e-05, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 11:03:11,786] Trial 17 finished with value: 0.8604376912117004 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.008524636948952195, 'alpha': 7.664942559835459e-05, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 11:06:06,572] Trial 18 finished with value: 0.7240508198738098 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'logistic', 'learning_rate': 0.0013109833200274275, 'alpha': 2.3168144905090774e-05, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 11:09:12,012] Trial 19 finished with value: 0.7150347828865051 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0022256533393844196, 'alpha': 1.0788661515919524e-05, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 11:12:35,032] Trial 20 finished with value: 0.8521726727485657 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'learning_rate': 0.0030141003373608042, 'alpha': 0.000269007987127602, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 11:15:30,853] Trial 21 finished with value: 0.7272816896438599 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0004797263181146409, 'alpha': 9.637313004562953e-05, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 11:18:25,261] Trial 22 finished with value: 0.7118779420852661 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.001056225840156382, 'alpha': 2.7117652000104647e-05, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 11:21:19,486] Trial 23 finished with value: 0.7156906127929688 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0011568357263966778, 'alpha': 2.696419812609454e-05, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 11:24:17,987] Trial 24 finished with value: 0.7106733322143555 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0007512268779819456, 'alpha': 4.801935021216153e-05, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 11:27:24,023] Trial 25 finished with value: 0.7200573086738586 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.00071293640568068, 'alpha': 4.21635596400331e-05, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 11:30:17,708] Trial 26 finished with value: 0.7192783355712891 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.00029195185627897875, 'alpha': 1.721120663444747e-05, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 11:33:08,211] Trial 27 finished with value: 0.7357147932052612 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0006201990845701004, 'alpha': 5.597553575324953e-05, 'optimizer': 'sgd'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 11:36:02,301] Trial 28 finished with value: 0.7344276309013367 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.002718238773218344, 'alpha': 0.00231676136600214, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# [I 2025-05-16 11:38:55,378] Trial 29 finished with value: 0.7265175580978394 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.0015293342256982939, 'alpha': 0.00021837166651839308, 'optimizer': 'adam'}. Best is trial 14 with value: 0.7096229195594788.
# === Best Hyperparameters ===
# {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0018112940680520416, 'alpha': 1.3013964280289444e-05, 'optimizer': 'adam'}
# Best Mean MAE: 0.7096

# %%
import os
import optuna
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    # 采样超参数
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        model = XGBRegressor(n_jobs=-1, verbosity=0, **params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 以 MAE 为优化目标


# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best XGBoost Hyperparameters via Optuna ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 20:35:03,283] A new study created in memory with name: no-name-84fa2f7b-adb8-4208-ba32-3b6bf7bac49c
# [I 2025-05-16 20:37:08,642] Trial 0 finished with value: 0.7793591618537903 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 8, 'subsample': 0.8795975452591109, 'colsample_bytree': 0.6624074561769746}. Best is trial 0 with value: 0.7793591618537903.
# [I 2025-05-16 20:39:06,085] Trial 1 finished with value: 0.7531528472900391 and parameters: {'n_estimators': 200, 'learning_rate': 0.011900590783184251, 'max_depth': 9, 'subsample': 0.8803345035229626, 'colsample_bytree': 0.8832290311184181}. Best is trial 1 with value: 0.7531528472900391.
# [I 2025-05-16 20:39:41,076] Trial 2 finished with value: 0.7363443374633789 and parameters: {'n_estimators': 100, 'learning_rate': 0.18276027831785724, 'max_depth': 8, 'subsample': 0.7637017332034828, 'colsample_bytree': 0.6727299868828402}. Best is trial 2 with value: 0.7363443374633789.
# [I 2025-05-16 20:40:34,165] Trial 3 finished with value: 0.7087488770484924 and parameters: {'n_estimators': 200, 'learning_rate': 0.024878734419814436, 'max_depth': 6, 'subsample': 0.8295835055926347, 'colsample_bytree': 0.7164916560792167}. Best is trial 3 with value: 0.7087488770484924.
# [I 2025-05-16 20:42:41,888] Trial 4 finished with value: 0.7062374353408813 and parameters: {'n_estimators': 700, 'learning_rate': 0.01518747922672247, 'max_depth': 5, 'subsample': 0.8099085529881075, 'colsample_bytree': 0.7824279936868144}. Best is trial 4 with value: 0.7062374353408813.
# [I 2025-05-16 20:45:26,133] Trial 5 finished with value: 0.709819495677948 and parameters: {'n_estimators': 800, 'learning_rate': 0.018187859051288217, 'max_depth': 6, 'subsample': 0.8777243706586128, 'colsample_bytree': 0.6185801650879991}. Best is trial 4 with value: 0.7062374353408813.
# [I 2025-05-16 20:46:46,724] Trial 6 finished with value: 0.7056316137313843 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'subsample': 0.984665661176, 'colsample_bytree': 0.9862528132298237}. Best is trial 6 with value: 0.7056316137313843.
# [I 2025-05-16 20:48:20,339] Trial 7 finished with value: 0.7053771615028381 and parameters: {'n_estimators': 900, 'learning_rate': 0.0249064396938244, 'max_depth': 3, 'subsample': 0.905269907953647, 'colsample_bytree': 0.7760609974958406}. Best is trial 7 with value: 0.7053771615028381.
# [I 2025-05-16 20:48:43,750] Trial 8 finished with value: 0.706142008304596 and parameters: {'n_estimators': 200, 'learning_rate': 0.04407984038169244, 'max_depth': 3, 'subsample': 0.9727961206236346, 'colsample_bytree': 0.7035119926400067}. Best is trial 7 with value: 0.7053771615028381.
# [I 2025-05-16 20:51:06,206] Trial 9 finished with value: 0.7120614051818848 and parameters: {'n_estimators': 700, 'learning_rate': 0.02544166090938368, 'max_depth': 6, 'subsample': 0.8640130838029838, 'colsample_bytree': 0.6739417822102108}. Best is trial 7 with value: 0.7053771615028381.
# [I 2025-05-16 20:53:29,158] Trial 10 finished with value: 0.7239528894424438 and parameters: {'n_estimators': 1000, 'learning_rate': 0.08138762607805286, 'max_depth': 4, 'subsample': 0.7053885626844458, 'colsample_bytree': 0.8560354009870226}. Best is trial 7 with value: 0.7053771615028381.
# [I 2025-05-16 20:55:11,798] Trial 11 finished with value: 0.7074055671691895 and parameters: {'n_estimators': 1000, 'learning_rate': 0.03962196116773197, 'max_depth': 3, 'subsample': 0.9941994740078894, 'colsample_bytree': 0.9926743653872057}. Best is trial 7 with value: 0.7053771615028381.
# [I 2025-05-16 20:57:16,227] Trial 12 finished with value: 0.7052432894706726 and parameters: {'n_estimators': 800, 'learning_rate': 0.010259443333354297, 'max_depth': 4, 'subsample': 0.9465244376887645, 'colsample_bytree': 0.9976023236378931}. Best is trial 12 with value: 0.7052432894706726.
# [I 2025-05-16 20:59:29,080] Trial 13 finished with value: 0.7048441171646118 and parameters: {'n_estimators': 900, 'learning_rate': 0.010571183495838844, 'max_depth': 4, 'subsample': 0.9338716506768701, 'colsample_bytree': 0.8028657451835427}. Best is trial 13 with value: 0.7048441171646118.
# [I 2025-05-16 21:01:14,757] Trial 14 finished with value: 0.7071459293365479 and parameters: {'n_estimators': 500, 'learning_rate': 0.010387802325021962, 'max_depth': 5, 'subsample': 0.9368431198958393, 'colsample_bytree': 0.9087696049520285}. Best is trial 13 with value: 0.7048441171646118.
# [I 2025-05-16 21:03:18,296] Trial 15 finished with value: 0.7053658962249756 and parameters: {'n_estimators': 800, 'learning_rate': 0.010176351943160031, 'max_depth': 4, 'subsample': 0.922707940373607, 'colsample_bytree': 0.935711165942556}. Best is trial 13 with value: 0.7048441171646118.
# [I 2025-05-16 21:05:48,502] Trial 16 finished with value: 0.7399102449417114 and parameters: {'n_estimators': 900, 'learning_rate': 0.10854616665078166, 'max_depth': 5, 'subsample': 0.949543924676935, 'colsample_bytree': 0.8354797325674044}. Best is trial 13 with value: 0.7048441171646118.
# [I 2025-05-16 21:06:56,802] Trial 17 finished with value: 0.7072612047195435 and parameters: {'n_estimators': 500, 'learning_rate': 0.05801566819287058, 'max_depth': 4, 'subsample': 0.9536455982706056, 'colsample_bytree': 0.9427791985016687}. Best is trial 13 with value: 0.7048441171646118.
# [I 2025-05-16 21:09:24,342] Trial 18 finished with value: 0.7196364998817444 and parameters: {'n_estimators': 600, 'learning_rate': 0.033236142618932665, 'max_depth': 7, 'subsample': 0.9067467468954586, 'colsample_bytree': 0.7488640622363577}. Best is trial 13 with value: 0.7048441171646118.
# [I 2025-05-16 21:11:34,362] Trial 19 finished with value: 0.7043427228927612 and parameters: {'n_estimators': 900, 'learning_rate': 0.01286891159507524, 'max_depth': 4, 'subsample': 0.7952639031001203, 'colsample_bytree': 0.8291620154459769}. Best is trial 19 with value: 0.7043427228927612.
# [I 2025-05-16 21:14:15,680] Trial 20 finished with value: 0.706723153591156 and parameters: {'n_estimators': 900, 'learning_rate': 0.014671510526796048, 'max_depth': 5, 'subsample': 0.7742545263541473, 'colsample_bytree': 0.8347596951848958}. Best is trial 19 with value: 0.7043427228927612.
# [I 2025-05-16 21:16:12,707] Trial 21 finished with value: 0.7044142484664917 and parameters: {'n_estimators': 800, 'learning_rate': 0.013315757603799005, 'max_depth': 4, 'subsample': 0.7893369918375327, 'colsample_bytree': 0.8064114554738082}. Best is trial 19 with value: 0.7043427228927612.
# [I 2025-05-16 21:18:31,851] Trial 22 finished with value: 0.705987811088562 and parameters: {'n_estimators': 1000, 'learning_rate': 0.019900364956516942, 'max_depth': 4, 'subsample': 0.7824558846985787, 'colsample_bytree': 0.8239787332306301}. Best is trial 19 with value: 0.7043427228927612.
# [I 2025-05-16 21:21:13,975] Trial 23 finished with value: 0.7063781023025513 and parameters: {'n_estimators': 900, 'learning_rate': 0.013849281479178849, 'max_depth': 5, 'subsample': 0.7245733972933356, 'colsample_bytree': 0.8009607958272795}. Best is trial 19 with value: 0.7043427228927612.
# [I 2025-05-16 21:23:04,514] Trial 24 finished with value: 0.7049754858016968 and parameters: {'n_estimators': 800, 'learning_rate': 0.020723164399004016, 'max_depth': 4, 'subsample': 0.8082037591016669, 'colsample_bytree': 0.7507983883065513}. Best is trial 19 with value: 0.7043427228927612.
# [I 2025-05-16 21:24:14,999] Trial 25 finished with value: 0.7056937217712402 and parameters: {'n_estimators': 600, 'learning_rate': 0.013281000981738718, 'max_depth': 3, 'subsample': 0.7522492609712187, 'colsample_bytree': 0.870559608022065}. Best is trial 19 with value: 0.7043427228927612.
# [I 2025-05-16 21:27:47,595] Trial 26 finished with value: 0.721153736114502 and parameters: {'n_estimators': 1000, 'learning_rate': 0.032364976450325746, 'max_depth': 6, 'subsample': 0.8373528356107499, 'colsample_bytree': 0.7918431510158368}. Best is trial 19 with value: 0.7043427228927612.
# [I 2025-05-16 21:31:45,106] Trial 27 finished with value: 0.7496954798698425 and parameters: {'n_estimators': 900, 'learning_rate': 0.05736617564318713, 'max_depth': 7, 'subsample': 0.8065293907001349, 'colsample_bytree': 0.7465007067759208}. Best is trial 19 with value: 0.7043427228927612.
# [I 2025-05-16 21:33:31,175] Trial 28 finished with value: 0.7043700218200684 and parameters: {'n_estimators': 700, 'learning_rate': 0.012210439288207156, 'max_depth': 4, 'subsample': 0.7407594403064754, 'colsample_bytree': 0.815583850342487}. Best is trial 19 with value: 0.7043427228927612.
# [I 2025-05-16 21:34:45,438] Trial 29 finished with value: 0.7273123860359192 and parameters: {'n_estimators': 400, 'learning_rate': 0.13390499764355235, 'max_depth': 5, 'subsample': 0.7381431526026616, 'colsample_bytree': 0.9100913116670416}. Best is trial 19 with value: 0.7043427228927612.
# === Best XGBoost Hyperparameters via Optuna ===
# {'n_estimators': 900, 'learning_rate': 0.01286891159507524, 'max_depth': 4, 'subsample': 0.7952639031001203, 'colsample_bytree': 0.8291620154459769}
# 10-Fold Mean MAE = 0.7043

# %%
import os
import optuna
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'objective': 'poisson',         # ✅ 强制正输出
        'n_jobs': -1,
        'verbose': -1
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        # Poisson 回归要求标签必须大于 0
        if np.any(y_train <= 0) or np.any(y_val <= 0):
            return np.inf

        model = LGBMRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 使用 MAE 作为优化目标

# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 20:18:57,233] A new study created in memory with name: no-name-4fa603ba-07ae-4fa3-a5ac-4e9d71fdd7ad
# [I 2025-05-16 20:19:21,646] Trial 0 finished with value: 0.7189521632659275 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 10, 'num_leaves': 68, 'feature_fraction': 0.6624074561769746, 'bagging_fraction': 0.662397808134481}. Best is trial 0 with value: 0.7189521632659275.
# [I 2025-05-16 20:19:34,214] Trial 1 finished with value: 0.7106236968718014 and parameters: {'n_estimators': 100, 'learning_rate': 0.13394334706750485, 'max_depth': 9, 'num_leaves': 77, 'feature_fraction': 0.608233797718321, 'bagging_fraction': 0.9879639408647978}. Best is trial 1 with value: 0.7106236968718014.
# [I 2025-05-16 20:20:08,133] Trial 2 finished with value: 0.7036759831992474 and parameters: {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:20:44,304] Trial 3 finished with value: 0.7074435104079906 and parameters: {'n_estimators': 500, 'learning_rate': 0.023927528765580644, 'max_depth': 9, 'num_leaves': 31, 'feature_fraction': 0.7168578594140873, 'bagging_fraction': 0.7465447373174767}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:21:02,137] Trial 4 finished with value: 0.7061309978086723 and parameters: {'n_estimators': 500, 'learning_rate': 0.10508421338691762, 'max_depth': 4, 'num_leaves': 61, 'feature_fraction': 0.836965827544817, 'bagging_fraction': 0.6185801650879991}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:21:31,410] Trial 5 finished with value: 0.7086499242002428 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'num_leaves': 96, 'feature_fraction': 0.9862528132298237, 'bagging_fraction': 0.9233589392465844}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:22:13,964] Trial 6 finished with value: 0.7380781121038564 and parameters: {'n_estimators': 400, 'learning_rate': 0.013399060561509796, 'max_depth': 9, 'num_leaves': 55, 'feature_fraction': 0.6488152939379115, 'bagging_fraction': 0.798070764044508}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:22:23,731] Trial 7 finished with value: 0.7063329402204656 and parameters: {'n_estimators': 100, 'learning_rate': 0.15242391728466367, 'max_depth': 5, 'num_leaves': 73, 'feature_fraction': 0.7246844304357644, 'bagging_fraction': 0.8080272084711243}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:23:55,668] Trial 8 finished with value: 0.7121481360477524 and parameters: {'n_estimators': 600, 'learning_rate': 0.017398074711291726, 'max_depth': 12, 'num_leaves': 82, 'feature_fraction': 0.9757995766256756, 'bagging_fraction': 0.9579309401710595}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:24:09,532] Trial 9 finished with value: 0.7072838577530305 and parameters: {'n_estimators': 600, 'learning_rate': 0.15826541904647565, 'max_depth': 3, 'num_leaves': 35, 'feature_fraction': 0.6180909155642152, 'bagging_fraction': 0.7301321323053057}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:24:51,689] Trial 10 finished with value: 0.7064674372039205 and parameters: {'n_estimators': 1000, 'learning_rate': 0.041286972973122775, 'max_depth': 6, 'num_leaves': 21, 'feature_fraction': 0.8423486893732017, 'bagging_fraction': 0.876098829427658}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:25:25,617] Trial 11 finished with value: 0.7090598047652092 and parameters: {'n_estimators': 900, 'learning_rate': 0.06761147179060022, 'max_depth': 5, 'num_leaves': 50, 'feature_fraction': 0.8538749198685689, 'bagging_fraction': 0.6068702083207481}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:26:00,306] Trial 12 finished with value: 0.7103232450635935 and parameters: {'n_estimators': 800, 'learning_rate': 0.06436196934340957, 'max_depth': 6, 'num_leaves': 45, 'feature_fraction': 0.7854367421284487, 'bagging_fraction': 0.8366734543720239}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:26:17,142] Trial 13 finished with value: 0.7108829746345736 and parameters: {'n_estimators': 300, 'learning_rate': 0.03193535039712928, 'max_depth': 4, 'num_leaves': 62, 'feature_fraction': 0.9086656573027753, 'bagging_fraction': 0.7097939893129924}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:26:51,470] Trial 14 finished with value: 0.7135540969617776 and parameters: {'n_estimators': 800, 'learning_rate': 0.09549211889362913, 'max_depth': 7, 'num_leaves': 38, 'feature_fraction': 0.769969334703295, 'bagging_fraction': 0.6096559237192299}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:27:23,203] Trial 15 finished with value: 0.7064087709334894 and parameters: {'n_estimators': 1000, 'learning_rate': 0.06293060290108869, 'max_depth': 4, 'num_leaves': 23, 'feature_fraction': 0.8554212220255627, 'bagging_fraction': 0.8742018432515738}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:27:55,831] Trial 16 finished with value: 0.713475262144869 and parameters: {'n_estimators': 300, 'learning_rate': 0.02981229465853, 'max_depth': 7, 'num_leaves': 91, 'feature_fraction': 0.7322208821507772, 'bagging_fraction': 0.6695499746947424}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:28:21,317] Trial 17 finished with value: 0.7070753802557075 and parameters: {'n_estimators': 700, 'learning_rate': 0.09514304141838337, 'max_depth': 4, 'num_leaves': 46, 'feature_fraction': 0.9146511487079994, 'bagging_fraction': 0.7578569862343952}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:28:46,621] Trial 18 finished with value: 0.7048081527391943 and parameters: {'n_estimators': 500, 'learning_rate': 0.04487866858808402, 'max_depth': 5, 'num_leaves': 61, 'feature_fraction': 0.7973367611803591, 'bagging_fraction': 0.6775201914158141}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:29:48,733] Trial 19 finished with value: 0.7137011991251441 and parameters: {'n_estimators': 800, 'learning_rate': 0.010320350151502298, 'max_depth': 6, 'num_leaves': 55, 'feature_fraction': 0.6716737471599205, 'bagging_fraction': 0.685052145172123}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:30:07,682] Trial 20 finished with value: 0.7057089642488229 and parameters: {'n_estimators': 300, 'learning_rate': 0.04597646922014528, 'max_depth': 5, 'num_leaves': 40, 'feature_fraction': 0.774482468414814, 'bagging_fraction': 0.7784580168299584}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:30:22,472] Trial 21 finished with value: 0.7098992907352573 and parameters: {'n_estimators': 200, 'learning_rate': 0.045736403184169015, 'max_depth': 5, 'num_leaves': 30, 'feature_fraction': 0.7612174947897106, 'bagging_fraction': 0.7872403676460258}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:30:37,631] Trial 22 finished with value: 0.7049281062712804 and parameters: {'n_estimators': 400, 'learning_rate': 0.041980107139375195, 'max_depth': 3, 'num_leaves': 42, 'feature_fraction': 0.8120031819728298, 'bagging_fraction': 0.8465973871819514}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:30:53,832] Trial 23 finished with value: 0.7096688100003283 and parameters: {'n_estimators': 400, 'learning_rate': 0.027830225931164552, 'max_depth': 3, 'num_leaves': 52, 'feature_fraction': 0.8140613973229024, 'bagging_fraction': 0.8380352701884155}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:31:11,350] Trial 24 finished with value: 0.7088325089382106 and parameters: {'n_estimators': 500, 'learning_rate': 0.023970197754215335, 'max_depth': 3, 'num_leaves': 43, 'feature_fraction': 0.7006004362889782, 'bagging_fraction': 0.8891102795812381}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:31:43,158] Trial 25 finished with value: 0.7049537869484866 and parameters: {'n_estimators': 700, 'learning_rate': 0.019519876098175456, 'max_depth': 4, 'num_leaves': 27, 'feature_fraction': 0.8069410260856267, 'bagging_fraction': 0.8296802412965462}. Best is trial 2 with value: 0.7036759831992474.
# [I 2025-05-16 20:32:04,884] Trial 26 finished with value: 0.7036563670441173 and parameters: {'n_estimators': 600, 'learning_rate': 0.03465771693594685, 'max_depth': 3, 'num_leaves': 63, 'feature_fraction': 0.8927667771131523, 'bagging_fraction': 0.9171979198143885}. Best is trial 26 with value: 0.7036563670441173.
# [I 2025-05-16 20:32:53,179] Trial 27 finished with value: 0.7075281377435473 and parameters: {'n_estimators': 900, 'learning_rate': 0.036258497076636594, 'max_depth': 6, 'num_leaves': 63, 'feature_fraction': 0.8989805265351054, 'bagging_fraction': 0.9287211378997813}. Best is trial 26 with value: 0.7036563670441173.
# [I 2025-05-16 20:34:01,472] Trial 28 finished with value: 0.7102322761561838 and parameters: {'n_estimators': 600, 'learning_rate': 0.021679920054538452, 'max_depth': 8, 'num_leaves': 83, 'feature_fraction': 0.9472945206729352, 'bagging_fraction': 0.9935120390756307}. Best is trial 26 with value: 0.7036563670441173.
# [I 2025-05-16 20:35:03,252] Trial 29 finished with value: 0.7161460781495956 and parameters: {'n_estimators': 900, 'learning_rate': 0.05296346008283497, 'max_depth': 12, 'num_leaves': 68, 'feature_fraction': 0.748115852877664, 'bagging_fraction': 0.7076119682357808}. Best is trial 26 with value: 0.7036563670441173.
# === Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===
# {'n_estimators': 600, 'learning_rate': 0.03465771693594685, 'max_depth': 3, 'num_leaves': 63, 'feature_fraction': 0.8927667771131523, 'bagging_fraction': 0.9171979198143885}
# 10-Fold Mean MAE = 0.7037
