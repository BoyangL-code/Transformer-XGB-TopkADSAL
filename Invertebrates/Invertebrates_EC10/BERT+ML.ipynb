# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import random
import numpy as np
# 固定随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # for multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)  # 设置固定种子

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import optuna
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# ----------------- CONFIGURATION -----------------
n_folds    = 10
n_trials   = 30
data_dir   = "./k_folds_model/embeddings"
batch_size = 256
num_epochs = 200
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------- MODEL DEFINITION -----------------
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        layers = []
        prev_dim = input_dim
        act = {
            'relu':     nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh':     nn.Tanh()
        }[activation]
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act]
            prev_dim = h
        layers.append(nn.Linear(prev_dim, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = self.net(x).squeeze(-1)
        return F.softplus(x)  # 输出 > 0

# ----------------- OPTUNA OBJECTIVE -----------------
def objective(trial):
    hidden_sizes      = trial.suggest_categorical('hidden_layer_sizes',
                            [(50,), (100,), (150,), (100, 50), (150, 100, 50)])
    activation        = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh'])
    lr                = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    weight_decay      = trial.suggest_float('alpha', 1e-5, 1e-2, log=True)
    optimizer_choice  = trial.suggest_categorical('optimizer', ['sgd', 'adam'])

    fold_maes = []

    for fold in range(1, n_folds + 1):
        X_train = np.load(f"{data_dir}/train_fold_{fold}.npy")
        y_train = np.load(f"{data_dir}/train_labels_fold_{fold}.npy")
        X_val   = np.load(f"{data_dir}/val_fold_{fold}.npy")
        y_val   = np.load(f"{data_dir}/val_labels_fold_{fold}.npy")

        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val   = scaler.transform(X_val)

        train_ds = TensorDataset(torch.from_numpy(X_train).float(),
                                 torch.from_numpy(y_train).float())
        val_ds = TensorDataset(torch.from_numpy(X_val).float(),
                               torch.from_numpy(y_val).float())
        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        model = MLP(input_dim=X_train.shape[1],
                    hidden_sizes=hidden_sizes,
                    activation=activation).to(device)
        criterion = nn.MSELoss()
        optimizer = {
            'sgd': torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay),
            'adam': torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        }[optimizer_choice]

        try:
            for epoch in range(num_epochs):
                model.train()
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    preds = model(xb)
                    loss = criterion(preds, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            all_preds = []
            with torch.no_grad():
                for xb, _ in val_loader:
                    xb = xb.to(device)
                    batch_pred = model(xb).cpu().numpy()
                    all_preds.append(batch_pred)
            all_preds = np.concatenate(all_preds)

            mae = mean_absolute_error(y_val, all_preds)
            fold_maes.append(mae)

        except Exception:
            return np.inf

    return float(np.mean(fold_maes))

# ----------------- RUN OPTUNA -----------------
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)

    print("\n=== Best Hyperparameters ===")
    print(study.best_params)
    print(f"Best Mean MAE: {study.best_value:.4f}")
# Out:
# [I 2025-05-16 10:08:23,315] A new study created in memory with name: no-name-869c50ca-1d25-4a40-a760-33b518f0067d
# [I 2025-05-16 10:11:16,719] Trial 0 finished with value: 0.5753805637359619 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.0015930522616241021, 'alpha': 0.001331121608073689, 'optimizer': 'adam'}. Best is trial 0 with value: 0.5753805637359619.
# [I 2025-05-16 10:13:59,822] Trial 1 finished with value: 0.5755142569541931 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0016738085788752138, 'alpha': 2.621087878265438e-05, 'optimizer': 'adam'}. Best is trial 0 with value: 0.5753805637359619.
# [I 2025-05-16 10:16:19,837] Trial 2 finished with value: 0.7463901042938232 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00013492834268013249, 'alpha': 0.007025166339242158, 'optimizer': 'sgd'}. Best is trial 0 with value: 0.5753805637359619.
# [I 2025-05-16 10:18:32,855] Trial 3 finished with value: 0.5697455406188965 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00032927591344236165, 'alpha': 0.0009717775305059633, 'optimizer': 'adam'}. Best is trial 3 with value: 0.5697455406188965.
# [I 2025-05-16 10:20:47,553] Trial 4 finished with value: 0.5684730410575867 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00015030900645056822, 'alpha': 3.872118032174584e-05, 'optimizer': 'adam'}. Best is trial 4 with value: 0.5684730410575867.
# [I 2025-05-16 10:22:54,318] Trial 5 finished with value: 0.6467458009719849 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00014096175149815865, 'alpha': 0.009133995846860976, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.5684730410575867.
# [I 2025-05-16 10:24:59,408] Trial 6 finished with value: 0.5800238847732544 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.005323617594751502, 'alpha': 0.0007411299781083245, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.5684730410575867.
# [I 2025-05-16 10:27:25,002] Trial 7 finished with value: 0.5781665444374084 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0033233042062267943, 'alpha': 0.00048287152161792117, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.5684730410575867.
# [I 2025-05-16 10:29:42,885] Trial 8 finished with value: 0.5861760377883911 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.006533305220227739, 'alpha': 5.59598687800608e-05, 'optimizer': 'adam'}. Best is trial 4 with value: 0.5684730410575867.
# [I 2025-05-16 10:32:04,590] Trial 9 finished with value: 0.5781054496765137 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.004048966222584676, 'alpha': 3.6283583803549155e-05, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.5684730410575867.
# [I 2025-05-16 10:34:26,782] Trial 10 finished with value: 0.5704831480979919 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0004216644107007115, 'alpha': 0.00012956995794619435, 'optimizer': 'adam'}. Best is trial 4 with value: 0.5684730410575867.
# [I 2025-05-16 10:36:40,570] Trial 11 finished with value: 0.56803959608078 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0003921612135270866, 'alpha': 0.00016477670830228577, 'optimizer': 'adam'}. Best is trial 11 with value: 0.56803959608078.
# [I 2025-05-16 10:38:55,463] Trial 12 finished with value: 0.5735025405883789 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00039983761884014867, 'alpha': 0.0001657191138792429, 'optimizer': 'adam'}. Best is trial 11 with value: 0.56803959608078.
# [I 2025-05-16 10:41:09,264] Trial 13 finished with value: 0.5656492710113525 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0002439187104733081, 'alpha': 1.0609009340206071e-05, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 10:43:21,738] Trial 14 finished with value: 0.56792813539505 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0006923843398030677, 'alpha': 1.8159620377484468e-05, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 10:45:43,838] Trial 15 finished with value: 0.5746498703956604 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.0008476798466510087, 'alpha': 1.7121386221145043e-05, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 10:48:01,673] Trial 16 finished with value: 0.5710241198539734 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0007256451862638576, 'alpha': 1.1431092629414292e-05, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 10:50:19,252] Trial 17 finished with value: 0.5686221122741699 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00023842497672063175, 'alpha': 1.1957801447351183e-05, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 10:52:31,784] Trial 18 finished with value: 0.5744748711585999 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.0013938240589411873, 'alpha': 7.633519183320513e-05, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 10:54:54,497] Trial 19 finished with value: 0.5797803997993469 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.0006947230756612974, 'alpha': 2.2921495263778718e-05, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 10:57:25,115] Trial 20 finished with value: 0.5696362853050232 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0002426057303171107, 'alpha': 0.0017988433461076933, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 10:59:46,174] Trial 21 finished with value: 0.5781204104423523 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0006054881073161941, 'alpha': 0.00027131713354741627, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 11:02:03,311] Trial 22 finished with value: 0.567773163318634 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0002459878700945848, 'alpha': 9.28912619936983e-05, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 11:04:16,106] Trial 23 finished with value: 0.5678943991661072 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0002243445852028346, 'alpha': 7.294537843321018e-05, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 11:06:35,179] Trial 24 finished with value: 0.5674768686294556 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00021302619505456167, 'alpha': 8.120412771166532e-05, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 11:08:57,102] Trial 25 finished with value: 0.5666689276695251 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'learning_rate': 0.00018059424088144726, 'alpha': 0.00028838651154630544, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 11:11:20,169] Trial 26 finished with value: 0.57056725025177 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'learning_rate': 0.00010580637504288371, 'alpha': 0.0002948595005650232, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 11:13:27,693] Trial 27 finished with value: 0.6512753367424011 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'learning_rate': 0.0001547299537745719, 'alpha': 0.0034981652018371188, 'optimizer': 'sgd'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 11:15:41,137] Trial 28 finished with value: 0.8115526437759399 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.009827674611457334, 'alpha': 0.0004945283659355492, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# [I 2025-05-16 11:17:55,895] Trial 29 finished with value: 0.5758832097053528 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00010549744050522123, 'alpha': 0.0020983892148080828, 'optimizer': 'adam'}. Best is trial 13 with value: 0.5656492710113525.
# === Best Hyperparameters ===
# {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0002439187104733081, 'alpha': 1.0609009340206071e-05, 'optimizer': 'adam'}
# Best Mean MAE: 0.5656

# %%
import os
import optuna
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    # 采样超参数
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        model = XGBRegressor(n_jobs=-1, verbosity=0, **params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 以 MAE 为优化目标


# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best XGBoost Hyperparameters via Optuna ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 18:23:35,498] A new study created in memory with name: no-name-6067542f-8582-408d-9760-f12648629d25
# [I 2025-05-16 18:25:50,500] Trial 0 finished with value: 0.6284773945808411 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 8, 'subsample': 0.8795975452591109, 'colsample_bytree': 0.6624074561769746}. Best is trial 0 with value: 0.6284773945808411.
# [I 2025-05-16 18:27:42,786] Trial 1 finished with value: 0.6041899919509888 and parameters: {'n_estimators': 200, 'learning_rate': 0.011900590783184251, 'max_depth': 9, 'subsample': 0.8803345035229626, 'colsample_bytree': 0.8832290311184181}. Best is trial 1 with value: 0.6041899919509888.
# [I 2025-05-16 18:28:19,723] Trial 2 finished with value: 0.5889726877212524 and parameters: {'n_estimators': 100, 'learning_rate': 0.18276027831785724, 'max_depth': 8, 'subsample': 0.7637017332034828, 'colsample_bytree': 0.6727299868828402}. Best is trial 2 with value: 0.5889726877212524.
# [I 2025-05-16 18:29:10,953] Trial 3 finished with value: 0.5583137273788452 and parameters: {'n_estimators': 200, 'learning_rate': 0.024878734419814436, 'max_depth': 6, 'subsample': 0.8295835055926347, 'colsample_bytree': 0.7164916560792167}. Best is trial 3 with value: 0.5583137273788452.
# [I 2025-05-16 18:31:20,934] Trial 4 finished with value: 0.5572618842124939 and parameters: {'n_estimators': 700, 'learning_rate': 0.01518747922672247, 'max_depth': 5, 'subsample': 0.8099085529881075, 'colsample_bytree': 0.7824279936868144}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:34:13,389] Trial 5 finished with value: 0.5605071783065796 and parameters: {'n_estimators': 800, 'learning_rate': 0.018187859051288217, 'max_depth': 6, 'subsample': 0.8777243706586128, 'colsample_bytree': 0.6185801650879991}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:35:28,785] Trial 6 finished with value: 0.562057614326477 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'subsample': 0.984665661176, 'colsample_bytree': 0.9862528132298237}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:37:05,230] Trial 7 finished with value: 0.5594019889831543 and parameters: {'n_estimators': 900, 'learning_rate': 0.0249064396938244, 'max_depth': 3, 'subsample': 0.905269907953647, 'colsample_bytree': 0.7760609974958406}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:37:27,600] Trial 8 finished with value: 0.5635296106338501 and parameters: {'n_estimators': 200, 'learning_rate': 0.04407984038169244, 'max_depth': 3, 'subsample': 0.9727961206236346, 'colsample_bytree': 0.7035119926400067}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:40:01,945] Trial 9 finished with value: 0.5648024678230286 and parameters: {'n_estimators': 700, 'learning_rate': 0.02544166090938368, 'max_depth': 6, 'subsample': 0.8640130838029838, 'colsample_bytree': 0.6739417822102108}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:43:15,727] Trial 10 finished with value: 0.5927852392196655 and parameters: {'n_estimators': 1000, 'learning_rate': 0.08138762607805286, 'max_depth': 5, 'subsample': 0.7053885626844458, 'colsample_bytree': 0.8560354009870226}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:44:46,587] Trial 11 finished with value: 0.5639470219612122 and parameters: {'n_estimators': 500, 'learning_rate': 0.040709631715981964, 'max_depth': 5, 'subsample': 0.7995121765879235, 'colsample_bytree': 0.7518416973680894}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:46:11,689] Trial 12 finished with value: 0.5620900392532349 and parameters: {'n_estimators': 400, 'learning_rate': 0.010451884996645688, 'max_depth': 5, 'subsample': 0.7921694148112817, 'colsample_bytree': 0.8298338646294268}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:48:59,230] Trial 13 finished with value: 0.5727666616439819 and parameters: {'n_estimators': 600, 'learning_rate': 0.029494007671085606, 'max_depth': 7, 'subsample': 0.818426391770873, 'colsample_bytree': 0.7537231576650608}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:49:44,024] Trial 14 finished with value: 0.5598935484886169 and parameters: {'n_estimators': 300, 'learning_rate': 0.07890559538527207, 'max_depth': 4, 'subsample': 0.7391953700536992, 'colsample_bytree': 0.9087696049520285}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:52:04,865] Trial 15 finished with value: 0.5587383508682251 and parameters: {'n_estimators': 600, 'learning_rate': 0.016306868080947872, 'max_depth': 6, 'subsample': 0.8310744187537542, 'colsample_bytree': 0.8059881656083773}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:52:36,113] Trial 16 finished with value: 0.5637351274490356 and parameters: {'n_estimators': 100, 'learning_rate': 0.06698989078238432, 'max_depth': 7, 'subsample': 0.7685614516559672, 'colsample_bytree': 0.7248939743688465}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:53:44,569] Trial 17 finished with value: 0.5576655864715576 and parameters: {'n_estimators': 500, 'learning_rate': 0.03281021514832159, 'max_depth': 4, 'subsample': 0.9244106093492094, 'colsample_bytree': 0.6062213831819934}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:54:55,930] Trial 18 finished with value: 0.5611020922660828 and parameters: {'n_estimators': 500, 'learning_rate': 0.05995436309213423, 'max_depth': 4, 'subsample': 0.9369897065593998, 'colsample_bytree': 0.9281889012746769}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:56:40,664] Trial 19 finished with value: 0.5801594853401184 and parameters: {'n_estimators': 800, 'learning_rate': 0.12011335478197706, 'max_depth': 4, 'subsample': 0.9381594957668853, 'colsample_bytree': 0.6056365844940073}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:58:19,392] Trial 20 finished with value: 0.5588760375976562 and parameters: {'n_estimators': 700, 'learning_rate': 0.034235274363514714, 'max_depth': 4, 'subsample': 0.9025421228442005, 'colsample_bytree': 0.9779114520402716}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 18:59:34,051] Trial 21 finished with value: 0.5577287077903748 and parameters: {'n_estimators': 400, 'learning_rate': 0.021423421601430438, 'max_depth': 5, 'subsample': 0.8433477220116721, 'colsample_bytree': 0.641374330807756}. Best is trial 4 with value: 0.5572618842124939.
# [I 2025-05-16 19:00:49,453] Trial 22 finished with value: 0.5568767189979553 and parameters: {'n_estimators': 400, 'learning_rate': 0.019675334037267168, 'max_depth': 5, 'subsample': 0.8411249070432528, 'colsample_bytree': 0.6393783999957465}. Best is trial 22 with value: 0.5568767189979553.
# [I 2025-05-16 19:02:23,323] Trial 23 finished with value: 0.5566994547843933 and parameters: {'n_estimators': 500, 'learning_rate': 0.014509456908913889, 'max_depth': 5, 'subsample': 0.9387632330805947, 'colsample_bytree': 0.6410965653177675}. Best is trial 23 with value: 0.5566994547843933.
# [I 2025-05-16 19:04:15,012] Trial 24 finished with value: 0.5575124025344849 and parameters: {'n_estimators': 600, 'learning_rate': 0.013376157603299157, 'max_depth': 5, 'subsample': 0.7997347257800553, 'colsample_bytree': 0.6429377225654836}. Best is trial 23 with value: 0.5566994547843933.
# [I 2025-05-16 19:05:51,593] Trial 25 finished with value: 0.5632455945014954 and parameters: {'n_estimators': 300, 'learning_rate': 0.014244819071626906, 'max_depth': 7, 'subsample': 0.9606059650576324, 'colsample_bytree': 0.6916622345023855}. Best is trial 23 with value: 0.5566994547843933.
# [I 2025-05-16 19:08:56,954] Trial 26 finished with value: 0.5575746297836304 and parameters: {'n_estimators': 800, 'learning_rate': 0.010085133716971466, 'max_depth': 6, 'subsample': 0.849656004437728, 'colsample_bytree': 0.7394638319353717}. Best is trial 23 with value: 0.5566994547843933.
# [I 2025-05-16 19:09:57,506] Trial 27 finished with value: 0.5571293830871582 and parameters: {'n_estimators': 300, 'learning_rate': 0.019805510961779446, 'max_depth': 5, 'subsample': 0.7525587802016377, 'colsample_bytree': 0.7954516284603023}. Best is trial 23 with value: 0.5566994547843933.
# [I 2025-05-16 19:11:12,364] Trial 28 finished with value: 0.5572409629821777 and parameters: {'n_estimators': 400, 'learning_rate': 0.019293921753071337, 'max_depth': 5, 'subsample': 0.7012288189023516, 'colsample_bytree': 0.6406581474537846}. Best is trial 23 with value: 0.5566994547843933.
# [I 2025-05-16 19:12:02,019] Trial 29 finished with value: 0.5705584287643433 and parameters: {'n_estimators': 300, 'learning_rate': 0.012283725098454408, 'max_depth': 4, 'subsample': 0.9981528355149126, 'colsample_bytree': 0.9476077563455207}. Best is trial 23 with value: 0.5566994547843933.
# === Best XGBoost Hyperparameters via Optuna ===
# {'n_estimators': 500, 'learning_rate': 0.014509456908913889, 'max_depth': 5, 'subsample': 0.9387632330805947, 'colsample_bytree': 0.6410965653177675}
# 10-Fold Mean MAE = 0.5567

# %%
import os
import optuna
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'objective': 'poisson',         # ✅ 强制正输出
        'n_jobs': -1,
        'verbose': -1
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        # Poisson 回归要求标签必须大于 0
        if np.any(y_train <= 0) or np.any(y_val <= 0):
            return np.inf

        model = LGBMRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 使用 MAE 作为优化目标

# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 19:12:02,097] A new study created in memory with name: no-name-2566d1e3-7546-4155-a41b-ce74ee80c798
# [I 2025-05-16 19:12:30,119] Trial 0 finished with value: 0.5619972000273276 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 10, 'num_leaves': 68, 'feature_fraction': 0.6624074561769746, 'bagging_fraction': 0.662397808134481}. Best is trial 0 with value: 0.5619972000273276.
# [I 2025-05-16 19:12:41,326] Trial 1 finished with value: 0.5557357293115059 and parameters: {'n_estimators': 100, 'learning_rate': 0.13394334706750485, 'max_depth': 9, 'num_leaves': 77, 'feature_fraction': 0.608233797718321, 'bagging_fraction': 0.9879639408647978}. Best is trial 1 with value: 0.5557357293115059.
# [I 2025-05-16 19:13:09,966] Trial 2 finished with value: 0.5564102010058931 and parameters: {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}. Best is trial 1 with value: 0.5557357293115059.
# [I 2025-05-16 19:13:42,788] Trial 3 finished with value: 0.5547997696064699 and parameters: {'n_estimators': 500, 'learning_rate': 0.023927528765580644, 'max_depth': 9, 'num_leaves': 31, 'feature_fraction': 0.7168578594140873, 'bagging_fraction': 0.7465447373174767}. Best is trial 3 with value: 0.5547997696064699.
# [I 2025-05-16 19:13:59,402] Trial 4 finished with value: 0.5512867682995676 and parameters: {'n_estimators': 500, 'learning_rate': 0.10508421338691762, 'max_depth': 4, 'num_leaves': 61, 'feature_fraction': 0.836965827544817, 'bagging_fraction': 0.6185801650879991}. Best is trial 4 with value: 0.5512867682995676.
# [I 2025-05-16 19:14:22,812] Trial 5 finished with value: 0.569476993260511 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'num_leaves': 96, 'feature_fraction': 0.9862528132298237, 'bagging_fraction': 0.9233589392465844}. Best is trial 4 with value: 0.5512867682995676.
# [I 2025-05-16 19:15:00,641] Trial 6 finished with value: 0.589840997016923 and parameters: {'n_estimators': 400, 'learning_rate': 0.013399060561509796, 'max_depth': 9, 'num_leaves': 55, 'feature_fraction': 0.6488152939379115, 'bagging_fraction': 0.798070764044508}. Best is trial 4 with value: 0.5512867682995676.
# [I 2025-05-16 19:15:07,333] Trial 7 finished with value: 0.5541401045637634 and parameters: {'n_estimators': 100, 'learning_rate': 0.15242391728466367, 'max_depth': 5, 'num_leaves': 73, 'feature_fraction': 0.7246844304357644, 'bagging_fraction': 0.8080272084711243}. Best is trial 4 with value: 0.5512867682995676.
# [I 2025-05-16 19:16:32,406] Trial 8 finished with value: 0.5564122704932906 and parameters: {'n_estimators': 600, 'learning_rate': 0.017398074711291726, 'max_depth': 12, 'num_leaves': 82, 'feature_fraction': 0.9757995766256756, 'bagging_fraction': 0.9579309401710595}. Best is trial 4 with value: 0.5512867682995676.
# [I 2025-05-16 19:16:45,213] Trial 9 finished with value: 0.5537196301210724 and parameters: {'n_estimators': 600, 'learning_rate': 0.15826541904647565, 'max_depth': 3, 'num_leaves': 35, 'feature_fraction': 0.6180909155642152, 'bagging_fraction': 0.7301321323053057}. Best is trial 4 with value: 0.5512867682995676.
# [I 2025-05-16 19:17:30,752] Trial 10 finished with value: 0.5538545456291211 and parameters: {'n_estimators': 1000, 'learning_rate': 0.07549726627694736, 'max_depth': 6, 'num_leaves': 54, 'feature_fraction': 0.8676285972451436, 'bagging_fraction': 0.6154900799844731}. Best is trial 4 with value: 0.5512867682995676.
# [I 2025-05-16 19:17:48,614] Trial 11 finished with value: 0.5554670835331974 and parameters: {'n_estimators': 700, 'learning_rate': 0.06761147179060022, 'max_depth': 3, 'num_leaves': 20, 'feature_fraction': 0.8407490346717955, 'bagging_fraction': 0.692472096815693}. Best is trial 4 with value: 0.5512867682995676.
# [I 2025-05-16 19:18:06,946] Trial 12 finished with value: 0.5516100681005982 and parameters: {'n_estimators': 300, 'learning_rate': 0.09014261338227042, 'max_depth': 6, 'num_leaves': 45, 'feature_fraction': 0.9060364751816561, 'bagging_fraction': 0.6058406751068152}. Best is trial 4 with value: 0.5512867682995676.
# [I 2025-05-16 19:18:26,075] Trial 13 finished with value: 0.5518890206113163 and parameters: {'n_estimators': 300, 'learning_rate': 0.0767740519213016, 'max_depth': 6, 'num_leaves': 47, 'feature_fraction': 0.9066894745376978, 'bagging_fraction': 0.6181400084793356}. Best is trial 4 with value: 0.5512867682995676.
# [I 2025-05-16 19:18:43,974] Trial 14 finished with value: 0.5614856347331763 and parameters: {'n_estimators': 200, 'learning_rate': 0.0414053058084107, 'max_depth': 7, 'num_leaves': 44, 'feature_fraction': 0.7886369489536518, 'bagging_fraction': 0.6011807579551777}. Best is trial 4 with value: 0.5512867682995676.
# [I 2025-05-16 19:18:58,811] Trial 15 finished with value: 0.5502769603055373 and parameters: {'n_estimators': 300, 'learning_rate': 0.10940563768087051, 'max_depth': 5, 'num_leaves': 63, 'feature_fraction': 0.9191979476316068, 'bagging_fraction': 0.6638123593227387}. Best is trial 15 with value: 0.5502769603055373.
# [I 2025-05-16 19:19:17,851] Trial 16 finished with value: 0.5533625033340096 and parameters: {'n_estimators': 400, 'learning_rate': 0.048398909014269895, 'max_depth': 5, 'num_leaves': 65, 'feature_fraction': 0.8002663857750008, 'bagging_fraction': 0.6727498634047833}. Best is trial 15 with value: 0.5502769603055373.
# [I 2025-05-16 19:19:44,060] Trial 17 finished with value: 0.5524509261694889 and parameters: {'n_estimators': 800, 'learning_rate': 0.10660290908929802, 'max_depth': 4, 'num_leaves': 87, 'feature_fraction': 0.9379338151451567, 'bagging_fraction': 0.7371876160116895}. Best is trial 15 with value: 0.5502769603055373.
# [I 2025-05-16 19:20:18,901] Trial 18 finished with value: 0.5527251353803375 and parameters: {'n_estimators': 500, 'learning_rate': 0.04745430226637879, 'max_depth': 7, 'num_leaves': 61, 'feature_fraction': 0.843703982484205, 'bagging_fraction': 0.8821430354913009}. Best is trial 15 with value: 0.5502769603055373.
# [I 2025-05-16 19:20:35,764] Trial 19 finished with value: 0.5589861908113616 and parameters: {'n_estimators': 300, 'learning_rate': 0.034877767539036125, 'max_depth': 5, 'num_leaves': 92, 'feature_fraction': 0.7911302960155628, 'bagging_fraction': 0.6672126873962325}. Best is trial 15 with value: 0.5502769603055373.
# [I 2025-05-16 19:20:44,978] Trial 20 finished with value: 0.553749735729099 and parameters: {'n_estimators': 200, 'learning_rate': 0.11991974499731622, 'max_depth': 4, 'num_leaves': 73, 'feature_fraction': 0.9354704630240357, 'bagging_fraction': 0.7074602754327602}. Best is trial 15 with value: 0.5502769603055373.
# [I 2025-05-16 19:21:03,169] Trial 21 finished with value: 0.5516545263703828 and parameters: {'n_estimators': 300, 'learning_rate': 0.09446342643232017, 'max_depth': 6, 'num_leaves': 49, 'feature_fraction': 0.9041184654778652, 'bagging_fraction': 0.6370558255528249}. Best is trial 15 with value: 0.5502769603055373.
# [I 2025-05-16 19:21:15,746] Trial 22 finished with value: 0.5566378748579724 and parameters: {'n_estimators': 200, 'learning_rate': 0.060831018254732284, 'max_depth': 5, 'num_leaves': 58, 'feature_fraction': 0.8933360270939352, 'bagging_fraction': 0.6392681258596059}. Best is trial 15 with value: 0.5502769603055373.
# [I 2025-05-16 19:21:44,175] Trial 23 finished with value: 0.5520323993224169 and parameters: {'n_estimators': 400, 'learning_rate': 0.09435124634411736, 'max_depth': 8, 'num_leaves': 42, 'feature_fraction': 0.9500532601433155, 'bagging_fraction': 0.6451735755552097}. Best is trial 15 with value: 0.5502769603055373.
# [I 2025-05-16 19:22:07,703] Trial 24 finished with value: 0.5561687125191944 and parameters: {'n_estimators': 500, 'learning_rate': 0.18667715938909293, 'max_depth': 6, 'num_leaves': 65, 'feature_fraction': 0.8315589637476114, 'bagging_fraction': 0.7022690911780489}. Best is trial 15 with value: 0.5502769603055373.
# [I 2025-05-16 19:22:20,072] Trial 25 finished with value: 0.5528819129154454 and parameters: {'n_estimators': 300, 'learning_rate': 0.09587254837995894, 'max_depth': 4, 'num_leaves': 51, 'feature_fraction': 0.867740774081281, 'bagging_fraction': 0.7715420432606681}. Best is trial 15 with value: 0.5502769603055373.
# [I 2025-05-16 19:22:34,049] Trial 26 finished with value: 0.5524982439405464 and parameters: {'n_estimators': 200, 'learning_rate': 0.11958893634199315, 'max_depth': 7, 'num_leaves': 40, 'feature_fraction': 0.7591515600635438, 'bagging_fraction': 0.6026938738021319}. Best is trial 15 with value: 0.5502769603055373.
# [I 2025-05-16 19:23:08,540] Trial 27 finished with value: 0.5505499712052626 and parameters: {'n_estimators': 600, 'learning_rate': 0.06230240730645509, 'max_depth': 8, 'num_leaves': 26, 'feature_fraction': 0.8759007430695046, 'bagging_fraction': 0.6772759201932619}. Best is trial 15 with value: 0.5502769603055373.
# [I 2025-05-16 19:23:51,555] Trial 28 finished with value: 0.5508226441141394 and parameters: {'n_estimators': 700, 'learning_rate': 0.05411656313309258, 'max_depth': 11, 'num_leaves': 28, 'feature_fraction': 0.8703286632639328, 'bagging_fraction': 0.6873145909690288}. Best is trial 15 with value: 0.5502769603055373.
# [I 2025-05-16 19:24:31,627] Trial 29 finished with value: 0.551141257972543 and parameters: {'n_estimators': 700, 'learning_rate': 0.03650221419429244, 'max_depth': 12, 'num_leaves': 22, 'feature_fraction': 0.877055825078133, 'bagging_fraction': 0.8460828797097181}. Best is trial 15 with value: 0.5502769603055373.
# === Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===
# {'n_estimators': 300, 'learning_rate': 0.10940563768087051, 'max_depth': 5, 'num_leaves': 63, 'feature_fraction': 0.9191979476316068, 'bagging_fraction': 0.6638123593227387}
# 10-Fold Mean MAE = 0.5503
