# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import random

# 固定随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # for multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)  # 设置固定种子

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import optuna
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# ----------------- CONFIGURATION -----------------
n_folds    = 10
n_trials   = 30
data_dir   = "./k_folds_model/embeddings"
batch_size = 256
num_epochs = 200
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------- MODEL DEFINITION -----------------
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        layers = []
        prev_dim = input_dim
        act = {
            'relu':     nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh':     nn.Tanh()
        }[activation]
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act]
            prev_dim = h
        layers.append(nn.Linear(prev_dim, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = self.net(x).squeeze(-1)
        return F.softplus(x)  # 输出 > 0

# ----------------- OPTUNA OBJECTIVE -----------------
def objective(trial):
    hidden_sizes      = trial.suggest_categorical('hidden_layer_sizes',
                            [(50,), (100,), (150,), (100, 50), (150, 100, 50)])
    activation        = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh'])
    lr                = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    weight_decay      = trial.suggest_float('alpha', 1e-5, 1e-2, log=True)
    optimizer_choice  = trial.suggest_categorical('optimizer', ['sgd', 'adam'])

    fold_maes = []

    for fold in range(1, n_folds + 1):
        X_train = np.load(f"{data_dir}/train_fold_{fold}.npy")
        y_train = np.load(f"{data_dir}/train_labels_fold_{fold}.npy")
        X_val   = np.load(f"{data_dir}/val_fold_{fold}.npy")
        y_val   = np.load(f"{data_dir}/val_labels_fold_{fold}.npy")

        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val   = scaler.transform(X_val)

        train_ds = TensorDataset(torch.from_numpy(X_train).float(),
                                 torch.from_numpy(y_train).float())
        val_ds = TensorDataset(torch.from_numpy(X_val).float(),
                               torch.from_numpy(y_val).float())
        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        model = MLP(input_dim=X_train.shape[1],
                    hidden_sizes=hidden_sizes,
                    activation=activation).to(device)
        criterion = nn.MSELoss()
        optimizer = {
            'sgd': torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay),
            'adam': torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        }[optimizer_choice]

        try:
            for epoch in range(num_epochs):
                model.train()
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    preds = model(xb)
                    loss = criterion(preds, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            all_preds = []
            with torch.no_grad():
                for xb, _ in val_loader:
                    xb = xb.to(device)
                    batch_pred = model(xb).cpu().numpy()
                    all_preds.append(batch_pred)
            all_preds = np.concatenate(all_preds)

            mae = mean_absolute_error(y_val, all_preds)
            fold_maes.append(mae)

        except Exception:
            return np.inf

    return float(np.mean(fold_maes))

# ----------------- RUN OPTUNA -----------------
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)

    print("\n=== Best Hyperparameters ===")
    print(study.best_params)
    print(f"Best Mean MAE: {study.best_value:.4f}")
# Out:
# [I 2025-05-16 10:03:29,089] A new study created in memory with name: no-name-2f77ef0a-e0db-41a9-b602-1f8bea463bf7
# [I 2025-05-16 10:05:58,021] Trial 0 finished with value: 0.8055718541145325 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.0015930522616241021, 'alpha': 0.001331121608073689, 'optimizer': 'adam'}. Best is trial 0 with value: 0.8055718541145325.
# [I 2025-05-16 10:08:06,841] Trial 1 finished with value: 0.7954075932502747 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0016738085788752138, 'alpha': 2.621087878265438e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.7954075932502747.
# [I 2025-05-16 10:10:36,266] Trial 2 finished with value: 0.8068268895149231 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00013492834268013249, 'alpha': 0.007025166339242158, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.7954075932502747.
# [I 2025-05-16 10:12:32,142] Trial 3 finished with value: 0.7837855815887451 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00032927591344236165, 'alpha': 0.0009717775305059633, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:15:10,835] Trial 4 finished with value: 0.7901574373245239 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00015030900645056822, 'alpha': 3.872118032174584e-05, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:16:52,401] Trial 5 finished with value: 0.9383050203323364 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00014096175149815865, 'alpha': 0.009133995846860976, 'optimizer': 'sgd'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:18:48,071] Trial 6 finished with value: 0.7958769798278809 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.005323617594751502, 'alpha': 0.0007411299781083245, 'optimizer': 'sgd'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:21:27,360] Trial 7 finished with value: 0.8078611493110657 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0033233042062267943, 'alpha': 0.00048287152161792117, 'optimizer': 'sgd'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:23:46,825] Trial 8 finished with value: 0.8109545707702637 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.006533305220227739, 'alpha': 5.59598687800608e-05, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:26:29,071] Trial 9 finished with value: 0.8203986883163452 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.004048966222584676, 'alpha': 3.6283583803549155e-05, 'optimizer': 'sgd'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:28:48,342] Trial 10 finished with value: 0.7990909218788147 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0004124662544192987, 'alpha': 0.00015098273831684584, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:31:14,789] Trial 11 finished with value: 0.8065690994262695 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0003921612135270866, 'alpha': 0.00016477670830228577, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:33:04,857] Trial 12 finished with value: 0.8013005256652832 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00037299981541424096, 'alpha': 0.00218443395970587, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:35:12,047] Trial 13 finished with value: 0.8082293272018433 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0002291862656839158, 'alpha': 1.1323186753878092e-05, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:37:43,163] Trial 14 finished with value: 0.8116589784622192 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0007740967355271402, 'alpha': 0.00013566969734149178, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:40:21,894] Trial 15 finished with value: 0.8103575706481934 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.0001061391643892118, 'alpha': 0.0023614425795649282, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:42:54,079] Trial 16 finished with value: 0.7981827855110168 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00023422604938330685, 'alpha': 0.00022268783613813985, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:44:43,455] Trial 17 finished with value: 0.7947724461555481 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0008945789712170808, 'alpha': 1.221454305162071e-05, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:46:21,972] Trial 18 finished with value: 0.7941625714302063 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.0002391867282241365, 'alpha': 7.633519183320513e-05, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:48:24,799] Trial 19 finished with value: 0.8002883195877075 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.00018585501361966027, 'alpha': 0.0004599355675791596, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:50:21,815] Trial 20 finished with value: 0.809158980846405 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0006184571342778895, 'alpha': 0.004438217512617065, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:52:21,883] Trial 21 finished with value: 0.8081696629524231 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.0002924637787025793, 'alpha': 6.912977822923798e-05, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:54:08,347] Trial 22 finished with value: 0.7943660616874695 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.0005439023955316972, 'alpha': 8.267019076196386e-05, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:56:03,154] Trial 23 finished with value: 0.8015989065170288 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.00017741368126109977, 'alpha': 2.2540948753306994e-05, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:57:39,260] Trial 24 finished with value: 0.799015462398529 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0001052002220300876, 'alpha': 0.00030566281708638374, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 10:59:17,325] Trial 25 finished with value: 0.8021379709243774 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.0002760709595867932, 'alpha': 0.0009091886550549115, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 11:01:18,489] Trial 26 finished with value: 0.808029055595398 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0015364095491505962, 'alpha': 4.018748820180411e-05, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 11:03:13,336] Trial 27 finished with value: 0.9316331744194031 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0001742359489014693, 'alpha': 8.190903652609617e-05, 'optimizer': 'sgd'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 11:05:04,878] Trial 28 finished with value: 1.5110281705856323 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.009827674611457334, 'alpha': 1.6951889818154517e-05, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# [I 2025-05-16 11:06:44,136] Trial 29 finished with value: 0.798078715801239 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.001216147966541517, 'alpha': 0.0014130490232818751, 'optimizer': 'adam'}. Best is trial 3 with value: 0.7837855815887451.
# === Best Hyperparameters ===
# {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00032927591344236165, 'alpha': 0.0009717775305059633, 'optimizer': 'adam'}
# Best Mean MAE: 0.7838

# %%
import os
import optuna
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    # 采样超参数
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        model = XGBRegressor(n_jobs=-1, verbosity=0, **params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 以 MAE 为优化目标


# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best XGBoost Hyperparameters via Optuna ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 16:30:17,874] A new study created in memory with name: no-name-c030a105-dda2-4c8c-a8d9-53595892907b
# [I 2025-05-16 16:32:13,661] Trial 0 finished with value: 0.8799948692321777 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 8, 'subsample': 0.8795975452591109, 'colsample_bytree': 0.6624074561769746}. Best is trial 0 with value: 0.8799948692321777.
# [I 2025-05-16 16:33:42,037] Trial 1 finished with value: 0.837240993976593 and parameters: {'n_estimators': 200, 'learning_rate': 0.011900590783184251, 'max_depth': 9, 'subsample': 0.8803345035229626, 'colsample_bytree': 0.8832290311184181}. Best is trial 1 with value: 0.837240993976593.
# [I 2025-05-16 16:34:14,562] Trial 2 finished with value: 0.831487774848938 and parameters: {'n_estimators': 100, 'learning_rate': 0.18276027831785724, 'max_depth': 8, 'subsample': 0.7637017332034828, 'colsample_bytree': 0.6727299868828402}. Best is trial 2 with value: 0.831487774848938.
# [I 2025-05-16 16:35:00,316] Trial 3 finished with value: 0.7984839677810669 and parameters: {'n_estimators': 200, 'learning_rate': 0.024878734419814436, 'max_depth': 6, 'subsample': 0.8295835055926347, 'colsample_bytree': 0.7164916560792167}. Best is trial 3 with value: 0.7984839677810669.
# [I 2025-05-16 16:37:02,531] Trial 4 finished with value: 0.795976459980011 and parameters: {'n_estimators': 700, 'learning_rate': 0.01518747922672247, 'max_depth': 5, 'subsample': 0.8099085529881075, 'colsample_bytree': 0.7824279936868144}. Best is trial 4 with value: 0.795976459980011.
# [I 2025-05-16 16:39:42,547] Trial 5 finished with value: 0.8015338182449341 and parameters: {'n_estimators': 800, 'learning_rate': 0.018187859051288217, 'max_depth': 6, 'subsample': 0.8777243706586128, 'colsample_bytree': 0.6185801650879991}. Best is trial 4 with value: 0.795976459980011.
# [I 2025-05-16 16:40:51,512] Trial 6 finished with value: 0.7922602295875549 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'subsample': 0.984665661176, 'colsample_bytree': 0.9862528132298237}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 16:42:15,684] Trial 7 finished with value: 0.7948240041732788 and parameters: {'n_estimators': 900, 'learning_rate': 0.0249064396938244, 'max_depth': 3, 'subsample': 0.905269907953647, 'colsample_bytree': 0.7760609974958406}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 16:42:35,620] Trial 8 finished with value: 0.7926411628723145 and parameters: {'n_estimators': 200, 'learning_rate': 0.04407984038169244, 'max_depth': 3, 'subsample': 0.9727961206236346, 'colsample_bytree': 0.7035119926400067}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 16:44:54,307] Trial 9 finished with value: 0.8041883707046509 and parameters: {'n_estimators': 700, 'learning_rate': 0.02544166090938368, 'max_depth': 6, 'subsample': 0.8640130838029838, 'colsample_bytree': 0.6739417822102108}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 16:47:06,634] Trial 10 finished with value: 0.8213971853256226 and parameters: {'n_estimators': 1000, 'learning_rate': 0.08138762607805286, 'max_depth': 4, 'subsample': 0.9865434487124839, 'colsample_bytree': 0.9935584941681304}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 16:47:54,427] Trial 11 finished with value: 0.7950541973114014 and parameters: {'n_estimators': 500, 'learning_rate': 0.05243600136835885, 'max_depth': 3, 'subsample': 0.9944677871984587, 'colsample_bytree': 0.8953622178900085}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 16:48:48,913] Trial 12 finished with value: 0.8003784418106079 and parameters: {'n_estimators': 400, 'learning_rate': 0.053291436624982674, 'max_depth': 4, 'subsample': 0.9539327148024781, 'colsample_bytree': 0.9976023236378931}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 16:50:07,215] Trial 13 finished with value: 0.8108665347099304 and parameters: {'n_estimators': 600, 'learning_rate': 0.09953202087035609, 'max_depth': 4, 'subsample': 0.9407239274525441, 'colsample_bytree': 0.8583425762812965}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 16:50:36,304] Trial 14 finished with value: 0.7927953600883484 and parameters: {'n_estimators': 300, 'learning_rate': 0.038239324422150126, 'max_depth': 3, 'subsample': 0.9368431198958393, 'colsample_bytree': 0.7390533721986331}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 16:52:25,991] Trial 15 finished with value: 0.7957754731178284 and parameters: {'n_estimators': 600, 'learning_rate': 0.01065581619179544, 'max_depth': 5, 'subsample': 0.7235387154900341, 'colsample_bytree': 0.928718305352048}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 16:52:46,307] Trial 16 finished with value: 0.8034080266952515 and parameters: {'n_estimators': 100, 'learning_rate': 0.03486835198204206, 'max_depth': 5, 'subsample': 0.965842619897272, 'colsample_bytree': 0.8381822309079032}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 16:53:35,099] Trial 17 finished with value: 0.7987860441207886 and parameters: {'n_estimators': 500, 'learning_rate': 0.08579868959534684, 'max_depth': 3, 'subsample': 0.911958324229738, 'colsample_bytree': 0.9426423981937595}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 16:55:19,447] Trial 18 finished with value: 0.7955144643783569 and parameters: {'n_estimators': 800, 'learning_rate': 0.016214268461977047, 'max_depth': 4, 'subsample': 0.997021348582407, 'colsample_bytree': 0.8075353388093552}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 16:56:21,589] Trial 19 finished with value: 0.8013299703598022 and parameters: {'n_estimators': 400, 'learning_rate': 0.06529596110050329, 'max_depth': 5, 'subsample': 0.9242681607850999, 'colsample_bytree': 0.6088399867772502}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 17:00:05,235] Trial 20 finished with value: 0.8831170797348022 and parameters: {'n_estimators': 1000, 'learning_rate': 0.1326460524236043, 'max_depth': 7, 'subsample': 0.9685301594952096, 'colsample_bytree': 0.7279490294387551}. Best is trial 6 with value: 0.7922602295875549.
# [I 2025-05-16 17:00:35,101] Trial 21 finished with value: 0.7921584248542786 and parameters: {'n_estimators': 300, 'learning_rate': 0.036347596279465794, 'max_depth': 3, 'subsample': 0.9291242184744558, 'colsample_bytree': 0.7284761199393444}. Best is trial 21 with value: 0.7921584248542786.
# [I 2025-05-16 17:01:04,831] Trial 22 finished with value: 0.7925170660018921 and parameters: {'n_estimators': 300, 'learning_rate': 0.03204795955082687, 'max_depth': 3, 'subsample': 0.9678534396891171, 'colsample_bytree': 0.7511301747490007}. Best is trial 21 with value: 0.7921584248542786.
# [I 2025-05-16 17:01:45,365] Trial 23 finished with value: 0.7936021089553833 and parameters: {'n_estimators': 300, 'learning_rate': 0.029965720966397262, 'max_depth': 4, 'subsample': 0.947009831047721, 'colsample_bytree': 0.7553628566992681}. Best is trial 21 with value: 0.7921584248542786.
# [I 2025-05-16 17:02:16,106] Trial 24 finished with value: 0.7954128980636597 and parameters: {'n_estimators': 300, 'learning_rate': 0.018501643354876904, 'max_depth': 3, 'subsample': 0.9035804060054502, 'colsample_bytree': 0.8174952108912189}. Best is trial 21 with value: 0.7921584248542786.
# [I 2025-05-16 17:03:45,274] Trial 25 finished with value: 0.7949711680412292 and parameters: {'n_estimators': 700, 'learning_rate': 0.02081746226557753, 'max_depth': 4, 'subsample': 0.9637748185980373, 'colsample_bytree': 0.6956761585783126}. Best is trial 21 with value: 0.7921584248542786.
# [I 2025-05-16 17:04:35,063] Trial 26 finished with value: 0.7945266962051392 and parameters: {'n_estimators': 500, 'learning_rate': 0.012815116821513973, 'max_depth': 3, 'subsample': 0.924033923602676, 'colsample_bytree': 0.7684314789574025}. Best is trial 21 with value: 0.7921584248542786.
# [I 2025-05-16 17:05:26,812] Trial 27 finished with value: 0.7944594621658325 and parameters: {'n_estimators': 400, 'learning_rate': 0.033737798775914596, 'max_depth': 4, 'subsample': 0.8360981607250861, 'colsample_bytree': 0.6385028136517571}. Best is trial 21 with value: 0.7921584248542786.
# [I 2025-05-16 17:06:24,794] Trial 28 finished with value: 0.7967154383659363 and parameters: {'n_estimators': 600, 'learning_rate': 0.047173266906116625, 'max_depth': 3, 'subsample': 0.975275859210389, 'colsample_bytree': 0.9640436291564142}. Best is trial 21 with value: 0.7921584248542786.
# [I 2025-05-16 17:07:33,157] Trial 29 finished with value: 0.7954496145248413 and parameters: {'n_estimators': 400, 'learning_rate': 0.02928604846396876, 'max_depth': 5, 'subsample': 0.7842588546890383, 'colsample_bytree': 0.7445092890639768}. Best is trial 21 with value: 0.7921584248542786.
# === Best XGBoost Hyperparameters via Optuna ===
# {'n_estimators': 300, 'learning_rate': 0.036347596279465794, 'max_depth': 3, 'subsample': 0.9291242184744558, 'colsample_bytree': 0.7284761199393444}
# 10-Fold Mean MAE = 0.7922

# %%
import os
import optuna
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'objective': 'poisson',         # ✅ 强制正输出
        'n_jobs': -1,
        'verbose': -1
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        # Poisson 回归要求标签必须大于 0
        if np.any(y_train <= 0) or np.any(y_val <= 0):
            return np.inf

        model = LGBMRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 使用 MAE 作为优化目标

# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 17:07:33,371] A new study created in memory with name: no-name-53e56cd5-e01b-4eda-951a-2e710db15caa
# [I 2025-05-16 17:07:53,330] Trial 0 finished with value: 0.8049801559461986 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 10, 'num_leaves': 68, 'feature_fraction': 0.6624074561769746, 'bagging_fraction': 0.662397808134481}. Best is trial 0 with value: 0.8049801559461986.
# [I 2025-05-16 17:08:01,770] Trial 1 finished with value: 0.798919874611193 and parameters: {'n_estimators': 100, 'learning_rate': 0.13394334706750485, 'max_depth': 9, 'num_leaves': 77, 'feature_fraction': 0.608233797718321, 'bagging_fraction': 0.9879639408647978}. Best is trial 1 with value: 0.798919874611193.
# [I 2025-05-16 17:08:23,327] Trial 2 finished with value: 0.792906154689669 and parameters: {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:08:48,398] Trial 3 finished with value: 0.7939982579975273 and parameters: {'n_estimators': 500, 'learning_rate': 0.023927528765580644, 'max_depth': 9, 'num_leaves': 31, 'feature_fraction': 0.7168578594140873, 'bagging_fraction': 0.7465447373174767}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:09:01,041] Trial 4 finished with value: 0.7972327205487082 and parameters: {'n_estimators': 500, 'learning_rate': 0.10508421338691762, 'max_depth': 4, 'num_leaves': 61, 'feature_fraction': 0.836965827544817, 'bagging_fraction': 0.6185801650879991}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:09:18,185] Trial 5 finished with value: 0.798759404466524 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'num_leaves': 96, 'feature_fraction': 0.9862528132298237, 'bagging_fraction': 0.9233589392465844}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:09:48,595] Trial 6 finished with value: 0.820872871856723 and parameters: {'n_estimators': 400, 'learning_rate': 0.013399060561509796, 'max_depth': 9, 'num_leaves': 55, 'feature_fraction': 0.6488152939379115, 'bagging_fraction': 0.798070764044508}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:09:53,783] Trial 7 finished with value: 0.7940558590656069 and parameters: {'n_estimators': 100, 'learning_rate': 0.15242391728466367, 'max_depth': 5, 'num_leaves': 73, 'feature_fraction': 0.7246844304357644, 'bagging_fraction': 0.8080272084711243}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:10:59,779] Trial 8 finished with value: 0.8033478093984439 and parameters: {'n_estimators': 600, 'learning_rate': 0.017398074711291726, 'max_depth': 12, 'num_leaves': 82, 'feature_fraction': 0.9757995766256756, 'bagging_fraction': 0.9579309401710595}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:11:10,141] Trial 9 finished with value: 0.8018224602959556 and parameters: {'n_estimators': 600, 'learning_rate': 0.15826541904647565, 'max_depth': 3, 'num_leaves': 35, 'feature_fraction': 0.6180909155642152, 'bagging_fraction': 0.7301321323053057}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:11:42,370] Trial 10 finished with value: 0.7988535792961258 and parameters: {'n_estimators': 1000, 'learning_rate': 0.041286972973122775, 'max_depth': 6, 'num_leaves': 21, 'feature_fraction': 0.8423486893732017, 'bagging_fraction': 0.876098829427658}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:12:17,211] Trial 11 finished with value: 0.7988479169304976 and parameters: {'n_estimators': 900, 'learning_rate': 0.032403579261005684, 'max_depth': 7, 'num_leaves': 42, 'feature_fraction': 0.7532336562338404, 'bagging_fraction': 0.7628900279921988}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:12:45,069] Trial 12 finished with value: 0.7953776250182024 and parameters: {'n_estimators': 800, 'learning_rate': 0.026160308927601773, 'max_depth': 7, 'num_leaves': 21, 'feature_fraction': 0.7331336920786393, 'bagging_fraction': 0.7212450905180019}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:13:03,091] Trial 13 finished with value: 0.7968256605276024 and parameters: {'n_estimators': 300, 'learning_rate': 0.06922749265952521, 'max_depth': 11, 'num_leaves': 39, 'feature_fraction': 0.7874820875551369, 'bagging_fraction': 0.8530004117857514}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:13:51,773] Trial 14 finished with value: 0.7987630226870966 and parameters: {'n_estimators': 800, 'learning_rate': 0.011058500546306225, 'max_depth': 8, 'num_leaves': 47, 'feature_fraction': 0.696300989557843, 'bagging_fraction': 0.6815008331349779}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:14:24,637] Trial 15 finished with value: 0.7940069651888325 and parameters: {'n_estimators': 1000, 'learning_rate': 0.02313538107259092, 'max_depth': 5, 'num_leaves': 29, 'feature_fraction': 0.8752918047800797, 'bagging_fraction': 0.8374820761833434}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:14:43,255] Trial 16 finished with value: 0.7957339480791635 and parameters: {'n_estimators': 300, 'learning_rate': 0.04392852336621884, 'max_depth': 8, 'num_leaves': 50, 'feature_fraction': 0.793372341923534, 'bagging_fraction': 0.9006453699263156}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:15:17,729] Trial 17 finished with value: 0.798655304342714 and parameters: {'n_estimators': 700, 'learning_rate': 0.06592511809065209, 'max_depth': 10, 'num_leaves': 30, 'feature_fraction': 0.9146511487079994, 'bagging_fraction': 0.7717199731836432}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:15:39,624] Trial 18 finished with value: 0.7958290836796634 and parameters: {'n_estimators': 500, 'learning_rate': 0.020490705233170366, 'max_depth': 6, 'num_leaves': 30, 'feature_fraction': 0.7006605823675769, 'bagging_fraction': 0.7128638943099164}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:16:48,362] Trial 19 finished with value: 0.801981212382184 and parameters: {'n_estimators': 800, 'learning_rate': 0.010316475004898525, 'max_depth': 12, 'num_leaves': 61, 'feature_fraction': 0.7682075212678564, 'bagging_fraction': 0.6209920475410307}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:17:00,275] Trial 20 finished with value: 0.7971583299520854 and parameters: {'n_estimators': 300, 'learning_rate': 0.03204795955082687, 'max_depth': 5, 'num_leaves': 47, 'feature_fraction': 0.676631198744518, 'bagging_fraction': 0.8091846793244003}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:17:24,829] Trial 21 finished with value: 0.7935692792094321 and parameters: {'n_estimators': 1000, 'learning_rate': 0.024285383009483585, 'max_depth': 4, 'num_leaves': 32, 'feature_fraction': 0.901259368429216, 'bagging_fraction': 0.840941963206565}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:17:48,189] Trial 22 finished with value: 0.7937541643898264 and parameters: {'n_estimators': 900, 'learning_rate': 0.02946147282554694, 'max_depth': 4, 'num_leaves': 25, 'feature_fraction': 0.9283901572734171, 'bagging_fraction': 0.7650745181069674}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:18:11,384] Trial 23 finished with value: 0.7941118190184955 and parameters: {'n_estimators': 900, 'learning_rate': 0.033757110268405305, 'max_depth': 4, 'num_leaves': 20, 'feature_fraction': 0.9298528902087924, 'bagging_fraction': 0.8380352701884155}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:18:32,610] Trial 24 finished with value: 0.7988761608355811 and parameters: {'n_estimators': 900, 'learning_rate': 0.05700685672078798, 'max_depth': 4, 'num_leaves': 39, 'feature_fraction': 0.9359043382273078, 'bagging_fraction': 0.7858790838892679}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:18:53,188] Trial 25 finished with value: 0.7958534260466765 and parameters: {'n_estimators': 1000, 'learning_rate': 0.015107902773255851, 'max_depth': 3, 'num_leaves': 26, 'feature_fraction': 0.8713279625162539, 'bagging_fraction': 0.8709988145186612}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:19:28,465] Trial 26 finished with value: 0.7954344072566268 and parameters: {'n_estimators': 900, 'learning_rate': 0.02060784809340101, 'max_depth': 6, 'num_leaves': 35, 'feature_fraction': 0.8947104102342555, 'bagging_fraction': 0.9171979198143885}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:19:52,146] Trial 27 finished with value: 0.7934396827391396 and parameters: {'n_estimators': 1000, 'learning_rate': 0.029174799076958195, 'max_depth': 4, 'num_leaves': 42, 'feature_fraction': 0.8286029192197548, 'bagging_fraction': 0.8251323334561256}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:20:21,254] Trial 28 finished with value: 0.7994550347935282 and parameters: {'n_estimators': 1000, 'learning_rate': 0.05196370138891357, 'max_depth': 5, 'num_leaves': 44, 'feature_fraction': 0.8254360456253786, 'bagging_fraction': 0.8888531461059263}. Best is trial 2 with value: 0.792906154689669.
# [I 2025-05-16 17:20:36,665] Trial 29 finished with value: 0.8032555625562982 and parameters: {'n_estimators': 700, 'learning_rate': 0.01285534015847087, 'max_depth': 3, 'num_leaves': 53, 'feature_fraction': 0.8169202546559953, 'bagging_fraction': 0.8300024383871503}. Best is trial 2 with value: 0.792906154689669.
# === Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===
# {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}
# 10-Fold Mean MAE = 0.7929
