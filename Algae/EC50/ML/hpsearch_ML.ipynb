# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import torch
from sklearn.model_selection import StratifiedKFold
import pandas as pd
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.metrics import precision_recall_curve, auc
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
import joblib
import optuna
from rdkit.Chem import Descriptors, AllChem
from tqdm import tqdm  # 导入tqdm
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GroupKFold

# %%
# 函数：将SMILES转换为分子描述符和指纹
def smiles_to_features(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None
    # 提取描述符
    descriptors = [
        Descriptors.MolWt(mol),  # 分子量
        Descriptors.MolLogP(mol),  # LogP
        Descriptors.NumHDonors(mol),  # 氢键供体数量
        Descriptors.NumHAcceptors(mol)  # 氢键受体数量
    ]
    # 生成Morgan指纹
    fingerprint = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=2048)
    fingerprint_array = np.zeros((2048,))
    Chem.DataStructs.ConvertToNumpyArray(fingerprint, fingerprint_array)
    # 合并描述符和指纹
    features = np.concatenate([descriptors, fingerprint_array])
    return features

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold
from tqdm import tqdm
import optuna
import numpy as np

def train_evaluate_regression_model_with_optuna(model_name, model_class, param_func, X, y, groups):
    def objective(trial):
        params = param_func(trial)
        model = model_class(**params)

        gkf = GroupKFold(n_splits=10)
        maes = []

        for train_idx, val_idx in tqdm(gkf.split(X, y, groups=groups), total=10, desc=f"Training {model_name}"):
            X_train, X_val = X[train_idx], X[val_idx]
            y_train, y_val = y[train_idx], y[val_idx]

            model.fit(X_train, y_train)
            y_pred = model.predict(X_val)

            # ✅ 计算 MAE
            mae = mean_absolute_error(y_val, y_pred)
            maes.append(mae)

        return np.mean(maes)

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=30)

    print(f'Best parameters for {model_name}: {study.best_params}')
    print(f'Best mean MAE: {study.best_value:.4f}')

# %%
# 数据预处理
df = pd.read_excel('../algae_EC50_unique.xlsx')
labels = df['mgperL'].values
smiles_list = df['SMILES_Canonical_RDKit'].tolist()
endpoints_a = df['endpoint']
Duration_Values_a = df['Duration_Value'].values
effects_a = df['effect']

# %%
features = []
new_labels = []
new_smiles_list = []
endpoints = []
Duration_Values = []
effects =[]


for smiles, label,a,b,c in zip(smiles_list, labels,Duration_Values_a,effects_a,endpoints_a):
    feature = smiles_to_features(smiles)
    if feature is not None:
        features.append(feature)
        new_labels.append(label)
        new_smiles_list.append(smiles)
        Duration_Values.append(a)
        effects.append(b)
        endpoints.append(c)

X = np.array(features)
y = np.array(new_labels)
groups = new_smiles_list  # 可直接用于 GroupKFold

# %%
def encode_column(zz):
    zz_series = pd.Series(zz)  # 转换为 Series
    unique_values = zz_series.unique()
    if len(unique_values) > 1:
        encoder = OneHotEncoder(sparse_output=False)
        return encoder.fit_transform(zz_series.values.reshape(-1, 1))
    else:
        return None  # 只有一种类别时忽略

Duration_Values =pd.Series(Duration_Values)


# 编码 effect、endpoint 和 species_group 列
effect_encoded = encode_column(effects)
endpoint_encoded = encode_column(endpoints)
#species_encoded = encode_column(df, 'species_group')

# # 将需要的列拼接成输入 X
X = np.hstack((X, Duration_Values.values.reshape(-1, 1)))

# # 拼接编码后的列（如果存在）
for encoded_feature in [effect_encoded, endpoint_encoded]:
     if encoded_feature is not None:
         X = np.hstack((X, encoded_feature))



y=np.log1p(y)

# %%
def xgb_param_func(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 100, 600),
        'max_depth': trial.suggest_int('max_depth', 5, 20),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),   # L1 正则
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0)  # L2 正则
    }
from xgboost import XGBRegressor

train_evaluate_regression_model_with_optuna(
    "XGBoost",
    XGBRegressor,
    xgb_param_func,
    X, y, groups
)
# Out:
# [I 2025-05-16 11:44:43,290] A new study created in memory with name: no-name-85bd02e8-2297-46b3-b1ef-96a3604cc13b
# Training XGBoost: 100%|██████████| 10/10 [01:54<00:00, 11.44s/it]
# [I 2025-05-16 11:46:37,722] Trial 0 finished with value: 1.131928866395143 and parameters: {'n_estimators': 474, 'max_depth': 12, 'learning_rate': 0.18023131654486024, 'subsample': 0.9853468711144471, 'colsample_bytree': 0.7873842437393003, 'reg_alpha': 0.5710029090185722, 'reg_lambda': 0.5210135992168969}. Best is trial 0 with value: 1.131928866395143.
# Training XGBoost: 100%|██████████| 10/10 [00:51<00:00,  5.19s/it]
# [I 2025-05-16 11:47:29,648] Trial 1 finished with value: 1.1875753912114047 and parameters: {'n_estimators': 261, 'max_depth': 11, 'learning_rate': 0.016291820289622002, 'subsample': 0.9305622650598427, 'colsample_bytree': 0.9222372855235994, 'reg_alpha': 0.29780983031677377, 'reg_lambda': 0.2736452492671415}. Best is trial 0 with value: 1.131928866395143.
# Training XGBoost: 100%|██████████| 10/10 [00:17<00:00,  1.79s/it]
# [I 2025-05-16 11:47:47,606] Trial 2 finished with value: 1.148732767607165 and parameters: {'n_estimators': 133, 'max_depth': 11, 'learning_rate': 0.08783338467780985, 'subsample': 0.9674762129827708, 'colsample_bytree': 0.950534336609976, 'reg_alpha': 0.6702116444786974, 'reg_lambda': 0.3308685791877686}. Best is trial 0 with value: 1.131928866395143.
# Training XGBoost: 100%|██████████| 10/10 [01:09<00:00,  6.95s/it]
# [I 2025-05-16 11:48:57,131] Trial 3 finished with value: 1.173935397137702 and parameters: {'n_estimators': 341, 'max_depth': 12, 'learning_rate': 0.29506726161023544, 'subsample': 0.6287326424406227, 'colsample_bytree': 0.8573832567709049, 'reg_alpha': 0.650045358084886, 'reg_lambda': 0.4494166001769826}. Best is trial 0 with value: 1.131928866395143.
# Training XGBoost: 100%|██████████| 10/10 [00:46<00:00,  4.65s/it]
# [I 2025-05-16 11:49:43,587] Trial 4 finished with value: 1.1163743833647997 and parameters: {'n_estimators': 355, 'max_depth': 12, 'learning_rate': 0.056086442506156485, 'subsample': 0.9405483553879259, 'colsample_bytree': 0.741581889488584, 'reg_alpha': 0.6090036635690623, 'reg_lambda': 0.8297433385871796}. Best is trial 4 with value: 1.1163743833647997.
# Training XGBoost: 100%|██████████| 10/10 [00:33<00:00,  3.39s/it]
# [I 2025-05-16 11:50:17,500] Trial 5 finished with value: 1.143533560399895 and parameters: {'n_estimators': 152, 'max_depth': 15, 'learning_rate': 0.03662318468487332, 'subsample': 0.7942029971186467, 'colsample_bytree': 0.8444012349439057, 'reg_alpha': 0.4921249350410719, 'reg_lambda': 0.8217878730121164}. Best is trial 4 with value: 1.1163743833647997.
# Training XGBoost: 100%|██████████| 10/10 [00:44<00:00,  4.43s/it]
# [I 2025-05-16 11:51:01,818] Trial 6 finished with value: 1.1274669291879205 and parameters: {'n_estimators': 167, 'max_depth': 18, 'learning_rate': 0.03613596504844429, 'subsample': 0.7231588491075707, 'colsample_bytree': 0.7079501906252543, 'reg_alpha': 0.5495632094625907, 'reg_lambda': 0.004646345104540539}. Best is trial 4 with value: 1.1163743833647997.
# Training XGBoost: 100%|██████████| 10/10 [01:33<00:00,  9.31s/it]
# [I 2025-05-16 11:52:34,876] Trial 7 finished with value: 1.150594170320987 and parameters: {'n_estimators': 530, 'max_depth': 11, 'learning_rate': 0.24745743623214464, 'subsample': 0.669807750413924, 'colsample_bytree': 0.7098276395411195, 'reg_alpha': 0.5146740917379765, 'reg_lambda': 0.34687699665581984}. Best is trial 4 with value: 1.1163743833647997.
# Training XGBoost: 100%|██████████| 10/10 [00:45<00:00,  4.56s/it]
# [I 2025-05-16 11:53:20,443] Trial 8 finished with value: 1.2513888415082168 and parameters: {'n_estimators': 529, 'max_depth': 5, 'learning_rate': 0.012047500210970948, 'subsample': 0.9312744974796952, 'colsample_bytree': 0.9902324258173322, 'reg_alpha': 0.49880528134809743, 'reg_lambda': 0.35408028480011167}. Best is trial 4 with value: 1.1163743833647997.
# Training XGBoost: 100%|██████████| 10/10 [01:06<00:00,  6.62s/it]
# [I 2025-05-16 11:54:26,669] Trial 9 finished with value: 1.1273356793169398 and parameters: {'n_estimators': 420, 'max_depth': 15, 'learning_rate': 0.14758101285544648, 'subsample': 0.8643577822706434, 'colsample_bytree': 0.831783142971954, 'reg_alpha': 0.12361303740490548, 'reg_lambda': 0.49484898384299425}. Best is trial 4 with value: 1.1163743833647997.
# Training XGBoost: 100%|██████████| 10/10 [00:26<00:00,  2.64s/it]
# [I 2025-05-16 11:54:53,098] Trial 10 finished with value: 1.141338076641384 and parameters: {'n_estimators': 306, 'max_depth': 7, 'learning_rate': 0.06910957506789482, 'subsample': 0.8376939686672475, 'colsample_bytree': 0.6048139855250172, 'reg_alpha': 0.9958317593185972, 'reg_lambda': 0.9898949819200863}. Best is trial 4 with value: 1.1163743833647997.
# Training XGBoost: 100%|██████████| 10/10 [01:11<00:00,  7.19s/it]
# [I 2025-05-16 11:56:05,051] Trial 11 finished with value: 1.1206839729595757 and parameters: {'n_estimators': 424, 'max_depth': 17, 'learning_rate': 0.10005477968588734, 'subsample': 0.8631074410500895, 'colsample_bytree': 0.7695674744224185, 'reg_alpha': 0.06035619106840373, 'reg_lambda': 0.6716198942884972}. Best is trial 4 with value: 1.1163743833647997.
# Training XGBoost: 100%|██████████| 10/10 [01:25<00:00,  8.58s/it]
# [I 2025-05-16 11:57:30,918] Trial 12 finished with value: 1.1154319736481964 and parameters: {'n_estimators': 421, 'max_depth': 20, 'learning_rate': 0.11781145076609342, 'subsample': 0.8635675518464196, 'colsample_bytree': 0.7392687632881341, 'reg_alpha': 0.00883123405851434, 'reg_lambda': 0.7268884788411443}. Best is trial 12 with value: 1.1154319736481964.
# Training XGBoost: 100%|██████████| 10/10 [01:12<00:00,  7.22s/it]
# [I 2025-05-16 11:58:43,196] Trial 13 finished with value: 1.1020407954087408 and parameters: {'n_estimators': 247, 'max_depth': 20, 'learning_rate': 0.043116814496776165, 'subsample': 0.7966722975201084, 'colsample_bytree': 0.6887340933188979, 'reg_alpha': 0.8650703746942799, 'reg_lambda': 0.7975922303993872}. Best is trial 13 with value: 1.1020407954087408.
# Training XGBoost: 100%|██████████| 10/10 [01:08<00:00,  6.87s/it]
# [I 2025-05-16 11:59:51,966] Trial 14 finished with value: 1.1080887893561013 and parameters: {'n_estimators': 240, 'max_depth': 20, 'learning_rate': 0.029361465349557612, 'subsample': 0.7813783154661789, 'colsample_bytree': 0.6348570748001777, 'reg_alpha': 0.9487640209053797, 'reg_lambda': 0.7259395907909499}. Best is trial 13 with value: 1.1020407954087408.
# Training XGBoost: 100%|██████████| 10/10 [01:02<00:00,  6.22s/it]
# [I 2025-05-16 12:00:54,192] Trial 15 finished with value: 1.1222086370492206 and parameters: {'n_estimators': 210, 'max_depth': 20, 'learning_rate': 0.027784542150962373, 'subsample': 0.7568964182643421, 'colsample_bytree': 0.6253297628102126, 'reg_alpha': 0.9945530644444458, 'reg_lambda': 0.9280175446252829}. Best is trial 13 with value: 1.1020407954087408.
# Training XGBoost: 100%|██████████| 10/10 [00:53<00:00,  5.40s/it]
# [I 2025-05-16 12:01:48,179] Trial 16 finished with value: 1.1246996685177764 and parameters: {'n_estimators': 236, 'max_depth': 18, 'learning_rate': 0.025815654858361497, 'subsample': 0.7103286234015731, 'colsample_bytree': 0.6688712355129256, 'reg_alpha': 0.8205023157280217, 'reg_lambda': 0.6360344159447358}. Best is trial 13 with value: 1.1020407954087408.
# Training XGBoost: 100%|██████████| 10/10 [00:57<00:00,  5.71s/it]
# [I 2025-05-16 12:02:45,347] Trial 17 finished with value: 1.1455641351522317 and parameters: {'n_estimators': 281, 'max_depth': 15, 'learning_rate': 0.018311278900277343, 'subsample': 0.7876189361398616, 'colsample_bytree': 0.6534090580597638, 'reg_alpha': 0.789487636419868, 'reg_lambda': 0.8220682015953557}. Best is trial 13 with value: 1.1020407954087408.
# Training XGBoost: 100%|██████████| 10/10 [02:55<00:00, 17.59s/it]
# [I 2025-05-16 12:05:41,267] Trial 18 finished with value: 1.0999168708060023 and parameters: {'n_estimators': 597, 'max_depth': 20, 'learning_rate': 0.046204700774673826, 'subsample': 0.755478687928603, 'colsample_bytree': 0.6726952441855981, 'reg_alpha': 0.8625535828971062, 'reg_lambda': 0.7163342866739615}. Best is trial 18 with value: 1.0999168708060023.
# Training XGBoost: 100%|██████████| 10/10 [02:26<00:00, 14.64s/it]
# [I 2025-05-16 12:08:07,661] Trial 19 finished with value: 1.1004644325671933 and parameters: {'n_estimators': 587, 'max_depth': 17, 'learning_rate': 0.052222200449899066, 'subsample': 0.7265360999033539, 'colsample_bytree': 0.6814957618952332, 'reg_alpha': 0.8340245761089584, 'reg_lambda': 0.6315728335895504}. Best is trial 18 with value: 1.0999168708060023.
# Training XGBoost: 100%|██████████| 10/10 [02:26<00:00, 14.60s/it]
# [I 2025-05-16 12:10:33,701] Trial 20 finished with value: 1.0995814989070603 and parameters: {'n_estimators': 595, 'max_depth': 17, 'learning_rate': 0.06122428883447058, 'subsample': 0.6136912835388852, 'colsample_bytree': 0.748039136262786, 'reg_alpha': 0.7334622268677061, 'reg_lambda': 0.5757917770418484}. Best is trial 20 with value: 1.0995814989070603.
# Training XGBoost: 100%|██████████| 10/10 [02:21<00:00, 14.11s/it]
# [I 2025-05-16 12:12:54,869] Trial 21 finished with value: 1.0989430360375063 and parameters: {'n_estimators': 582, 'max_depth': 17, 'learning_rate': 0.05447726259566802, 'subsample': 0.6008950319520899, 'colsample_bytree': 0.7455545418727336, 'reg_alpha': 0.7645125574311191, 'reg_lambda': 0.581625722570503}. Best is trial 21 with value: 1.0989430360375063.
# Training XGBoost: 100%|██████████| 10/10 [02:37<00:00, 15.79s/it]
# [I 2025-05-16 12:15:32,828] Trial 22 finished with value: 1.1017276732200603 and parameters: {'n_estimators': 593, 'max_depth': 18, 'learning_rate': 0.06324896581687459, 'subsample': 0.6087481365237215, 'colsample_bytree': 0.7715248124067462, 'reg_alpha': 0.7321247509362269, 'reg_lambda': 0.5458455527079487}. Best is trial 21 with value: 1.0989430360375063.
# Training XGBoost: 100%|██████████| 10/10 [01:17<00:00,  7.74s/it]
# [I 2025-05-16 12:16:50,308] Trial 23 finished with value: 1.1141057136638342 and parameters: {'n_estimators': 539, 'max_depth': 14, 'learning_rate': 0.07488424550767857, 'subsample': 0.6523064504549421, 'colsample_bytree': 0.7381419614444644, 'reg_alpha': 0.3701670044902356, 'reg_lambda': 0.5708532940986493}. Best is trial 21 with value: 1.0989430360375063.
# Training XGBoost: 100%|██████████| 10/10 [01:50<00:00, 11.07s/it]
# [I 2025-05-16 12:18:41,065] Trial 24 finished with value: 1.0995923255864302 and parameters: {'n_estimators': 483, 'max_depth': 17, 'learning_rate': 0.04779908350129011, 'subsample': 0.6755126257665065, 'colsample_bytree': 0.8067145351011431, 'reg_alpha': 0.7402844227270875, 'reg_lambda': 0.43858576308248887}. Best is trial 21 with value: 1.0989430360375063.
# Training XGBoost: 100%|██████████| 10/10 [01:59<00:00, 11.93s/it]
# [I 2025-05-16 12:20:40,412] Trial 25 finished with value: 1.126447274948093 and parameters: {'n_estimators': 486, 'max_depth': 16, 'learning_rate': 0.11762637352648099, 'subsample': 0.6661883800451895, 'colsample_bytree': 0.8108691989066056, 'reg_alpha': 0.7161466128012874, 'reg_lambda': 0.18999501288967469}. Best is trial 21 with value: 1.0989430360375063.
# Training XGBoost: 100%|██████████| 10/10 [01:22<00:00,  8.21s/it]
# [I 2025-05-16 12:22:02,546] Trial 26 finished with value: 1.1158443544901142 and parameters: {'n_estimators': 560, 'max_depth': 14, 'learning_rate': 0.02106148436046177, 'subsample': 0.6131099181777603, 'colsample_bytree': 0.8880855479437488, 'reg_alpha': 0.41330297218617484, 'reg_lambda': 0.4478949204103831}. Best is trial 21 with value: 1.0989430360375063.
# Training XGBoost: 100%|██████████| 10/10 [01:38<00:00,  9.89s/it]
# [I 2025-05-16 12:23:41,520] Trial 27 finished with value: 1.0992407952425078 and parameters: {'n_estimators': 464, 'max_depth': 17, 'learning_rate': 0.03583583366547758, 'subsample': 0.6927146738216253, 'colsample_bytree': 0.798116437169281, 'reg_alpha': 0.7512285420898491, 'reg_lambda': 0.16177304829086714}. Best is trial 21 with value: 1.0989430360375063.
# Training XGBoost: 100%|██████████| 10/10 [00:49<00:00,  4.97s/it]
# [I 2025-05-16 12:24:31,203] Trial 28 finished with value: 1.1301426200134272 and parameters: {'n_estimators': 508, 'max_depth': 9, 'learning_rate': 0.03352267106696919, 'subsample': 0.6385390669618192, 'colsample_bytree': 0.8857468135179337, 'reg_alpha': 0.900959714427263, 'reg_lambda': 0.020471540230966645}. Best is trial 21 with value: 1.0989430360375063.
# Training XGBoost: 100%|██████████| 10/10 [01:37<00:00,  9.76s/it]
# [I 2025-05-16 12:26:08,863] Trial 29 finished with value: 1.1341751178322097 and parameters: {'n_estimators': 467, 'max_depth': 14, 'learning_rate': 0.16658040267119245, 'subsample': 0.6922635877277843, 'colsample_bytree': 0.7811462514596683, 'reg_alpha': 0.5951565559511527, 'reg_lambda': 0.15329440299848748}. Best is trial 21 with value: 1.0989430360375063.
# Best parameters for XGBoost: {'n_estimators': 582, 'max_depth': 17, 'learning_rate': 0.05447726259566802, 'subsample': 0.6008950319520899, 'colsample_bytree': 0.7455545418727336, 'reg_alpha': 0.7645125574311191, 'reg_lambda': 0.581625722570503}
# Best mean MAE: 1.0989

# %%
from lightgbm import LGBMRegressor

def lgbm_param_func(trial):
    return {
        'n_estimators': trial.suggest_int('n_estimators', 100, 600),
        'max_depth': trial.suggest_int('max_depth', 5, 20),
        'num_leaves': trial.suggest_int('num_leaves', 20, 300),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'bagging_freq': trial.suggest_int('bagging_freq', 1, 7),
        'reg_alpha': trial.suggest_float('reg_alpha', 0.0, 1.0),
        'reg_lambda': trial.suggest_float('reg_lambda', 0.0, 1.0),
        'verbose': -1
    }

print("Training LightGBM (Poisson)...")
train_evaluate_regression_model_with_optuna(
    "LightGBM",
    lambda **params: LGBMRegressor(objective="poisson", **params),  # ✅ 加入 Poisson 目标
    lgbm_param_func,
    X, y, groups
)
# Out:
# [I 2025-05-16 12:26:08,871] A new study created in memory with name: no-name-ccb426b3-b981-4da3-a36b-acfc38baa36d
# Training LightGBM (Poisson)...
# Training LightGBM: 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
# [I 2025-05-16 12:26:22,507] Trial 0 finished with value: 1.2194580939692108 and parameters: {'n_estimators': 281, 'max_depth': 20, 'num_leaves': 199, 'learning_rate': 0.01894788709998699, 'feature_fraction': 0.6440327048715067, 'bagging_fraction': 0.6463867243599526, 'bagging_freq': 4, 'reg_alpha': 0.3671066110143859, 'reg_lambda': 0.528979077551033}. Best is trial 0 with value: 1.2194580939692108.
# Training LightGBM: 100%|██████████| 10/10 [00:04<00:00,  2.11it/s]
# [I 2025-05-16 12:26:27,256] Trial 1 finished with value: 1.3730370491486972 and parameters: {'n_estimators': 134, 'max_depth': 8, 'num_leaves': 138, 'learning_rate': 0.012853107316269758, 'feature_fraction': 0.8696288853580227, 'bagging_fraction': 0.6324893178449351, 'bagging_freq': 2, 'reg_alpha': 0.7469245668013818, 'reg_lambda': 0.12085459905475604}. Best is trial 0 with value: 1.2194580939692108.
# Training LightGBM: 100%|██████████| 10/10 [00:06<00:00,  1.46it/s]
# [I 2025-05-16 12:26:34,132] Trial 2 finished with value: 1.1482414937913448 and parameters: {'n_estimators': 535, 'max_depth': 6, 'num_leaves': 183, 'learning_rate': 0.13105274406812945, 'feature_fraction': 0.6719036752570506, 'bagging_fraction': 0.6097845768375375, 'bagging_freq': 7, 'reg_alpha': 0.31305399958314273, 'reg_lambda': 0.3969459397143832}. Best is trial 2 with value: 1.1482414937913448.
# Training LightGBM: 100%|██████████| 10/10 [00:03<00:00,  3.07it/s]
# [I 2025-05-16 12:26:37,396] Trial 3 finished with value: 1.1573655809015344 and parameters: {'n_estimators': 144, 'max_depth': 9, 'num_leaves': 48, 'learning_rate': 0.2073476040949803, 'feature_fraction': 0.7050955995911956, 'bagging_fraction': 0.7793109828622801, 'bagging_freq': 1, 'reg_alpha': 0.0027823704503761038, 'reg_lambda': 0.48869359920654587}. Best is trial 2 with value: 1.1482414937913448.
# Training LightGBM: 100%|██████████| 10/10 [00:05<00:00,  1.74it/s]
# [I 2025-05-16 12:26:43,170] Trial 4 finished with value: 1.3314448464174846 and parameters: {'n_estimators': 169, 'max_depth': 8, 'num_leaves': 53, 'learning_rate': 0.014965526003238184, 'feature_fraction': 0.9135938462632623, 'bagging_fraction': 0.7514530692734506, 'bagging_freq': 3, 'reg_alpha': 0.7468422108859847, 'reg_lambda': 0.6611942454671716}. Best is trial 2 with value: 1.1482414937913448.
# Training LightGBM: 100%|██████████| 10/10 [00:16<00:00,  1.65s/it]
# [I 2025-05-16 12:26:59,699] Trial 5 finished with value: 1.129194465596271 and parameters: {'n_estimators': 514, 'max_depth': 17, 'num_leaves': 103, 'learning_rate': 0.05662216466170241, 'feature_fraction': 0.664695276074592, 'bagging_fraction': 0.7574154198676327, 'bagging_freq': 6, 'reg_alpha': 0.6504248431191781, 'reg_lambda': 0.5948692038446131}. Best is trial 5 with value: 1.129194465596271.
# Training LightGBM: 100%|██████████| 10/10 [00:06<00:00,  1.45it/s]
# [I 2025-05-16 12:27:06,584] Trial 6 finished with value: 1.1456230361571575 and parameters: {'n_estimators': 202, 'max_depth': 15, 'num_leaves': 161, 'learning_rate': 0.16496798263102053, 'feature_fraction': 0.807976159461771, 'bagging_fraction': 0.6810413164074511, 'bagging_freq': 4, 'reg_alpha': 0.07614874481926392, 'reg_lambda': 0.7691182711718567}. Best is trial 5 with value: 1.129194465596271.
# Training LightGBM: 100%|██████████| 10/10 [00:13<00:00,  1.38s/it]
# [I 2025-05-16 12:27:20,396] Trial 7 finished with value: 1.120939733364649 and parameters: {'n_estimators': 381, 'max_depth': 19, 'num_leaves': 222, 'learning_rate': 0.06864718784795552, 'feature_fraction': 0.8829736361248924, 'bagging_fraction': 0.8315123782808673, 'bagging_freq': 6, 'reg_alpha': 0.8183597982315305, 'reg_lambda': 0.15379045589497786}. Best is trial 7 with value: 1.120939733364649.
# Training LightGBM: 100%|██████████| 10/10 [00:04<00:00,  2.12it/s]
# [I 2025-05-16 12:27:25,137] Trial 8 finished with value: 1.2433761135584072 and parameters: {'n_estimators': 129, 'max_depth': 15, 'num_leaves': 49, 'learning_rate': 0.03471678520506518, 'feature_fraction': 0.9687058666101855, 'bagging_fraction': 0.7108109584286184, 'bagging_freq': 1, 'reg_alpha': 0.8856648400500697, 'reg_lambda': 0.9945946629823283}. Best is trial 7 with value: 1.120939733364649.
# Training LightGBM: 100%|██████████| 10/10 [00:06<00:00,  1.59it/s]
# [I 2025-05-16 12:27:31,436] Trial 9 finished with value: 1.1563969524809252 and parameters: {'n_estimators': 516, 'max_depth': 5, 'num_leaves': 93, 'learning_rate': 0.13606934288492223, 'feature_fraction': 0.7491571877591954, 'bagging_fraction': 0.9842578708563077, 'bagging_freq': 3, 'reg_alpha': 0.9740034897821092, 'reg_lambda': 0.5813331837053395}. Best is trial 7 with value: 1.120939733364649.
# Training LightGBM: 100%|██████████| 10/10 [00:14<00:00,  1.47s/it]
# [I 2025-05-16 12:27:46,153] Trial 10 finished with value: 1.1276427584953361 and parameters: {'n_estimators': 394, 'max_depth': 20, 'num_leaves': 288, 'learning_rate': 0.06056284807850765, 'feature_fraction': 0.8307811127199651, 'bagging_fraction': 0.8842192373961307, 'bagging_freq': 6, 'reg_alpha': 0.5427984739485503, 'reg_lambda': 0.007257563060425798}. Best is trial 7 with value: 1.120939733364649.
# Training LightGBM: 100%|██████████| 10/10 [00:14<00:00,  1.43s/it]
# [I 2025-05-16 12:28:00,447] Trial 11 finished with value: 1.1292569664619705 and parameters: {'n_estimators': 376, 'max_depth': 20, 'num_leaves': 285, 'learning_rate': 0.06562298530030891, 'feature_fraction': 0.846591396641296, 'bagging_fraction': 0.8778683846531762, 'bagging_freq': 6, 'reg_alpha': 0.5111756660864425, 'reg_lambda': 0.008137219918840208}. Best is trial 7 with value: 1.120939733364649.
# Training LightGBM: 100%|██████████| 10/10 [00:13<00:00,  1.39s/it]
# [I 2025-05-16 12:28:14,420] Trial 12 finished with value: 1.1213049037005889 and parameters: {'n_estimators': 400, 'max_depth': 18, 'num_leaves': 276, 'learning_rate': 0.08377928829442481, 'feature_fraction': 0.9954433401251002, 'bagging_fraction': 0.8588451290423565, 'bagging_freq': 6, 'reg_alpha': 0.5107348241046011, 'reg_lambda': 0.2409436464659585}. Best is trial 7 with value: 1.120939733364649.
# Training LightGBM: 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]
# [I 2025-05-16 12:28:28,012] Trial 13 finished with value: 1.1196681338957233 and parameters: {'n_estimators': 434, 'max_depth': 17, 'num_leaves': 231, 'learning_rate': 0.08725128122080628, 'feature_fraction': 0.9618837945289168, 'bagging_fraction': 0.8559730568546978, 'bagging_freq': 7, 'reg_alpha': 0.30219152964996165, 'reg_lambda': 0.2733892248138761}. Best is trial 13 with value: 1.1196681338957233.
# Training LightGBM: 100%|██████████| 10/10 [00:11<00:00,  1.16s/it]
# [I 2025-05-16 12:28:39,636] Trial 14 finished with value: 1.1624426296352328 and parameters: {'n_estimators': 456, 'max_depth': 12, 'num_leaves': 235, 'learning_rate': 0.03374130608469955, 'feature_fraction': 0.9196767063768957, 'bagging_fraction': 0.8274939139273366, 'bagging_freq': 7, 'reg_alpha': 0.3410311079582349, 'reg_lambda': 0.27242049725547174}. Best is trial 13 with value: 1.1196681338957233.
# Training LightGBM: 100%|██████████| 10/10 [00:07<00:00,  1.28it/s]
# [I 2025-05-16 12:28:47,470] Trial 15 finished with value: 1.1381396994427524 and parameters: {'n_estimators': 282, 'max_depth': 13, 'num_leaves': 235, 'learning_rate': 0.10107847623793803, 'feature_fraction': 0.9261998008448973, 'bagging_fraction': 0.9449234656790287, 'bagging_freq': 5, 'reg_alpha': 0.17877170357089636, 'reg_lambda': 0.25931895300021185}. Best is trial 13 with value: 1.1196681338957233.
# Training LightGBM: 100%|██████████| 10/10 [00:18<00:00,  1.80s/it]
# [I 2025-05-16 12:29:05,543] Trial 16 finished with value: 1.143543680673091 and parameters: {'n_estimators': 591, 'max_depth': 17, 'num_leaves': 227, 'learning_rate': 0.2820426782104896, 'feature_fraction': 0.7675704407402562, 'bagging_fraction': 0.9121539569696919, 'bagging_freq': 7, 'reg_alpha': 0.22593971318591033, 'reg_lambda': 0.3621219262195282}. Best is trial 13 with value: 1.1196681338957233.
# Training LightGBM: 100%|██████████| 10/10 [00:10<00:00,  1.01s/it]
# [I 2025-05-16 12:29:15,725] Trial 17 finished with value: 1.1757285221517624 and parameters: {'n_estimators': 282, 'max_depth': 15, 'num_leaves': 253, 'learning_rate': 0.03358815478164898, 'feature_fraction': 0.8791775983959309, 'bagging_fraction': 0.8183099262611421, 'bagging_freq': 5, 'reg_alpha': 0.6574302440134927, 'reg_lambda': 0.14022869146957698}. Best is trial 13 with value: 1.1196681338957233.
# Training LightGBM: 100%|██████████| 10/10 [00:16<00:00,  1.66s/it]
# [I 2025-05-16 12:29:32,376] Trial 18 finished with value: 1.121558253719626 and parameters: {'n_estimators': 464, 'max_depth': 18, 'num_leaves': 202, 'learning_rate': 0.09716002080601632, 'feature_fraction': 0.9508852781718051, 'bagging_fraction': 0.8256496193822107, 'bagging_freq': 5, 'reg_alpha': 0.8367160614345823, 'reg_lambda': 0.15310939404708995}. Best is trial 13 with value: 1.1196681338957233.
# Training LightGBM: 100%|██████████| 10/10 [00:08<00:00,  1.11it/s]
# [I 2025-05-16 12:29:41,411] Trial 19 finished with value: 1.1764842680443175 and parameters: {'n_estimators': 310, 'max_depth': 12, 'num_leaves': 139, 'learning_rate': 0.04251115871836491, 'feature_fraction': 0.9968649748123479, 'bagging_fraction': 0.9289658022979604, 'bagging_freq': 7, 'reg_alpha': 0.42936596424132056, 'reg_lambda': 0.3708807379677428}. Best is trial 13 with value: 1.1196681338957233.
# Training LightGBM: 100%|██████████| 10/10 [00:15<00:00,  1.54s/it]
# [I 2025-05-16 12:29:56,824] Trial 20 finished with value: 1.1195073873314194 and parameters: {'n_estimators': 440, 'max_depth': 18, 'num_leaves': 254, 'learning_rate': 0.0779392142213918, 'feature_fraction': 0.8793759969316225, 'bagging_fraction': 0.7346148675218056, 'bagging_freq': 5, 'reg_alpha': 0.20398829206790717, 'reg_lambda': 0.19792777169859332}. Best is trial 20 with value: 1.1195073873314194.
# Training LightGBM: 100%|██████████| 10/10 [00:15<00:00,  1.57s/it]
# [I 2025-05-16 12:30:12,567] Trial 21 finished with value: 1.1265380926956408 and parameters: {'n_estimators': 442, 'max_depth': 18, 'num_leaves': 218, 'learning_rate': 0.07363754938027729, 'feature_fraction': 0.8876370713160555, 'bagging_fraction': 0.7179074034058593, 'bagging_freq': 5, 'reg_alpha': 0.21867351311683503, 'reg_lambda': 0.19533841089429954}. Best is trial 20 with value: 1.1195073873314194.
# Training LightGBM: 100%|██████████| 10/10 [00:12<00:00,  1.29s/it]
# [I 2025-05-16 12:30:25,567] Trial 22 finished with value: 1.1785192114327914 and parameters: {'n_estimators': 337, 'max_depth': 16, 'num_leaves': 259, 'learning_rate': 0.024481740484648296, 'feature_fraction': 0.9526969958317288, 'bagging_fraction': 0.7834447751008475, 'bagging_freq': 6, 'reg_alpha': 0.14143967529569193, 'reg_lambda': 0.0810179684214809}. Best is trial 20 with value: 1.1195073873314194.
# Training LightGBM: 100%|██████████| 10/10 [00:15<00:00,  1.59s/it]
# [I 2025-05-16 12:30:41,542] Trial 23 finished with value: 1.1306954301392298 and parameters: {'n_estimators': 428, 'max_depth': 19, 'num_leaves': 260, 'learning_rate': 0.04883606438149708, 'feature_fraction': 0.8430666992773296, 'bagging_fraction': 0.8562195461126051, 'bagging_freq': 5, 'reg_alpha': 0.2633533795536004, 'reg_lambda': 0.31259194430916926}. Best is trial 20 with value: 1.1195073873314194.
# Training LightGBM: 100%|██████████| 10/10 [00:09<00:00,  1.02it/s]
# [I 2025-05-16 12:30:51,435] Trial 24 finished with value: 1.1316521057209907 and parameters: {'n_estimators': 356, 'max_depth': 14, 'num_leaves': 180, 'learning_rate': 0.11115061281510023, 'feature_fraction': 0.7845615689782443, 'bagging_fraction': 0.7305030067983858, 'bagging_freq': 7, 'reg_alpha': 0.11549936107076046, 'reg_lambda': 0.44219937396267056}. Best is trial 20 with value: 1.1195073873314194.
# Training LightGBM: 100%|██████████| 10/10 [00:16<00:00,  1.61s/it]
# [I 2025-05-16 12:31:07,605] Trial 25 finished with value: 1.121518494180823 and parameters: {'n_estimators': 476, 'max_depth': 17, 'num_leaves': 299, 'learning_rate': 0.07827951620496403, 'feature_fraction': 0.8975127989372562, 'bagging_fraction': 0.8031055589733662, 'bagging_freq': 6, 'reg_alpha': 0.4483812278990961, 'reg_lambda': 0.20038074831366223}. Best is trial 20 with value: 1.1195073873314194.
# Training LightGBM: 100%|██████████| 10/10 [00:21<00:00,  2.13s/it]
# [I 2025-05-16 12:31:28,996] Trial 26 finished with value: 1.1291579501182558 and parameters: {'n_estimators': 563, 'max_depth': 19, 'num_leaves': 208, 'learning_rate': 0.046531145904846506, 'feature_fraction': 0.9454172978570293, 'bagging_fraction': 0.6831314554333903, 'bagging_freq': 4, 'reg_alpha': 0.6048578218508448, 'reg_lambda': 0.0940418696853509}. Best is trial 20 with value: 1.1195073873314194.
# Training LightGBM: 100%|██████████| 10/10 [00:07<00:00,  1.30it/s]
# [I 2025-05-16 12:31:36,736] Trial 27 finished with value: 1.1295302433882275 and parameters: {'n_estimators': 225, 'max_depth': 16, 'num_leaves': 250, 'learning_rate': 0.20457746450814732, 'feature_fraction': 0.8642604459343887, 'bagging_fraction': 0.8547519201951169, 'bagging_freq': 6, 'reg_alpha': 0.3924045863924128, 'reg_lambda': 0.29614709565745506}. Best is trial 20 with value: 1.1195073873314194.
# Training LightGBM: 100%|██████████| 10/10 [00:09<00:00,  1.09it/s]
# [I 2025-05-16 12:31:45,939] Trial 28 finished with value: 1.124001858111511 and parameters: {'n_estimators': 415, 'max_depth': 11, 'num_leaves': 181, 'learning_rate': 0.13335739159881277, 'feature_fraction': 0.8091391791463634, 'bagging_fraction': 0.9004817828223862, 'bagging_freq': 7, 'reg_alpha': 0.2858180216861267, 'reg_lambda': 0.06480058643682345}. Best is trial 20 with value: 1.1195073873314194.
# Training LightGBM: 100%|██████████| 10/10 [00:22<00:00,  2.21s/it]
# [I 2025-05-16 12:32:08,128] Trial 29 finished with value: 1.1573791639903848 and parameters: {'n_estimators': 497, 'max_depth': 20, 'num_leaves': 271, 'learning_rate': 0.022681448562635265, 'feature_fraction': 0.9212481839996945, 'bagging_fraction': 0.9562100767930757, 'bagging_freq': 4, 'reg_alpha': 0.9898837050629333, 'reg_lambda': 0.1905308661217082}. Best is trial 20 with value: 1.1195073873314194.
# Best parameters for LightGBM: {'n_estimators': 440, 'max_depth': 18, 'num_leaves': 254, 'learning_rate': 0.0779392142213918, 'feature_fraction': 0.8793759969316225, 'bagging_fraction': 0.7346148675218056, 'bagging_freq': 5, 'reg_alpha': 0.20398829206790717, 'reg_lambda': 0.19792777169859332}
# Best mean MAE: 1.1195

# %%
import random

# 固定随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # for multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)  # 设置固定种子

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import GroupKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
import optuna
import numpy as np


class DNNWithSoftplus(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        act_fn = {
            'relu': nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh': nn.Tanh()
        }[activation]
        layers = []
        prev_dim = input_dim
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act_fn]
            prev_dim = h
        layers += [nn.Linear(prev_dim, 1)]
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        return F.softplus(self.net(x)).squeeze(-1)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
def train_dnn_with_optuna_pytorch(X, y, groups, device=device):
    def dnn_param_func(trial):
        return {
            'hidden_layer_sizes': trial.suggest_categorical(
                'hidden_layer_sizes', [(50,), (100,), (150,), (100, 50), (150, 100, 50)]
            ),
            'activation': trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh']),
            'alpha': trial.suggest_float('alpha', 1e-5, 1e-2, log=True),
            'learning_rate': trial.suggest_float('learning_rate_init', 1e-4, 1e-2, log=True),
            'optimizer': trial.suggest_categorical('solver', ['adam', 'sgd'])
        }

    def objective(trial):
        params = dnn_param_func(trial)
        model = DNNWithSoftplus(
            input_dim=X.shape[1],
            hidden_sizes=params['hidden_layer_sizes'],
            activation=params['activation']
        ).to(device)

        optimizer = {
            'adam': torch.optim.Adam,
            'sgd': torch.optim.SGD
        }[params['optimizer']](model.parameters(), lr=params['learning_rate'], weight_decay=params['alpha'])

        loss_fn = nn.MSELoss()
        gkf = GroupKFold(n_splits=10)
        fold_maes = []

        for train_idx, val_idx in gkf.split(X, y, groups=groups):
            X_train, y_train = X[train_idx], y[train_idx]
            X_val, y_val = X[val_idx], y[val_idx]

            scaler = StandardScaler()
            X_train = scaler.fit_transform(X_train)
            X_val = scaler.transform(X_val)

            train_ds = TensorDataset(torch.tensor(X_train).float(), torch.tensor(y_train).float())
            train_loader = DataLoader(train_ds, batch_size=256, shuffle=True)

            model.train()
            for epoch in range(100):
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    pred = model(xb)
                    loss = loss_fn(pred, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            with torch.no_grad():
                val_preds = model(torch.tensor(X_val).float().to(device)).cpu().numpy()
                mae = mean_absolute_error(y_val, val_preds)
                fold_maes.append(mae)

        return np.mean(fold_maes)

    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=30)
    print("\n✅ Best Parameters Found:")
    print(study.best_params)
    print(f"Mean MAE = {study.best_value:.4f}")
    return study.best_params


best_dnn_params = train_dnn_with_optuna_pytorch(X, y, groups)
# Out:
# [I 2025-05-16 12:55:47,981] A new study created in memory with name: no-name-3b6666f5-d9a3-42f8-adcb-d79c7994fa21
# [I 2025-05-16 12:56:57,677] Trial 0 finished with value: 1.0993823322545844 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'logistic', 'alpha': 8.282367194106422e-05, 'learning_rate_init': 0.008671806525474066, 'solver': 'adam'}. Best is trial 0 with value: 1.0993823322545844.
# [I 2025-05-16 12:58:25,061] Trial 1 finished with value: 1.1798123067393105 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 0.0011404078629711812, 'learning_rate_init': 0.00746513949228382, 'solver': 'adam'}. Best is trial 0 with value: 1.0993823322545844.
# [I 2025-05-16 12:59:33,534] Trial 2 finished with value: 0.9809252435734086 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'logistic', 'alpha': 0.00016578186839942585, 'learning_rate_init': 0.0011227697197882924, 'solver': 'sgd'}. Best is trial 2 with value: 0.9809252435734086.
# [I 2025-05-16 13:00:38,237] Trial 3 finished with value: 1.5264144983407302 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'alpha': 1.5384005718834545e-05, 'learning_rate_init': 0.0003571562670279468, 'solver': 'sgd'}. Best is trial 2 with value: 0.9809252435734086.
# [I 2025-05-16 13:01:59,362] Trial 4 finished with value: 0.7846742114564055 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'alpha': 7.76102035709291e-05, 'learning_rate_init': 0.0019612366913510466, 'solver': 'adam'}. Best is trial 4 with value: 0.7846742114564055.
# [I 2025-05-16 13:03:09,732] Trial 5 finished with value: 0.6735578638386872 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'alpha': 5.1270794458470204e-05, 'learning_rate_init': 0.0022127785834911077, 'solver': 'adam'}. Best is trial 5 with value: 0.6735578638386872.
# [I 2025-05-16 13:04:42,047] Trial 6 finished with value: 0.6424215575373123 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'alpha': 0.0009750595655958254, 'learning_rate_init': 0.0006455441746093966, 'solver': 'adam'}. Best is trial 6 with value: 0.6424215575373123.
# [I 2025-05-16 13:06:09,927] Trial 7 finished with value: 0.8639431414985044 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'alpha': 0.004287053791586331, 'learning_rate_init': 0.009229657877409033, 'solver': 'sgd'}. Best is trial 6 with value: 0.6424215575373123.
# [I 2025-05-16 13:07:48,749] Trial 8 finished with value: 0.6313499476851685 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'alpha': 0.0012530128008729994, 'learning_rate_init': 0.00032928245995991095, 'solver': 'adam'}. Best is trial 8 with value: 0.6313499476851685.
# [I 2025-05-16 13:09:11,492] Trial 9 finished with value: 0.49736569785222284 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'alpha': 3.53147454713421e-05, 'learning_rate_init': 0.00013682006215334585, 'solver': 'adam'}. Best is trial 9 with value: 0.49736569785222284.
# [I 2025-05-16 13:10:22,172] Trial 10 finished with value: 0.97266464544138 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'alpha': 1.423966562382814e-05, 'learning_rate_init': 0.00015880541740824212, 'solver': 'sgd'}. Best is trial 9 with value: 0.49736569785222284.
# [I 2025-05-16 13:11:43,525] Trial 11 finished with value: 0.6353939862321695 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'alpha': 0.0006455096198689392, 'learning_rate_init': 0.00010286572521981049, 'solver': 'adam'}. Best is trial 9 with value: 0.49736569785222284.
# [I 2025-05-16 13:13:16,518] Trial 12 finished with value: 0.7119353803620915 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'alpha': 0.005858241254026509, 'learning_rate_init': 0.0002650781408385612, 'solver': 'adam'}. Best is trial 9 with value: 0.49736569785222284.
# [I 2025-05-16 13:14:35,315] Trial 13 finished with value: 0.6366139098212918 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'alpha': 0.0022327010909738492, 'learning_rate_init': 0.0002666861696772779, 'solver': 'adam'}. Best is trial 9 with value: 0.49736569785222284.
# [I 2025-05-16 13:15:49,088] Trial 14 finished with value: 0.5700081478742015 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 0.00039927539762955557, 'learning_rate_init': 0.0005274540451425602, 'solver': 'adam'}. Best is trial 9 with value: 0.49736569785222284.
# [I 2025-05-16 13:17:12,278] Trial 15 finished with value: 0.5785733717260318 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 0.00025852667088407065, 'learning_rate_init': 0.0006930608320924718, 'solver': 'adam'}. Best is trial 9 with value: 0.49736569785222284.
# [I 2025-05-16 13:18:47,915] Trial 16 finished with value: 0.47481325989508977 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 3.034063696269033e-05, 'learning_rate_init': 0.00010173619659118546, 'solver': 'adam'}. Best is trial 16 with value: 0.47481325989508977.
# [I 2025-05-16 13:20:24,852] Trial 17 finished with value: 0.46410462843095013 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 3.2233316561842896e-05, 'learning_rate_init': 0.00010992962624169604, 'solver': 'adam'}. Best is trial 17 with value: 0.46410462843095013.
# [I 2025-05-16 13:21:49,560] Trial 18 finished with value: 1.117827477988654 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 2.4509945539185887e-05, 'learning_rate_init': 0.00016898297451064558, 'solver': 'sgd'}. Best is trial 17 with value: 0.46410462843095013.
# [I 2025-05-16 13:23:26,249] Trial 19 finished with value: 0.47511042835989975 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 0.00013149531500347984, 'learning_rate_init': 0.00011611889399445865, 'solver': 'adam'}. Best is trial 17 with value: 0.46410462843095013.
# [I 2025-05-16 13:24:39,424] Trial 20 finished with value: 0.4304470028944471 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 1.1091144107568942e-05, 'learning_rate_init': 0.00020716944733509428, 'solver': 'adam'}. Best is trial 20 with value: 0.4304470028944471.
# [I 2025-05-16 13:25:50,073] Trial 21 finished with value: 0.43602511806177047 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 1.09394045591328e-05, 'learning_rate_init': 0.00020361589929833766, 'solver': 'adam'}. Best is trial 20 with value: 0.4304470028944471.
# [I 2025-05-16 13:27:05,422] Trial 22 finished with value: 0.4249904687936265 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 1.1440401458927014e-05, 'learning_rate_init': 0.00021994410801664909, 'solver': 'adam'}. Best is trial 22 with value: 0.4249904687936265.
# [I 2025-05-16 13:28:29,324] Trial 23 finished with value: 0.4370816268496188 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 1.039872290787192e-05, 'learning_rate_init': 0.000208548701143295, 'solver': 'adam'}. Best is trial 22 with value: 0.4249904687936265.
# [I 2025-05-16 13:29:39,664] Trial 24 finished with value: 0.44064691473415146 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 1.904461243755943e-05, 'learning_rate_init': 0.00041467124910012706, 'solver': 'adam'}. Best is trial 22 with value: 0.4249904687936265.
# [I 2025-05-16 13:31:06,878] Trial 25 finished with value: 0.4800498158454283 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 1.0779350587959278e-05, 'learning_rate_init': 0.0010768997299232853, 'solver': 'adam'}. Best is trial 22 with value: 0.4249904687936265.
# [I 2025-05-16 13:32:28,270] Trial 26 finished with value: 0.9013352752184511 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'relu', 'alpha': 5.553540876446828e-05, 'learning_rate_init': 0.00021400424585982683, 'solver': 'sgd'}. Best is trial 22 with value: 0.4249904687936265.
# [I 2025-05-16 13:33:36,717] Trial 27 finished with value: 0.4338046073433575 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 1.9000891653603953e-05, 'learning_rate_init': 0.0004523218930813568, 'solver': 'adam'}. Best is trial 22 with value: 0.4249904687936265.
# [I 2025-05-16 13:34:43,869] Trial 28 finished with value: 0.5044017225451718 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'alpha': 2.0770281376742797e-05, 'learning_rate_init': 0.0004958420056863984, 'solver': 'adam'}. Best is trial 22 with value: 0.4249904687936265.
# [I 2025-05-16 13:35:46,182] Trial 29 finished with value: 0.5462004133161744 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'alpha': 0.00010983629383596557, 'learning_rate_init': 0.0007369924499313356, 'solver': 'adam'}. Best is trial 22 with value: 0.4249904687936265.
# ✅ Best Parameters Found:
# {'hidden_layer_sizes': (150, 100, 50), 'activation': 'relu', 'alpha': 1.1440401458927014e-05, 'learning_rate_init': 0.00021994410801664909, 'solver': 'adam'}
# Mean MAE = 0.4250
