# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import optuna
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# ----------------- CONFIGURATION -----------------
n_folds    = 10
n_trials   = 30
data_dir   = "./k_folds_model/embeddings"
batch_size = 256
num_epochs = 200
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------- MODEL DEFINITION -----------------
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        layers = []
        prev_dim = input_dim
        act = {
            'relu':     nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh':     nn.Tanh()
        }[activation]
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act]
            prev_dim = h
        layers.append(nn.Linear(prev_dim, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = self.net(x).squeeze(-1)
        return F.softplus(x)  # 输出 > 0

# ----------------- OPTUNA OBJECTIVE -----------------
def objective(trial):
    hidden_sizes      = trial.suggest_categorical('hidden_layer_sizes',
                            [(50,), (100,), (150,), (100, 50), (150, 100, 50)])
    activation        = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh'])
    lr                = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    weight_decay      = trial.suggest_float('alpha', 1e-5, 1e-2, log=True)
    optimizer_choice  = trial.suggest_categorical('optimizer', ['sgd', 'adam'])

    fold_maes = []

    for fold in range(1, n_folds + 1):
        X_train = np.load(f"{data_dir}/train_fold_{fold}.npy")
        y_train = np.load(f"{data_dir}/train_labels_fold_{fold}.npy")
        X_val   = np.load(f"{data_dir}/val_fold_{fold}.npy")
        y_val   = np.load(f"{data_dir}/val_labels_fold_{fold}.npy")

        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val   = scaler.transform(X_val)

        train_ds = TensorDataset(torch.from_numpy(X_train).float(),
                                 torch.from_numpy(y_train).float())
        val_ds = TensorDataset(torch.from_numpy(X_val).float(),
                               torch.from_numpy(y_val).float())
        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        model = MLP(input_dim=X_train.shape[1],
                    hidden_sizes=hidden_sizes,
                    activation=activation).to(device)
        criterion = nn.MSELoss()
        optimizer = {
            'sgd': torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay),
            'adam': torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        }[optimizer_choice]

        try:
            for epoch in range(num_epochs):
                model.train()
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    preds = model(xb)
                    loss = criterion(preds, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            all_preds = []
            with torch.no_grad():
                for xb, _ in val_loader:
                    xb = xb.to(device)
                    batch_pred = model(xb).cpu().numpy()
                    all_preds.append(batch_pred)
            all_preds = np.concatenate(all_preds)

            mae = mean_absolute_error(y_val, all_preds)
            fold_maes.append(mae)

        except Exception:
            return np.inf

    return float(np.mean(fold_maes))

# ----------------- RUN OPTUNA -----------------
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)

    print("\n=== Best Hyperparameters ===")
    print(study.best_params)
    print(f"Best Mean MAE: {study.best_value:.4f}")
# Out:
# [I 2025-05-16 08:07:36,918] A new study created in memory with name: no-name-f22f966a-4dcd-4c85-8d4d-79b7c37cd895
# [I 2025-05-16 08:09:58,473] Trial 0 finished with value: 0.6895575523376465 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.0015930522616241021, 'alpha': 0.001331121608073689, 'optimizer': 'adam'}. Best is trial 0 with value: 0.6895575523376465.
# [I 2025-05-16 08:11:34,385] Trial 1 finished with value: 0.6854884624481201 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0016738085788752138, 'alpha': 2.621087878265438e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.6854884624481201.
# [I 2025-05-16 08:13:21,861] Trial 2 finished with value: 0.7344767451286316 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00013492834268013249, 'alpha': 0.007025166339242158, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.6854884624481201.
# [I 2025-05-16 08:15:35,124] Trial 3 finished with value: 0.672917902469635 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00032927591344236165, 'alpha': 0.0009717775305059633, 'optimizer': 'adam'}. Best is trial 3 with value: 0.672917902469635.
# [I 2025-05-16 08:17:18,744] Trial 4 finished with value: 0.6701499223709106 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00015030900645056822, 'alpha': 3.872118032174584e-05, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:18:47,160] Trial 5 finished with value: 0.7383740544319153 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00014096175149815865, 'alpha': 0.009133995846860976, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:20:21,365] Trial 6 finished with value: 0.6979774832725525 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.005323617594751502, 'alpha': 0.0007411299781083245, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:22:25,024] Trial 7 finished with value: 0.6797013282775879 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0033233042062267943, 'alpha': 0.00048287152161792117, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:24:24,441] Trial 8 finished with value: 0.6953338980674744 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.006533305220227739, 'alpha': 5.59598687800608e-05, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:26:06,601] Trial 9 finished with value: 0.6805127859115601 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.004048966222584676, 'alpha': 3.6283583803549155e-05, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:28:18,215] Trial 10 finished with value: 0.6799924969673157 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0004216644107007115, 'alpha': 0.00012956995794619435, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:30:10,736] Trial 11 finished with value: 0.6772629618644714 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0003921612135270866, 'alpha': 0.00016477670830228577, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:31:47,879] Trial 12 finished with value: 0.681771457195282 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00037299981541424096, 'alpha': 0.00218443395970587, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:33:37,577] Trial 13 finished with value: 0.6794682741165161 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0002291862656839158, 'alpha': 1.1323186753878092e-05, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:35:13,916] Trial 14 finished with value: 0.6799794435501099 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0007740967355271402, 'alpha': 0.00021409663159050845, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:37:00,590] Trial 15 finished with value: 0.6911064386367798 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.0001061391643892118, 'alpha': 0.0023614425795649282, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:38:54,774] Trial 16 finished with value: 0.6792393326759338 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00023422604938330685, 'alpha': 8.797157896538147e-05, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:40:57,190] Trial 17 finished with value: 0.6835445165634155 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0008945789712170808, 'alpha': 1.221454305162071e-05, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:42:45,679] Trial 18 finished with value: 0.6916700005531311 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.0002391867282241365, 'alpha': 0.00037648340635481063, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:44:39,492] Trial 19 finished with value: 0.6906432509422302 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.00018585501361966027, 'alpha': 0.0009717427194116951, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:46:27,635] Trial 20 finished with value: 0.6933823823928833 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0006184571342778895, 'alpha': 0.004438217512617065, 'optimizer': 'adam'}. Best is trial 4 with value: 0.6701499223709106.
# [I 2025-05-16 08:48:32,315] Trial 21 finished with value: 0.6672791242599487 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00039250682337108603, 'alpha': 0.0001715124493238906, 'optimizer': 'adam'}. Best is trial 21 with value: 0.6672791242599487.
# [I 2025-05-16 08:50:50,176] Trial 22 finished with value: 0.6795625686645508 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0005209314402340293, 'alpha': 7.469274905956518e-05, 'optimizer': 'adam'}. Best is trial 21 with value: 0.6672791242599487.
# [I 2025-05-16 08:52:48,824] Trial 23 finished with value: 0.6785510778427124 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00030928932018647176, 'alpha': 0.00029564519165168734, 'optimizer': 'adam'}. Best is trial 21 with value: 0.6672791242599487.
# [I 2025-05-16 08:54:43,372] Trial 24 finished with value: 0.6946031451225281 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0012613926022904235, 'alpha': 2.379649787820624e-05, 'optimizer': 'adam'}. Best is trial 21 with value: 0.6672791242599487.
# [I 2025-05-16 08:56:31,231] Trial 25 finished with value: 0.6719857454299927 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'learning_rate': 0.00015715949669096267, 'alpha': 0.0006407085145395013, 'optimizer': 'adam'}. Best is trial 21 with value: 0.6672791242599487.
# [I 2025-05-16 08:58:12,518] Trial 26 finished with value: 0.6664785146713257 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'learning_rate': 0.0001049591144275673, 'alpha': 0.00012119676285622187, 'optimizer': 'adam'}. Best is trial 26 with value: 0.6664785146713257.
# [I 2025-05-16 09:00:09,173] Trial 27 finished with value: 0.7503091096878052 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'learning_rate': 0.00010710199777166222, 'alpha': 0.00011641927459300012, 'optimizer': 'sgd'}. Best is trial 26 with value: 0.6664785146713257.
# [I 2025-05-16 09:02:03,014] Trial 28 finished with value: 0.8709076046943665 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.009827674611457334, 'alpha': 4.973304162616186e-05, 'optimizer': 'adam'}. Best is trial 26 with value: 0.6664785146713257.
# [I 2025-05-16 09:03:51,670] Trial 29 finished with value: 0.6733115315437317 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00019112746253510077, 'alpha': 0.00021837166651839308, 'optimizer': 'adam'}. Best is trial 26 with value: 0.6664785146713257.
# === Best Hyperparameters ===
# {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'learning_rate': 0.0001049591144275673, 'alpha': 0.00012119676285622187, 'optimizer': 'adam'}
# Best Mean MAE: 0.6665

# %%
import os
import optuna
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    # 采样超参数
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        model = XGBRegressor(n_jobs=-1, verbosity=0, **params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 以 MAE 为优化目标


# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best XGBoost Hyperparameters via Optuna ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 15:26:41,420] A new study created in memory with name: no-name-92778970-6ba8-4a55-9244-d9593f6d6ecb
# [I 2025-05-16 15:28:26,933] Trial 0 finished with value: 0.7731354832649231 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 8, 'subsample': 0.8795975452591109, 'colsample_bytree': 0.6624074561769746}. Best is trial 0 with value: 0.7731354832649231.
# [I 2025-05-16 15:29:57,741] Trial 1 finished with value: 0.7332432270050049 and parameters: {'n_estimators': 200, 'learning_rate': 0.011900590783184251, 'max_depth': 9, 'subsample': 0.8803345035229626, 'colsample_bytree': 0.8832290311184181}. Best is trial 1 with value: 0.7332432270050049.
# [I 2025-05-16 15:30:27,447] Trial 2 finished with value: 0.731562077999115 and parameters: {'n_estimators': 100, 'learning_rate': 0.18276027831785724, 'max_depth': 8, 'subsample': 0.7637017332034828, 'colsample_bytree': 0.6727299868828402}. Best is trial 2 with value: 0.731562077999115.
# [I 2025-05-16 15:31:12,471] Trial 3 finished with value: 0.6882110834121704 and parameters: {'n_estimators': 200, 'learning_rate': 0.024878734419814436, 'max_depth': 6, 'subsample': 0.8295835055926347, 'colsample_bytree': 0.7164916560792167}. Best is trial 3 with value: 0.6882110834121704.
# [I 2025-05-16 15:33:08,926] Trial 4 finished with value: 0.6868414878845215 and parameters: {'n_estimators': 700, 'learning_rate': 0.01518747922672247, 'max_depth': 5, 'subsample': 0.8099085529881075, 'colsample_bytree': 0.7824279936868144}. Best is trial 4 with value: 0.6868414878845215.
# [I 2025-05-16 15:35:41,283] Trial 5 finished with value: 0.6957933902740479 and parameters: {'n_estimators': 800, 'learning_rate': 0.018187859051288217, 'max_depth': 6, 'subsample': 0.8777243706586128, 'colsample_bytree': 0.6185801650879991}. Best is trial 4 with value: 0.6868414878845215.
# [I 2025-05-16 15:36:48,076] Trial 6 finished with value: 0.6835647821426392 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'subsample': 0.984665661176, 'colsample_bytree': 0.9862528132298237}. Best is trial 6 with value: 0.6835647821426392.
# [I 2025-05-16 15:38:09,276] Trial 7 finished with value: 0.6833667755126953 and parameters: {'n_estimators': 900, 'learning_rate': 0.0249064396938244, 'max_depth': 3, 'subsample': 0.905269907953647, 'colsample_bytree': 0.7760609974958406}. Best is trial 7 with value: 0.6833667755126953.
# [I 2025-05-16 15:38:28,339] Trial 8 finished with value: 0.6815217733383179 and parameters: {'n_estimators': 200, 'learning_rate': 0.04407984038169244, 'max_depth': 3, 'subsample': 0.9727961206236346, 'colsample_bytree': 0.7035119926400067}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:40:42,749] Trial 9 finished with value: 0.7018848657608032 and parameters: {'n_estimators': 700, 'learning_rate': 0.02544166090938368, 'max_depth': 6, 'subsample': 0.8640130838029838, 'colsample_bytree': 0.6739417822102108}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:41:32,621] Trial 10 finished with value: 0.6971647143363953 and parameters: {'n_estimators': 400, 'learning_rate': 0.08074732196639918, 'max_depth': 4, 'subsample': 0.9864906201399816, 'colsample_bytree': 0.8607466203112714}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:42:59,838] Trial 11 finished with value: 0.6920010447502136 and parameters: {'n_estimators': 1000, 'learning_rate': 0.048698259817030486, 'max_depth': 3, 'subsample': 0.935088886344705, 'colsample_bytree': 0.7719426734862375}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:44:59,421] Trial 12 finished with value: 0.6999619007110596 and parameters: {'n_estimators': 1000, 'learning_rate': 0.0519552893200751, 'max_depth': 4, 'subsample': 0.9376905650203332, 'colsample_bytree': 0.742869807831149}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:46:02,056] Trial 13 finished with value: 0.6968749761581421 and parameters: {'n_estimators': 500, 'learning_rate': 0.07938351763081361, 'max_depth': 4, 'subsample': 0.9338716506768701, 'colsample_bytree': 0.8400926519321323}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:47:25,629] Trial 14 finished with value: 0.6870108842849731 and parameters: {'n_estimators': 900, 'learning_rate': 0.03360385287840602, 'max_depth': 3, 'subsample': 0.725910676545781, 'colsample_bytree': 0.9221007674655294}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:48:46,573] Trial 15 finished with value: 0.7024780511856079 and parameters: {'n_estimators': 500, 'learning_rate': 0.06448860406064431, 'max_depth': 5, 'subsample': 0.9175232146683694, 'colsample_bytree': 0.8059881656083773}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:49:36,548] Trial 16 finished with value: 0.6895797252655029 and parameters: {'n_estimators': 300, 'learning_rate': 0.03366244516368652, 'max_depth': 5, 'subsample': 0.9978528836500535, 'colsample_bytree': 0.7248939743688465}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:50:28,536] Trial 17 finished with value: 0.6977010369300842 and parameters: {'n_estimators': 600, 'learning_rate': 0.10940376820215537, 'max_depth': 3, 'subsample': 0.9581365573150018, 'colsample_bytree': 0.601881501439665}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:50:44,007] Trial 18 finished with value: 0.705299973487854 and parameters: {'n_estimators': 100, 'learning_rate': 0.02719749706255682, 'max_depth': 4, 'subsample': 0.9067467468954586, 'colsample_bytree': 0.8075353388093552}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:53:02,570] Trial 19 finished with value: 0.7005540132522583 and parameters: {'n_estimators': 900, 'learning_rate': 0.037230277516869525, 'max_depth': 5, 'subsample': 0.9615787675437196, 'colsample_bytree': 0.7073913788469822}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:54:20,751] Trial 20 finished with value: 0.6954544186592102 and parameters: {'n_estimators': 300, 'learning_rate': 0.021305427616008968, 'max_depth': 7, 'subsample': 0.7930203791848457, 'colsample_bytree': 0.7636296878541365}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:55:29,930] Trial 21 finished with value: 0.6823083162307739 and parameters: {'n_estimators': 700, 'learning_rate': 0.010404306227829146, 'max_depth': 3, 'subsample': 0.9743300314096723, 'colsample_bytree': 0.9787219705654253}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:56:47,502] Trial 22 finished with value: 0.6821367144584656 and parameters: {'n_estimators': 800, 'learning_rate': 0.01028965831288887, 'max_depth': 3, 'subsample': 0.9614648665877208, 'colsample_bytree': 0.9482512004607759}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:58:09,305] Trial 23 finished with value: 0.6849350929260254 and parameters: {'n_estimators': 600, 'learning_rate': 0.013281475735279581, 'max_depth': 4, 'subsample': 0.9687201381729933, 'colsample_bytree': 0.9863149509456302}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 15:59:27,151] Trial 24 finished with value: 0.6817612051963806 and parameters: {'n_estimators': 800, 'learning_rate': 0.010424717239281397, 'max_depth': 3, 'subsample': 0.9545031951339454, 'colsample_bytree': 0.9358838399279698}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 16:01:16,165] Trial 25 finished with value: 0.6845257878303528 and parameters: {'n_estimators': 800, 'learning_rate': 0.01015052768663657, 'max_depth': 4, 'subsample': 0.9456270514246387, 'colsample_bytree': 0.9250296527387504}. Best is trial 8 with value: 0.6815217733383179.
# [I 2025-05-16 16:02:33,440] Trial 26 finished with value: 0.6813738942146301 and parameters: {'n_estimators': 800, 'learning_rate': 0.013184384270236356, 'max_depth': 3, 'subsample': 0.9151113240783383, 'colsample_bytree': 0.9433652849644489}. Best is trial 26 with value: 0.6813738942146301.
# [I 2025-05-16 16:04:14,182] Trial 27 finished with value: 0.7248024940490723 and parameters: {'n_estimators': 800, 'learning_rate': 0.11947803304250912, 'max_depth': 4, 'subsample': 0.9165035907402707, 'colsample_bytree': 0.9023547469765345}. Best is trial 26 with value: 0.6813738942146301.
# [I 2025-05-16 16:05:13,068] Trial 28 finished with value: 0.6813879013061523 and parameters: {'n_estimators': 600, 'learning_rate': 0.01349471123902621, 'max_depth': 3, 'subsample': 0.901604050473405, 'colsample_bytree': 0.9514572844050104}. Best is trial 26 with value: 0.6813738942146301.
# [I 2025-05-16 16:06:19,043] Trial 29 finished with value: 0.7251949310302734 and parameters: {'n_estimators': 400, 'learning_rate': 0.13390499764355235, 'max_depth': 5, 'subsample': 0.8414970095264982, 'colsample_bytree': 0.8376435990713395}. Best is trial 26 with value: 0.6813738942146301.
# === Best XGBoost Hyperparameters via Optuna ===
# {'n_estimators': 800, 'learning_rate': 0.013184384270236356, 'max_depth': 3, 'subsample': 0.9151113240783383, 'colsample_bytree': 0.9433652849644489}
# 10-Fold Mean MAE = 0.6814

# %%
import os
import optuna
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'objective': 'poisson',         # ✅ 强制正输出
        'n_jobs': -1,
        'verbose': -1
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        # Poisson 回归要求标签必须大于 0
        if np.any(y_train <= 0) or np.any(y_val <= 0):
            return np.inf

        model = LGBMRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 使用 MAE 作为优化目标

# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 16:06:19,243] A new study created in memory with name: no-name-90e57101-b95d-4808-a9a8-1b5cdcd6102d
# [I 2025-05-16 16:06:39,982] Trial 0 finished with value: 0.7014189633199182 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 10, 'num_leaves': 68, 'feature_fraction': 0.6624074561769746, 'bagging_fraction': 0.662397808134481}. Best is trial 0 with value: 0.7014189633199182.
# [I 2025-05-16 16:06:49,118] Trial 1 finished with value: 0.6896488861879095 and parameters: {'n_estimators': 100, 'learning_rate': 0.13394334706750485, 'max_depth': 9, 'num_leaves': 77, 'feature_fraction': 0.608233797718321, 'bagging_fraction': 0.9879639408647978}. Best is trial 1 with value: 0.6896488861879095.
# [I 2025-05-16 16:07:10,749] Trial 2 finished with value: 0.6830772618527269 and parameters: {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:07:38,037] Trial 3 finished with value: 0.6850004940403795 and parameters: {'n_estimators': 500, 'learning_rate': 0.023927528765580644, 'max_depth': 9, 'num_leaves': 31, 'feature_fraction': 0.7168578594140873, 'bagging_fraction': 0.7465447373174767}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:07:50,810] Trial 4 finished with value: 0.6848964435696334 and parameters: {'n_estimators': 500, 'learning_rate': 0.10508421338691762, 'max_depth': 4, 'num_leaves': 61, 'feature_fraction': 0.836965827544817, 'bagging_fraction': 0.6185801650879991}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:08:09,530] Trial 5 finished with value: 0.6850368236199523 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'num_leaves': 96, 'feature_fraction': 0.9862528132298237, 'bagging_fraction': 0.9233589392465844}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:08:40,614] Trial 6 finished with value: 0.711816529723375 and parameters: {'n_estimators': 400, 'learning_rate': 0.013399060561509796, 'max_depth': 9, 'num_leaves': 55, 'feature_fraction': 0.6488152939379115, 'bagging_fraction': 0.798070764044508}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:08:46,221] Trial 7 finished with value: 0.6835726930699723 and parameters: {'n_estimators': 100, 'learning_rate': 0.15242391728466367, 'max_depth': 5, 'num_leaves': 73, 'feature_fraction': 0.7246844304357644, 'bagging_fraction': 0.8080272084711243}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:09:53,555] Trial 8 finished with value: 0.692305414937282 and parameters: {'n_estimators': 600, 'learning_rate': 0.017398074711291726, 'max_depth': 12, 'num_leaves': 82, 'feature_fraction': 0.9757995766256756, 'bagging_fraction': 0.9579309401710595}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:10:03,665] Trial 9 finished with value: 0.6853638793099227 and parameters: {'n_estimators': 600, 'learning_rate': 0.15826541904647565, 'max_depth': 3, 'num_leaves': 35, 'feature_fraction': 0.6180909155642152, 'bagging_fraction': 0.7301321323053057}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:10:36,962] Trial 10 finished with value: 0.6870705448096179 and parameters: {'n_estimators': 1000, 'learning_rate': 0.041286972973122775, 'max_depth': 6, 'num_leaves': 21, 'feature_fraction': 0.8423486893732017, 'bagging_fraction': 0.876098829427658}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:11:08,123] Trial 11 finished with value: 0.6934076983492241 and parameters: {'n_estimators': 1000, 'learning_rate': 0.06761147179060022, 'max_depth': 6, 'num_leaves': 48, 'feature_fraction': 0.759327832364161, 'bagging_fraction': 0.8469817891972083}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:11:14,588] Trial 12 finished with value: 0.7687343265706731 and parameters: {'n_estimators': 100, 'learning_rate': 0.03448509229937973, 'max_depth': 5, 'num_leaves': 45, 'feature_fraction': 0.7389917503278137, 'bagging_fraction': 0.7957386374412774}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:11:46,612] Trial 13 finished with value: 0.692040919084741 and parameters: {'n_estimators': 800, 'learning_rate': 0.06922749265952521, 'max_depth': 7, 'num_leaves': 91, 'feature_fraction': 0.7874820875551369, 'bagging_fraction': 0.8630011610888938}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:11:57,736] Trial 14 finished with value: 0.8732381971426678 and parameters: {'n_estimators': 200, 'learning_rate': 0.011058500546306225, 'max_depth': 5, 'num_leaves': 72, 'feature_fraction': 0.6975499843454273, 'bagging_fraction': 0.727828023050229}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:12:17,102] Trial 15 finished with value: 0.6843600354270006 and parameters: {'n_estimators': 800, 'learning_rate': 0.06294173699450725, 'max_depth': 4, 'num_leaves': 39, 'feature_fraction': 0.8762695696311745, 'bagging_fraction': 0.8108076649175742}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:12:39,338] Trial 16 finished with value: 0.6898362460448767 and parameters: {'n_estimators': 300, 'learning_rate': 0.02981229465853, 'max_depth': 7, 'num_leaves': 58, 'feature_fraction': 0.9110846414027765, 'bagging_fraction': 0.9006453699263156}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:13:00,807] Trial 17 finished with value: 0.6914997420350313 and parameters: {'n_estimators': 900, 'learning_rate': 0.09514304141838337, 'max_depth': 5, 'num_leaves': 85, 'feature_fraction': 0.6772876502180768, 'bagging_fraction': 0.765354826674926}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:13:12,517] Trial 18 finished with value: 0.6969965324036952 and parameters: {'n_estimators': 300, 'learning_rate': 0.02154636144117931, 'max_depth': 4, 'num_leaves': 65, 'feature_fraction': 0.7839069453230693, 'bagging_fraction': 0.6735390759594541}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:13:34,908] Trial 19 finished with value: 0.6857272492466039 and parameters: {'n_estimators': 700, 'learning_rate': 0.049212596873501845, 'max_depth': 6, 'num_leaves': 22, 'feature_fraction': 0.737415887737509, 'bagging_fraction': 0.8307796695558712}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:13:51,711] Trial 20 finished with value: 0.6859507321363205 and parameters: {'n_estimators': 900, 'learning_rate': 0.11178113803323297, 'max_depth': 3, 'num_leaves': 51, 'feature_fraction': 0.8343872902276027, 'bagging_fraction': 0.690165187143056}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:14:11,721] Trial 21 finished with value: 0.6850427307173649 and parameters: {'n_estimators': 800, 'learning_rate': 0.06263810774520157, 'max_depth': 4, 'num_leaves': 38, 'feature_fraction': 0.9020304440769008, 'bagging_fraction': 0.8158052480744893}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:14:30,419] Trial 22 finished with value: 0.6844680980041622 and parameters: {'n_estimators': 800, 'learning_rate': 0.05125992204198718, 'max_depth': 4, 'num_leaves': 42, 'feature_fraction': 0.8825732469471799, 'bagging_fraction': 0.7846381375593074}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:14:56,567] Trial 23 finished with value: 0.6891969934368736 and parameters: {'n_estimators': 900, 'learning_rate': 0.08332176484668552, 'max_depth': 5, 'num_leaves': 31, 'feature_fraction': 0.9298528902087924, 'bagging_fraction': 0.8380352701884155}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:15:10,931] Trial 24 finished with value: 0.6836680104266882 and parameters: {'n_estimators': 700, 'learning_rate': 0.027764645298449128, 'max_depth': 3, 'num_leaves': 30, 'feature_fraction': 0.7993215917523222, 'bagging_fraction': 0.8846184628590349}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:15:24,787] Trial 25 finished with value: 0.6837225581491316 and parameters: {'n_estimators': 700, 'learning_rate': 0.027262325889749413, 'max_depth': 3, 'num_leaves': 28, 'feature_fraction': 0.8069410260856267, 'bagging_fraction': 0.9042951998595478}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:15:37,794] Trial 26 finished with value: 0.6849124895678049 and parameters: {'n_estimators': 600, 'learning_rate': 0.019645011574718107, 'max_depth': 3, 'num_leaves': 74, 'feature_fraction': 0.7564694463752024, 'bagging_fraction': 0.8823899804367765}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:16:09,899] Trial 27 finished with value: 0.6869379087855406 and parameters: {'n_estimators': 1000, 'learning_rate': 0.036258497076636594, 'max_depth': 6, 'num_leaves': 52, 'feature_fraction': 0.7007255581888321, 'bagging_fraction': 0.9287211378997813}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:16:44,560] Trial 28 finished with value: 0.6863736202108123 and parameters: {'n_estimators': 700, 'learning_rate': 0.01330818186648299, 'max_depth': 8, 'num_leaves': 25, 'feature_fraction': 0.8045226994370361, 'bagging_fraction': 0.7585221448939756}. Best is trial 2 with value: 0.6830772618527269.
# [I 2025-05-16 16:17:08,110] Trial 29 finished with value: 0.7034452690642187 and parameters: {'n_estimators': 400, 'learning_rate': 0.19848978742652873, 'max_depth': 12, 'num_leaves': 67, 'feature_fraction': 0.6424419696832592, 'bagging_fraction': 0.7094289115145793}. Best is trial 2 with value: 0.6830772618527269.
# === Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===
# {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}
# 10-Fold Mean MAE = 0.6831
