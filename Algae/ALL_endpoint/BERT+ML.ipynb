# %%
import warnings
from rdkit import RDLogger

# 屏蔽 RDKit 警告
RDLogger.DisableLog('rdApp.*')

# 或屏蔽所有 Python 警告
warnings.filterwarnings("ignore")
# 屏蔽 LightGBM 警告
warnings.filterwarnings("ignore", category=UserWarning, module="lightgbm")

# %%
import random

# 固定随机种子
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)  # for multi-GPU
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(42)  # 设置固定种子

# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader
import optuna
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# ----------------- CONFIGURATION -----------------
n_folds    = 10
n_trials   = 30
data_dir   = "./k_folds_model/embeddings"
batch_size = 256
num_epochs = 200
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ----------------- MODEL DEFINITION -----------------
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_sizes, activation):
        super().__init__()
        layers = []
        prev_dim = input_dim
        act = {
            'relu':     nn.ReLU(),
            'logistic': nn.Sigmoid(),
            'tanh':     nn.Tanh()
        }[activation]
        for h in hidden_sizes:
            layers += [nn.Linear(prev_dim, h), act]
            prev_dim = h
        layers.append(nn.Linear(prev_dim, 1))
        self.net = nn.Sequential(*layers)

    def forward(self, x):
        x = self.net(x).squeeze(-1)
        return F.softplus(x)  # 输出 > 0

# ----------------- OPTUNA OBJECTIVE -----------------
def objective(trial):
    hidden_sizes      = trial.suggest_categorical('hidden_layer_sizes',
                            [(50,), (100,), (150,), (100, 50), (150, 100, 50)])
    activation        = trial.suggest_categorical('activation', ['relu', 'logistic', 'tanh'])
    lr                = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    weight_decay      = trial.suggest_float('alpha', 1e-5, 1e-2, log=True)
    optimizer_choice  = trial.suggest_categorical('optimizer', ['sgd', 'adam'])

    fold_maes = []

    for fold in range(1, n_folds + 1):
        X_train = np.load(f"{data_dir}/train_fold_{fold}.npy")
        y_train = np.load(f"{data_dir}/train_labels_fold_{fold}.npy")
        X_val   = np.load(f"{data_dir}/val_fold_{fold}.npy")
        y_val   = np.load(f"{data_dir}/val_labels_fold_{fold}.npy")

        scaler = StandardScaler()
        X_train = scaler.fit_transform(X_train)
        X_val   = scaler.transform(X_val)

        train_ds = TensorDataset(torch.from_numpy(X_train).float(),
                                 torch.from_numpy(y_train).float())
        val_ds = TensorDataset(torch.from_numpy(X_val).float(),
                               torch.from_numpy(y_val).float())
        train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
        val_loader   = DataLoader(val_ds, batch_size=batch_size, shuffle=False)

        model = MLP(input_dim=X_train.shape[1],
                    hidden_sizes=hidden_sizes,
                    activation=activation).to(device)
        criterion = nn.MSELoss()
        optimizer = {
            'sgd': torch.optim.SGD(model.parameters(), lr=lr, weight_decay=weight_decay),
            'adam': torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        }[optimizer_choice]

        try:
            for epoch in range(num_epochs):
                model.train()
                for xb, yb in train_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    optimizer.zero_grad()
                    preds = model(xb)
                    loss = criterion(preds, yb)
                    loss.backward()
                    optimizer.step()

            model.eval()
            all_preds = []
            with torch.no_grad():
                for xb, _ in val_loader:
                    xb = xb.to(device)
                    batch_pred = model(xb).cpu().numpy()
                    all_preds.append(batch_pred)
            all_preds = np.concatenate(all_preds)

            mae = mean_absolute_error(y_val, all_preds)
            fold_maes.append(mae)

        except Exception:
            return np.inf

    return float(np.mean(fold_maes))

# ----------------- RUN OPTUNA -----------------
if __name__ == "__main__":
    study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
    study.optimize(objective, n_trials=n_trials)

    print("\n=== Best Hyperparameters ===")
    print(study.best_params)
    print(f"Best Mean MAE: {study.best_value:.4f}")
# Out:
# [I 2025-05-16 10:03:36,747] A new study created in memory with name: no-name-751d5936-ec0a-4542-a7da-86bddc81a9fd
# [I 2025-05-16 10:08:12,175] Trial 0 finished with value: 0.8136321306228638 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'tanh', 'learning_rate': 0.0015930522616241021, 'alpha': 0.001331121608073689, 'optimizer': 'adam'}. Best is trial 0 with value: 0.8136321306228638.
# [I 2025-05-16 10:13:24,877] Trial 1 finished with value: 0.8044773936271667 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.0016738085788752138, 'alpha': 2.621087878265438e-05, 'optimizer': 'adam'}. Best is trial 1 with value: 0.8044773936271667.
# [I 2025-05-16 10:17:09,165] Trial 2 finished with value: 0.8762676119804382 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.00013492834268013249, 'alpha': 0.007025166339242158, 'optimizer': 'sgd'}. Best is trial 1 with value: 0.8044773936271667.
# [I 2025-05-16 10:21:16,153] Trial 3 finished with value: 0.8094425201416016 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00032927591344236165, 'alpha': 0.0009717775305059633, 'optimizer': 'adam'}. Best is trial 1 with value: 0.8044773936271667.
# [I 2025-05-16 10:25:54,319] Trial 4 finished with value: 0.7971921563148499 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00015030900645056822, 'alpha': 3.872118032174584e-05, 'optimizer': 'adam'}. Best is trial 4 with value: 0.7971921563148499.
# [I 2025-05-16 10:30:07,332] Trial 5 finished with value: 0.8023691177368164 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.00014096175149815865, 'alpha': 0.009133995846860976, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.7971921563148499.
# [I 2025-05-16 10:34:12,345] Trial 6 finished with value: 0.7998456358909607 and parameters: {'hidden_layer_sizes': (100,), 'activation': 'logistic', 'learning_rate': 0.005323617594751502, 'alpha': 0.0007411299781083245, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.7971921563148499.
# [I 2025-05-16 10:39:15,193] Trial 7 finished with value: 0.8003487586975098 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0033233042062267943, 'alpha': 0.00048287152161792117, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.7971921563148499.
# [I 2025-05-16 10:43:27,385] Trial 8 finished with value: 0.9078649282455444 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'relu', 'learning_rate': 0.006533305220227739, 'alpha': 5.59598687800608e-05, 'optimizer': 'adam'}. Best is trial 4 with value: 0.7971921563148499.
# [I 2025-05-16 10:47:46,076] Trial 9 finished with value: 0.799079418182373 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.004048966222584676, 'alpha': 3.6283583803549155e-05, 'optimizer': 'sgd'}. Best is trial 4 with value: 0.7971921563148499.
# [I 2025-05-16 10:51:43,577] Trial 10 finished with value: 0.8030627369880676 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0004216644107007115, 'alpha': 0.00012956995794619435, 'optimizer': 'adam'}. Best is trial 4 with value: 0.7971921563148499.
# [I 2025-05-16 10:55:23,257] Trial 11 finished with value: 0.7910338640213013 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.000609404678718349, 'alpha': 1.3025834290061221e-05, 'optimizer': 'sgd'}. Best is trial 11 with value: 0.7910338640213013.
# [I 2025-05-16 10:59:20,847] Trial 12 finished with value: 0.8030063509941101 and parameters: {'hidden_layer_sizes': (150, 100, 50), 'activation': 'tanh', 'learning_rate': 0.0005105082867172804, 'alpha': 1.2361678441857428e-05, 'optimizer': 'adam'}. Best is trial 11 with value: 0.7910338640213013.
# [I 2025-05-16 11:02:27,598] Trial 13 finished with value: 0.78248530626297 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0002479867927676136, 'alpha': 1.0633897489987635e-05, 'optimizer': 'sgd'}. Best is trial 13 with value: 0.78248530626297.
# [I 2025-05-16 11:05:25,792] Trial 14 finished with value: 0.7858450412750244 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.0008657857585898337, 'alpha': 1.3680659154642284e-05, 'optimizer': 'sgd'}. Best is trial 13 with value: 0.78248530626297.
# [I 2025-05-16 11:09:34,030] Trial 15 finished with value: 0.8529449701309204 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.0009920562866268196, 'alpha': 6.647299073296805e-05, 'optimizer': 'sgd'}. Best is trial 13 with value: 0.78248530626297.
# [I 2025-05-16 11:13:28,340] Trial 16 finished with value: 0.7789722681045532 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.0002511450098471183, 'alpha': 0.00019215111857795382, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.7789722681045532.
# [I 2025-05-16 11:16:57,921] Trial 17 finished with value: 0.78034508228302 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.00025868387431198333, 'alpha': 0.00022486669408099252, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.7789722681045532.
# [I 2025-05-16 11:20:34,852] Trial 18 finished with value: 0.82933109998703 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'relu', 'learning_rate': 0.0003108741985648983, 'alpha': 0.00022683545208500107, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.7789722681045532.
# [I 2025-05-16 11:24:24,635] Trial 19 finished with value: 1.1135449409484863 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'logistic', 'learning_rate': 0.00021292968832191988, 'alpha': 0.0018851697574479279, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.7789722681045532.
# [I 2025-05-16 11:28:05,096] Trial 20 finished with value: 0.829789936542511 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.00010278525411696242, 'alpha': 0.00018717662855152967, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.7789722681045532.
# [I 2025-05-16 11:31:22,261] Trial 21 finished with value: 0.7818002700805664 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0002702372397456047, 'alpha': 9.637313004562953e-05, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.7789722681045532.
# [I 2025-05-16 11:35:01,015] Trial 22 finished with value: 0.7863436937332153 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.00020570770211421235, 'alpha': 0.00011110554605076073, 'optimizer': 'sgd'}. Best is trial 16 with value: 0.7789722681045532.
# [I 2025-05-16 11:38:21,819] Trial 23 finished with value: 0.7770915627479553 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0006876416561781921, 'alpha': 0.00027967294498790484, 'optimizer': 'sgd'}. Best is trial 23 with value: 0.7770915627479553.
# [I 2025-05-16 11:42:01,189] Trial 24 finished with value: 0.7839223146438599 and parameters: {'hidden_layer_sizes': (100, 50), 'activation': 'tanh', 'learning_rate': 0.0005874809146189633, 'alpha': 0.00024455916786101105, 'optimizer': 'sgd'}. Best is trial 23 with value: 0.7770915627479553.
# [I 2025-05-16 11:44:55,444] Trial 25 finished with value: 0.7846947312355042 and parameters: {'hidden_layer_sizes': (50,), 'activation': 'tanh', 'learning_rate': 0.0015241767831214777, 'alpha': 0.0003963802694235201, 'optimizer': 'sgd'}. Best is trial 23 with value: 0.7770915627479553.
# [I 2025-05-16 11:48:20,457] Trial 26 finished with value: 0.7777019143104553 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0007844634483804858, 'alpha': 0.002815825930935634, 'optimizer': 'sgd'}. Best is trial 23 with value: 0.7770915627479553.
# [I 2025-05-16 11:52:32,652] Trial 27 finished with value: 0.7902430295944214 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0024612337922821402, 'alpha': 0.004263867469852598, 'optimizer': 'sgd'}. Best is trial 23 with value: 0.7770915627479553.
# [I 2025-05-16 11:57:15,570] Trial 28 finished with value: 0.8102882504463196 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'relu', 'learning_rate': 0.009827674611457334, 'alpha': 0.00231676136600214, 'optimizer': 'sgd'}. Best is trial 23 with value: 0.7770915627479553.
# [I 2025-05-16 12:00:49,822] Trial 29 finished with value: 0.8251854777336121 and parameters: {'hidden_layer_sizes': (150,), 'activation': 'logistic', 'learning_rate': 0.0008034112927237099, 'alpha': 0.0006266688681416651, 'optimizer': 'sgd'}. Best is trial 23 with value: 0.7770915627479553.
# === Best Hyperparameters ===
# {'hidden_layer_sizes': (150,), 'activation': 'tanh', 'learning_rate': 0.0006876416561781921, 'alpha': 0.00027967294498790484, 'optimizer': 'sgd'}
# Best Mean MAE: 0.7771

# %%
import os
import optuna
import numpy as np
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GroupKFold

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    # 采样超参数
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 9),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0)
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        model = XGBRegressor(n_jobs=-1, verbosity=0, **params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 以 MAE 为优化目标


# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best XGBoost Hyperparameters via Optuna ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 14:21:01,926] A new study created in memory with name: no-name-c0188856-968e-4249-8bfc-be816455a75c
# [I 2025-05-16 14:23:05,611] Trial 0 finished with value: 0.8776510953903198 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 8, 'subsample': 0.8795975452591109, 'colsample_bytree': 0.6624074561769746}. Best is trial 0 with value: 0.8776510953903198.
# [I 2025-05-16 14:25:25,448] Trial 1 finished with value: 0.8497026562690735 and parameters: {'n_estimators': 200, 'learning_rate': 0.011900590783184251, 'max_depth': 9, 'subsample': 0.8803345035229626, 'colsample_bytree': 0.8832290311184181}. Best is trial 1 with value: 0.8497026562690735.
# [I 2025-05-16 14:26:04,642] Trial 2 finished with value: 0.8408845067024231 and parameters: {'n_estimators': 100, 'learning_rate': 0.18276027831785724, 'max_depth': 8, 'subsample': 0.7637017332034828, 'colsample_bytree': 0.6727299868828402}. Best is trial 2 with value: 0.8408845067024231.
# [I 2025-05-16 14:27:04,620] Trial 3 finished with value: 0.8090460896492004 and parameters: {'n_estimators': 200, 'learning_rate': 0.024878734419814436, 'max_depth': 6, 'subsample': 0.8295835055926347, 'colsample_bytree': 0.7164916560792167}. Best is trial 3 with value: 0.8090460896492004.
# [I 2025-05-16 14:29:29,378] Trial 4 finished with value: 0.8079153299331665 and parameters: {'n_estimators': 700, 'learning_rate': 0.01518747922672247, 'max_depth': 5, 'subsample': 0.8099085529881075, 'colsample_bytree': 0.7824279936868144}. Best is trial 4 with value: 0.8079153299331665.
# [I 2025-05-16 14:32:43,818] Trial 5 finished with value: 0.8138666152954102 and parameters: {'n_estimators': 800, 'learning_rate': 0.018187859051288217, 'max_depth': 6, 'subsample': 0.8777243706586128, 'colsample_bytree': 0.6185801650879991}. Best is trial 4 with value: 0.8079153299331665.
# [I 2025-05-16 14:34:08,438] Trial 6 finished with value: 0.8046930432319641 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'subsample': 0.984665661176, 'colsample_bytree': 0.9862528132298237}. Best is trial 6 with value: 0.8046930432319641.
# [I 2025-05-16 14:35:48,574] Trial 7 finished with value: 0.8063560724258423 and parameters: {'n_estimators': 900, 'learning_rate': 0.0249064396938244, 'max_depth': 3, 'subsample': 0.905269907953647, 'colsample_bytree': 0.7760609974958406}. Best is trial 6 with value: 0.8046930432319641.
# [I 2025-05-16 14:36:13,117] Trial 8 finished with value: 0.8042973279953003 and parameters: {'n_estimators': 200, 'learning_rate': 0.04407984038169244, 'max_depth': 3, 'subsample': 0.9727961206236346, 'colsample_bytree': 0.7035119926400067}. Best is trial 8 with value: 0.8042973279953003.
# [I 2025-05-16 14:39:05,278] Trial 9 finished with value: 0.8175064325332642 and parameters: {'n_estimators': 700, 'learning_rate': 0.02544166090938368, 'max_depth': 6, 'subsample': 0.8640130838029838, 'colsample_bytree': 0.6739417822102108}. Best is trial 8 with value: 0.8042973279953003.
# [I 2025-05-16 14:40:04,100] Trial 10 finished with value: 0.8155757188796997 and parameters: {'n_estimators': 400, 'learning_rate': 0.08074732196639918, 'max_depth': 4, 'subsample': 0.9864906201399816, 'colsample_bytree': 0.8607466203112714}. Best is trial 8 with value: 0.8042973279953003.
# [I 2025-05-16 14:41:01,616] Trial 11 finished with value: 0.809306263923645 and parameters: {'n_estimators': 500, 'learning_rate': 0.05243600136835885, 'max_depth': 3, 'subsample': 0.9944677871984587, 'colsample_bytree': 0.9926743653872057}. Best is trial 8 with value: 0.8042973279953003.
# [I 2025-05-16 14:43:28,620] Trial 12 finished with value: 0.8243481516838074 and parameters: {'n_estimators': 1000, 'learning_rate': 0.053291436624982674, 'max_depth': 4, 'subsample': 0.9539327148024781, 'colsample_bytree': 0.9976023236378931}. Best is trial 8 with value: 0.8042973279953003.
# [I 2025-05-16 14:44:55,611] Trial 13 finished with value: 0.8280647993087769 and parameters: {'n_estimators': 600, 'learning_rate': 0.09953202087035609, 'max_depth': 4, 'subsample': 0.9407239274525441, 'colsample_bytree': 0.9020148628201681}. Best is trial 8 with value: 0.8042973279953003.
# [I 2025-05-16 14:45:31,583] Trial 14 finished with value: 0.8039690256118774 and parameters: {'n_estimators': 300, 'learning_rate': 0.038239324422150126, 'max_depth': 3, 'subsample': 0.9368431198958393, 'colsample_bytree': 0.7390533721986331}. Best is trial 14 with value: 0.8039690256118774.
# [I 2025-05-16 14:46:33,172] Trial 15 finished with value: 0.8074711561203003 and parameters: {'n_estimators': 300, 'learning_rate': 0.03899905819947883, 'max_depth': 5, 'subsample': 0.9315600003651645, 'colsample_bytree': 0.7378423507455648}. Best is trial 14 with value: 0.8039690256118774.
# [I 2025-05-16 14:46:59,203] Trial 16 finished with value: 0.811665415763855 and parameters: {'n_estimators': 100, 'learning_rate': 0.038104301423020376, 'max_depth': 5, 'subsample': 0.917567982214315, 'colsample_bytree': 0.7265423468756215}. Best is trial 14 with value: 0.8039690256118774.
# [I 2025-05-16 14:47:33,703] Trial 17 finished with value: 0.8077195882797241 and parameters: {'n_estimators': 300, 'learning_rate': 0.07724415360160086, 'max_depth': 3, 'subsample': 0.7416438512657763, 'colsample_bytree': 0.8282460599148197}. Best is trial 14 with value: 0.8039690256118774.
# [I 2025-05-16 14:48:19,825] Trial 18 finished with value: 0.8043120503425598 and parameters: {'n_estimators': 300, 'learning_rate': 0.03572357921230152, 'max_depth': 4, 'subsample': 0.9607281971329612, 'colsample_bytree': 0.6254990995378304}. Best is trial 14 with value: 0.8039690256118774.
# [I 2025-05-16 14:49:52,705] Trial 19 finished with value: 0.8434861302375793 and parameters: {'n_estimators': 500, 'learning_rate': 0.1256478539029311, 'max_depth': 5, 'subsample': 0.7032967567731313, 'colsample_bytree': 0.753242765688537}. Best is trial 14 with value: 0.8039690256118774.
# [I 2025-05-16 14:51:01,803] Trial 20 finished with value: 0.8196699023246765 and parameters: {'n_estimators': 200, 'learning_rate': 0.06492756759888016, 'max_depth': 7, 'subsample': 0.9024806460174593, 'colsample_bytree': 0.8138539263936048}. Best is trial 14 with value: 0.8039690256118774.
# [I 2025-05-16 14:51:48,606] Trial 21 finished with value: 0.8049542307853699 and parameters: {'n_estimators': 300, 'learning_rate': 0.03177243180169923, 'max_depth': 4, 'subsample': 0.9625697497169058, 'colsample_bytree': 0.623755150496174}. Best is trial 14 with value: 0.8039690256118774.
# [I 2025-05-16 14:52:32,722] Trial 22 finished with value: 0.8063653111457825 and parameters: {'n_estimators': 400, 'learning_rate': 0.0487698400478041, 'max_depth': 3, 'subsample': 0.9642282899685012, 'colsample_bytree': 0.6010947940589405}. Best is trial 14 with value: 0.8039690256118774.
# [I 2025-05-16 14:52:51,939] Trial 23 finished with value: 0.8162681460380554 and parameters: {'n_estimators': 100, 'learning_rate': 0.033019481985329655, 'max_depth': 4, 'subsample': 0.9993916746916552, 'colsample_bytree': 0.6997108097658562}. Best is trial 14 with value: 0.8039690256118774.
# [I 2025-05-16 14:53:26,339] Trial 24 finished with value: 0.8064103126525879 and parameters: {'n_estimators': 300, 'learning_rate': 0.061716689334383665, 'max_depth': 3, 'subsample': 0.9338356984720112, 'colsample_bytree': 0.6601012515767699}. Best is trial 14 with value: 0.8039690256118774.
# [I 2025-05-16 14:53:59,338] Trial 25 finished with value: 0.8037236332893372 and parameters: {'n_estimators': 200, 'learning_rate': 0.039822371053489784, 'max_depth': 4, 'subsample': 0.9656219006075455, 'colsample_bytree': 0.6416682591868675}. Best is trial 25 with value: 0.8037236332893372.
# [I 2025-05-16 14:54:26,631] Trial 26 finished with value: 0.8098293542861938 and parameters: {'n_estimators': 200, 'learning_rate': 0.022646711536772158, 'max_depth': 3, 'subsample': 0.9724984619706516, 'colsample_bytree': 0.7018178839089533}. Best is trial 25 with value: 0.8037236332893372.
# [I 2025-05-16 14:54:45,632] Trial 27 finished with value: 0.8077582120895386 and parameters: {'n_estimators': 100, 'learning_rate': 0.0430463801518469, 'max_depth': 4, 'subsample': 0.8360981607250861, 'colsample_bytree': 0.7600021376081741}. Best is trial 25 with value: 0.8037236332893372.
# [I 2025-05-16 14:56:03,072] Trial 28 finished with value: 0.8081272840499878 and parameters: {'n_estimators': 400, 'learning_rate': 0.029394723190573638, 'max_depth': 5, 'subsample': 0.9137816362312153, 'colsample_bytree': 0.6471120518530958}. Best is trial 25 with value: 0.8037236332893372.
# [I 2025-05-16 14:56:25,524] Trial 29 finished with value: 0.8062904477119446 and parameters: {'n_estimators': 200, 'learning_rate': 0.13390499764355235, 'max_depth': 3, 'subsample': 0.9350099408631127, 'colsample_bytree': 0.6965645209738722}. Best is trial 25 with value: 0.8037236332893372.
# === Best XGBoost Hyperparameters via Optuna ===
# {'n_estimators': 200, 'learning_rate': 0.039822371053489784, 'max_depth': 4, 'subsample': 0.9656219006075455, 'colsample_bytree': 0.6416682591868675}
# 10-Fold Mean MAE = 0.8037

# %%
import os
import optuna
import numpy as np
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# 配置
n_folds = 10
n_trials = 30
data_dir = './k_folds_model/embeddings'

# ========== 目标函数 ==========
def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step=100),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'num_leaves': trial.suggest_int('num_leaves', 20, 100),
        'feature_fraction': trial.suggest_float('feature_fraction', 0.6, 1.0),
        'bagging_fraction': trial.suggest_float('bagging_fraction', 0.6, 1.0),
        'objective': 'poisson',         # ✅ 强制正输出
        'n_jobs': -1,
        'verbose': -1
    }

    fold_maes = []

    for fold in range(1, n_folds + 1):
        # 读取数据
        X_train = np.load(os.path.join(data_dir, f'train_fold_{fold}.npy'))
        y_train = np.load(os.path.join(data_dir, f'train_labels_fold_{fold}.npy'))
        X_val = np.load(os.path.join(data_dir, f'val_fold_{fold}.npy'))
        y_val = np.load(os.path.join(data_dir, f'val_labels_fold_{fold}.npy'))

        # Poisson 回归要求标签必须大于 0
        if np.any(y_train <= 0) or np.any(y_val <= 0):
            return np.inf

        model = LGBMRegressor(**params)
        model.fit(X_train, y_train)
        y_pred = model.predict(X_val)

        mae = mean_absolute_error(y_val, y_pred)
        fold_maes.append(mae)

    return np.mean(fold_maes)  # ✅ 使用 MAE 作为优化目标

# ========== 启动 Optuna 搜索 ==========
study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=42))
study.optimize(objective, n_trials=n_trials)

# ========== 输出最优结果 ==========
best_params = study.best_params
best_score = study.best_value

print("\n=== Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===")
print(best_params)
print(f"10-Fold Mean MAE = {best_score:.4f}")
# Out:
# [I 2025-05-16 14:56:25,614] A new study created in memory with name: no-name-8f2a133b-aa10-4ae5-8dfa-1b4ddb43b99b
# [I 2025-05-16 14:57:01,158] Trial 0 finished with value: 0.8248364962372806 and parameters: {'n_estimators': 400, 'learning_rate': 0.17254716573280354, 'max_depth': 10, 'num_leaves': 68, 'feature_fraction': 0.6624074561769746, 'bagging_fraction': 0.662397808134481}. Best is trial 0 with value: 0.8248364962372806.
# [I 2025-05-16 14:57:17,792] Trial 1 finished with value: 0.8096453093943925 and parameters: {'n_estimators': 100, 'learning_rate': 0.13394334706750485, 'max_depth': 9, 'num_leaves': 77, 'feature_fraction': 0.608233797718321, 'bagging_fraction': 0.9879639408647978}. Best is trial 1 with value: 0.8096453093943925.
# [I 2025-05-16 14:58:16,451] Trial 2 finished with value: 0.8034312681963364 and parameters: {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 14:59:09,501] Trial 3 finished with value: 0.8052596908383782 and parameters: {'n_estimators': 500, 'learning_rate': 0.023927528765580644, 'max_depth': 9, 'num_leaves': 31, 'feature_fraction': 0.7168578594140873, 'bagging_fraction': 0.7465447373174767}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 14:59:39,730] Trial 4 finished with value: 0.8085626899123082 and parameters: {'n_estimators': 500, 'learning_rate': 0.10508421338691762, 'max_depth': 4, 'num_leaves': 61, 'feature_fraction': 0.836965827544817, 'bagging_fraction': 0.6185801650879991}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:00:30,152] Trial 5 finished with value: 0.8087757928336059 and parameters: {'n_estimators': 700, 'learning_rate': 0.016666983286066417, 'max_depth': 3, 'num_leaves': 96, 'feature_fraction': 0.9862528132298237, 'bagging_fraction': 0.9233589392465844}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:01:30,467] Trial 6 finished with value: 0.8306018508684643 and parameters: {'n_estimators': 400, 'learning_rate': 0.013399060561509796, 'max_depth': 9, 'num_leaves': 55, 'feature_fraction': 0.6488152939379115, 'bagging_fraction': 0.798070764044508}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:01:40,486] Trial 7 finished with value: 0.8050849110494414 and parameters: {'n_estimators': 100, 'learning_rate': 0.15242391728466367, 'max_depth': 5, 'num_leaves': 73, 'feature_fraction': 0.7246844304357644, 'bagging_fraction': 0.8080272084711243}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:03:42,542] Trial 8 finished with value: 0.8094805871925498 and parameters: {'n_estimators': 600, 'learning_rate': 0.017398074711291726, 'max_depth': 12, 'num_leaves': 82, 'feature_fraction': 0.9757995766256756, 'bagging_fraction': 0.9579309401710595}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:04:03,456] Trial 9 finished with value: 0.8097184997081659 and parameters: {'n_estimators': 600, 'learning_rate': 0.15826541904647565, 'max_depth': 3, 'num_leaves': 35, 'feature_fraction': 0.6180909155642152, 'bagging_fraction': 0.7301321323053057}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:05:10,367] Trial 10 finished with value: 0.8115025161939823 and parameters: {'n_estimators': 1000, 'learning_rate': 0.041286972973122775, 'max_depth': 6, 'num_leaves': 21, 'feature_fraction': 0.8423486893732017, 'bagging_fraction': 0.876098829427658}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:06:13,065] Trial 11 finished with value: 0.8177043949075337 and parameters: {'n_estimators': 1000, 'learning_rate': 0.06761147179060022, 'max_depth': 6, 'num_leaves': 48, 'feature_fraction': 0.759327832364161, 'bagging_fraction': 0.8469817891972083}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:06:25,757] Trial 12 finished with value: 0.8864050398428635 and parameters: {'n_estimators': 100, 'learning_rate': 0.03448509229937973, 'max_depth': 5, 'num_leaves': 45, 'feature_fraction': 0.7389917503278137, 'bagging_fraction': 0.7957386374412774}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:07:20,982] Trial 13 finished with value: 0.819878096947112 and parameters: {'n_estimators': 800, 'learning_rate': 0.06922749265952521, 'max_depth': 7, 'num_leaves': 91, 'feature_fraction': 0.7874820875551369, 'bagging_fraction': 0.8630011610888938}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:07:42,243] Trial 14 finished with value: 0.982175346228607 and parameters: {'n_estimators': 200, 'learning_rate': 0.011058500546306225, 'max_depth': 5, 'num_leaves': 72, 'feature_fraction': 0.6975499843454273, 'bagging_fraction': 0.727828023050229}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:08:27,722] Trial 15 finished with value: 0.8077772408953173 and parameters: {'n_estimators': 800, 'learning_rate': 0.06294173699450725, 'max_depth': 4, 'num_leaves': 39, 'feature_fraction': 0.8762695696311745, 'bagging_fraction': 0.8108076649175742}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:09:19,264] Trial 16 finished with value: 0.8103227455739699 and parameters: {'n_estimators': 300, 'learning_rate': 0.02981229465853, 'max_depth': 7, 'num_leaves': 58, 'feature_fraction': 0.9110846414027765, 'bagging_fraction': 0.9006453699263156}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:09:59,923] Trial 17 finished with value: 0.817164025767436 and parameters: {'n_estimators': 900, 'learning_rate': 0.09514304141838337, 'max_depth': 5, 'num_leaves': 85, 'feature_fraction': 0.6772876502180768, 'bagging_fraction': 0.765354826674926}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:10:28,870] Trial 18 finished with value: 0.819858676617881 and parameters: {'n_estimators': 300, 'learning_rate': 0.02154636144117931, 'max_depth': 4, 'num_leaves': 65, 'feature_fraction': 0.7839069453230693, 'bagging_fraction': 0.6735390759594541}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:11:21,200] Trial 19 finished with value: 0.8089319411274671 and parameters: {'n_estimators': 700, 'learning_rate': 0.049212596873501845, 'max_depth': 6, 'num_leaves': 22, 'feature_fraction': 0.737415887737509, 'bagging_fraction': 0.8307796695558712}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:12:00,883] Trial 20 finished with value: 0.8130024446265753 and parameters: {'n_estimators': 900, 'learning_rate': 0.11178113803323297, 'max_depth': 3, 'num_leaves': 51, 'feature_fraction': 0.8343872902276027, 'bagging_fraction': 0.690165187143056}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:12:56,162] Trial 21 finished with value: 0.8056641010864316 and parameters: {'n_estimators': 500, 'learning_rate': 0.024285383009483585, 'max_depth': 9, 'num_leaves': 33, 'feature_fraction': 0.7026827755877711, 'bagging_fraction': 0.7508545201878779}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:13:15,159] Trial 22 finished with value: 0.8423400596699206 and parameters: {'n_estimators': 200, 'learning_rate': 0.02352997917697853, 'max_depth': 11, 'num_leaves': 29, 'feature_fraction': 0.7327753165867998, 'bagging_fraction': 0.7650745181069674}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:13:53,429] Trial 23 finished with value: 0.8178338216589444 and parameters: {'n_estimators': 400, 'learning_rate': 0.016416473719376656, 'max_depth': 8, 'num_leaves': 42, 'feature_fraction': 0.7079358586398357, 'bagging_fraction': 0.7092614395684426}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:14:32,338] Trial 24 finished with value: 0.8084776599639325 and parameters: {'n_estimators': 700, 'learning_rate': 0.033365543868051475, 'max_depth': 8, 'num_leaves': 25, 'feature_fraction': 0.7620478035633896, 'bagging_fraction': 0.7942963314768141}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:14:59,393] Trial 25 finished with value: 0.9114251050505956 and parameters: {'n_estimators': 300, 'learning_rate': 0.010094219347431287, 'max_depth': 10, 'num_leaves': 32, 'feature_fraction': 0.6368964618223039, 'bagging_fraction': 0.8370412856347438}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:15:36,260] Trial 26 finished with value: 0.8124448760803334 and parameters: {'n_estimators': 800, 'learning_rate': 0.050661895944526254, 'max_depth': 7, 'num_leaves': 39, 'feature_fraction': 0.7125328734079353, 'bagging_fraction': 0.6207812113614294}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:15:53,025] Trial 27 finished with value: 0.8312344474813331 and parameters: {'n_estimators': 200, 'learning_rate': 0.02640258860231785, 'max_depth': 5, 'num_leaves': 28, 'feature_fraction': 0.8085977064448052, 'bagging_fraction': 0.7720885507149156}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:16:23,746] Trial 28 finished with value: 0.8034578013773069 and parameters: {'n_estimators': 900, 'learning_rate': 0.02024039140249267, 'max_depth': 4, 'num_leaves': 74, 'feature_fraction': 0.6787750785236079, 'bagging_fraction': 0.8888531461059263}. Best is trial 2 with value: 0.8034312681963364.
# [I 2025-05-16 15:16:47,523] Trial 29 finished with value: 0.8282108530287868 and parameters: {'n_estimators': 1000, 'learning_rate': 0.19848978742652873, 'max_depth': 4, 'num_leaves': 67, 'feature_fraction': 0.6657374610104676, 'bagging_fraction': 0.9047487195505687}. Best is trial 2 with value: 0.8034312681963364.
# === Best LightGBM Hyperparameters via Optuna (Poisson + MAE) ===
# {'n_estimators': 900, 'learning_rate': 0.018891200276189388, 'max_depth': 4, 'num_leaves': 34, 'feature_fraction': 0.7216968971838151, 'bagging_fraction': 0.8099025726528951}
# 10-Fold Mean MAE = 0.8034
