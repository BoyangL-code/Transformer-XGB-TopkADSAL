# %%
import numpy as np
import pickle
from sklearn.metrics import (
    mean_absolute_error,
    root_mean_squared_error,
    r2_score
)
from scipy.stats import pearsonr

def evaluate_regression_metrics(y_true, y_pred):
    mae = mean_absolute_error(y_true, y_pred)
    rmse = root_mean_squared_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    pearson_r, _ = pearsonr(y_true, y_pred)

    print("✅ 总体评估指标：")
    print(f"MAE      = {mae:.4f}")
    print(f"RMSE     = {rmse:.4f}")
    print(f"R²       = {r2:.4f}")
    print(f"PearsonR = {pearson_r:.4f}")

    return {
        'MAE': mae,
        'RMSE': rmse,
        'R2': r2,
        'PearsonR': pearson_r
    }

# %% [markdown]
# #LGB

# %%
errors=[]
all_val =  []
all_pred = []
for i in range(10):
    val = np.load(f'./lgbm_cv_results/fold_{i}_y_true.npy')
    preds = np.load(f'./lgbm_cv_results/fold_{i}_y_pred.npy')
    error = np.maximum(val, preds) / np.minimum(val, preds)
    
    errors.append(error)
    all_val.append(val)
    all_pred.append(preds)
errors = np.concatenate(errors)

all_val = np.concatenate(all_val)
all_pred = np.concatenate(all_pred)

# %%
evaluate_regression_metrics(all_val, all_pred)
# Out:
# ✅ 总体评估指标：
# MAE      = 0.9094
# RMSE     = 1.2960
# R²       = 0.4524
# PearsonR = 0.6869
# {'MAE': 0.9093685036836527,
#  'RMSE': 1.2959937566324051,
#  'R2': 0.452449095406133,
#  'PearsonR': 0.6868557447322122}

# %% [markdown]
# #XGB

# %%
errors=[]
all_val =  []
all_pred = []
for i in range(10):
    val = np.load(f'./xgb_cv_results/fold_{i}_y_true.npy')
    preds = np.load(f'./xgb_cv_results/fold_{i}_y_pred.npy')
    error = np.maximum(val, preds) / np.minimum(val, preds)
    
    errors.append(error)
    all_val.append(val)
    all_pred.append(preds)
errors = np.concatenate(errors)

all_val = np.concatenate(all_val)
all_pred = np.concatenate(all_pred)
evaluate_regression_metrics(all_val, all_pred)
# Out:
# ✅ 总体评估指标：
# MAE      = 0.8817
# RMSE     = 1.2102
# R²       = 0.5225
# PearsonR = 0.7233
# {'MAE': 0.8817061898958372,
#  'RMSE': 1.2102275083725342,
#  'R2': 0.5225227076266166,
#  'PearsonR': 0.723306211233807}

# %% [markdown]
# #DNN

# %%
errors=[]
all_val =  []
all_pred = []
for i in range(10):
    val = np.load(f'./dnn_cv_results/fold_{i}_y_true.npy')
    preds = np.load(f'./dnn_cv_results/fold_{i}_y_pred.npy')
    error = np.maximum(val, preds) / np.minimum(val, preds)
    
    errors.append(error)
    all_val.append(val)
    all_pred.append(preds)
errors = np.concatenate(errors)

all_val = np.concatenate(all_val)
all_pred = np.concatenate(all_pred)

# %%
evaluate_regression_metrics(all_val, all_pred)
# Out:
# ✅ 总体评估指标：
# MAE      = 1.0616
# RMSE     = 1.5589
# R²       = 0.2077
# PearsonR = 0.5885
# {'MAE': 1.0616493493323544,
#  'RMSE': 1.558921727649255,
#  'R2': 0.20774077949562775,
#  'PearsonR': 0.5884815577119761}
